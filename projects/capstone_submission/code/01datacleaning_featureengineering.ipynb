# %% [markdown]
# # Data Cleaning

# %% [markdown]
# In this notebook, I will be cleaning the data which has been scraped as well as doing some feature engineering to prepare the dataset for modelling.

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# These are the scraped datasets

# %%
activity = pd.read_csv('../datasets/activity.csv')
ss = pd.read_csv('../datasets/ss.csv')
yelp = pd.read_csv('../datasets/yelp.csv')

# %% [markdown]
# ## Cleaning of Activity data

# %% [markdown]
# Removing of item numbers in each activity name.

# %%
activity.head()
# Out:
#                                     Activity        Contact  \
# 0                 2. See the S.E.A. Aquarium  not available
# 1           3. Visit the Museum of Ice Cream  not available
# 2                   4. Swim at Wild Wild Wet      6581 9128
# 3               5. Roller skate at Hi-Roller      9694 4094
# 4  6. Play arcade games at Timezone Westgate      6265 1132
#
#                                        Opening hours  \
# 0                                    10am-5pm, Daily
# 1  Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed ...
# 2  Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Clo...
# 3  Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 1...
# 4  Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-1...
#
#                                              Address
# 0  8 Sentosa Gateway, Sentosa Island, Singapore 0...
# 1                  100 Loewen Road, Singapore 248837
# 2  1 Pasir Ris Close, Downtown East, Singapore 51...
# 3  1 Pasir Ris Close, E!Hub, Market Square @ Down...
# 4  3 Gateway Drive, Westgate #B1-45, Singapore 60...

# %% [markdown]
# Remove leading numbers and dots from the 'Activity' column

# %%
activity['Activity'] = activity['Activity'].str.replace(r'^\d{1,3}\.\s', '', regex=True)

activity.head()
# Out:
#                                  Activity        Contact  \
# 0                 See the S.E.A. Aquarium  not available
# 1           Visit the Museum of Ice Cream  not available
# 2                   Swim at Wild Wild Wet      6581 9128
# 3               Roller skate at Hi-Roller      9694 4094
# 4  Play arcade games at Timezone Westgate      6265 1132
#
#                                        Opening hours  \
# 0                                    10am-5pm, Daily
# 1  Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed ...
# 2  Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Clo...
# 3  Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 1...
# 4  Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-1...
#
#                                              Address
# 0  8 Sentosa Gateway, Sentosa Island, Singapore 0...
# 1                  100 Loewen Road, Singapore 248837
# 2  1 Pasir Ris Close, Downtown East, Singapore 51...
# 3  1 Pasir Ris Close, E!Hub, Market Square @ Down...
# 4  3 Gateway Drive, Westgate #B1-45, Singapore 60...

# %%
activity.tail()
# Out:
#                                  Activity        Contact  \
# 124                 Discover T for Toys$1      9021 7376
# 125      Browse through comic book stores  not available
# 126                 Shop at Don Don Donki  not available
# 127           Stroll through Bugis Street      6338 9513
# 128  Wine, dine, and shop at Dempsey Hill  not available
#
#                            Opening hours  \
# 124  Mon-Fri 12pm-6pm | Sat-Sun 12pm-7pm
# 125                        not available
# 126                        not available
# 127                     10am-10pm, Daily
# 128                        not available
#
#                                                Address
# 124  18 Tampines Industrial Crescent, Space @ Tampi...
# 125                                      not available
# 126                                      not available
# 127                                      not available
# 128                     Dempsey Road, Singapore 249679

# %% [markdown]
# Extracting postal code for generating long/lat later on

# %%
import re

def extract_postal_code(address):
    # Regular expression pattern to match postal codes
    postal_code_pattern = r'\b\d{6}\b'  # Assumes postal codes in Singapore are 6 digits long
    
    # Find all matches of postal codes in the address string
    postal_codes = re.findall(postal_code_pattern, address)
    
    # Return the first postal code found, or 'not available' if none found
    return postal_codes[0] if postal_codes else 'not available'

# %%
activity['postal code'] = activity["Address"].apply(lambda x: extract_postal_code(x))
activity.head()
# Out:
#                                  Activity        Contact  \
# 0                 See the S.E.A. Aquarium  not available
# 1           Visit the Museum of Ice Cream  not available
# 2                   Swim at Wild Wild Wet      6581 9128
# 3               Roller skate at Hi-Roller      9694 4094
# 4  Play arcade games at Timezone Westgate      6265 1132
#
#                                        Opening hours  \
# 0                                    10am-5pm, Daily
# 1  Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed ...
# 2  Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Clo...
# 3  Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 1...
# 4  Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-1...
#
#                                              Address postal code
# 0  8 Sentosa Gateway, Sentosa Island, Singapore 0...      098269
# 1                  100 Loewen Road, Singapore 248837      248837
# 2  1 Pasir Ris Close, Downtown East, Singapore 51...      519599
# 3  1 Pasir Ris Close, E!Hub, Market Square @ Down...      519599
# 4  3 Gateway Drive, Westgate #B1-45, Singapore 60...      608532

# %% [markdown]
# Check for the different entries of opening hours in the dataframe

# %%
activity['Opening hours'].unique()
# Out:
# array(['10am-5pm, Daily',
#        'Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed on Tuesdays)',
#        'Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Closed on Tuesdays)',
#        'Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 11am-10pm',
#        'Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-11pm | Sun 10am-10pm',
#        'not available', 'Tue-Fri 10am-5pm | Sat-Sun & PH 10am-6pm',
#        'Mon-Fri 9am-6pm | Sat-Sun 9am-7pm',
#        'Mon 3pm-10pm | Tue-Fri 10am-9pm | Sat-Sun 10am-10pm',
#        'Sat-Sun 11.30am-12.30pm, 5pm-6pm (Closed from Mondays to Fridays)',
#        'Mon-Fri 12.30pm-7pm | Sat–Sun 11.30pm-7pm ',
#        'Mon-Thu 11am-7.30pm | Fri 11am-9pm | Sat 10am-9pm | Sun 10am-7.30pm',
#        '12pm-8pm, Daily',
#        'Tue 2pm-5.30pm | Wed-Fri 2pm-5.30pm and 6pm-9.30pm | Sat-Sun, School Holidays & PH 10am-1.30pm, 2pm-5.30pm, and 6pm-9.30pm (Closed on Mondays)',
#        'Tue-Fri 1pm-9pm | Sat-Sun 9am-9pm (Closed on Mondays)',
#        '10am-8pm, Daily | Sat-Sun 9am-8pm',
#        'Tue-Sun 12pm-10pm (Closed on Mondays)',
#        'Mon-Sat 7am-12am | Sun 7am-8pm',
#        'Thu-Tue & PH 9am-10pm | Wed 11am-10pm', '10am-1am, Daily',
#        'Refer to Universal Studios Singapore’s calendar for more information',
#        'Sat-Sun 9am-6pm, by appointment (Closed from Mondays to Fridays)',
#        'Mon-Fri 2pm-6pm | Sat-Sun & PH 11am-6pm',
#        'Sun-Thu 10am-10pm | Fri-Sat & Eve of PH 10am-12am | PH 9am-10pm',
#        'Fri-Tue 10am-5pm (Closed Wed-Thu)',
#        'Tue-Sun 8am-8pm (Closed on Mondays)',
#        'Various hours; view all GoCycling opening hours',
#        'Tue-Sun 8am-10pm (Closed on Mondays)',
#        'Mon-Fri 9.30am-6pm | Sat-Sun & PH 9.30am-6.30pm',
#        'Selected nights, 7.45pm – end of screening', '9am-5pm, Daily',
#        'Mon-Fri 12pm-7pm | Sat-Sun & PH 11am-7pm (last admission 6pm)',
#        'Tue-Thu 2pm-9pm | Fri-Sun 10am-9pm (Closed on Mondays)',
#        '12am-10pm, Daily', '9am-6am, Daily',
#        'Tue-Sun 2am-6am (Closed on Mondays)', '24 hours, Daily',
#        'Wed-Mon 10am-6pm (Closed on Tuesdays)', '7am-7pm, Daily',
#        '7am-7pm, Daily (last entry at 6.30pm)', '8am-10pm, Daily',
#        '10am-7pm, Daily (Closed on alternate Mondays)',
#        '11am-10pm, Daily', 'Tue-Sun 11am-10pm (Closed on Mondays)',
#        '10am-10pm, Daily', '11am-7pm, Daily',
#        'Tue-Sun 10am-5pm (last entry 4.15pm) (Closed Mondays except for public holidays and school holidays)',
#        'Tue-Sun 10am-5pm (Closed on Mondays)', 'By appointment only',
#        '10am-7pm, Daily', 'Tue-Sun 10am-6pm (Closed on Mondays)',
#        'Sun-Thu 9am-8pm | Fri-Sat 9am-10pm',
#        'Mon-Fri 10am-12.30pm & 2pm-5pm (Closed on Sat-Sun & PHs)',
#        'Mon-Sat 9am-5pm (Closed on Sundays & PH)',
#        'Sat-Sun & PH 9.30am-12pm',
#        'Tue-Thu 4pm-8pm | Fri-Sat 2-9pm (Closed Sundays & Mondays)',
#        '10am-9.30pm, Daily',
#        'Wed-Sat 10am-7pm | Sun-Mon 10am-6pm (Closed on Tuesdays)',
#        'Mon 11am-6pm | Tue-Sat 11am-8pm | Sun & PH 11am-7pm',
#        'Mon-Fri 12pm-6pm | Sat-Sun 12pm-7pm'], dtype=object)

# %% [markdown]
# Creating a function to extract opening hours for each day of the week and create separate columns for them

# %%
days_of_week = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# Define a function to extract opening hours for each day of the week
def extract_opening_hours(hours, day):
    if day in hours:
        match = re.search(r'{}.*?(\d{{1,2}}(?:am|pm)-\d{{1,2}}(?:am|pm))'.format(day), hours, re.IGNORECASE)
        if match:
            return match.group(1)
    return 'Closed'

# Create separate columns for each day of the week and extract opening hours
for day in days_of_week:
    activity[day] = activity['Opening hours'].map(lambda x: extract_opening_hours(x, day))

activity.head()
# Out:
#                                  Activity        Contact  \
# 0                 See the S.E.A. Aquarium  not available
# 1           Visit the Museum of Ice Cream  not available
# 2                   Swim at Wild Wild Wet      6581 9128
# 3               Roller skate at Hi-Roller      9694 4094
# 4  Play arcade games at Timezone Westgate      6265 1132
#
#                                        Opening hours  \
# 0                                    10am-5pm, Daily
# 1  Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed ...
# 2  Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Clo...
# 3  Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 1...
# 4  Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-1...
#
#                                              Address postal code        Mon  \
# 0  8 Sentosa Gateway, Sentosa Island, Singapore 0...      098269     Closed
# 1                  100 Loewen Road, Singapore 248837      248837   10am-6pm
# 2  1 Pasir Ris Close, Downtown East, Singapore 51...      519599   12pm-6pm
# 3  1 Pasir Ris Close, E!Hub, Market Square @ Down...      519599   12pm-8pm
# 4  3 Gateway Drive, Westgate #B1-45, Singapore 60...      608532  11am-10pm
#
#       Tue       Wed        Thu        Fri        Sat        Sun
# 0  Closed    Closed     Closed     Closed     Closed     Closed
# 1  Closed  10am-6pm   10am-9pm     Closed     Closed   10am-9pm
# 2  Closed  12pm-6pm     Closed   12pm-6pm   11am-6pm   11am-6pm
# 3  Closed    Closed   12pm-8pm   12pm-8pm  11am-10pm  11am-10pm
# 4  Closed    Closed  11am-10pm  11am-11pm  10am-11pm  10am-10pm

# %%
activity['Opening hours'][1]
# Out:
# 'Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed on Tuesdays)'

# %% [markdown]
# ## Cleaning of SecretSingapore Data

# %%
ss.head()
# Out:
#    Unnamed: 0                                           activity  \
# 0           0  See the world’s largest public display of Sout...
# 1           1           Race at Singapore’s only night luge ride
# 2           2                   Stroll around Gardens By The Bay
# 3           3            Indulge on famous Singapore Chilli Crab
# 4           4  Battle it out on Asia’s first gamified electri...
#
#                                   location
# 0         Civic District, Singapore 178957
# 1            1 Imbiah Rd, Singapore 099692
# 2   18 Marina Gardens Dr, Singapore 018953
# 3                       Various Locations
# 4  54 Palawan Beach Walk, Singapore 098233

# %%
ss.columns
# Out:
# Index(['Unnamed: 0', 'activity', 'location'], dtype='object')

# %% [markdown]
# Dropping irrelevant columns

# %%
ss.drop(columns=['Unnamed: 0'], inplace = True)

# %%
ss.head()
# Out:
#                                             activity  \
# 0  See the world’s largest public display of Sout...
# 1           Race at Singapore’s only night luge ride
# 2                   Stroll around Gardens By The Bay
# 3            Indulge on famous Singapore Chilli Crab
# 4  Battle it out on Asia’s first gamified electri...
#
#                                   location
# 0         Civic District, Singapore 178957
# 1            1 Imbiah Rd, Singapore 099692
# 2   18 Marina Gardens Dr, Singapore 018953
# 3                       Various Locations
# 4  54 Palawan Beach Walk, Singapore 098233

# %% [markdown]
# Extracting postal code from location data and into new column 'postal code' for extraction of coordinates later on

# %%
ss['postal code'] = ss["location"].apply(lambda x: extract_postal_code(x))
ss.head()
# Out:
#                                             activity  \
# 0  See the world’s largest public display of Sout...
# 1           Race at Singapore’s only night luge ride
# 2                   Stroll around Gardens By The Bay
# 3            Indulge on famous Singapore Chilli Crab
# 4  Battle it out on Asia’s first gamified electri...
#
#                                   location    postal code
# 0         Civic District, Singapore 178957         178957
# 1            1 Imbiah Rd, Singapore 099692         099692
# 2   18 Marina Gardens Dr, Singapore 018953         018953
# 3                       Various Locations   not available
# 4  54 Palawan Beach Walk, Singapore 098233         098233

# %% [markdown]
# ## Cleaning of Yelp Data

# %%
yelp.head()
# Out:
#    Unnamed: 0  restaurant number                                 name  rating  \
# 0           0                  1             11. The Garden @ Sentosa     5.0
# 1           1                  2     12. Tian Tian Seafood Restaurant     4.7
# 2           2                  3              13. Song Fa Bak Kut Teh     4.6
# 3           3                  4  14. Zhong Guo La Mian Xiao Long Bao     4.4
# 4           4                  5                        15. La Strada     4.4
#
#                           cuisine price     location
# 0                 Modern European   $$$      Sentosa
# 1                Seafood, Chinese    $$  Tiong Bahru
# 2            Chinese, Singaporean     $    Chinatown
# 3  Shanghainese, Dim Sum, Noodles     $    Chinatown
# 4                         Italian   $$$      Tanglin

# %% [markdown]
# Dropping irrelevant columns

# %%
yelp.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
yelp.head()
# Out:
#    restaurant number                                 name  rating  \
# 0                  1             11. The Garden @ Sentosa     5.0
# 1                  2     12. Tian Tian Seafood Restaurant     4.7
# 2                  3              13. Song Fa Bak Kut Teh     4.6
# 3                  4  14. Zhong Guo La Mian Xiao Long Bao     4.4
# 4                  5                        15. La Strada     4.4
#
#                           cuisine price     location
# 0                 Modern European   $$$      Sentosa
# 1                Seafood, Chinese    $$  Tiong Bahru
# 2            Chinese, Singaporean     $    Chinatown
# 3  Shanghainese, Dim Sum, Noodles     $    Chinatown
# 4                         Italian   $$$      Tanglin

# %%
yelp.drop(columns = ['restaurant number'], inplace = True)

# %% [markdown]
# Removing number from the name.

# %%
# Remove leading numbers and dots from the 'Activity' column
yelp['name'] = yelp['name'].str.replace(r'^\d{1,3}\.\s', '', regex=True)

yelp.head()
# Out:
#                               name  rating                         cuisine  \
# 0             The Garden @ Sentosa     5.0                 Modern European
# 1     Tian Tian Seafood Restaurant     4.7                Seafood, Chinese
# 2              Song Fa Bak Kut Teh     4.6            Chinese, Singaporean
# 3  Zhong Guo La Mian Xiao Long Bao     4.4  Shanghainese, Dim Sum, Noodles
# 4                        La Strada     4.4                         Italian
#
#   price     location
# 0   $$$      Sentosa
# 1    $$  Tiong Bahru
# 2     $    Chinatown
# 3     $    Chinatown
# 4   $$$      Tanglin

# %%
ss.head()
# Out:
#                                             activity  \
# 0  See the world’s largest public display of Sout...
# 1           Race at Singapore’s only night luge ride
# 2                   Stroll around Gardens By The Bay
# 3            Indulge on famous Singapore Chilli Crab
# 4  Battle it out on Asia’s first gamified electri...
#
#                                   location    postal code
# 0         Civic District, Singapore 178957         178957
# 1            1 Imbiah Rd, Singapore 099692         099692
# 2   18 Marina Gardens Dr, Singapore 018953         018953
# 3                       Various Locations   not available
# 4  54 Palawan Beach Walk, Singapore 098233         098233

# %%
activity.head()
# Out:
#                                  Activity        Contact  \
# 0                 See the S.E.A. Aquarium  not available
# 1           Visit the Museum of Ice Cream  not available
# 2                   Swim at Wild Wild Wet      6581 9128
# 3               Roller skate at Hi-Roller      9694 4094
# 4  Play arcade games at Timezone Westgate      6265 1132
#
#                                        Opening hours  \
# 0                                    10am-5pm, Daily
# 1  Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed ...
# 2  Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Clo...
# 3  Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 1...
# 4  Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-1...
#
#                                              Address postal code        Mon  \
# 0  8 Sentosa Gateway, Sentosa Island, Singapore 0...      098269     Closed
# 1                  100 Loewen Road, Singapore 248837      248837   10am-6pm
# 2  1 Pasir Ris Close, Downtown East, Singapore 51...      519599   12pm-6pm
# 3  1 Pasir Ris Close, E!Hub, Market Square @ Down...      519599   12pm-8pm
# 4  3 Gateway Drive, Westgate #B1-45, Singapore 60...      608532  11am-10pm
#
#       Tue       Wed        Thu        Fri        Sat        Sun
# 0  Closed    Closed     Closed     Closed     Closed     Closed
# 1  Closed  10am-6pm   10am-9pm     Closed     Closed   10am-9pm
# 2  Closed  12pm-6pm     Closed   12pm-6pm   11am-6pm   11am-6pm
# 3  Closed    Closed   12pm-8pm   12pm-8pm  11am-10pm  11am-10pm
# 4  Closed    Closed  11am-10pm  11am-11pm  10am-11pm  10am-10pm

# %% [markdown]
# Reordering the columns for merging

# %%
activity = activity[['Activity', 'Address', 'postal code', 'Contact', 'Opening hours', 'Mon','Tue','Wed','Thu','Fri','Sat','Sun']]

# %%
activity.rename(columns = {'Activity':'activity','Contact':'contact','Address':'location','Opening hours':'opening hours'}, inplace = True)

# %% [markdown]
# Merging ss and activity dataframe into a combined activity dataframe

# %%
combined_activity = pd.concat([activity, ss], ignore_index = True)

# %%
combined_activity
# Out:
#                                      activity  \
# 0                     See the S.E.A. Aquarium
# 1               Visit the Museum of Ice Cream
# 2                       Swim at Wild Wild Wet
# 3                   Roller skate at Hi-Roller
# 4      Play arcade games at Timezone Westgate
# ..                                        ...
# 183                Have a unique yacht picnic
# 184    Take the children to the new KidzWorld
# 185           Go crazy at KF1 Karting Circuit
# 186  Get your adrenaline fix at the waterpark
# 187         Go on an Instagrammable adventure
#
#                                               location    postal code  \
# 0    8 Sentosa Gateway, Sentosa Island, Singapore 0...         098269
# 1                    100 Loewen Road, Singapore 248837         248837
# 2    1 Pasir Ris Close, Downtown East, Singapore 51...         519599
# 3    1 Pasir Ris Close, E!Hub, Market Square @ Down...         519599
# 4    3 Gateway Drive, Westgate #B1-45, Singapore 60...         608532
# ..                                                 ...            ...
# 183                                  Various Locations  not available
# 184      11 Cove Drive, Sentosa Cove, Singapore 098497         098497
# 185                80 Mandai Lake Rd, Singapore 729826         729826
# 186               1 Turf Club Avenue, Singapore 738078         738078
# 187                                  Various Locations  not available
#
#            contact                                      opening hours  \
# 0    not available                                    10am-5pm, Daily
# 1    not available  Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed ...
# 2        6581 9128  Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Clo...
# 3        9694 4094  Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 1...
# 4        6265 1132  Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-1...
# ..             ...                                                ...
# 183            NaN                                                NaN
# 184            NaN                                                NaN
# 185            NaN                                                NaN
# 186            NaN                                                NaN
# 187            NaN                                                NaN
#
#            Mon     Tue       Wed        Thu        Fri        Sat        Sun
# 0       Closed  Closed    Closed     Closed     Closed     Closed     Closed
# 1     10am-6pm  Closed  10am-6pm   10am-9pm     Closed     Closed   10am-9pm
# 2     12pm-6pm  Closed  12pm-6pm     Closed   12pm-6pm   11am-6pm   11am-6pm
# 3     12pm-8pm  Closed    Closed   12pm-8pm   12pm-8pm  11am-10pm  11am-10pm
# 4    11am-10pm  Closed    Closed  11am-10pm  11am-11pm  10am-11pm  10am-10pm
# ..         ...     ...       ...        ...        ...        ...        ...
# 183        NaN     NaN       NaN        NaN        NaN        NaN        NaN
# 184        NaN     NaN       NaN        NaN        NaN        NaN        NaN
# 185        NaN     NaN       NaN        NaN        NaN        NaN        NaN
# 186        NaN     NaN       NaN        NaN        NaN        NaN        NaN
# 187        NaN     NaN       NaN        NaN        NaN        NaN        NaN
#
# [188 rows x 12 columns]

# %% [markdown]
# ## Geocoding: extracting longitude and latitude from postal codes

# %%
import googlemaps
from datetime import datetime

# %%
gmaps = googlemaps.Client(key = 'AIzaSyB0R1Hos1Zy_W4BtfgXNcJcBnflOpIcE0U')

# %% [markdown]
# Creating a function to extract longitudes and latitudes from postal codes/addresses and appending them to separate longitude and latitude lists to create columns in the dataframe later on.

# %%
def get_co(addresses):
    longs = []
    lats = []

    for address in addresses:
        try:
        # Use gmaps.geocode to get the geographical coordinates
            coordinates = gmaps.geocode(address)

        # Extract latitude and longitude
            longitude = coordinates[0]['geometry']['location']['lng']
            latitude = coordinates[0]['geometry']['location']['lat']

            longs.append(longitude)
            lats.append(latitude)
        
        except:
            longs.append(None)
            lats.append(None)
    
    return longs, lats

# %%
gmaps.geocode(119243)
# Out:
# [{'address_components': [{'long_name': '119243',
#     'short_name': '119243',
#     'types': ['postal_code']},
#    {'long_name': 'Queenstown',
#     'short_name': 'Queenstown',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Singapore',
#     'short_name': 'Singapore',
#     'types': ['locality', 'political']},
#    {'long_name': 'Singapore',
#     'short_name': 'SG',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Singapore 119243',
#   'geometry': {'location': {'lat': 1.292611, 'lng': 103.771027},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 1.293959980291502,
#      'lng': 103.7723759802915},
#     'southwest': {'lat': 1.291262019708498, 'lng': 103.7696780197085}}},
#   'place_id': 'ChIJSU626f4a2jER8ZaSM5bidL4',
#   'types': ['postal_code']}]

# %%
get_co(['119243'])
# Out:
# ([103.771027], [1.292611])

# %% [markdown]
# Extracting coordinates from postal codes in combined_activity and yelp datasets and adding them into new columns 'longitude' and 'latitude' within the dataframe

# %%
postal = combined_activity['postal code']
longitudes, latitudes = get_co(postal)

# %%
combined_activity['latitude'] = latitudes
combined_activity['longitude'] = longitudes

# %%
combined_activity.head(30)
# Out:
#                                              activity  \
# 0                             See the S.E.A. Aquarium
# 1                       Visit the Museum of Ice Cream
# 2                               Swim at Wild Wild Wet
# 3                           Roller skate at Hi-Roller
# 4              Play arcade games at Timezone Westgate
# 5   Frolic around at Airzone (temporarily closed t...
# 6                   Learn new skills at NLB libraries
# 7               Discover new playgrounds in Singapore
# 8                              Chill out at Snow City
# 9             Tour the Jacob Ballas Children’s Garden
# 10                   Try fishing at Qian Hu Fish Farm
# 11                  Play with felines at The Cat Cafe
# 12                       Support the Kitten Sanctuary
# 13                 Relax in Singapore’s newest hotels
# 14        Bungy jump at Skypark Sentosa by AJ Hackett
# 15                              Ride the Skyline Luge
# 16      Spend a day at NERF Action Xperience (Closed)
# 17                            Retreat to Adventure HQ
# 18                       Go-kart at The Karting Arena
# 19                   Cable-ski at Singapore Wake Park
# 20                           Throw axes at Axe Factor
# 21                   Golf virtually at Five Iron Golf
# 22                  Skydive indoors at iFly Singapore
# 23                    Jump around in trampoline parks
# 24                    Try bouldering or rock climbing
# 25                       Go bowling at K Bowling Club
# 26       Ride coasters at Universal Studios Singapore
# 27                     Cycle on water at WaterbikeSG
# 28               Try extreme sports at Mega Adventure
# 29                Play outdoor laser tag with GO Team
#
#                                              location    postal code  \
# 0   8 Sentosa Gateway, Sentosa Island, Singapore 0...         098269
# 1                   100 Loewen Road, Singapore 248837         248837
# 2   1 Pasir Ris Close, Downtown East, Singapore 51...         519599
# 3   1 Pasir Ris Close, E!Hub, Market Square @ Down...         519599
# 4   3 Gateway Drive, Westgate #B1-45, Singapore 60...         608532
# 5                                       not available  not available
# 6                                       not available  not available
# 7                                       not available  not available
# 8          21 Jurong Town Hall Road, Singapore 609433         609433
# 9              481 Bukit Timah Road, Singapore 259769         259769
# 10               No. 71 Jalan Lekar, Singapore 698950         698950
# 11             241B Victoria Street, Singapore 188030         188030
# 12   781A North Bridge Road, #02-01, Singapore 198749         198749
# 13                                      not available  not available
# 14             30 Siloso Beach Walk, Singapore 099011         099011
# 15    45 Siloso Beach Walk, Sentosa, Singapore 099003         099003
# 16  6 Raffles Boulevard, Marina Square #01-208, Si...         039594
# 17  2 Yishun Walk, HomeTeamNS Khatib, Singapore 76...         767944
# 18   511 Upper Jurong Road, Block B, Singapore 638366         638366
# 19         1206A East Coast Parkway, Singapore 449891         449891
# 20  200 Turf Club Road, The Grandstand #01-32A/B &...         287994
# 21         139 Cecil Street, #13-01, Singapore 069539         069539
# 22     43 Siloso Beach Walk, #01-01, Singapore 099010         099010
# 23                                      not available  not available
# 24                                      not available  not available
# 25  313 Orchard Road, 313@Somerset #03-27, Singapo...         238895
# 26                8 Sentosa Gateway, Singapore 098269         098269
# 27  Campsite 1 at Pasir Ris Park, near Carpark F, ...         519149
# 28            10A Siloso Beach Walk, Singapore 099008         099008
# 29                                      not available  not available
#
#           contact                                      opening hours  \
# 0   not available                                    10am-5pm, Daily
# 1   not available  Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed ...
# 2       6581 9128  Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Clo...
# 3       9694 4094  Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 1...
# 4       6265 1132  Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-1...
# 5   not available                                      not available
# 6   not available                                      not available
# 7   not available                                      not available
# 8       6560 2306           Tue-Fri 10am-5pm | Sat-Sun & PH 10am-6pm
# 9   1800 471 7300                                      not available
# 10      6766 1554                  Mon-Fri 9am-6pm | Sat-Sun 9am-7pm
# 11      6338 6815  Mon 3pm-10pm | Tue-Fri 10am-9pm | Sat-Sun 10am...
# 12      6336 2133  Sat-Sun 11.30am-12.30pm, 5pm-6pm (Closed from ...
# 13  not available                                      not available
# 14     6911 3070          Mon-Fri 12.30pm-7pm | Sat–Sun 11.30pm-7pm
# 15    6274 0472    Mon-Thu 11am-7.30pm | Fri 11am-9pm | Sat 10am-...
# 16  not available                                    12pm-8pm, Daily
# 17      6705 9420  Tue 2pm-5.30pm | Wed-Fri 2pm-5.30pm and 6pm-9....
# 18  not available  Tue-Fri 1pm-9pm | Sat-Sun 9am-9pm (Closed on M...
# 19      6636 4266                  10am-8pm, Daily | Sat-Sun 9am-8pm
# 20      8923 8945              Tue-Sun 12pm-10pm (Closed on Mondays)
# 21      6993 4131                     Mon-Sat 7am-12am | Sun 7am-8pm
# 22      6571 0000              Thu-Tue & PH 9am-10pm | Wed 11am-10pm
# 23  not available                                      not available
# 24  not available                                      not available
# 25      6737 5313                                    10am-1am, Daily
# 26      6577 8888  Refer to Universal Studios Singapore’s calenda...
# 27      9871 8007  Sat-Sun 9am-6pm, by appointment (Closed from M...
# 28      6722 3785            Mon-Fri 2pm-6pm | Sat-Sun & PH 11am-6pm
# 29      9003 1177                                      not available
#
#           Mon        Tue        Wed        Thu        Fri        Sat  \
# 0      Closed     Closed     Closed     Closed     Closed     Closed
# 1    10am-6pm     Closed   10am-6pm   10am-9pm     Closed     Closed
# 2    12pm-6pm     Closed   12pm-6pm     Closed   12pm-6pm   11am-6pm
# 3    12pm-8pm     Closed     Closed   12pm-8pm   12pm-8pm  11am-10pm
# 4   11am-10pm     Closed     Closed  11am-10pm  11am-11pm  10am-11pm
# 5      Closed     Closed     Closed     Closed     Closed     Closed
# 6      Closed     Closed     Closed     Closed     Closed     Closed
# 7      Closed     Closed     Closed     Closed     Closed     Closed
# 8      Closed   10am-5pm     Closed     Closed   10am-5pm   10am-6pm
# 9      Closed     Closed     Closed     Closed     Closed     Closed
# 10    9am-6pm     Closed     Closed     Closed    9am-6pm    9am-7pm
# 11   3pm-10pm   10am-9pm     Closed     Closed   10am-9pm  10am-10pm
# 12     Closed     Closed     Closed     Closed     Closed    5pm-6pm
# 13     Closed     Closed     Closed     Closed     Closed     Closed
# 14   30pm-7pm     Closed     Closed     Closed   30pm-7pm   30pm-7pm
# 15   11am-9pm     Closed     Closed   11am-9pm   11am-9pm   10am-9pm
# 16     Closed     Closed     Closed     Closed     Closed     Closed
# 17     Closed     Closed     Closed     Closed     Closed     Closed
# 18     Closed    1pm-9pm     Closed     Closed    1pm-9pm    9am-9pm
# 19     Closed     Closed     Closed     Closed     Closed    9am-8pm
# 20     Closed  12pm-10pm     Closed     Closed     Closed     Closed
# 21   7am-12am     Closed     Closed     Closed     Closed   7am-12am
# 22     Closed   9am-10pm  11am-10pm   9am-10pm     Closed     Closed
# 23     Closed     Closed     Closed     Closed     Closed     Closed
# 24     Closed     Closed     Closed     Closed     Closed     Closed
# 25     Closed     Closed     Closed     Closed     Closed     Closed
# 26     Closed     Closed     Closed     Closed     Closed     Closed
# 27     Closed     Closed     Closed     Closed     Closed    9am-6pm
# 28    2pm-6pm     Closed     Closed     Closed    2pm-6pm   11am-6pm
# 29     Closed     Closed     Closed     Closed     Closed     Closed
#
#           Sun  latitude   longitude
# 0      Closed  1.256752  103.820331
# 1    10am-9pm  1.302730  103.812423
# 2    11am-6pm  1.378947  103.955273
# 3   11am-10pm  1.378947  103.955273
# 4   10am-10pm  1.334533  103.742798
# 5      Closed       NaN         NaN
# 6      Closed       NaN         NaN
# 7      Closed       NaN         NaN
# 8    10am-6pm  1.335403  103.735459
# 9      Closed       NaN         NaN
# 10    9am-7pm  1.385036  103.721658
# 11  10am-10pm  1.300458  103.855282
# 12    5pm-6pm  1.303608  103.859822
# 13     Closed       NaN         NaN
# 14   30pm-7pm  1.255319  103.813133
# 15     Closed  1.252287  103.816842
# 16     Closed  1.290989  103.857422
# 17     Closed  1.417395  103.832884
# 18    9am-9pm  1.329444  103.682860
# 19    9am-8pm  1.305595  103.931679
# 20  12pm-10pm  1.337685  103.793667
# 21    7am-8pm  1.279503  103.848442
# 22     Closed  1.252009  103.817604
# 23     Closed       NaN         NaN
# 24     Closed       NaN         NaN
# 25     Closed  1.301509  103.838394
# 26     Closed  1.256752  103.820331
# 27    9am-6pm  1.384943  103.944815
# 28   11am-6pm  1.255989  103.812385
# 29     Closed       NaN         NaN

# %%
yelp.head()
# Out:
#                               name  rating                         cuisine  \
# 0             The Garden @ Sentosa     5.0                 Modern European
# 1     Tian Tian Seafood Restaurant     4.7                Seafood, Chinese
# 2              Song Fa Bak Kut Teh     4.6            Chinese, Singaporean
# 3  Zhong Guo La Mian Xiao Long Bao     4.4  Shanghainese, Dim Sum, Noodles
# 4                        La Strada     4.4                         Italian
#
#   price     location
# 0   $$$      Sentosa
# 1    $$  Tiong Bahru
# 2     $    Chinatown
# 3     $    Chinatown
# 4   $$$      Tanglin

# %%
yelp.location.unique()
# Out:
# array(['Sentosa', 'Tiong Bahru', 'Chinatown', 'Tanglin', 'Novena',
#        'Tanjong Pagar', 'Arab Street', 'Little India', 'Bukit Timah',
#        'Lavender', 'Bayfront', 'Bugis', 'Clarke Quay', 'Orchard',
#        'Geylang', 'Newton', 'Farrer Park', 'City Hall', 'Bencoolen',
#        'Raffles Place', nan, 'Robertson Quay', 'Katong', 'Ubi',
#        'Bukit Batok', 'Thomson', 'Bishan', 'Alexandra', 'Sixth Avenue',
#        'Boat Quay', 'River Valley', 'Ann Siang Hill', 'Duxton Hill',
#        'Boon Keng', 'Bras Brasah', 'Dempsey Hill', 'Mount Sophia',
#        'Dhoby Ghaut', 'Ang Mo Kio', 'Mountbatten', 'West Coast',
#        'Toa Payoh', 'Yio Chu Kang', 'Macpherson', 'Somerset',
#        'Harbourfront', 'Telok Blangah', 'Marine Parade', 'Hougang',
#        'Holland Village', 'Serangoon'], dtype=object)

# %%
postal1 = yelp['location']
longitudes1, latitudes1 = get_co(postal1)

# %%
yelp['longitude'] = longitudes1
yelp['latitude'] = latitudes1

# %%
yelp.head()
# Out:
#                               name  rating                         cuisine  \
# 0             The Garden @ Sentosa     5.0                 Modern European
# 1     Tian Tian Seafood Restaurant     4.7                Seafood, Chinese
# 2              Song Fa Bak Kut Teh     4.6            Chinese, Singaporean
# 3  Zhong Guo La Mian Xiao Long Bao     4.4  Shanghainese, Dim Sum, Noodles
# 4                        La Strada     4.4                         Italian
#
#   price     location   longitude  latitude
# 0   $$$      Sentosa  103.830321  1.249404
# 1    $$  Tiong Bahru  103.825298  1.286371
# 2     $    Chinatown         NaN       NaN
# 3     $    Chinatown         NaN       NaN
# 4   $$$      Tanglin  103.818884  1.306932

# %% [markdown]
# Import restaurant datset from google places to merge with yelp dataset

# %%
gplaces = pd.read_csv('../datasets/gplaces.csv')

# %%
gplaces.head()
# Out:
#                                           Unnamed: 0  \
# 0  https://www.google.com/maps/place/The+Butcher'...
# 1  https://www.google.com/maps/place/Little+Eleph...
# 2  https://www.google.com/maps/place/Ristorante+L...
# 3  https://www.google.com/maps/place/98+Bistro/da...
# 4  https://www.google.com/maps/place/DANIU+TEOCHE...
#
#                               name   rating   cuisine price  \
# 0                The Butcher's Wife      4.5      NaN   NaN
# 1                Little Elephant SG      4.2     Thai    $$
# 2   Ristorante Luka - Tanjong Pagar      4.3  Italian   NaN
# 3                         98 Bistro      4.9   Bistro   NaN
# 4  DANIU TEOCHEW SEAFOOD RESTAURANT      4.2  Seafood   NaN
#
#                                         location   longitude  latitude   \
# 0              19 Yong Siak St, Singapore 168650  103.830199   1.282741
# 1       57 Eng Hoon St, #01-72, Singapore 160057  103.833568   1.284557
# 2               18 Tg Pagar Rd, Singapore 088441  103.843855   1.279989
# 3  85 Kampong Bahru Rd, #01-01, Singapore 169380  103.835528   1.276213
# 4          61 Kampong Bahru Rd, Singapore 169368  103.835969   1.276570
#
#                                           time_table  \
# 0  Thursday\nFriday\nSaturday\nSunday\nMonday\nTu...
# 1  Thursday\nFriday\nSaturday\nSunday\nMonday\nTu...
# 2  Thursday\nFriday\nSaturday\nSunday\nMonday\nTu...
# 3  Thursday\nFriday\nSaturday\nSunday\nMonday\nTu...
# 4  Thursday\nFriday\nSaturday\nSunday\nMonday\nTu...
#
#                                           place_tags        contact
# 0  Outdoor seating\nNo-contact delivery\nDelivery...  +65 6221 9307
# 1  Outdoor seating\nDelivery\nTakeaway\nDine-in\n...  +65 6224 1646
# 2  Outdoor seating\nTakeaway\nDine-in\nWheelchair...  +65 6221 3988
# 3  Kerbside pickup\nNo-contact delivery\nDelivery...  +65 9117 9669
# 4  Kerbside pickup\nNo-contact delivery\nDelivery...  +65 6677 6725

# %% [markdown]
# Drop irrelevant columns

# %%
gplaces.drop(columns = ['Unnamed: 0', 'time_table', 'place_tags','contact'], inplace = True)

# %%
gplaces.rename(columns={'name ': 'name', 'rating ': 'rating', 'latitude ': 'latitude'}, inplace = True)

# %%
yelp.info
# Out:
# <bound method DataFrame.info of                                 name  rating                         cuisine  \
# 0               The Garden @ Sentosa     5.0                 Modern European
# 1       Tian Tian Seafood Restaurant     4.7                Seafood, Chinese
# 2                Song Fa Bak Kut Teh     4.6            Chinese, Singaporean
# 3    Zhong Guo La Mian Xiao Long Bao     4.4  Shanghainese, Dim Sum, Noodles
# 4                          La Strada     4.4                         Italian
# ..                               ...     ...                             ...
# 225                  Old Hen Kitchen     4.7                           Cafes
# 226             Chin Chin Restaurant     3.8           Chinese, Coffee & Tea
# 227          Hong Chang Eating House     5.0                         Chinese
# 228                     Whampoa Keng     4.0                         Teochew
# 229                         Westlake     3.8                         Chinese
#
#     price     location   longitude   latitude
# 0     $$$      Sentosa  103.830321   1.249404
# 1      $$  Tiong Bahru  103.825298   1.286371
# 2       $    Chinatown         NaN        NaN
# 3       $    Chinatown         NaN        NaN
# 4     $$$      Tanglin  103.818884   1.306932
# ..    ...          ...         ...        ...
# 225    $$  Farrer Park   28.242429 -26.247152
# 226     $        Bugis         NaN        NaN
# 227    $$    Serangoon  103.867871   1.355357
# 228    $$  Farrer Park   28.242429 -26.247152
# 229    $$  Bukit Timah  103.802078   1.329411
#
# [230 rows x 7 columns]>

# %%
print(yelp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       230 non-null    object
#  1   rating     230 non-null    float64
#  2   cuisine    230 non-null    object
#  3   price      230 non-null    object
#  4   location   228 non-null    object
#  5   longitude  142 non-null    float64
#  6   latitude   142 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 12.7+ KB
# None

# %%
print (gplaces.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       96 non-null     object
#  1   rating     96 non-null     float64
#  2   cuisine    71 non-null     object
#  3   price      66 non-null     object
#  4   location   96 non-null     object
#  5   longitude  96 non-null     float64
#  6   latitude   96 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 5.4+ KB
# None

# %% [markdown]
# merging yelp and gplaces dataset for into combined_restaurant dataframe

# %%
# Assuming df1 and df2 are your two dataframes
combined_restaurant = pd.concat([yelp, gplaces], ignore_index=True)

# Print the combined dataframe information
print(combined_restaurant.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326 entries, 0 to 325
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       326 non-null    object
#  1   rating     326 non-null    float64
#  2   cuisine    301 non-null    object
#  3   price      296 non-null    object
#  4   location   324 non-null    object
#  5   longitude  238 non-null    float64
#  6   latitude   238 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 18.0+ KB
# None

# %%
combined_restaurant.tail()
# Out:
#                                                   name  rating    cuisine  \
# 321                         Alati Divine Greek Cuisine     4.5    Seafood
# 322                          Ah Yat Seafood Restaurant     4.0    Seafood
# 323  Abundance: Taiwanese Restaurant & Craft Beer B...     4.3  Taiwanese
# 324             Charlie's Restaurant & Bar (Boat Quay)     4.2        NaN
# 325                            Inle Myanmar Restaurant     4.0    Burmese
#
#     price                                           location   longitude  \
# 321   $$$                       73 Amoy St, Singapore 069892  103.846748
# 322   NaN  401 Havelock Rd, #03-00 Hotel Miramar, Singapo...  103.837375
# 323    $$       63A Lengkok Bahru, #01-378, Singapore 151063  103.815376
# 324    $$                     32 Boat Quay, Singapore 049821  103.849821
# 325     $  111 North Bridge Rd, #B1-07A Peninsula Plaza, ...  103.850745
#
#      latitude
# 321  1.280341
# 322  1.288468
# 323  1.289692
# 324  1.286223
# 325  1.292118

# %% [markdown]
# Checking for null values and replacing them with 'not avaialable'

# %%
combined_restaurant.cuisine.isnull().sum()
# Out:
# 25

# %%
combined_restaurant.price.value_counts()
# Out:
# price
# $$               140
# $                 79
# $$$               75
# Not available      2
# Name: count, dtype: int64

# %%
combined_restaurant.price.isnull().sum()
# Out:
# 30

# %% [markdown]
# 32 restaurants with not available or null pricing

# %%
combined_restaurant.cuisine.isnull().sum()
# Out:
# 25

# %%
combined_restaurant = combined_restaurant.fillna('not available')
combined_activity = combined_activity.fillna('not available')

# %% [markdown]
# Checking all different types of cuisines in combined_restaurant dataframe. For the modelling, it is impractical to include every unique combination as a category by itself, as i plan to have the user input his ranking for each cuisine category, and this would be very tedious for him to manually input his ranking for so many cuisines. Furthermore, the dataset is relatively small, with less than 200 restaurants, so splitting them into so many categories would result in many categories only having one restaurant.

# %%
combined_restaurant.cuisine.unique()
# Out:
# array(['Modern European', 'Seafood, Chinese', 'Chinese, Singaporean',
#        'Shanghainese, Dim Sum, Noodles', 'Italian',
#        'Chicken Shop, Hainan', 'Bagels, Breakfast & Brunch, Sandwiches',
#        'Bars, Cafes', 'Vietnamese, Barbeque', 'Japanese', 'Cantonese',
#        'Singaporean, Chinese, Noodles', 'Singaporean', 'American, Bars',
#        'Mexican', 'Seafood', 'Ramen', 'Sushi Bars, Japanese',
#        'Chinese, Seafood', 'Indian',
#        'Seafood, Specialty Food, Street Vendors', 'Burgers',
#        'Indian, Vegetarian', 'Dim Sum', 'Noodles', 'Chinese',
#        'Italian, Wine Bars', 'Dim Sum, Cantonese',
#        'Singaporean, Seafood, Noodles', 'Malaysian, Seafood', 'Buffets',
#        'Vegetarian, Japanese', 'Seafood, Singaporean',
#        'Chinese, Asian Fusion, Singaporean', 'Malaysian', 'Teochew',
#        'Seafood, Barbeque', 'Chinese, Noodles', 'Persian/Iranian',
#        'Noodles, Chicken Shop', 'Cafes, Asian Fusion, Desserts', 'Thai',
#        'Soup, Chinese', 'Breakfast & Brunch, Chinese, Buffets', 'Cafes',
#        'Noodles, Teochew', 'Izakaya', 'Vietnamese', 'Brazilian',
#        'Street Vendors, Italian', 'Pubs, Irish',
#        'Coffee & Tea, Bakeries, Breakfast & Brunch', 'Indonesian',
#        'Indian, Halal', 'Food Court', 'Tapas/Small Plates, Spanish',
#        'Coffee & Tea, Breakfast & Brunch',
#        'Wine Bars, Italian, Imported Food', 'Indian, Asian Fusion',
#        'Korean, Barbeque', 'Taiwanese, Hot Pot', 'Barbeque',
#        'Chinese, Asian Fusion, Bars', 'Korean', 'Hot Pot, Singaporean',
#        'Food Stands, Ramen, Singaporean', 'Bars, Singaporean',
#        'Szechuan, Imported Food', 'Cantonese, Dim Sum, Seafood',
#        'Japanese, Cocktail Bars, Whiskey Bars',
#        'Lounges, Tapas/Small Plates, Mexican', 'Congee, Dim Sum, Noodles',
#        'Shanghainese, Taiwanese, Dumplings', 'American, Steakhouses',
#        'Breakfast & Brunch, Bagels', 'Taiwanese, Shanghainese, Dumplings',
#        'Mediterranean, Greek', 'Coffee & Tea, Food Court, Asian Fusion',
#        'Singaporean, Meat Shops, Barbeque', 'Vegetarian',
#        'Desserts, Salad, Cafes', 'Teppanyaki, Steakhouses',
#        'Cafes, Breakfast & Brunch', 'Japanese, Hot Pot',
#        'Hawker Centre, Food Court', 'Tapas/Small Plates, Cocktail Bars',
#        'Moroccan', 'Singaporean, Noodles, Soup', 'Burmese',
#        'Gastropubs, Lounges', 'Bistros, Tapas/Small Plates',
#        'Barbeque, Japanese', 'Greek', 'Szechuan', 'Bars, Middle Eastern',
#        'Breakfast & Brunch, Asian Fusion, Singaporean',
#        'Bars, American, Barbeque', 'Italian, Pizza',
#        'American, Seafood, Cocktail Bars',
#        'Singaporean, Breakfast & Brunch',
#        'Breakfast & Brunch, Coffee & Tea', 'Coffee & Tea, Sandwiches',
#        'Bars, Burgers', 'Seafood, Seafood Markets',
#        'Bars, Japanese, Asian Fusion',
#        'Coffee Roasteries, Breakfast & Brunch', 'Noodles, Cantonese',
#        'Breakfast & Brunch, Cupcakes, Sandwiches',
#        'Breakfast & Brunch, Bars, Australian', 'Bars, Asian Fusion',
#        'Chinese, Hot Pot',
#        'Organic Stores, Italian, Venues & Event Spaces',
#        'Chinese, Asian Fusion', 'Bars, Gastropubs', 'Cantonese, Dim Sum',
#        'Singaporean, Food Stands', 'Bars, American, Burgers',
#        'Italian, Desserts, Coffee & Tea', 'Food Court, Singaporean',
#        'Australian', 'Asian Fusion, Cocktail Bars', 'Restaurants',
#        'Indonesian, Barbeque', 'American, Sports Bars', 'Chinese, Soup',
#        'Bistros, Specialty Food', 'Mediterranean, Lebanese',
#        'Asian Fusion', 'Thai, Asian Fusion', 'German, Beer Bar',
#        'Indian, Cocktail Bars', 'Bars, American', 'French, Desserts',
#        'Chinese, Coffee & Tea', 'not available', 'Bistro', 'French',
#        'Fine Dining', 'Nyonya', 'Pan-Asian', 'Spanish', 'Middle Eastern',
#        'Western', 'Swiss', 'Fusion', 'Taiwanese', 'Israeli', 'Persian',
#        '\nItalian restaurant'], dtype=object)

# %% [markdown]
# Function to categorise restaurants into 16 most common cuisines

# %%
def categorize_cuisine(cuisine):
    cuisine = cuisine.lower()  # Convert cuisine to lowercase for case-insensitive comparison
    
    categories = []

    if 'western' in cuisine or 'european' in cuisine or 'american' in cuisine:
        categories.append('Western')
    if 'chinese' in cuisine:
        categories.append('Chinese')
    if 'indian' in cuisine:
        categories.append('Indian')
    if 'fusion' in cuisine:
        categories.append('Fusion')
    if 'malaysian' in cuisine:
        categories.append('Malaysian')
    if 'taiwanese' in cuisine:
        categories.append('Taiwanese')
    if 'japanese' in cuisine or 'ramen' in cuisine or 'izakaya' in cuisine or 'teppanyaki' in cuisine:
        categories.append('Japanese')
    if 'italian' in cuisine:
        categories.append('Italian')
    if 'persian' in cuisine or 'israeli' in cuisine or 'middle eastern' in cuisine:
        categories.append('Middle Eastern')
    if 'indonesian' in cuisine:
        categories.append('Indonesian')
    if 'spanish' in cuisine:
        categories.append('Spanish')
    if 'vietnamese' in cuisine:
        categories.append('Vietnamese')
    if 'mexican' in cuisine:
        categories.append('Mexican')
    if 'singaporean' in cuisine:
        categories.append('Singaporean')
    if 'french' in cuisine:
        categories.append('French')

    if not categories:
        categories.append('Other')

    return ', '.join(categories)  # Convert the list to a comma-separated string

# %% [markdown]
# Adding the new column 'cuisine category' to the dataframe with the generalised cuisine for each restaurant which we will refer to from now on in and in the modelling process.

# %%
combined_restaurant['cuisine category'] = combined_restaurant['cuisine'].apply(lambda x: categorize_cuisine(x))

# %%
combined_restaurant.head()
# Out:
#                               name  rating                         cuisine  \
# 0             The Garden @ Sentosa     5.0                 Modern European
# 1     Tian Tian Seafood Restaurant     4.7                Seafood, Chinese
# 2              Song Fa Bak Kut Teh     4.6            Chinese, Singaporean
# 3  Zhong Guo La Mian Xiao Long Bao     4.4  Shanghainese, Dim Sum, Noodles
# 4                        La Strada     4.4                         Italian
#
#   price     location      longitude       latitude      cuisine category
# 0   $$$      Sentosa     103.830321       1.249404               Western
# 1    $$  Tiong Bahru     103.825298       1.286371               Chinese
# 2     $    Chinatown  not available  not available  Chinese, Singaporean
# 3     $    Chinatown  not available  not available                 Other
# 4   $$$      Tanglin     103.818884       1.306932               Italian

# %% [markdown]
# Cleaning of 'price' column

# %%
combined_restaurant.price.value_counts()
# Out:
# price
# $$               140
# $                 79
# $$$               75
# not available     30
# Not available      2
# Name: count, dtype: int64

# %% [markdown]
# Converting the price values of $$$ to numerical for easier accessing later on in the modelling.

# %%
# Define the mapping of symbols to numbers
price_mapping = {'$$$': 3, '$$': 2, '$': 1}

# Replace symbols with numbers
combined_restaurant['price'] = combined_restaurant['price'].replace(price_mapping)

# %% [markdown]
# Replacing 'Not available' with lower case for standardisation across the dataframe

# %%
combined_restaurant.replace('Not available', 'not available', inplace = True)

# %% [markdown]
# export dataframes to csv for manual labelling

# %%
combined_restaurant.to_csv('../datasets/combined_restaurant1.csv')

# %%
combined_activity.to_csv('../datasets/combined_activity.csv')
