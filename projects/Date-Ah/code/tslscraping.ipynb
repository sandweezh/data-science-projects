# %% [markdown]
# # TSL Scraping

# %% [markdown]
# In this notebook i will be scraping data from The Smart Local for activities to do in Singapore

# %%
import pandas as pd 
import re
from scrapingbee import ScrapingBeeClient
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://thesmartlocal.com/read/things-to-do-singapore/'
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '<!doctype html>\n<html class="no-js" lang="en-GB">\n<head>\n<meta charset="UTF-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="p:domain_verify" content="774ac8a9cb7d4649843c57c40f5f68b0" />\n<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin />\n<link rel="preload" as="style" href="https://fonts.googleapis.com/css?family=Heebo:400,700&display=optional" />\n\n<link rel="alternate" href="https://thesmartlocal.com/" hreflang="x-default" />\n<link rel="alternate" href="https://thesmartlocal.com/" hreflang="en-sg" />\n<link rel="alternate" href="https://thesmartlocal.my/" hreflang="en-my" />\n<link rel="alternate" href="https://thesmartlocal.co.th/" hreflang="en-th" />\n<link rel="alternate" href="https://thesmartlocal.com/vietnam/" hreflang="en-vn" />\n<link rel="alternate" href="https://thesmartlocal.id/" hreflang="en-id" />\n<link rel="alternate" href="https://thesmartlocal.ph/" hreflang="en-ph" />\n<link rel="alternate" href="https://thesmartlocal.kr/" hreflang="en-kr" />\n<link rel="alternate" href="https://thesmartlocal.jp/" hreflang="en-jp" />\n\n<meta name="robots" content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" />\n\n<title>130 Best Things To Do In Singapore</title>\n<meta name="description" content="This may be a small island but there are loads of things to do in Singapore, whether you&#039;re a tourist or local. Here are 130 to try." />\n<link rel="canonical" href="https://thesmartlocal.com/read/things-to-do-singapore/" />\n<meta property="og:locale" content="en_GB" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="130 Best Things To Do In Singapore That’ll Give You Something To Do Every Single Weekend" />\n<meta property="og:description" content="This may be a small island but there are loads of things to do in Singapore, whether you&#039;re a tourist or local. Here are 130 to try." />\n<meta property="og:url" content="https://thesmartlocal.com/read/things-to-do-singapore/" />\n<meta property="og:site_name" content="TheSmartLocal - Singapore&#039;s Leading Travel and Lifestyle Portal" />\n<meta property="article:publisher" content="https://www.facebook.com/TheSmartLocal/" />\n<meta property="article:published_time" content="2024-04-16T01:00:24+00:00" />\n<meta property="article:modified_time" content="2024-04-29T01:15:12+00:00" />\n<meta property="og:image" content="https://thesmartlocal.com/wp-content/uploads/2022/04/130-things-to-do-in-singapore.jpg" />\n<meta property="og:image:width" content="1500" />\n<meta property="og:image:height" content="785" />\n<meta property="og:image:type" content="image/jpeg" />\n<meta name="author" content="TSL" />\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:label1" content="Written by" />\n<meta name="twitter:data1" content="TSL" />\n<meta name="twitter:label2" content="Estimated reading time" />\n<meta name="twitter:data2" content="100 minutes" />\n<script data-jetpack-boost="ignore" type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"Article","@id":"https://thesmartlocal.com/read/things-to-do-singapore/#article","isPartOf":{"@id":"https://thesmartlocal.com/read/things-to-do-singapore/"},"author":[{"@id":"https://thesmartlocal.com/#/schema/person/920946ac76a71b533f1eb14207e8cf52"}],"headline":"130 Best Things To Do In Singapore That’ll Give You Something To Do Every Single Weekend","datePublished":"2024-04-16T01:00:24+00:00","dateModified":"2024-04-29T01:15:12+00:00","mainEntityOfPage":{"@id":"https://thesmartlocal.com/read/things-to-do-singapore/"},"wordCount":15870,"publisher":{"@id":"https://thesmartlocal.com/#organization"},"image":{"@id":"https://thesmartlocal.com/read/things-to-do-singapore/#primaryimage"},"thumbnailUrl":"https://thesmartlocal.com/wp-content/uploads/2022/04/130-things-to-do-in-singapore.j ...

# %% [markdown]
# ### Create a BeautifulSoup object

# %%
soup = BeautifulSoup(res.text, 'lxml') # parse html for python
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-GB">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="774ac8a9cb7d4649843c57c40f5f68b0" name="p:domain_verify"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link as="style" href="https://fonts.googleapis.com/css?family=Heebo:400,700&amp;display=optional" rel="preload"/>
# <link href="https://thesmartlocal.com/" hreflang="x-default" rel="alternate"/>
# <link href="https://thesmartlocal.com/" hreflang="en-sg" rel="alternate"/>
# <link href="https://thesmartlocal.my/" hreflang="en-my" rel="alternate"/>
# <link href="https://thesmartlocal.co.th/" hreflang="en-th" rel="alternate"/>
# <link href="https://thesmartlocal.com/vietnam/" hreflang="en-vn" rel="alternate"/>
# <link href="https://thesmartlocal.id/" hreflang="en-id" rel="alternate"/>
# <link href="https://thesmartlocal.ph/" hreflang="en-ph" rel="alternate"/>
# <link href="https://thesmartlocal.kr/" hreflang="en-kr" rel="alternate"/>
# <link href="https://thesmartlocal.jp/" hreflang="en-jp" rel="alternate"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <title>130 Best Things To Do In Singapore</title>
# <meta content="This may be a small island but there are loads of things to do in Singapore, whether you're a tourist or local. Here are 130 to try." name="description"/>
# <link href="https://thesmartlocal.com/read/things-to-do-singapore/" rel="canonical"/>
# <meta content="en_GB" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="130 Best Things To Do In Singapore That’ll Give You Something To Do Every Single Weekend" property="og:title"/>
# <meta content="This may be a small island but there are loads of things to do in Singapore, whether you're a tourist or local. Here are 130 to try." property="og:description"/>
# <meta content="https://thesmartlocal.com/read/things-to-do-singapore/" property="og:url"/>
# <meta content="TheSmartLocal - Singapore's Leading Travel and Lifestyle Portal" property="og:site_name"/>
# <meta content="https://www.facebook.com/TheSmartLocal/" property="article:publisher"/>
# <meta content="2024-04-16T01:00:24+00:00" property="article:published_time"/>
# <meta content="2024-04-29T01:15:12+00:00" property="article:modified_time"/>
# <meta content="https://thesmartlocal.com/wp-content/uploads/2022/04/130-things-to-do-in-singapore.jpg" property="og:image"/>
# <meta content="1500" property="og:image:width"/>
# <meta content="785" property="og:image:height"/>
# <meta content="image/jpeg" property="og:image:type"/>
# <meta content="TSL" name="author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Written by" name="twitter:label1"/>
# <meta content="TSL" name="twitter:data1"/>
# <meta content="Estimated reading time" name="twitter:label2"/>
# <meta content="100 minutes" name="twitter:data2"/>
# <script class="yoast-schema-graph" data-jetpack-boost="ignore" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Article","@id":"https://thesmartlocal.com/read/things-to-do-singapore/#article","isPartOf":{"@id":"https://thesmartlocal.com/read/things-to-do-singapore/"},"author":[{"@id":"https://thesmartlocal.com/#/schema/person/920946ac76a71b533f1eb14207e8cf52"}],"headline":"130 Best Things To Do In Singapore That’ll Give You Something To Do Every Single Weekend","datePublished":"2024-04-16T01:00:24+00:00","dateModified":"2024-04-29T01:15:12+00:00","mainEntityOfPage":{"@id":"https://thesmartlocal.com/read/things-to-do-singapore/"},"wordCount":15870,"publisher":{"@id":"https://thesmartlocal.com/#organization"},"image":{"@id":"https://thesmartlocal.com/read/things-to-do-singapore/#primaryimage"},"thumbnailUrl":"https://thesmartlocal.com/wp-content/uploads/2022/04/130-things-to-do-in-singapore.jpg","keywords":["things to do in singapore"],"articleSection":["Things To Do"],"inLanguage":"en-GB"},{"@type":"WebPage","@id":"https://thesmartlocal.com/read/things-to-do-singapore/","url":"https://thesmartlocal.com/read/things-to-do-singapore/","name":"130 Best Things To Do In Singapore","isPartOf":{"@id":"https://thesmartlocal.com/#website"},"primaryImageOfPage":{"@id":"https://thesmartlocal.com/read/things-to-do-singapore/#primaryimage"},"image":{"@id":"https://thesmartlocal.com/read/things-to-do-singapore/#primaryimage"},"thumbnailUrl":"https://thesmartlocal.com/wp-content/uploads/2022/04/130-things-to-do-in-singapore.jpg","datePublished":"2024-04-16T01:00:24+00:00","dateModified":"2024-04-29T01:15:12+00:00","description":"This may be a small island but there are loads of things to do in Singapore, whether you're a tourist or local. Here are 130 to try.","breadcrumb":{"@id":"https://thesmartlocal.com/read/things-to-do-singapore/#breadcrumb"},"inLanguage":"en-GB","potentialAction":[{"@type":"ReadAction","target":["https://thesmartlocal.com/read/things-to-do-singapore/"]}]},{"@type":"ImageObject","inLanguage":"en-GB","@id":"https://thesmartlocal.com/read/things-to-do-singapore/#primaryimage","url":"https://thesmartlocal.com/wp-content/uploads/2022/04/130-things-to-do-in-singapore.jpg","contentUrl":"https://thesmartlocal.com/wp-content/uploads/2022/04/130-things-to-do-in-singapore.jpg","width":1500,"height":785,"caption":"things to do in singapore"},{"@type":"BreadcrumbList","@id":"https://thesmartlocal.com/read/things-to-do-singapore/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://thesmartlocal.com/"},{"@type":"ListItem","position":2,"name":"130 Best Things To Do In Singapore That’ll Give You Something To Do Every Single Weekend"}]},{"@type":"WebSite","@id":"https://thesmartlocal.com/#website","url":"https://thesmartlocal.com/","name":"TheSmartLocal - Singapore&#039;s Leading Travel and Lifestyle Portal","description":"Created by locals, we share things to do in and out of Singapore.","publisher":{"@id":"https://thesmartlocal.com/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://thesmartlocal.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-GB"},{"@type":"Organization","@id":"https://thesmartlocal.com/#organization","name":"TheSmartLocal","url":"https://thesmartlocal.com/","logo":{"@type":"ImageObject","inLanguage":"en-GB","@id":"https://thesmartlocal.com/#/schema/logo/image/","url":"https://thesmartlocal.com/vietnam/wp-content/uploads/2021/03/TSL-Vietnam-Square.png","contentUrl":"https://thesmartlocal.com/vietnam/wp-content/uploads/2021/03/TSL-Vietnam-Square.png","width":2500,"height":2500,"caption":"TheSmartLocal"},"image":{"@id":"https://thesmartlocal.com/#/schema/logo/image/"},"sameAs":["https://www.facebook.com/TheSmartLocal/","https://www.instagram.com/thesmartlocalsg/","https://sg.linkedin.com/company/thesmartlocal-com","https://www.youtube.com/u ...
# <link href="https://thesmartlocal.com/read/things-to-do-singapore/amp/" rel="amphtml"/><meta content="AMP for WP 1.0.92" name="generator"/><link href="//stackpath.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="//stats.wp.com" rel="dns-prefetch"/>
# <link href="https://thesmartlocal.com/feed/" rel="alternate" title="TheSmartLocal - Singapore's Leading Travel and Lifestyle Portal » Feed" type="application/rss+xml"/>
# <link href="https://thesmartlocal.com/comments/feed/" rel="alternate" title="TheSmartLocal - Singapore's Leading Travel and Lifestyle Portal » Comments Feed" type="application/rss+xml"/>
# <style id="wp-emoji-styles-inline-css" type="text/css">
#
# 	img.wp-smiley, img.emoji {
# 		display: inline !important;
# 		border: none !important;
# 		box-shadow: none !important;
# 		height: 1em !important;
# 		width: 1em !important;
# 		margin: 0 0.07em !important;
# 		vertical-align: -0.1em !important;
# 		background: none !important;
# 		padding: 0 !important;
# 	}
# </style>
# <link href="https://thesmartlocal.com/wp-includes/js/mediaelement/mediaelementplayer-legacy.min.css?ver=4.2.17" id="mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-includes/js/mediaelement/wp-mediaelement.min.css?ver=6.4.2" id="wp-mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="classic-theme-styles-inline-css" type="text/css">
# /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
# </style>
# <style id="global-styles-inline-css" type="text/css">
# body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}:where(.is-layout-grid){gap: 0.5em;}body .is-layout-flow > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-flow > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-flow > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-constrained > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-constrained > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > :where(:not(.alignleft):not(.alignright):not(.alignfull)){max-width: var(--wp--style--global--content-size);margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignwide{max-width: var(--wp--style--global--wide-size);}body .is-layout-flex{display: flex;}body .is-layout-flex{flex-wrap: wrap;align-items: center;}body .is-layout-flex > *{margin: 0;}body .is-layout-grid{display: grid;}body .is-layout-grid > *{margin: 0;}:where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-colu ...
# .wp-block-navigation a:where(:not(.wp-element-button)){color: inherit;}
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# .wp-block-pullquote{font-size: 1.5em;line-height: 1.6;}
# </style>
# <link href="https://thesmartlocal.com/wp-content/plugins/facebook-sharecount-plugin/assets/css/mashsb.min.css?ver=3.5.7" id="mashsb-styles-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="mashsb-styles-inline-css" type="text/css">
# .mashsb-count {color:#cccccc;}@media only screen and (min-width:568px){.mashsb-buttons a {min-width: 177px;}}
# </style>
# <link href="https://thesmartlocal.com/wp-content/plugins/redux-framework/redux-core/assets/css/extendify-utilities.css?ver=4.4.5" id="redux-extendify-styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/plugins/table-of-contents-plus/screen.min.css?ver=2309" id="toc-screen-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="toc-screen-inline-css" type="text/css">
# div#toc_container {width: 75%;}div#toc_container ul li {font-size: 99%;}
# </style>
# <link href="https://thesmartlocal.com/wp-content/plugins/tiktok-block/assets/tiktok-block.css?ver=6.4.2" id="tiktok-block-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/plugins/worth-the-read/css/wtr.css?ver=6.4.2" id="wtr-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/plugins/youtube-block/assets/youtube-block.css?ver=6.4.2" id="youtube-block-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/plugins/explorer-client/assets/explorer.min.css?ver=ea9d0f1b91416359388e7b14f2eae317" id="tsl-explorer-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/plugins/delivery-directory/public/css/dd.css?ver=6.4.2" id="DD-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/uploads/maxmegamenu/style.css?ver=cd63d6" id="megamenu-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-includes/css/dashicons.min.css?ver=6.4.2" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/themes/tsl/css/fasocial.min.css?ver=1.0.5" id="fontawesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.0/css/bootstrap.min.css?ver=1.0.5" id="bootstrap-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/themes/tsl/css/reset.css?ver=1.0.5" id="reset-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/themes/tsl/css/normalize.min.css?ver=1.0.5" id="normalize-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/themes/tsl/css/main.min.css?ver=1.0.5" id="main-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/themes/tsl/css/flag-icon.min.css?ver=1.0.5" id="flags-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/plugins/whats-fun-nearby-plugin/public/css/wfnb.css?ver=6.4.2" id="wfnb-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/plugins/wp-review/public/css/wp-review.css?ver=5.3.5" id="wp_review-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://thesmartlocal.com/wp-content/plugins/jetpack/css/jetpack.css?ver=12.9" id="jetpack_css-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="solstice-custom-style" media="screen" type="text/css">
# 			.footer-div {
#  width: 100%;
# }
#
# .footer-div>a {
#  padding-bottom: 1em;
#  display: block;
# }
#
# .review-wrapper .review-heading>h5.review-title {
#  color: #fff !important;
# }
#
#
# ul.toc_list {
#  padding-inline-start: 10px !important;
# }
#
# body #toc_container>.toc_title {
#  font-size: 16px;
#  font-weight: bold;
# }
#
# body #toc_container ul.toc_list>li>a {
#  font-weight: bold;
# }
#
#
# body #toc_container ul.toc_list ul {
#  padding-inline-start: 10px !important;
#  margin-left: 0;
# }
#
# div#toc_container ul li {
#  font-size: 14px;
# }
#
# body .post-content h6 {
#  font-size: 18pt;
#  color: #4a90e2;
#  font-weight: bold;
# }
#
# body .post-content p>i {
#  font-style: italic !important;
# }
#
# body .post-content p>a>i,
# body .post-content p>a>i>span,
# body .post-content p>i {
#  font-style: italic !important;
# }
#
# #tslwapp {
#  bottom: 100px;
# }
#
# .policy-badge {
#  display: inline-block;
#  border-radius: 10px;
#  text-align: center;
#  padding: 0 0.5rem;
#  font-size: 12px;
#  background: #4a90e2;
#  color: #ffffff;
#  margin: 20px 0;
#  line-height: 1.4;
# }
#
# .privacy-policy ol {
#  list-style-type: none;
# }
#
# .privacy-policy ol>li:before {
#  counter-increment: mycounter;
#  content: counter(mycounter) ". ";
# }
#
# .privacy-policy ol:first-of-type {
#  counter-reset: mycounter;
# }
#
# @media (min-width: 768px) {
#
#  /* for desktop */
#  .sidebar-ads-wrapper--top {
#  /* for the targeted ads */
#  min-height: 270px;
#  /* as discussed define a height to prevent layout shift, the value still need to fine tune */
#  }
# }		</style>
# <link href="https://thesmartlocal.com/wp-json/" rel="https://api.w.org/"/><link href="https://thesmartlocal.com/wp-json/wp/v2/posts/109357" rel="alternate" type="application/json"/><link href="https://thesmartlocal.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <meta content="WordPress 6.4.2" name="generator"/>
# <link href="https://thesmartlocal.com/?p=109357" rel="shortlink"/>
# <link href="https://thesmartlocal.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fthesmartlocal.com%2Fread%2Fthings-to-do-singapore%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://thesmartlocal.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fthesmartlocal.com%2Fread%2Fthings-to-do-singapore%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <meta content="Redux 4.4.5" name="generator"/><style type="text/css">.wtr-time-wrap{
# 	/* wraps the entire label */
# 	margin: 0 10px;
# }
#
# .wtr-time-number{
# 	/* applies only to the number */
#
# }
#
# .wtr-time-wrap.block, .wtr-time-wrap.before-content {
#     display: inline;
#     padding-left:3px;
#     color: #888888;
#     font-size: 14px
# }</style> <style>img#wpstats{display:none}</style>
# <link as="font" crossorigin="" href="https://thesmartlocal.com/wp-content/plugins/wordpress-popup/assets/hustle-ui/fonts/hustle-icons-font.woff2" rel="preload" type="font/woff2"/>
# <style>	:root {
# 	--exp-colors-primary-700: 38,118,192;
# 	}
# </style><link href="https://thesmartlocal.com/wp-content/uploads/2019/06/cropped-favicon-1-32x32.jpg" rel="icon" sizes="32x32"/>
# <link href="https://thesmartlocal.com/wp-content/uploads/2019/06/cropped-favicon-1-192x192.jpg" rel="icon" sizes="192x192"/>
# <link href="https://thesmartlocal.com/wp-content/uploads/2019/06/cropped-favicon-1-180x180.jpg" rel="apple-touch-icon"/>
# <meta content="https://thesmartlocal.com/wp-content/uploads/2019/06/cropped-favicon-1-270x270.jpg" name="msapplication-TileImage"/>
# <style id="wp-custom-css" type="text/css">
# 			.page-id-314650 .heading a {
#     border: none;
#     padding: 0;
#     text-align: left;
#     text-transform: none;
#     font-size: 2.2rem;
#     line-height: 1.2;
#     font-weight: bold;
# }
#
# /* Footer Sidebar 4 */
# #text-2 .textwidget p {
#     line-height: 1.3rem;
# }
#
# #mashbar-header {
#     z-index: 99 !important;
# }
#
# .wp-block-group h5 {
# 	margin-bottom: 15px;
#     /* padding-top: 12px; */
#     padding-bottom: 5px;
#     border-bottom: 0.4rem solid #EEEEEE;
#     font-size: 22px;
#     /* letter-spacing: 1px; */
#     color: #4a90e2;
#     font-weight: bold;
# }
#
#
# /* Jetpack Trending Widget */
# .widget_top-posts .widgets-list-layout img.widgets-list-layout-blavatar,
# .widget_tsl-latest-posts .widgets-list-layout img.widgets-list-layout-blavatar{
#     max-width: 28%;
# }
#
# .widget_top-posts .widgets-list-layout div.widgets-list-layout-links,
# .widget_tsl-latest-posts .widgets-list-layout div.widgets-list-layout-links{
#     max-width: 100%;
#     width: 70%;
# }
#
# .widget_top-posts .widgets-list-layout div.widgets-list-layout-links a ,
# .widget_tsl-latest-posts .widgets-list-layout div.widgets-list-layout-links a {
#     color: #333;
# }
#
# @media only screen and (max-width: 1019px) {
#
#     .widget_top-posts ul.widgets-list-layout,
# 	.widget_tsl-latest-posts ul.widgets-list-layout {
#         max-width: 600px;
#         margin: 0 auto;
#     }
#
#     .widget_top-posts .widgets-list-layout div.widgets-list-layout-links,
# 	.widget_tsl-latest-posts .widgets-list-layout div.widgets-list-layout-links{
#         font-size: 24px;
#     }
# }
#
# @media only screen and (max-width:768px) {
#
#     .widget_top-posts .widgets-list-layout img.widgets-list-layout-blavatar, .widget_tsl-latest-posts .widgets-list-layout img.widgets-list-layout-blavatar {
#         max-width: 28%;
#     }
#
#     .widget_top-posts .widgets-list-layout div.widgets-list-layout-links,
# 	.widget_tsl-latest-posts .widgets-list-layout div.widgets-list-layout-links{
#         max-width: 100%;
#         width: 70%;
#     }
#
#     .widget_top-posts .widgets-list-layout div.widgets-list-layout-links,
# 	.widget_tsl-latest-posts .widgets-list-layout div.widgets-list-layout-links{
#         font-size: inherit;
#     }
# }
#
#
# .review-wrapper .review-heading>h5.review-title {
#     color: #fff !important;
#     background-color: #4a90e2;
#     font-weight: 600;
#     font-size: 1.5em;
# }
#
# /* Portrait Image Resized for Desktop , default for mobile */
# @media only screen and (min-width:992px) {
#     .tsl-portrait {
#         width: 50% !important;
#     }
#
# }		</style>
# <style class="redux-options-output" id="solstice_theme_options-dynamic-css" title="dynamic-css">.single .blog-post .post-content a, .blog-post .post-meta .author a, .archive .blog-post .post-content a, .page-content a{color:#4a90e2;}.single .blog-post .post-content a:hover, .blog-post .post-meta .author a:hover, .archive .blog-post .post-content a:hover, .page-content a:hover{color:#1f69c1;}</style><style class="redux-options-output" id="wtr_settings-dynamic-css" title="dynamic-css">.wtr-time-wrap{line-height:16px;color:#CCCCCC;font-size:16px;}</style><style type="text/css">/** Mega Menu CSS: fs **/</style>
# <style>
# .ai-viewports                 {--ai: 1;}
# .ai-viewport-3                { display: none !important;}
# .ai-viewport-2                { display: none !important;}
# .ai-viewport-1                { display: inherit !important;}
# .ai-viewport-0                { display: none !important;}
# @media (min-width: 768px) and (max-width: 979px) {
# .ai-viewport-1                { display: none !important;}
# .ai-viewport-2                { display: inherit !important;}
# }
# @media (max-width: 767px) {
# .ai-viewport-1                { display: none !important;}
# .ai-viewport-3                { display: inherit !important;}
# }
# .ai-close {position: relative;}
# .ai-close-button {position: absolute; top: -8px; right: -8px; width: 24px; height: 24px; background: url(https://thesmartlocal.com/wp-content/plugins/ad-inserter-pro/css/images/close-button.png) no-repeat center center; cursor: pointer; z-index: 9; display: none;}
# .ai-close-show {display: block;}
# .ai-close-left {right: unset; left: -10px;}
# .ai-close-bottom {top: unset; bottom: -11px;}
# .ai-close-none {visibility: hidden;}
# .ai-close-fit {width: fit-content; width: -moz-fit-content;}
# </style>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=440268676697613&amp;ev=PageView
# &amp;noscript=1" width="1"/>
# </noscript>
# <style>
# 		.flag-icon {
# 			font-size: 30px !important;
# 			vertical-align: sub;
# 		}
#
# 		/*--------------------------------------------------------------
#     Custom CSS by StackIdeas|myh
#     25-06-2020
#     --------------------------------------------------------------*/
# 		.tsl-logo {
# 			width: 176px;
# 		}
#
# 		.social-icons li {
# 			width: 45px;
# 		}
#
# 		.social-icons.flags li {
# 			/* font-size: 1.5em;  */
# 			width: fit-content;
# 		}
#
# 		#selectedFlag {
# 			padding-left: 5rem;
# 			font-size: 14px;
# 			font-weight: 700;
# 		}
#
# 		.select-label {
# 			font-size: 11px !important;
# 		}
#
# 		.width-height-ovr {
# 			width: fit-content;
# 			height: fit-content;
# 		}
#
# 		.fa-16px {
# 			font-size: 16px;
# 		}
#
# 		.country-ddl {
# 			font-size: 14px;
# 			font-weight: 700;
# 		}
# 	</style>
# </head>
# <body class="post-template-default single single-post postid-109357 single-format-standard mega-menu-primary-menu fixed">
# <section id="wrapper">
# <header id="main-header">
# <div class="container">
# <div class="row">
# <div class="col-md-12">
# <nav class="navbar navbar-light navbar-expand-lg fixed-top">
# <div class="tsl-navbar container align-items-center justify-content-lg-between justify-content-center d-flex">
# <div class="tsl-navbar_left order-1 order-lg-1 order-xl-0 ml-auto mr-auto xml-lg-2 xmr-lg-2">
# <div class="tsl-logo">
# <a href="https://thesmartlocal.com/">
# <img alt="thesmartlocal" data-pagespeed-no-defer="" height="31" src="https://thesmartlocal.com/wp-content/uploads/2020/07/tsl-singapore-@2x.png" width="176"/>
# </a>
# </div>
# </div>
# <div class="tsl-navbar_center order-0 order-lg-0 order-xl-1 flex-xl-fill">
# <div class="mega-menu-wrap" id="mega-menu-wrap-primary-menu"><div class="mega-menu-toggle"><div class="mega-toggle-blocks-left"><div class="mega-toggle-block mega-menu-toggle-block mega-toggle-block-1" id="mega-toggle-block-1" tabindex="0"><span aria-expanded="false" aria-label="mega-toggle-label" class="mega-toggle-label" role="button"><span class="mega-toggle-label-closed"></span><span class="mega-toggle-label-open"></span></span></div></div><div class="mega-toggle-blocks-center"></div><div class="mega-toggle-blocks-right"></div></div><ul class="mega-menu max-mega-menu mega-menu-horizontal mega-no-js" data-breakpoint="1200" data-document-click="collapse" data-effect="disabled" data-effect-mobile="disabled" data-effect-speed="200" data-effect-speed-mobile="0" data-event="hover" data-hover-intent-interval="100" data-hover-intent-timeout="300" data-mobile-force-width="body" data-mobile-state="collapse_all" data-panel-inner-width=".container" data-panel-width=".container" data-second-click="go" data-unbind="true" data-vertical-behaviour="standard" id="mega-menu-primary-menu"><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-83131" id="mega-menu-item-83131"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/travel/" tabindex="0">TRAVEL<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-menu-item-83172" id="mega-menu-item-83172"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/travel/southeast-asia/">Southeast Asia<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83189" id="mega-menu-item-83189"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/southeast-asia/thailand/">Thailand</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83187" id="mega-menu-item-83187"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/southeast-asia/malaysia/">Malaysia</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83188" id="mega-menu-item-83188"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/southeast-asia/philippines/">Philippines</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83184" id="mega-menu-item-83184"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/southeast-asia/indonesia/">Indonesia</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83190" id="mega-menu-item-83190"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/southeast-asia/vietnam/">Vietnam</a></li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-menu-item-83175" id="mega-menu-item-83175"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/travel/rest-of-asia/">Rest Of Asia<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83181" id="mega-menu-item-83181"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/rest-of-asia/china/">China</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83182" id="mega-menu-item-83182"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/rest-of-asia/hong-kong/">Hong Kong</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83183" id="mega-menu-item-83183"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/rest-of-asia/japan/">Japan</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83185" id="mega-menu-item-83185"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/rest-of-asia/korea/">Korea</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83191" id="mega-menu-item-83191"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/rest-of-asia/taiwan/">Taiwan</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83186" id="mega-menu-item-83186"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/rest-of-asia/others-rest-of-asia/">Others</a></li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83179" id="mega-menu-item-83179"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/australia/">Australia</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83174" id="mega-menu-item-83174"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/new-zealand/">New Zealand</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83180" id="mega-menu-item-83180"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/europe/">Europe</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83177" id="mega-menu-item-83177"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/africa-middle-east/">Africa &amp; Middle East</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83178" id="mega-menu-item-83178"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/america/">America</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83176" id="mega-menu-item-83176"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/rest-of-the-world/">Rest of the World</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83173" id="mega-menu-item-83173"><a class="mega-menu-link" href="https://thesmartlocal.com/category/travel/travel-guides-tips/">Travel Guides &amp; Tips</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-current-post-ancestor mega-current-menu-parent mega-current-post-parent mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-83129" id="mega-menu-item-83129"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/" tabindex="0">THINGS TO DO<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-menu-item-83151" id="mega-menu-item-83151"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/activities/">Activities<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83167" id="mega-menu-item-83167"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/activities/attractions/">Attractions</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83162" id="mega-menu-item-83162"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/activities/volunteering/">Volunteering</a></li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-menu-item-83153" id="mega-menu-item-83153"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/events-things-to-do/">Events<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83166" id="mega-menu-item-83166"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/events-things-to-do/runs/">Runs</a></li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-menu-item-83160" id="mega-menu-item-83160"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/food-things-to-do/">Food<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83169" id="mega-menu-item-83169"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/food-things-to-do/food-reviews-food-things-to-do/">Food Reviews</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83168" id="mega-menu-item-83168"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/food-things-to-do/food-guides-food-things-to-do/">Food Guides</a></li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-menu-item-83156" id="mega-menu-item-83156"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/nightlife/">Nightlife<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83165" id="mega-menu-item-83165"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/nightlife/bars-clubs/">Bars &amp; Clubs</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83164" id="mega-menu-item-83164"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/nightlife/nightlife-guides/">Nightlife Guides</a></li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-menu-item-83155" id="mega-menu-item-83155"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/hotels-staycations/">Hotels &amp; Staycations<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83171" id="mega-menu-item-83171"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/hotels-staycations/hotel-reviews/">Hotel Reviews</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83170" id="mega-menu-item-83170"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/hotels-staycations/hotel-guides/">Hotel Guides</a></li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83154" id="mega-menu-item-83154"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/family-kid-friendly/">Family &amp; Kid-friendly</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83157" id="mega-menu-item-83157"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/photospots/">Photospots</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-menu-item-83158" id="mega-menu-item-83158"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/sales-promotions/">Sales &amp; Promotions<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-105336" id="mega-menu-item-105336"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/sales-promotions/contests/">Contests</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83163" id="mega-menu-item-83163"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/sales-promotions/monthly-lobangs/">Monthly Lobangs</a></li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83159" id="mega-menu-item-83159"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/sports-fitness/">Sports &amp; Fitness</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83152" id="mega-menu-item-83152"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/beauty-wellness/">Beauty &amp; Wellness</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83161" id="mega-menu-item-83161"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/fashion/">Fashion</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-259930" id="mega-menu-item-259930"><a class="mega-menu-link" href="https://thesmartlocal.com/category/things-to-do/gaming/">Gaming</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-83136" id="mega-menu-item-83136"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/local/" tabindex="0">LOCAL<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83148" id="mega-menu-item-83148"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/perspectives/">Perspectives</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83146" id="mega-menu-item-83146"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/inspiration/">Inspiration</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83145" id="mega-menu-item-83145"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/culture/">Culture</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83149" id="mega-menu-item-83149"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/students/">Students</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83150" id="mega-menu-item-83150"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/businesses/">Businesses</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-96266" id="mega-menu-item-96266"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/hacks/">Hacks</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-201912" id="mega-menu-item-201912"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/heritage/">Heritage</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-259951" id="mega-menu-item-259951"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/supernatural-mystery/">Supernatural &amp; Mystery</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-259958" id="mega-menu-item-259958"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/humour/">Humour</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83147" id="mega-menu-item-83147"><a class="mega-menu-link" href="https://thesmartlocal.com/category/local/misc/">Misc</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-83137" id="mega-menu-item-83137"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/" tabindex="0">ADULTING<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83139" id="mega-menu-item-83139"><a class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/finances/">Finances</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83140" id="mega-menu-item-83140"><a class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/home/">Home</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-105333" id="mega-menu-item-105333"><a class="mega-menu-link" href="https://thesmartlocal.com/category/dating-relationships/">Dating &amp; Relationships</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83143" id="mega-menu-item-83143"><a class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/wedding/">Wedding</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-has-children mega-menu-item-83141" id="mega-menu-item-83141"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/parenting/">Parenting<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83144" id="mega-menu-item-83144"><a class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/parenting/education/">Education</a></li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83138" id="mega-menu-item-83138"><a class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/career/">Career</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-83142" id="mega-menu-item-83142"><a class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/self-improvement/">Self Improvement</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-105335" id="mega-menu-item-105335"><a class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/pets/">Pets</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-201913" id="mega-menu-item-201913"><a class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/tech/">Tech</a></li><li class="mega-menu-item mega-menu-item-type-taxonomy mega-menu-item-object-category mega-menu-item-259931" id="mega-menu-item-259931"><a class="mega-menu-link" href="https://thesmartlocal.com/category/adulting/products/">Products</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-85726" id="mega-menu-item-85726"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://thesmartlocal.com/reviews/category/singapore/" tabindex="0">REVIEWS<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-98841" id="mega-menu-item-98841"><a class="mega-menu-link" href="https://thesmartlocal.com/reviews/latest-listings/">Latest Listings</a></li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-98842" id="mega-menu-item-98842"><a class="mega-menu-link" href="https://thesmartlocal.com/reviews/">Most Popular Listings</a></li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-98843" id="mega-menu-item-98843"><a class="mega-menu-link" href="https://thesmartlocal.com/reviews/latest-reviews/">Latest Reviews</a></li></ul>
# </li><li class="mega-country-list mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-236447 country-list" id="mega-menu-item-236447"><a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="#" tabindex="0">SELECT COUNTRY<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# ...
# parseInt(c))for(var q in ai_cookie[c])if("c"==q){var g=ai_cookie[c][q];if(0<g)if(ai_set_cookie(c,"c",g-1),1==g){g=d("span[data-ai-block="+f+"]").data("ai-cfp-time");var e=new Date;e=Math.round(e.getTime()/1E3);var p=e+604800;ai_set_cookie(c,"c",-p);setTimeout(function(){d("span[data-ai-block="+f+"]").closest("div[data-ai]").remove()},50);"undefined"!=typeof g&&(p=e+86400*g,ai_set_cookie(f,"x",p),d("span.ai-cfp").each(function(t){t=d(this).data("ai-block");var u=d(this);setTimeout(function(){u.closest("div[data-ai]").remove()},
# 50);ai_set_cookie(t,"x",p)}))}else ai_set_cookie(c,"c",g-1)}else if("cpt"==q)if(g=ai_cookie[c][q],0<g){if(ai_set_cookie(c,"cpt",g-1),1==g){g=d("span[data-ai-block="+f+"]").data("ai-cfp-time");e=new Date;e=Math.round(e.getTime()/1E3);var k=d(this);setTimeout(function(){k.closest("div[data-ai]").remove()},50);"undefined"!=typeof g&&(p=e+86400*g,ai_set_cookie(f,"x",p),d("span.ai-cfp").each(function(t){t=d(this).data("ai-block");var u=d(this);setTimeout(function(){u.closest("div[data-ai]").remove()},
# 50);ai_set_cookie(t,"x",p)}))}}else ai_check_data.hasOwnProperty(c)&&ai_check_data[c].hasOwnProperty("cpt")&&ai_check_data[c].hasOwnProperty("ct")?ai_cookie.hasOwnProperty(c)&&ai_cookie[c].hasOwnProperty("ct")&&(e=new Date,0>=ai_cookie[c].ct-Math.round(e.getTime()/1E3)&&(e=Math.round(e.getTime()/1E3),ai_set_cookie(c,"cpt",ai_check_data[c].cpt-1),ai_set_cookie(c,"ct",Math.round(e+86400*ai_check_data[c].ct)))):(ai_cookie.hasOwnProperty(c)&&ai_cookie[c].hasOwnProperty("cpt")&&ai_set_cookie(c,"cpt",""),
# ai_cookie.hasOwnProperty(c)&&ai_cookie[c].hasOwnProperty("ct")&&ai_set_cookie(c,"ct",""));x&&d.ajax({url:"/wp-admin/admin-ajax.php",type:"post",data:{action:"ai_ajax",ai_check:"149a449862",click:f,version:a,type:m},async:!0}).done(function(t){});if(B){var v=b[2],r=b[3];n("click",f,v,b[4],a,r,!1)}"function"==typeof ai_click_action&&ai_click_action(f,v,a,r)}}function w(){ai_check_data={};if("undefined"==typeof ai_iframe){ai_cookie=ai_load_cookie();d(".ai-check-block").each(function(){var a=
# d(this).data("ai-block"),c=d(this).data("ai-delay-pv"),q=d(this).data("ai-every-pv"),g=d(this).data("ai-hash"),e=d(this).data("ai-max-imp"),p=d(this).data("ai-limit-imp-per-time"),k=d(this).data("ai-limit-imp-time"),v=d(this).data("ai-max-clicks"),r=d(this).data("ai-limit-clicks-per-time"),t=d(this).data("ai-limit-clicks-time");if("undefined"!=typeof c&&0<c){ai_check_data.hasOwnProperty(a)||(ai_check_data[a]={});ai_check_data[a].d=c;var u="";ai_cookie.hasOwnProperty(a)&&ai_cookie[a].hasOwnProperty("d")&&
# (u=ai_cookie[a].d);""===u&&ai_set_cookie(a,"d",c-1)}"undefined"!=typeof q&&2<=q&&(ai_check_data.hasOwnProperty(a)||(ai_check_data[a]={}),"undefined"!==typeof ai_delay_showing_pageviews||ai_cookie.hasOwnProperty(a)&&ai_cookie[a].hasOwnProperty("d")||(ai_cookie.hasOwnProperty(a)||(ai_cookie[a]={}),ai_cookie[a].d=0),ai_check_data[a].e=q);if("undefined"!=typeof e&&0<e){if(ai_check_data.hasOwnProperty(a)||(ai_check_data[a]={}),ai_check_data[a].i=e,ai_check_data[a].h=g,q=c="",ai_cookie.hasOwnProperty(a)&&
# (ai_cookie[a].hasOwnProperty("i")&&(q=ai_cookie[a].i),ai_cookie[a].hasOwnProperty("h")&&(c=ai_cookie[a].h)),""===q||c!=g)ai_set_cookie(a,"i",e),ai_set_cookie(a,"h",g)}else ai_cookie.hasOwnProperty(a)&&ai_cookie[a].hasOwnProperty("i")&&(ai_set_cookie(a,"i",""),ai_cookie[a].hasOwnProperty("c")||ai_cookie[a].hasOwnProperty("x")||ai_set_cookie(a,"h",""));if("undefined"!=typeof p&&0<p&&"undefined"!=typeof k&&0<k){ai_check_data.hasOwnProperty(a)||(ai_check_data[a]={});ai_check_data[a].ipt=p;ai_check_data[a].it=
# k;e=c="";ai_cookie.hasOwnProperty(a)&&(ai_cookie[a].hasOwnProperty("ipt")&&(c=ai_cookie[a].ipt),ai_cookie[a].hasOwnProperty("it")&&(e=ai_cookie[a].it));if(""===c||""===e)ai_set_cookie(a,"ipt",p),c=new Date,c=Math.round(c.getTime()/1E3),ai_set_cookie(a,"it",Math.round(c+86400*k));0<e&&(c=new Date,c=Math.round(c.getTime()/1E3),e<=c&&(ai_set_cookie(a,"ipt",p),ai_set_cookie(a,"it",Math.round(c+86400*k))))}else ai_cookie.hasOwnProperty(a)&&(ai_cookie[a].hasOwnProperty("ipt")&&ai_set_cookie(a,"ipt",""),
# ai_cookie[a].hasOwnProperty("it")&&ai_set_cookie(a,"it",""));if("undefined"!=typeof v&&0<v){if(ai_check_data.hasOwnProperty(a)||(ai_check_data[a]={}),ai_check_data[a].c=v,ai_check_data[a].h=g,p=c="",ai_cookie.hasOwnProperty(a)&&(ai_cookie[a].hasOwnProperty("c")&&(p=ai_cookie[a].c),ai_cookie[a].hasOwnProperty("h")&&(c=ai_cookie[a].h)),""===p||c!=g)ai_set_cookie(a,"c",v),ai_set_cookie(a,"h",g)}else ai_cookie.hasOwnProperty(a)&&ai_cookie[a].hasOwnProperty("c")&&(ai_set_cookie(a,"c",""),ai_cookie[a].hasOwnProperty("i")||
# ai_cookie[a].hasOwnProperty("x")||ai_set_cookie(a,"h",""));if("undefined"!=typeof r&&0<r&&"undefined"!=typeof t&&0<t){ai_check_data.hasOwnProperty(a)||(ai_check_data[a]={});ai_check_data[a].cpt=r;ai_check_data[a].ct=t;g=v="";ai_cookie.hasOwnProperty(a)&&(ai_cookie[a].hasOwnProperty("cpt")&&(v=ai_cookie[a].cpt),ai_cookie[a].hasOwnProperty("ct")&&(g=ai_cookie[a].ct));if(""===v||""===g)ai_set_cookie(a,"cpt",r),c=new Date,c=Math.round(c.getTime()/1E3),ai_set_cookie(a,"ct",Math.round(c+86400*t));0<g&&
# (c=new Date,c=Math.round(c.getTime()/1E3),g<=c&&(ai_set_cookie(a,"cpt",r),ai_set_cookie(a,"ct",Math.round(c+86400*t))))}else ai_cookie.hasOwnProperty(a)&&(ai_cookie[a].hasOwnProperty("cpt")&&ai_set_cookie(a,"cpt",""),ai_cookie[a].hasOwnProperty("ct")&&ai_set_cookie(a,"ct",""))});for(var b in ai_cookie)for(var m in ai_cookie[b])if("d"==m){var f=ai_cookie[b][m];0<f?ai_set_cookie(b,"d",f-1):ai_check_data.hasOwnProperty(b)&&ai_check_data[b].hasOwnProperty("e")?ai_set_cookie(b,"d",ai_check_data[b].e-1):
# ai_check_data.hasOwnProperty(b)&&ai_check_data[b].hasOwnProperty("d")||ai_set_cookie(b,"d","")}}}function y(){if(D){var b=document.documentElement.clientWidth,m=window.innerWidth,f=b<m?m:b,a=0;d.each(E,function(q,g){if(f>=g)return a=F[q],!1});b=jQuery(b64d("Ym9keQ==")).attr(b64d ('ZGF0YS1kYXRhLW1hc2s='));if("string"===typeof b)var c=b==b64d("bWFzaw==");"string"===typeof b&&"boolean"===typeof c&&c&&(B&&n("ad blocking",0,G[a-1],0,0,"",!0),a|=128);x&&d.ajax({url:"/wp-admin/admin-ajax.php",type:"post",
# data:{action:"ai_ajax",ai_check:"149a449862",views:[0],versions:[a]},async:!0}).done(function(q){})}w();ai_tracking_finished=!0;ai_process_impressions()}var x=1,B=0,D=0,C=0,E=[980,768,0],F=[1,2,3],G=JSON.parse(b64d("WyJEZXNrdG9wIiwiVGFibGV0IiwiUGhvbmUiXQ=="));Number.isInteger=Number.isInteger||function(b){return"number"===typeof b&&isFinite(b)&&Math.floor(b)===b};ai_install_standard_click_trackers=function(b){"undefined"==
# typeof b&&(b=d("body"));b=d("div.ai-track[data-ai]:visible a",b);var m=d();b.each(function(){var f=d(this).find("div.ai-lazy"),a=d(this).find("div.ai-manual");0==f.length&&0==a.length&&(m=m.add(d(this)))});b=m;b.removeClass("ai-track");0!=b.length&&(C?b.click(function(){for(var f=d(this).closest("div[data-ai]");"undefined"!=typeof f.attr("data-ai");){var a=JSON.parse(b64d(f.attr("data-ai")));"undefined"!==typeof a&&a.constructor===Array&&Number.isInteger(a[1])&&!f.hasClass("clicked")&&(f.addClass("clicked"),
# l(a,"a.click"));f=f.parent().closest("div[data-ai]")}}):b.click(function(){for(var f=d(this).closest("div[data-ai]");"undefined"!=typeof f.attr("data-ai");){var a=JSON.parse(b64d(f.attr("data-ai")));"undefined"!==typeof a&&a.constructor===Array&&Number.isInteger(a[1])&&(l(a,"a.click"),clicked=!0);f=f.parent().closest("div[data-ai]")}}))};ai_install_click_trackers=function(b){"undefined"==typeof b&&(b=d("body"));if(C){var m=d("div.ai-track[data-ai]:visible, div.ai-rotate[data-info]:visible div.ai-track[data-ai]",
# b);"undefined"!=typeof d(b).attr("data-ai")&&d(b).hasClass("ai-track")&&d(b).is(":visible")&&(m=m.add(b));var f=d();m.each(function(){var a=d(this).find("div.ai-lazy"),c=d(this).find("div.ai-manual");0==a.length&&0==c.length&&(f=f.add(d(this)))});m=f;m.removeClass("ai-track");0!=m.length&&m.iframeTracker({blurCallback:function(){if(null!=this.ai_data&&null!=wrapper&&!wrapper.hasClass("clicked")){wrapper.addClass("clicked");l(this.ai_data,"blurCallback");for(var a=wrapper.find("div[data-ai]:visible");"undefined"!=
# typeof a.attr("data-ai");){var c=JSON.parse(b64d(a.attr("data-ai")));"undefined"!==typeof c&&c.constructor===Array&&Number.isInteger(c[1])&&l(c,"blurCallback INNER");a=a.find("div[data-ai]:visible")}}},overCallback:function(a){a=d(a).closest("div[data-ai]");if("undefined"!=typeof a.attr("data-ai")){var c=JSON.parse(b64d(a.attr("data-ai")));"undefined"!==typeof c&&c.constructor===Array&&Number.isInteger(c[1])?(wrapper=a,this.ai_data=c):(null!=wrapper&&wrapper.removeClass("clicked"),this.ai_data=wrapper=
# null)}},outCallback:function(a){null!=wrapper&&wrapper.removeClass("clicked");this.ai_data=wrapper=null},focusCallback:function(a){if(null!=this.ai_data&&null!=wrapper&&!wrapper.hasClass("clicked"))for(wrapper.addClass("clicked"),l(this.ai_data,"focusCallback"),a=wrapper.find("div[data-ai]:visible");"undefined"!=typeof a.attr("data-ai");){var c=JSON.parse(b64d(a.attr("data-ai")));"undefined"!==typeof c&&c.constructor===Array&&Number.isInteger(c[1])&&l(c,"focusCallback INNER");a=a.find("div[data-ai]:visible")}},
# wrapper:null,ai_data:null,block:null,version:null})}ai_install_standard_click_trackers(b)};ai_process_impressions=function(b){"undefined"==typeof b&&(b=d("body"));var m=[],f=[],a=[],c=[],q=[],g=d("div.ai-track[data-ai]:visible, div.ai-rotate[data-info]:visible div.ai-track[data-ai]",b);"undefined"!=typeof d(b).attr("data-ai")&&d(b).hasClass("ai-track")&&d(b).is(":visible")&&(g=g.add(b));0!=g.length&&d(g).each(function(){if("undefined"!=typeof d(this).attr("data-ai")){var k=JSON.parse(b64d(d(this).attr("data-ai")));
# if("undefined"!==typeof k&&k.constructor===Array){var v=0,r=d(this).find("div.ai-rotate[data-info]");1==r.length&&(v=JSON.parse(b64d(r.data("info")))[1]);if(Number.isInteger(k[0])&&0!=k[0]&&Number.isInteger(k[1])){r=0;var t=d(this).hasClass("ai-no-tracking"),u=jQuery(b64d("Ym9keQ==")).attr(b64d ('ZGF0YS1kYXRhLW1hc2s='));if("string"===typeof u)var A=u==b64d("bWFzaw==");if("string"===typeof u&&"boolean"===typeof A){var z=d(this).outerHeight();u=d(this).find(".ai-attributes");u.length&&u.each(function(){z>=d(this).outerHeight()&&
# (z-=d(this).outerHeight())});u=d(this).find(".ai-code");u.length&&(z=0,u.each(function(){z+=d(this).outerHeight()}));A&&0===z&&(r=128)}A=d(this).find("div.ai-lazy");u=d(this).find("div.ai-manual");if(0!=A.length||0!=u.length)t=!0;if(!t)if(0==v)m.push(k[0]),f.push(k[1]|r),a.push(k[2]),c.push(k[3]),q.push(k[4]);else for(t=1;t<=v;t++)m.push(k[0]),f.push(t|r),a.push(k[2]),c.push(k[3]),q.push(k[4])}}}});ai_cookie=ai_load_cookie();for(var e in ai_cookie)if(m.includes(parseInt(e)))for(var p in ai_cookie[e])"i"==
# p?(b=ai_cookie[e][p],0<b&&(1==b?(b=new Date,b=Math.round(b.getTime()/1E3)+604800,ai_set_cookie(e,"i",-b)):ai_set_cookie(e,"i",b-1))):"ipt"==p&&(b=ai_cookie[e][p],0<b?ai_set_cookie(e,"ipt",b-1):ai_check_data.hasOwnProperty(e)&&ai_check_data[e].hasOwnProperty("ipt")&&ai_check_data[e].hasOwnProperty("it")?ai_cookie.hasOwnProperty(e)&&ai_cookie[e].hasOwnProperty("it")&&(b=new Date,0>=ai_cookie[e].it-Math.round(b.getTime()/1E3)&&(b=Math.round(b.getTime()/1E3),ai_set_cookie(e,"ipt",ai_check_data[e].ipt),
# ai_set_cookie(e,"it",Math.round(b+86400*ai_check_data[e].it)))):(ai_cookie.hasOwnProperty(e)&&ai_cookie[e].hasOwnProperty("ipt")&&ai_set_cookie(e,"ipt",""),ai_cookie.hasOwnProperty(e)&&ai_cookie[e].hasOwnProperty("it")&&ai_set_cookie(e,"it","")));if(m.length&&(x&&d.ajax({url:"/wp-admin/admin-ajax.php",type:"post",data:{action:"ai_ajax",ai_check:"149a449862",views:m,versions:f},async:!0}).done(function(k){k=k.trim();if(""!=k&&(k=JSON.parse(k),"undefined"!=typeof k["#"])){var v=Math.round((new Date).getTime()/
# 1E3)+43200,r;for(r in k["#"])ai_cookie.hasOwnProperty(k["#"][r])&&ai_cookie[k["#"][r]].hasOwnProperty("x")||ai_set_cookie(k["#"][r],"x",v)}}),B))for(e=0;e<m.length;e++)n("impression",m[e],a[e],q[e],f[e],c[e],!0)};jQuery(window).on("load",function(){setTimeout(y,1200);setTimeout(ai_install_click_trackers,1300)})});
# ai_run_333202961538 = function(){
# ai_document_write=document.write;document.write=function(a){"interactive"==document.readyState?(console.error("document.write called after page load: ",a),"undefined"!=typeof ai_js_errors&&ai_js_errors.push(["document.write called after page load",a,0])):ai_document_write.call(document,a)};
# ai_insert ('after', 'div.post-meta', b64d ('...'));
# ai_insert ('after', 'div#wtr-content', b64d ('...'));
# };
# if (document.readyState === 'complete' || (document.readyState !== 'loading' && !document.documentElement.doScroll)) ai_run_333202961538 (); else document.addEventListener ('DOMContentLoaded', ai_run_333202961538);
# ai_js_code = true;
#
# </script><script type="text/javascript">
# 	jQuery(document).ready(function($) {
# 		var elem = $('#selectedFlag');
# 		var flagClass = 'flag-flaticon-sg';
#
# 		if (window.location.href.indexOf('thesmartlocal.my') > -1) {
# 			flagClass = 'flag-flaticon-my';
# 			document.getElementById('office_location').innerHTML = 'Malaysia Office';
# 			document.getElementById('office_address').innerHTML = 'Unit 43-8, The Boulevard Mid Valley City, Lingkaran Syed Putra, 59200 Kuala Lumpur';
# 			document.getElementById('office_phone_number').innerHTML = 'Tel: 03-4810 0599, 03-2202 2289';
# 		}
#
# 		if (window.location.href.indexOf('thesmartlocal.co.th') > -1 || window.location.href.indexOf('thailand.') > -1) {
# 			flagClass = 'flag-flaticon-th';
# 			document.getElementById('office_location').innerHTML = 'Thailand Office';
# 			document.getElementById('office_address').innerHTML = '30, Room No. 102, Soi Sukhumvit 61, Khlong Tan Nuea Subdistrict, Wattana District, Bangkok Bangkok, Thailand 10110';
# 			document.getElementById('office_phone_number').innerHTML = '';
# 		}
#
# 		if (window.location.href.indexOf('thesmartlocal.kr') > -1 || window.location.href.indexOf('korea.') > -1) {
# 			flagClass = 'flag-flaticon-kr';
# 			document.getElementById('office_location').innerHTML = 'Singapore Office';
# 			document.getElementById('office_address').innerHTML = '219 Kallang Bahru, #01-00 Chutex Building, Singapore 339348';
# 			document.getElementById('office_phone_number').innerHTML = 'Phone: 6514 0510';
# 		}
#
# 		if (window.location.href.indexOf('thesmartlocal.jp') > -1 || window.location.href.indexOf('japan.') > -1) {
# 			flagClass = 'flag-flaticon-jp';
# 			document.getElementById('office_location').innerHTML = 'Singapore Office';
# 			document.getElementById('office_address').innerHTML = '219 Kallang Bahru, #01-00 Chutex Building, Singapore 339348';
# 			document.getElementById('office_phone_number').innerHTML = 'Phone: 6514 0510';
# 		}
#
# 		if (window.location.href.indexOf('thesmartlocal.ph') > -1 || window.location.href.indexOf('philippines.') > -1) {
# 			flagClass = 'flag-flaticon-ph';
# 			document.getElementById('office_location').innerHTML = 'Singapore Office';
# 			document.getElementById('office_address').innerHTML = '219 Kallang Bahru, #01-00 Chutex Building, Singapore 339348';
# 			document.getElementById('office_phone_number').innerHTML = 'Phone: 6514 0510';
# 		}
#
# 		if (window.location.href.indexOf('thesmartlocal.id') > -1 || window.location.href.indexOf('indonesia.') > -1) {
# 			flagClass = 'flag-flaticon-id';
# 			document.getElementById('office_location').innerHTML = 'Singapore Office';
# 			document.getElementById('office_address').innerHTML = '219 Kallang Bahru, #01-00 Chutex Building, Singapore 339348';
# 			document.getElementById('office_phone_number').innerHTML = 'Phone: 6514 0510';
# 		}
#
# 		if (window.location.href.indexOf('.com/vietnam') > -1 || window.location.href.indexOf('vietnam.') > -1) {
# 			flagClass = 'flag-flaticon-vn';
# 			document.getElementById('office_location').innerHTML = 'Singapore Office';
# 			document.getElementById('office_address').innerHTML = '219 Kallang Bahru, #01-00 Chutex Building, Singapore 339348';
# 			document.getElementById('office_phone_number').innerHTML = 'Phone: 6514 0510';
# 		}
#
# 		elem.addClass(flagClass);
# 	});
# </script></body>
# </html>

# %% [markdown]
# Scraping all the activity names

# %%
listing = soup.find_all('h4')
listing
# Out:
# [<h4>1. Explore Mandai Wildlife Reserve</h4>,
#  <h4><b>2. See the S.E.A. Aquarium</b></h4>,
#  <h4>3. Visit the Museum of Ice Cream</h4>,
#  <h4>4. Swim at Wild Wild Wet</h4>,
#  <h4>5. Roller skate at Hi-Roller</h4>,
#  <h4>6. Play arcade games at Timezone Westgate</h4>,
#  <h4><b>7. Frolic around at Airzone (temporarily closed till Oct 2024)</b></h4>,
#  <h4>8. Learn new skills at NLB libraries</h4>,
#  <h4>9. Discover new playgrounds in Singapore</h4>,
#  <h4>10. Chill out at Snow City</h4>,
#  <h4>11. Tour the Jacob Ballas Children’s Garden</h4>,
#  <h4>12. Try fishing at Qian Hu Fish Farm</h4>,
#  <h4><b>13. Play with felines at The Cat Cafe</b></h4>,
#  <h4><b>14. Support the Kitten Sanctuary</b></h4>,
#  <h4>15. Relax in Singapore’s newest hotels</h4>,
#  <h4>16. Bungy jump at Skypark Sentosa by AJ Hackett</h4>,
#  <h4><b>17. Ride the Skyline Luge</b></h4>,
#  <h4><b>18. Spend a day at NERF Action Xperience (Closed)</b></h4>,
#  <h4><b>19. Retreat to Adventure HQ</b></h4>,
#  <h4>20. Go-kart at The Karting Arena</h4>,
#  <h4>21.  Cable-ski at Singapore Wake Park</h4>,
#  <h4><b>22. Throw axes at Axe Factor</b></h4>,
#  <h4>23. Golf virtually at Five Iron Golf</h4>,
#  <h4>24. Skydive indoors at iFly Singapore</h4>,
#  <h4>25. Jump around in trampoline parks</h4>,
#  <h4>26. Try bouldering or rock climbing</h4>,
#  <h4>27. Go bowling at K Bowling Club</h4>,
#  <h4><b>28. Ride coasters at Universal Studios Singapore</b></h4>,
#  <h4><b>29. Cycle on water at WaterbikeSG </b></h4>,
#  <h4><b>30.  Try extreme sports at Mega Adventure</b></h4>,
#  <h4>31. Play outdoor laser tag with GO Team</h4>,
#  <h4>32. Ice-skate at Kallang Ice World</h4>,
#  <h4>33. Mountain-bike across Singapore</h4>,
#  <h4>34. Snorkel at Adventure Cove Waterpark</h4>,
#  <h4>35. Scale and slide through Coastal PlayGrove</h4>,
#  <h4>36. Bike around Marina Bay</h4>,
#  <h4>37. Hang out at Skateparks</h4>,
#  <h4>38. Tackle a high elements course at Forest Adventure</h4>,
#  <h4>39. Have an overnight cycling trip</h4>,
#  <h4>40. Hop on a scenic bus ride around Singapore</h4>,
#  <h4><b>41. Watch movies at an outdoor cinema</b></h4>,
#  <h4><b>42. Make pottery at Thow Kwang Pottery Jungle</b></h4>,
#  <h4>43. Experience VR with Headrock VR</h4>,
#  <h4><b>44. Try the Boeing 737 Flight Experience</b></h4>,
#  <h4>45. Explore Pearl’s Hill Terrace</h4>,
#  <h4><b>46. Tour Tiger Brewery</b></h4>,
#  <h4><b>47. Watch films at The Projector</b></h4>,
#  <h4>48. Draw graffiti at Heaven Spot</h4>,
#  <h4><b>49.  Destress at The Fragment Room</b></h4>,
#  <h4><b>50. Hang out at board game cafes</b></h4>,
#  <h4><b>51. Navigate through an escape room</b></h4>,
#  <h4>52. Go prawning at FishBugis+</h4>,
#  <h4><b>53. Get competitive at Cow Play Cow Moo</b></h4>,
#  <h4><b>54. Attend an art jamming session</b></h4>,
#  <h4><b>55. Bathe in a Japanese-style onsen</b></h4>,
#  <h4><b>56. Book for a massage</b></h4>,
#  <h4><b>57. Visit ORTO </b></h4>,
#  <h4><b>58. Travel to Senoko or Jurong Fishery Port</b></h4>,
#  <h4><b>59. Stroll around Gardens by the Bay</b></h4>,
#  <h4><b>60. Drop by NTU’s Yunnan Garden</b></h4>,
#  <h4><b>61. See Little Guilin</b></h4>,
#  <h4><b>62. Tour urban farms in Singapore</b></h4>,
#  <h4>63. Island-hop between Lazarus, St John’s, &amp; Kusu Island</h4>,
#  <h4><b>64. Check out the Live Turtle &amp; Tortoise Museum</b></h4>,
#  <h4>65. Go fishing around Singapore</h4>,
#  <h4>66. Venture out to Changi Bay Point</h4>,
#  <h4><b>67. Birdwatch at Kranji Marshes</b></h4>,
#  <h4>68. Trek through Maju Forest</h4>,
#  <h4><b>69. Conquer the MacRitchie Treetop Walk</b></h4>,
#  <h4>70. Take a day trip to Pulau Ubin &amp; Chek Jawa Wetlands</h4>,
#  <h4><b>71. Have a romantic picnic</b></h4>,
#  <h4>72. Hike through Singapore’s parks &amp; nature reserves</h4>,
#  <h4>73. Unwind at Sembawang Hot Spring Park</h4>,
#  <h4>74. Explore Jurong Lake Gardens</h4>,
#  <h4>75. See “Avatar Trees” at Bukit Brown Cemetery</h4>,
#  <h4><b>76. Walk through Sungei Buloh Wetland Reserve</b></h4>,
#  <h4>77. Bike or hike through the Park Connector Network</h4>,
#  <h4>78. Visit the Tropical Montane Orchidetum</h4>,
#  <h4><b>79. Have a brunch date at a cafe</b></h4>,
#  <h4><b>80. Have a seaside meal while yacht-viewing</b></h4>,
#  <h4><b>81. Dine amidst nature at Lucky Saigon Cafe</b></h4>,
#  <h4>82. Travel to Smith Marine Floating Restaurant</h4>,
#  <h4>83. Dine at Soul Coffee</h4>,
#  <h4>84. Order a drink at Platform 1094 cafe</h4>,
#  <h4>85. Visit unique food courts in Singapore</h4>,
#  <h4><b>86. Take your dog to a dog-friendly cafe</b></h4>,
#  <h4>87. Go on a pub crawl</h4>,
#  <h4>88. Enjoy a foodie &amp; heritage walk in Geylang</h4>,
#  <h4>89. Catch free music &amp; art shows at the Esplanade</h4>,
#  <h4>90. Check out the Vintage Camera Museum</h4>,
#  <h4><b>91. Walk through the Japanese Cemetery Park</b></h4>,
#  <h4><b>92. Visit the Science Centre</b></h4>,
#  <h4><b>93. Go museum-hopping</b></h4>,
#  <h4>94. Visit the Civil Defence Heritage Gallery</h4>,
#  <h4><b>95. Tour The Intan</b></h4>,
#  <h4><b>96. Check out the Singapore Art Museum</b></h4>,
#  <h4>97. Go on a Fort Serapong tour</h4>,
#  <h4>98. Visit the Buddha Tooth Relic Temple</h4>,
#  <h4>99. Explore Kampong Lorong Buangkok</h4>,
#  <h4>100. Revisit St James Power Station</h4>,
#  <h4><b>101. Explore Haw Par Villa</b></h4>,
#  <h4><b>102</b>. Visit the ArtScience Museum</h4>,
#  <h4>103. Trawl Kampong Gelam</h4>,
#  <h4>104. Browse the grand Rotunda Library &amp; Archive</h4>,
#  <h4><b>105. Visit the Trick Eye Museum</b></h4>,
#  <h4><b>106. Tour the Singapore City Gallery</b></h4>,
#  <h4>107. Spend time at the Indian Heritage Centre</h4>,
#  <h4>108. Join the Kebun Baru Birdsinging Club</h4>,
#  <h4><b>109. Stop by Gillman Barracks</b></h4>,
#  <h4><b>110. See lighthouses in Singapore</b></h4>,
#  <h4>111. Admire Jewel Changi’s Rain Vortex</h4>,
#  <h4><b>112. Revisit old-school playgrounds</b></h4>,
#  <h4><b>113. Go on Apple Photo Walks</b></h4>,
#  <h4>114. Have a photoshoot at selfie studios</h4>,
#  <h4>115. Head up to ION Sky</h4>,
#  <h4><b>116. Have a date at Wings of Time</b></h4>,
#  <h4>117. Check out CapitaSpring</h4>,
#  <h4><b>118. Ride on the SkyHelix</b></h4>,
#  <h4><b>119. Watch the sunset at Yishun Dam</b></h4>,
#  <h4><b>120. Visit rooftop gardens around Singapore</b></h4>,
#  <h4>121. Go shopping in Little India</h4>,
#  <h4><b>122. Read at Woods in the Books</b></h4>,
#  <h4><b>123. Go thrifting at Turf Club Road’s Antique Row</b></h4>,
#  <h4><b>124. Shop around at Cat Socrates</b></h4>,
#  <h4>125. Revisit People’s Park Centre</h4>,
#  <h4>126. Discover T for Toys$1</h4>,
#  <h4><b>127. Browse through comic book stores</b></h4>,
#  <h4>128. Shop at Don Don Donki</h4>,
#  <h4><b>129. Stroll through Bugis Street</b></h4>,
#  <h4>130. Wine, dine, and shop at Dempsey Hill</h4>,
#  <h4><b>Things to do in Singapore</b></h4>]

# %%
ls1 =[]
for item in listing:
    ls1.append(item)
ls1
# Out:
# [<h4>1. Explore Mandai Wildlife Reserve</h4>,
#  <h4><b>2. See the S.E.A. Aquarium</b></h4>,
#  <h4>3. Visit the Museum of Ice Cream</h4>,
#  <h4>4. Swim at Wild Wild Wet</h4>,
#  <h4>5. Roller skate at Hi-Roller</h4>,
#  <h4>6. Play arcade games at Timezone Westgate</h4>,
#  <h4><b>7. Frolic around at Airzone (temporarily closed till Oct 2024)</b></h4>,
#  <h4>8. Learn new skills at NLB libraries</h4>,
#  <h4>9. Discover new playgrounds in Singapore</h4>,
#  <h4>10. Chill out at Snow City</h4>,
#  <h4>11. Tour the Jacob Ballas Children’s Garden</h4>,
#  <h4>12. Try fishing at Qian Hu Fish Farm</h4>,
#  <h4><b>13. Play with felines at The Cat Cafe</b></h4>,
#  <h4><b>14. Support the Kitten Sanctuary</b></h4>,
#  <h4>15. Relax in Singapore’s newest hotels</h4>,
#  <h4>16. Bungy jump at Skypark Sentosa by AJ Hackett</h4>,
#  <h4><b>17. Ride the Skyline Luge</b></h4>,
#  <h4><b>18. Spend a day at NERF Action Xperience (Closed)</b></h4>,
#  <h4><b>19. Retreat to Adventure HQ</b></h4>,
#  <h4>20. Go-kart at The Karting Arena</h4>,
#  <h4>21.  Cable-ski at Singapore Wake Park</h4>,
#  <h4><b>22. Throw axes at Axe Factor</b></h4>,
#  <h4>23. Golf virtually at Five Iron Golf</h4>,
#  <h4>24. Skydive indoors at iFly Singapore</h4>,
#  <h4>25. Jump around in trampoline parks</h4>,
#  <h4>26. Try bouldering or rock climbing</h4>,
#  <h4>27. Go bowling at K Bowling Club</h4>,
#  <h4><b>28. Ride coasters at Universal Studios Singapore</b></h4>,
#  <h4><b>29. Cycle on water at WaterbikeSG </b></h4>,
#  <h4><b>30.  Try extreme sports at Mega Adventure</b></h4>,
#  <h4>31. Play outdoor laser tag with GO Team</h4>,
#  <h4>32. Ice-skate at Kallang Ice World</h4>,
#  <h4>33. Mountain-bike across Singapore</h4>,
#  <h4>34. Snorkel at Adventure Cove Waterpark</h4>,
#  <h4>35. Scale and slide through Coastal PlayGrove</h4>,
#  <h4>36. Bike around Marina Bay</h4>,
#  <h4>37. Hang out at Skateparks</h4>,
#  <h4>38. Tackle a high elements course at Forest Adventure</h4>,
#  <h4>39. Have an overnight cycling trip</h4>,
#  <h4>40. Hop on a scenic bus ride around Singapore</h4>,
#  <h4><b>41. Watch movies at an outdoor cinema</b></h4>,
#  <h4><b>42. Make pottery at Thow Kwang Pottery Jungle</b></h4>,
#  <h4>43. Experience VR with Headrock VR</h4>,
#  <h4><b>44. Try the Boeing 737 Flight Experience</b></h4>,
#  <h4>45. Explore Pearl’s Hill Terrace</h4>,
#  <h4><b>46. Tour Tiger Brewery</b></h4>,
#  <h4><b>47. Watch films at The Projector</b></h4>,
#  <h4>48. Draw graffiti at Heaven Spot</h4>,
#  <h4><b>49.  Destress at The Fragment Room</b></h4>,
#  <h4><b>50. Hang out at board game cafes</b></h4>,
#  <h4><b>51. Navigate through an escape room</b></h4>,
#  <h4>52. Go prawning at FishBugis+</h4>,
#  <h4><b>53. Get competitive at Cow Play Cow Moo</b></h4>,
#  <h4><b>54. Attend an art jamming session</b></h4>,
#  <h4><b>55. Bathe in a Japanese-style onsen</b></h4>,
#  <h4><b>56. Book for a massage</b></h4>,
#  <h4><b>57. Visit ORTO </b></h4>,
#  <h4><b>58. Travel to Senoko or Jurong Fishery Port</b></h4>,
#  <h4><b>59. Stroll around Gardens by the Bay</b></h4>,
#  <h4><b>60. Drop by NTU’s Yunnan Garden</b></h4>,
#  <h4><b>61. See Little Guilin</b></h4>,
#  <h4><b>62. Tour urban farms in Singapore</b></h4>,
#  <h4>63. Island-hop between Lazarus, St John’s, &amp; Kusu Island</h4>,
#  <h4><b>64. Check out the Live Turtle &amp; Tortoise Museum</b></h4>,
#  <h4>65. Go fishing around Singapore</h4>,
#  <h4>66. Venture out to Changi Bay Point</h4>,
#  <h4><b>67. Birdwatch at Kranji Marshes</b></h4>,
#  <h4>68. Trek through Maju Forest</h4>,
#  <h4><b>69. Conquer the MacRitchie Treetop Walk</b></h4>,
#  <h4>70. Take a day trip to Pulau Ubin &amp; Chek Jawa Wetlands</h4>,
#  <h4><b>71. Have a romantic picnic</b></h4>,
#  <h4>72. Hike through Singapore’s parks &amp; nature reserves</h4>,
#  <h4>73. Unwind at Sembawang Hot Spring Park</h4>,
#  <h4>74. Explore Jurong Lake Gardens</h4>,
#  <h4>75. See “Avatar Trees” at Bukit Brown Cemetery</h4>,
#  <h4><b>76. Walk through Sungei Buloh Wetland Reserve</b></h4>,
#  <h4>77. Bike or hike through the Park Connector Network</h4>,
#  <h4>78. Visit the Tropical Montane Orchidetum</h4>,
#  <h4><b>79. Have a brunch date at a cafe</b></h4>,
#  <h4><b>80. Have a seaside meal while yacht-viewing</b></h4>,
#  <h4><b>81. Dine amidst nature at Lucky Saigon Cafe</b></h4>,
#  <h4>82. Travel to Smith Marine Floating Restaurant</h4>,
#  <h4>83. Dine at Soul Coffee</h4>,
#  <h4>84. Order a drink at Platform 1094 cafe</h4>,
#  <h4>85. Visit unique food courts in Singapore</h4>,
#  <h4><b>86. Take your dog to a dog-friendly cafe</b></h4>,
#  <h4>87. Go on a pub crawl</h4>,
#  <h4>88. Enjoy a foodie &amp; heritage walk in Geylang</h4>,
#  <h4>89. Catch free music &amp; art shows at the Esplanade</h4>,
#  <h4>90. Check out the Vintage Camera Museum</h4>,
#  <h4><b>91. Walk through the Japanese Cemetery Park</b></h4>,
#  <h4><b>92. Visit the Science Centre</b></h4>,
#  <h4><b>93. Go museum-hopping</b></h4>,
#  <h4>94. Visit the Civil Defence Heritage Gallery</h4>,
#  <h4><b>95. Tour The Intan</b></h4>,
#  <h4><b>96. Check out the Singapore Art Museum</b></h4>,
#  <h4>97. Go on a Fort Serapong tour</h4>,
#  <h4>98. Visit the Buddha Tooth Relic Temple</h4>,
#  <h4>99. Explore Kampong Lorong Buangkok</h4>,
#  <h4>100. Revisit St James Power Station</h4>,
#  <h4><b>101. Explore Haw Par Villa</b></h4>,
#  <h4><b>102</b>. Visit the ArtScience Museum</h4>,
#  <h4>103. Trawl Kampong Gelam</h4>,
#  <h4>104. Browse the grand Rotunda Library &amp; Archive</h4>,
#  <h4><b>105. Visit the Trick Eye Museum</b></h4>,
#  <h4><b>106. Tour the Singapore City Gallery</b></h4>,
#  <h4>107. Spend time at the Indian Heritage Centre</h4>,
#  <h4>108. Join the Kebun Baru Birdsinging Club</h4>,
#  <h4><b>109. Stop by Gillman Barracks</b></h4>,
#  <h4><b>110. See lighthouses in Singapore</b></h4>,
#  <h4>111. Admire Jewel Changi’s Rain Vortex</h4>,
#  <h4><b>112. Revisit old-school playgrounds</b></h4>,
#  <h4><b>113. Go on Apple Photo Walks</b></h4>,
#  <h4>114. Have a photoshoot at selfie studios</h4>,
#  <h4>115. Head up to ION Sky</h4>,
#  <h4><b>116. Have a date at Wings of Time</b></h4>,
#  <h4>117. Check out CapitaSpring</h4>,
#  <h4><b>118. Ride on the SkyHelix</b></h4>,
#  <h4><b>119. Watch the sunset at Yishun Dam</b></h4>,
#  <h4><b>120. Visit rooftop gardens around Singapore</b></h4>,
#  <h4>121. Go shopping in Little India</h4>,
#  <h4><b>122. Read at Woods in the Books</b></h4>,
#  <h4><b>123. Go thrifting at Turf Club Road’s Antique Row</b></h4>,
#  <h4><b>124. Shop around at Cat Socrates</b></h4>,
#  <h4>125. Revisit People’s Park Centre</h4>,
#  <h4>126. Discover T for Toys$1</h4>,
#  <h4><b>127. Browse through comic book stores</b></h4>,
#  <h4>128. Shop at Don Don Donki</h4>,
#  <h4><b>129. Stroll through Bugis Street</b></h4>,
#  <h4>130. Wine, dine, and shop at Dempsey Hill</h4>,
#  <h4><b>Things to do in Singapore</b></h4>]

# %% [markdown]
# Removing tags from name

# %%
def remove_html_tags(tag_obj):
    return tag_obj.get_text()
cleaned_text_list = [remove_html_tags(tag_obj) for tag_obj in ls1]

cleaned_text_list
# Out:
# ['1. Explore Mandai Wildlife Reserve',
#  '2. See the S.E.A. Aquarium',
#  '3. Visit the Museum of Ice Cream',
#  '4. Swim at Wild Wild Wet',
#  '5. Roller skate at Hi-Roller',
#  '6. Play arcade games at Timezone Westgate',
#  '7. Frolic around at Airzone (temporarily closed till Oct 2024)',
#  '8. Learn new skills at NLB libraries',
#  '9. Discover new playgrounds in Singapore',
#  '10. Chill out at Snow City',
#  '11. Tour the Jacob Ballas Children’s Garden',
#  '12. Try fishing at\xa0Qian Hu Fish Farm',
#  '13. Play with felines at The Cat Cafe',
#  '14. Support the Kitten Sanctuary',
#  '15. Relax in Singapore’s newest hotels',
#  '16. Bungy jump at Skypark Sentosa by AJ Hackett',
#  '17. Ride the Skyline Luge',
#  '18. Spend a day at NERF Action Xperience (Closed)',
#  '19. Retreat to Adventure HQ',
#  '20. Go-kart at The Karting Arena',
#  '21.\xa0 Cable-ski at Singapore Wake Park',
#  '22. Throw axes at Axe Factor',
#  '23. Golf virtually at Five Iron Golf',
#  '24. Skydive indoors at iFly Singapore',
#  '25. Jump around in trampoline parks',
#  '26. Try bouldering or rock climbing',
#  '27. Go bowling at K Bowling Club',
#  '28. Ride coasters at Universal Studios Singapore',
#  '29. Cycle on water at WaterbikeSG ',
#  '30. \xa0Try extreme sports at Mega Adventure',
#  '31. Play outdoor laser tag with GO Team',
#  '32. Ice-skate at Kallang Ice World',
#  '33. Mountain-bike across Singapore',
#  '34. Snorkel at Adventure Cove Waterpark',
#  '35. Scale and slide through Coastal PlayGrove',
#  '36. Bike around Marina Bay',
#  '37. Hang out at Skateparks',
#  '38. Tackle a high elements course at Forest Adventure',
#  '39. Have an overnight cycling trip',
#  '40. Hop on a scenic bus ride around Singapore',
#  '41. Watch movies at an outdoor cinema',
#  '42. Make pottery at Thow Kwang Pottery Jungle',
#  '43. Experience VR with Headrock VR',
#  '44. Try the Boeing 737 Flight Experience',
#  '45. Explore Pearl’s Hill Terrace',
#  '46. Tour Tiger Brewery',
#  '47. Watch films at The Projector',
#  '48. Draw graffiti at Heaven Spot',
#  '49.\xa0 Destress at The Fragment Room',
#  '50. Hang out at board game cafes',
#  '51. Navigate through an escape room',
#  '52. Go prawning at FishBugis+',
#  '53. Get competitive at Cow Play Cow Moo',
#  '54. Attend an art jamming session',
#  '55. Bathe in a Japanese-style onsen',
#  '56. Book for a massage',
#  '57. Visit ORTO\xa0',
#  '58. Travel to Senoko or Jurong Fishery Port',
#  '59. Stroll around Gardens by the Bay',
#  '60. Drop by NTU’s Yunnan Garden',
#  '61. See Little Guilin',
#  '62. Tour urban farms in Singapore',
#  '63. Island-hop between Lazarus, St John’s, & Kusu Island',
#  '64. Check out the Live Turtle & Tortoise Museum',
#  '65. Go fishing around Singapore',
#  '66. Venture out to Changi Bay Point',
#  '67. Birdwatch at Kranji Marshes',
#  '68. Trek through Maju Forest',
#  '69. Conquer the MacRitchie Treetop Walk',
#  '70. Take a day trip to Pulau Ubin & Chek Jawa Wetlands',
#  '71. Have a romantic picnic',
#  '72. Hike through Singapore’s parks & nature reserves',
#  '73. Unwind at Sembawang Hot Spring Park',
#  '74. Explore Jurong Lake Gardens',
#  '75. See “Avatar Trees” at Bukit Brown Cemetery',
#  '76. Walk through Sungei Buloh Wetland Reserve',
#  '77. Bike or hike through the Park Connector Network',
#  '78. Visit the Tropical Montane Orchidetum',
#  '79. Have a brunch date at a cafe',
#  '80. Have a seaside meal while yacht-viewing',
#  '81. Dine amidst nature at Lucky Saigon Cafe',
#  '82. Travel to Smith Marine Floating Restaurant',
#  '83. Dine at Soul Coffee',
#  '84. Order a drink at Platform 1094 cafe',
#  '85. Visit unique food courts in Singapore',
#  '86. Take your dog to a dog-friendly cafe',
#  '87. Go on a pub crawl',
#  '88. Enjoy a foodie & heritage walk in Geylang',
#  '89. Catch free music & art shows at the Esplanade',
#  '90. Check out the Vintage Camera Museum',
#  '91. Walk through the Japanese Cemetery Park',
#  '92. Visit the Science Centre',
#  '93. Go museum-hopping',
#  '94. Visit the Civil Defence Heritage Gallery',
#  '95. Tour The Intan',
#  '96. Check out the Singapore Art Museum',
#  '97. Go on a Fort Serapong tour',
#  '98. Visit the Buddha Tooth Relic Temple',
#  '99. Explore Kampong Lorong Buangkok',
#  '100. Revisit St James Power Station',
#  '101. Explore Haw Par Villa',
#  '102. Visit the ArtScience Museum',
#  '103. Trawl Kampong Gelam',
#  '104. Browse the grand Rotunda Library & Archive',
#  '105. Visit the Trick Eye Museum',
#  '106. Tour the Singapore City Gallery',
#  '107. Spend time at the Indian Heritage Centre',
#  '108. Join the Kebun Baru Birdsinging Club',
#  '109. Stop by Gillman Barracks',
#  '110. See lighthouses in Singapore',
#  '111. Admire Jewel Changi’s Rain Vortex',
#  '112. Revisit old-school playgrounds',
#  '113. Go on Apple Photo Walks',
#  '114. Have a photoshoot at selfie studios',
#  '115. Head up to ION Sky',
#  '116. Have a date at Wings of Time',
#  '117. Check out CapitaSpring',
#  '118. Ride on the SkyHelix',
#  '119. Watch the sunset at Yishun Dam',
#  '120. Visit rooftop gardens around Singapore',
#  '121. Go shopping in Little India',
#  '122. Read at Woods in the Books',
#  '123. Go thrifting at Turf Club Road’s Antique Row',
#  '124. Shop around at Cat Socrates',
#  '125. Revisit\xa0People’s Park Centre',
#  '126. Discover T for Toys$1',
#  '127. Browse through comic book stores',
#  '128. Shop at Don Don Donki',
#  '129. Stroll through Bugis Street',
#  '130. Wine, dine, and shop at Dempsey Hill',
#  'Things to do in Singapore']

# %% [markdown]
# Removing heading which is not an activity

# %%
cleaned_text_list.pop(-1)
# Out:
# 'Things to do in Singapore'

# %%
cleaned_text_list
# Out:
# ['1. Explore Mandai Wildlife Reserve',
#  '2. See the S.E.A. Aquarium',
#  '3. Visit the Museum of Ice Cream',
#  '4. Swim at Wild Wild Wet',
#  '5. Roller skate at Hi-Roller',
#  '6. Play arcade games at Timezone Westgate',
#  '7. Frolic around at Airzone (temporarily closed till Oct 2024)',
#  '8. Learn new skills at NLB libraries',
#  '9. Discover new playgrounds in Singapore',
#  '10. Chill out at Snow City',
#  '11. Tour the Jacob Ballas Children’s Garden',
#  '12. Try fishing at\xa0Qian Hu Fish Farm',
#  '13. Play with felines at The Cat Cafe',
#  '14. Support the Kitten Sanctuary',
#  '15. Relax in Singapore’s newest hotels',
#  '16. Bungy jump at Skypark Sentosa by AJ Hackett',
#  '17. Ride the Skyline Luge',
#  '18. Spend a day at NERF Action Xperience (Closed)',
#  '19. Retreat to Adventure HQ',
#  '20. Go-kart at The Karting Arena',
#  '21.\xa0 Cable-ski at Singapore Wake Park',
#  '22. Throw axes at Axe Factor',
#  '23. Golf virtually at Five Iron Golf',
#  '24. Skydive indoors at iFly Singapore',
#  '25. Jump around in trampoline parks',
#  '26. Try bouldering or rock climbing',
#  '27. Go bowling at K Bowling Club',
#  '28. Ride coasters at Universal Studios Singapore',
#  '29. Cycle on water at WaterbikeSG ',
#  '30. \xa0Try extreme sports at Mega Adventure',
#  '31. Play outdoor laser tag with GO Team',
#  '32. Ice-skate at Kallang Ice World',
#  '33. Mountain-bike across Singapore',
#  '34. Snorkel at Adventure Cove Waterpark',
#  '35. Scale and slide through Coastal PlayGrove',
#  '36. Bike around Marina Bay',
#  '37. Hang out at Skateparks',
#  '38. Tackle a high elements course at Forest Adventure',
#  '39. Have an overnight cycling trip',
#  '40. Hop on a scenic bus ride around Singapore',
#  '41. Watch movies at an outdoor cinema',
#  '42. Make pottery at Thow Kwang Pottery Jungle',
#  '43. Experience VR with Headrock VR',
#  '44. Try the Boeing 737 Flight Experience',
#  '45. Explore Pearl’s Hill Terrace',
#  '46. Tour Tiger Brewery',
#  '47. Watch films at The Projector',
#  '48. Draw graffiti at Heaven Spot',
#  '49.\xa0 Destress at The Fragment Room',
#  '50. Hang out at board game cafes',
#  '51. Navigate through an escape room',
#  '52. Go prawning at FishBugis+',
#  '53. Get competitive at Cow Play Cow Moo',
#  '54. Attend an art jamming session',
#  '55. Bathe in a Japanese-style onsen',
#  '56. Book for a massage',
#  '57. Visit ORTO\xa0',
#  '58. Travel to Senoko or Jurong Fishery Port',
#  '59. Stroll around Gardens by the Bay',
#  '60. Drop by NTU’s Yunnan Garden',
#  '61. See Little Guilin',
#  '62. Tour urban farms in Singapore',
#  '63. Island-hop between Lazarus, St John’s, & Kusu Island',
#  '64. Check out the Live Turtle & Tortoise Museum',
#  '65. Go fishing around Singapore',
#  '66. Venture out to Changi Bay Point',
#  '67. Birdwatch at Kranji Marshes',
#  '68. Trek through Maju Forest',
#  '69. Conquer the MacRitchie Treetop Walk',
#  '70. Take a day trip to Pulau Ubin & Chek Jawa Wetlands',
#  '71. Have a romantic picnic',
#  '72. Hike through Singapore’s parks & nature reserves',
#  '73. Unwind at Sembawang Hot Spring Park',
#  '74. Explore Jurong Lake Gardens',
#  '75. See “Avatar Trees” at Bukit Brown Cemetery',
#  '76. Walk through Sungei Buloh Wetland Reserve',
#  '77. Bike or hike through the Park Connector Network',
#  '78. Visit the Tropical Montane Orchidetum',
#  '79. Have a brunch date at a cafe',
#  '80. Have a seaside meal while yacht-viewing',
#  '81. Dine amidst nature at Lucky Saigon Cafe',
#  '82. Travel to Smith Marine Floating Restaurant',
#  '83. Dine at Soul Coffee',
#  '84. Order a drink at Platform 1094 cafe',
#  '85. Visit unique food courts in Singapore',
#  '86. Take your dog to a dog-friendly cafe',
#  '87. Go on a pub crawl',
#  '88. Enjoy a foodie & heritage walk in Geylang',
#  '89. Catch free music & art shows at the Esplanade',
#  '90. Check out the Vintage Camera Museum',
#  '91. Walk through the Japanese Cemetery Park',
#  '92. Visit the Science Centre',
#  '93. Go museum-hopping',
#  '94. Visit the Civil Defence Heritage Gallery',
#  '95. Tour The Intan',
#  '96. Check out the Singapore Art Museum',
#  '97. Go on a Fort Serapong tour',
#  '98. Visit the Buddha Tooth Relic Temple',
#  '99. Explore Kampong Lorong Buangkok',
#  '100. Revisit St James Power Station',
#  '101. Explore Haw Par Villa',
#  '102. Visit the ArtScience Museum',
#  '103. Trawl Kampong Gelam',
#  '104. Browse the grand Rotunda Library & Archive',
#  '105. Visit the Trick Eye Museum',
#  '106. Tour the Singapore City Gallery',
#  '107. Spend time at the Indian Heritage Centre',
#  '108. Join the Kebun Baru Birdsinging Club',
#  '109. Stop by Gillman Barracks',
#  '110. See lighthouses in Singapore',
#  '111. Admire Jewel Changi’s Rain Vortex',
#  '112. Revisit old-school playgrounds',
#  '113. Go on Apple Photo Walks',
#  '114. Have a photoshoot at selfie studios',
#  '115. Head up to ION Sky',
#  '116. Have a date at Wings of Time',
#  '117. Check out CapitaSpring',
#  '118. Ride on the SkyHelix',
#  '119. Watch the sunset at Yishun Dam',
#  '120. Visit rooftop gardens around Singapore',
#  '121. Go shopping in Little India',
#  '122. Read at Woods in the Books',
#  '123. Go thrifting at Turf Club Road’s Antique Row',
#  '124. Shop around at Cat Socrates',
#  '125. Revisit\xa0People’s Park Centre',
#  '126. Discover T for Toys$1',
#  '127. Browse through comic book stores',
#  '128. Shop at Don Don Donki',
#  '129. Stroll through Bugis Street',
#  '130. Wine, dine, and shop at Dempsey Hill']

# %% [markdown]
# Scraping of details of each activity

# %%
h4_tags = soup.find_all('h4')
ls2 = []
for h4_tag in h4_tags:
    # Find all <p> tags before the <hr> tag
    prev_p_tags = h4_tag.find_all_previous('p')
    if prev_p_tags:
        closest_p_tag = prev_p_tags[0]  # Get the closest preceding <p> tag
        if closest_p_tag not in ls2:
            ls2.append(closest_p_tag)
ls2

# %%
len(ls2)
# Out:
# 131

# %%
ls2
# Out:
# [<p>From seeing wildlife animals and birds at the zoo to roller skating and arcade games, there are plenty of fun activities in Singapore to do with the fam.</p>,
#  <p><strong><span style="color: #d47978">Contact:</span> </strong>6269 3411<br/>
#  <strong><span style="color: #d47978">Address:</span></strong> 80 Mandai Lake Road, Singapore 729826<br/>
#  <strong><span style="color: #d47978">Opening hours:</span></strong><br/>
#  <strong>Singapore Zoo:</strong> 8.30am-6pm, Daily (Last entry at 5pm)<br/>
#  <strong>River Wonders:</strong> 10am-7pm, Daily (Last entry at 6pm)<br/>
#  <strong>Night Safari:</strong> 7.15pm-12am, Daily (Last entry at 11.15pm)<br/>
#  <strong>Bird Paradise:</strong> 9am-6pm, Daily (Last entry at 5pm)</p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>8 Sentosa Gateway, Sentosa Island, Singapore 098269<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>10am-5pm, Daily</p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">100 Loewen Road, Singapore 248837</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Opening hours: </b></span><span style="font-weight: 400">Mon &amp; Wed 10am-6pm | Thu-Sun 10am-9pm (Closed on Tuesdays)<br/>
#  </span></p>,
#  <p><strong><span style="color: #d47978">Address:</span></strong> 1 Pasir Ris Close, Downtown East, Singapore 519599<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Mon &amp; Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Closed on Tuesdays)<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>6581 9128</p>,
#  <p><span style="color: #d47978"><b>Address: </b></span>1 Pasir Ris Close, E!Hub, Market Square @ Downtown East, #05-103, Singapore 519599<span style="color: #d47978"><b><br/>
#  Opening hours: </b></span>Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 11am-10pm<span style="color: #d47978"><b><br/>
#  Contact: </b></span>9694 4094</p>,
#  <p><span style="color: #d47978"><b>Address</b><span style="font-weight: 400">:</span></span><span style="font-weight: 400"> 3 Gateway Drive, Westgate #B1-45, Singapore 608532<br/>
#  </span><span style="color: #d47978"><b>Opening hours</b><span style="font-weight: 400">:</span></span><span style="font-weight: 400"> Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-11pm | Sun 10am-10pm<br/>
#  </span><span style="color: #d47978"><b>Contact</b><span style="font-weight: 400">:</span></span><span style="font-weight: 400"> 6265 1132</span></p>,
#  <p><em>*Airzone is temporarily closed for renovation works.</em></p>,
#  <p><span style="font-weight: 400"> </span></p>,
#  <p><strong>Book a session at <a href="https://www.klook.com/en-SG/activity/62263-kidodo-indoor-playground-admission-singapore/?aid=27405" rel="noopener" target="_blank">Kidodo Indoor Playground</a>.</strong></p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>21 Jurong Town Hall Road, Singapore 609433<br/>
#  <strong><span style="color: #d47978">Opening hours:</span></strong> Tue-Fri 10am-5pm | Sat-Sun &amp; PH 10am-6pm<br/>
#  <strong><span style="color: #d47978">Contact:</span></strong> 6560 2306</p>,
#  <p><strong><span style="color: #d47978">Address: </span></strong>481 Bukit Timah Road, Singapore 259769<br/>
#  <strong><span style="color: #d47978">Opening hours:</span></strong><br/>
#  <strong>Jacob Ballas Children’s Garden:</strong> Tue-Sun 8am-7pm (Closed on Mondays, except PHs)<br/>
#  <strong>Singapore Botanic Gardens:</strong> 5am-12am, Daily<br/>
#  <strong><span style="color: #d47978">Contact:</span></strong> 1800 471 7300</p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>No. 71 Jalan Lekar, Singapore 698950<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Mon-Fri 9am-6pm | Sat-Sun 9am-7pm<br/>
#  <strong><span style="color: #d47978">Contact:</span></strong> 6766 1554</p>,
#  <p><span style="text-decoration: underline"><strong>The Cat Cafe</strong></span><br/>
#  <strong><span style="color: #d47978">Address:</span></strong> 241B Victoria Street, Singapore 188030<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Mon 3pm-10pm | Tue-Fri 10am-9pm | Sat-Sun 10am-10pm<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>6338 6815</p>,
#  <p><span style="color: #d47978"><b><span style="color: #000000">Kitten Sanctuary Singapore</span><br/>
#  Address: </b><span style="color: #000000">737A North Bridge Road, Singapore 198705</span><b><br/>
#  Opening hours: </b><span style="color: #000000">Sat-Sun 10.30am-11.30am, 12pm-1pm, 2,30pm-3.30pm, 4pm-5pm | Tue 11am-12pm, 7pm-8pm | Fri 11am-12pm (Closed on Mondays)</span><b><br/>
#  Contact: </b><span style="color: #000000">9126 7379<br/>
#  </span><b><br/>
#  <span style="color: #000000">The Cat Museum &amp; Academy</span><br/>
#  Address: </b><span style="color: #000000">781A North Bridge Road, #02-01, Singapore 198749</span><b><br/>
#  Opening hours: </b><span style="color: #000000">Sat-Sun 11.30am-12.30pm, 5pm-6pm (Closed from Mondays to Fridays)</span><b><br/>
#  Contact: </b><span style="color: #000000">6336 2133</span></span></p>,
#  <p>Whether you’re a thrill seeker searching for their next adrenaline rush or a tired adult who likes to throw axes to relieve stress, there’s sure to be something for you at these fun outdoor places in Singapore.</p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 30 Siloso Beach Walk, Singapore 099011<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Mon-Fri 12.30pm-7pm | Sat–Sun 11.30pm-7pm </span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Contact:</b></span><span style="font-weight: 400"> 6911 3070 </span></p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">45 Siloso Beach Walk, Sentosa, Singapore 099003<br/>
#  </span><span style="color: #d47978"><b>Opening hours: </b></span><span style="font-weight: 400">Mon-Thu 11am-7.30pm | Fri 11am-9pm | Sat 10am-9pm | Sun 10am-7.30pm<br/>
#  </span><b></b><span style="color: #d47978"><b>Contact: </b></span><span style="font-weight: 400">6274 0472  </span></p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 6 Raffles Boulevard, Marina Square #01-208, Singapore 039594</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> 12pm-8pm, Daily</span></p>,
#  <p><span style="color: #d47978"><b>Address:</b></span> <span style="font-weight: 400">2 Yishun Walk, HomeTeamNS Khatib, Singapore 767944<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Tue 2pm-5.30pm | Wed-Fri 2pm-5.30pm and 6pm-9.30pm | Sat-Sun, School Holidays &amp; PH 10am-1.30pm, 2pm-5.30pm, and 6pm-9.30pm (Closed on Mondays)<br/>
#  <span style="color: #d47978"><strong>Contact:</strong> </span>6705 9420</span></p>,
#  <p><span style="text-decoration: underline"><strong>Bukit Timah outlet:</strong></span><br/>
#  <strong><span style="color: #d47978">Address:</span></strong> 200 Turf Club Road, The Grandstand #01-01B, South Car Park, Singapore 287994<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Wed-Fri 1pm-8.30pm | Sat-Sun 10am-9pm | Closed Mon-Tue<br/>
#  <strong><br/>
#  <span style="text-decoration: underline">Jurong outlet:</span></strong><br/>
#  <strong><span style="color: #d47978">Address:</span></strong> 511 Upper Jurong Road, Block B, Singapore 638366<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Tue-Fri 1pm-9pm | Sat-Sun 9am-9pm (Closed on Mondays)</p>,
#  <p><b><span style="color: #d47978">Address:</span> </b><span style="font-weight: 400">1206A East Coast Parkway, Singapore 449891<br/>
#  </span><span style="color: #d47978"><b>Opening hours: </b></span><span style="font-weight: 400">10am-8pm, Daily | Sat-Sun 9am-8pm<br/>
#  </span><span style="color: #d47978"><b>Contact: </b></span><span style="font-weight: 400">6636 4266</span></p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 200 Turf Club Road, The Grandstand #01-32A/B &amp; #01-34A/B, Singapore 287994<br/>
#  </span><span style="color: #d47978"><b>Opening hours: </b></span><span style="font-weight: 400">Tue-Sun 12pm-10pm (Closed on Mondays)<br/>
#  </span><span style="color: #d47978"><b>Contact:</b></span><span style="font-weight: 400"> 8923 8945</span></p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">139 Cecil Street, #13-01, Singapore 069539<br/>
#  </span><span style="color: #d47978"><b>Opening hours: </b></span><span style="font-weight: 400">Mon-Sat 7am-12am | Sun 7am-8pm<br/>
#  </span><span style="color: #d47978"><b>Contact: </b></span><span style="font-weight: 400">6993 4131</span></p>,
#  <p><strong><span style="color: #d47978">Address:</span></strong> 43 Siloso Beach Walk, #01-01, Singapore 099010<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Thu-Tue &amp; PH 9am-10pm | Wed 11am-10pm<br/>
#  <span style="color: #d47978"><strong>Contact:</strong> </span>6571 0000</p>,
#  <p><a href="https://thesmartlocal.com/read/jumprrocks-kinex/"><strong>Jumprrocks at Kinex</strong></a> offers free daily games in its Battle Groundz area at fixed timings, ideal for newbies to try trampolining out, and regular admissions discounts.<br/>
#  <strong><br/>
#  Book a session at <a href="https://www.klook.com/en-SG/activity/69335-jumprrocks-indoor-playground-kinex-singapore/?aid=27405" rel="noopener" target="_blank">Jumprrocks at Kinex</a>.</strong></p>,
#  <p>Apart from the standard rock walls, there are places with AR and Tetris-like walls for a bigger challenge.</p>,
#  <p><strong><span style="color: #d47978">Address:</span></strong> 313 Orchard Road, 313@Somerset #03-27, Singapore 238895<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>10am-1am, Daily<br/>
#  <strong><span style="color: #d47978">Contact:</span></strong> 6737 5313</p>,
#  <p><span style="color: #d47978"><strong>Address:</strong></span> 8 Sentosa Gateway, Singapore 098269<br/>
#  <span style="color: #d47978"><strong>Opening hours:</strong> </span>Refer to <a href="https://www.rwsentosa.com/en/attractions/universal-studios-singapore" rel="noopener" target="_blank">Universal Studios Singapore’s calendar</a> for more information<br/>
#  <strong><span style="color: #d47978">Contact:</span></strong> 6577 8888</p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>Campsite 1 at Pasir Ris Park, near Carpark F, 133 Pasir Ris Road, Singapore 519149<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Sat-Sun 9am-6pm, by appointment (Closed from Mondays to Fridays)<br/>
#  <strong><span style="color: #d47978">Contact:</span></strong> 9871 8007</p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>10A Siloso Beach Walk, Singapore 099008<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Mon-Fri 2pm-6pm | Sat-Sun &amp; PH 11am-6pm<br/>
#  <span style="color: #d47978"><strong>Contact:</strong> </span>6722 3785</p>,
#  <p><span style="color: #d47978"><strong>Contact:</strong> </span>9003 1177</p>,
#  <p><span style="text-decoration: underline"><strong>Kallang Ice World</strong></span><br/>
#  <strong><span style="color: #d47978">Address:</span> </strong>5 Stadium Walk, Kallang Leisure Park #03-08/09, Singapore 397693<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Sun-Thu 10am-10pm | Fri-Sat &amp; Eve of PH 10am-12am | PH 9am-10pm<br/>
#  <strong><span style="color: #d47978">Contact: </span></strong>6348 1347</p>,
#  <p><a href="https://www.klook.com/en-SG/activity/67260-mountain-bicycle-rental-gobike-singapore?aid=27405" rel="noopener" target="_blank"><strong>Rent a mountain bike in Singapore</strong></a><strong>.</strong></p>,
#  <p><span style="color: #d47978"><strong>Address:</strong></span> 8 Sentosa Gateway, Singapore 098269<br/>
#  <span style="color: #d47978"><strong>Opening hours:</strong> </span>Fri-Tue 10am-5pm (Closed Wed-Thu)</p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 902 East Coast Park Service Road, Singapore 449874<br/>
#  </span><span style="color: #d47978"><b>Opening hours: </b></span><span style="font-weight: 400">Tue-Sun 8am-8pm (Closed on Mondays)</span></p>,
#  <p><strong><span style="color: #d47978">Opening hours:</span></strong> Various hours; view all <a href="https://gocycling.sg/singapore/" rel="noopener" target="_blank">GoCycling opening hours</a><br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>8831 3068</p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>Yuan Ching Road, Jurong Lake Gardens<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Tue-Sun 8am-10pm (Closed on Mondays)</p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">Bedok Reservoir Park, Singapore 478931</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Mon-Fri 9.30am-6pm | Sat-Sun &amp; PH 9.30am-6.30pm<br/>
#  <span style="color: #d47978"><strong>Contact:</strong> </span>6206 9744</span></p>,
#  <p>If you’re planning a chill weekend with your friends, here are some activities that you can consider ranging from scenic road trips and pottery classes to getting rid of those sore muscles at Japanese onsen spas and massages.</p>,
#  <p>And if you just want a short break from the city, hop on bus 975 with your headphones and enjoy a restful bus ride down the Lim Chu Kang heritage road – it’ll even give you a glimpse of a sea view at the road’s northern end.</p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>2 Keppel Bay Vista, Singapore 098382<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Selected nights, 7.45pm – end of screening<br/>
#  <span style="color: #d47978"><strong>Contact:</strong> </span>info@cinewav.com</p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">85 Lorong Tawas, Singapore 639823</span><span style="font-weight: 400"><br/>
#  </span><b><span style="color: #d47978">Opening hours:</span> <span style="font-weight: 400">9am-5pm, Daily<br/>
#  <strong><span style="color: #d47978">Contact: </span></strong>6265 5808 | 8949 0168 (WhatsApp)</span></b></p>,
#  <p><strong>Book a session at <a href="https://click.linksynergy.com/link?id=kDzDXBtcEDo&amp;offerid=1001098.19551477842&amp;type=2&amp;murl=https%3A%2F%2Ffeverup.com%2Fm%2F97691" rel="noopener" target="_blank">HeadRock VR Theme Park Sentosa</a>.<br/>
#  </strong><br/>
#  <span style="color: #d47978"><b>Address: </b></span>80 Siloso Road, Block #01-03, Singapore 098969<br/>
#  <span style="color: #d47978"><strong>Opening hours:</strong> </span>Mon-Fri 12pm-7pm | Sat-Sun &amp; PH 11am-7pm (last admission 6pm)<br/>
#  <span style="color: #d47978"><strong>Contact:</strong> </span>6963 4127</p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>30 Raffles Avenue, Singapore Flyer #02-06, Singapore 039803<br/>
#  <strong><span style="color: #d47978">Contact:</span></strong> 6339 2737</p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 195 Pearl’s Hill Terrace, Singapore 168976</span></p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">459 Jalan Ahmad Ibrahim, Singapore 639934<br/>
#  </span><span style="color: #d47978"><b>Tour schedule: <span style="font-weight: 400;color: #000000">Fri-Sun 1pm-6.30pm (Excluding eves of PH and PH, last tours at 5pm)</span></b></span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Telephone: </b></span><span style="font-weight: 400">6860 3005</span></p>,
#  <p>There’s also a bar from which you can bring snacks and drinks into the screening halls, art and theatre spaces, and a ballroom for live events.<br/>
#  <span style="color: #d47978"><b><br/>
#  Address:</b></span><span style="font-weight: 400"> The Cathay, 2 Handy Rd, #05-01, Singapore 229233<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b><span style="font-weight: 400"> </span></span></p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>3 Lorong Bakar Batu, #03-01, Singapore 348741<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Tue-Thu 2pm-9pm | Fri-Sun 10am-9pm (Closed on Mondays)<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>8268 3160</p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>490 MacPherson Road, Singapore 368198<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>12am-10pm, Daily<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>6970 0343</p>,
#  <p>And with many open past midnight, you can play on through the night with boozy sustenance too.</p>,
#  <p><strong>Book a session at <a href="https://www.klook.com/en-SG/activity/59645-trapped-escape-room-singapore/?aid=27405" rel="noopener" target="_blank">Trapped Escape Room</a> and <a href="https://www.klook.com/en-SG/activity/34798-vr-escape-room-adventure-virtual/?aid=27405" rel="noopener" target="_blank">VR Escape Room</a>.</strong></p>,
#  <p><strong><span style="color: #d47978">Address:</span></strong> Bugis+, 201 Victoria Street, #07-05, Singapore 188067<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>9am-6am, Daily<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>9008 0201 | 83386530 (WhatsApp)</p>,
#  <p><span style="font-weight: 400">Also read our articles about <a href="https://thesmartlocal.com/read/arcade-game-hacks/">arcade game hacks</a> and <a href="https://thesmartlocal.com/read/90s-arcade-games/">nostalgic arcade games in Singapore.</a></span></p>,
#  <p><strong>Book an <a href="https://www.klook.com/en-SG/activity/47088-art-jamming-drinks-diy-experience-313somerset/?aid=27405" rel="noopener" target="_blank">art jamming session</a>.</strong></p>,
#  <p>There are private ones such as <strong>Elements Wellness</strong>, as well as communal ones such as <strong><a href="https://thesmartlocal.com/read/yunomori-onsen/">Yunomori Onsen &amp; Spa</a></strong> which gives you that true blue butt-naked experience.<br/>
#  <span style="font-weight: 400"><br/>
#  <strong>Book a visit to <a href="https://www.klook.com/en-SG/activity/45050-elements-wellness-spa-experience-singapore/?aid=27405" rel="noopener" target="_blank">Elements Wellness</a>.</strong></span></p>,
#  <p>In case you’re wondering, no, these aren’t the sleazy sort – there are quite a few wholesome spas that open till the wee hours, some even 24 hours a day. A few of these even come with added perks such as buffets and free movies.</p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 81 Lorong Chencharu, #01-01, Singapore 769198<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> 24 hours, Daily (individual establishments’ opening hours apply)<br/>
#  <span style="color: #d47978"><strong>Contact:</strong> </span>6257 8858</span></p>,
#  <p><b><span style="text-decoration: underline">Senoko Fishery Port</span><br/>
#  </b><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 31 Attap Valley Road, #02-29, Singapore 759908<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Tue-Sun 2am-6am (Closed on Mondays)<br/>
#  </span><span style="color: #d47978"><b>Contact:</b></span><span style="font-weight: 400"> 6257 6721</span></p>,
#  <p>This is your reminder to go outside and touch grass. Plan a romantic picnic date with the bae at one of the many parks in Singapore or immerse yourself in nature by trekking through Maju Forest.</p>,
#  <p><span style="color: #d47978"><b>Address:</b></span> 12 Nanyang Drive, Singapore 637721<br/>
#  <span style="color: #d47978"><b>Opening hours: </b></span>24 hours, Daily<br/>
#  <span style="color: #d47978"><b>Contact: </b></span> 6791 1744</p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> Along Bukit Batok East Avenue 5<br/>
#  </span><span style="color: #d47978"><b>Getting there:</b></span><span style="font-weight: 400"> Walk about 8 minutes from Bukit Gombak MRT station, or take Bus 945 to Bukit Gombak Stadium</span></p>,
#  <p>Some of them offer tours with explanations and demonstrations on what the farming process is like.</p>,
#  <p><span style="font-weight: 400">Also read our articles about islands in Singapore such as </span><a href="https://thesmartlocal.com/read/pulau-hantu/"><span style="font-weight: 400">Pulau Hantu</span></a><span style="font-weight: 400">, t</span><span style="font-weight: 400">he </span><a href="https://thesmartlocal.com/read/pulau-tekong/"><span style="font-weight: 400">history behind Pulau Tekong</span></a><span style="font-weight: 400">, and </span><a href="https://thesmartlocal.com/read/hidden-singapore-islands/"><span style="font-weight: 400">hidden Singapore islands.</span></a></p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 81 Lorong Chencharu, #01-16, <span style="color: #000000">Singapore</span> 769198</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Opening hours: <span style="font-weight: 400;color: #000000">Wed-Mon 10am-6pm (Closed on Tuesdays)</span></b></span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Contact:</b></span><span style="font-weight: 400"> 6268 5363</span></p>,
#  <p><strong>Book a <a href="https://www.klook.com/en-SG/activity/79056-purehybridz-kayak-fishing-mangrove-tour-singapore/?aid=27405" rel="noopener" target="_blank">guided kayak fishing tour in Singapore</a>.</strong></p>,
#  <p><b><span style="color: #d47978">Address:</span> </b><span style="font-weight: 400">Aviation Park Road</span></p>,
#  <p>Board the Kranji Farms Shuttle service to the Kranji Marshes, Sungei Buloh, and other Kranji farm attractions from Kranji MRT, and bring along a pair of binoculars to spot your next rare bird.</p>,
#  <p>Also read our article on <a href="https://thesmartlocal.com/read/hiking-trails-singapore/">hiking trails in Singapore</a>.</p>,
#  <p><strong><span style="color: #d47978">Opening hours:</span></strong> 7am-7pm, Daily</p>,
#  <p><strong>Make a<a href="https://www.klook.com/en-SG/activity/51175-pulau-ubin-bike-rental/?aid=27405" rel="noopener" target="_blank"> Pulau Ubin bike rental</a> and book an <a href="https://www.klook.com/en-SG/activity/46436-5-hour-join-round-ketam-kayaking-adventure-pulau-ubin-singapore/?aid=27405" rel="noopener" target="_blank">Ubin kayaking trip at Round Ketam Kayaking Adventure</a>.</strong></p>,
#  <p>A less bustling environment means it’s going to be all the more romantic! Some places to visit include Toa Payoh Town Park and Telok Blangah Hill Park, which is full of vibrant pink bougainvillaea blooms.</p>,
#  <p>Read our article on <a href="https://thesmartlocal.com/read/hiking-guide/">hiking for beginners</a> and check out our other hiking-related articles, covering topics from <a href="https://thesmartlocal.com/read/lost-ark-hiking-guide/">hiking to the “Lost Ark” in Alexandra</a> to <a href="https://thesmartlocal.com/read/kid-friendly-hiking-trails-singapore/">kid-friendly hiking trails in Singapore</a>.</p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>Along Gambas Avenue, Singapore 756952</p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>104 Yuan Ching Road, Singapore 618665<br/>
#  <span style="font-weight: 400"><strong><span style="color: #d47978">Opening hours:</span> </strong>24 hours, Daily</span></p>,
#  <p><strong>Or book a <a href="https://www.klook.com/en-SG/activity/52079-cemetery-excursion-bukit-brown-tour/?aid=27405">guided tour of Bukit Brown Cemetery</a>.</strong></p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 301 Neo Tiew Crescent, Singapore 718925<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> 7am-7pm, Daily (last entry at 6.30pm)<br/>
#  </span><span style="font-weight: 400"><strong><span style="color: #d47978">Contact:</span></strong> 6794 1401</span></p>,
#  <p>Check out <a href="https://thesmartlocal.com/read/bicycle-rental-singapore/">bike rental services in Singapore</a> that’ll help you cycle up a storm.</p>,
#  <p>If you’re a foodie on the lookout for their next new meal to review, then check out these restaurants and cafes in Singapore.</p>,
#  <p><i><span style="font-weight: 400"><img alt="" class="alignnone size-full wp-image-308341" decoding="async" height="667" loading="lazy" sizes="(max-width: 1000px) 100vw, 1000px" src="https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore.png" srcset="https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore.png 1000w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-300x200.png 300w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-150x100.png 150w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-768x512.png 768w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-690x460.png 690w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-750x500.png 750w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-310x207.png 310w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-400x267.png 400w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-210x140.png 210w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-90x60.png 90w, https://thesmartlocal.com/wp-content/uploads/2023/10/things-to-do-in-Singapore-480x320.png 480w" width="1000"/><br/>
#  </span></i><em><span style="font-weight: 400">Image adapted from: @mighty.explorers, @eatingwitheating via Instagram<br/>
#  </span></em><span style="font-weight: 400"><br/>
#  A brunch date is the one thing that’s hard to go wrong with whenever we’re planning a day out with bae. To switch things up, choose a cafe based on either your or your SO’s favourite colour from the many <a href="https://thesmartlocal.com/read/colour-themed-cafes-singapore/"><strong>colour-themed cafes in Singapore</strong></a>. On top of yummy cafe grub, you’ll be promised cool aesthetics that deserve a spot in your IG feeds.</span><span style="font-weight: 400"><br/>
#  </span><span style="font-weight: 400"><br/>
#  Some names to bookmark right off the bat: Smile Dessert for its blue and white ball pit; and Fraser Street Brothers for its vibrant rainbow theme.</span></p>,
#  <p>Both are date-worthy settings, so save them for a special occasion or when you need to impress!</p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 356 Tanglin Road, Singapore 247674<br/>
#  </span><span style="color: #d47978"><b>Opening hours: </b></span><span style="font-weight: 400">8am-10pm, Daily<br/>
#  </span><span style="color: #d47978"><b>Contact:</b></span><span style="font-weight: 400"> 6556 8228</span></p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 01’23’52″N – 103’57’42″E<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> 10am-7pm, Daily (Closed on alternate Mondays)<br/>
#  </span><span style="color: #d47978"><b>Contact:</b></span><span style="font-weight: 400"> 9792 7609 (WhatsApp/SMS for reservations)</span></p>,
#  <p><b><span style="color: #d47978">Address:</span> </b><span style="font-weight: 400">11 Tanjong Katong Road, Kinex Mall</span> <span style="font-weight: 400">#02-16, Singapore 437157<br/>
#  </span><b><span style="color: #d47978">Opening hours:</span> </b><span style="font-weight: 400">11am-10pm, Daily<br/>
#  </span><span style="color: #d47978"><b>Contact: </b></span><span style="font-weight: 400">9876 7257</span></p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 1094 Serangoon Road, Singapore 328192<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Tue-Sun 11am-10pm (Closed on Mondays)<br/>
#  </span><span style="color: #d47978"><b>Contact: </b></span><span style="font-weight: 400">6204 6003</span></p>,
#  <p><span style="text-decoration: underline"><strong>Great World Food Junction outlet:</strong></span><br/>
#  <strong><span style="color: #d47978">Address:</span> </strong>1 Kim Seng Promenade, #03-116 Great World, Singapore 237994<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>10am-10pm, Daily</p>,
#  <p>Check out our other dog-related articles about <a href="https://thesmartlocal.com/read/dog-training-hacks/">dog training hacks</a>, the <a href="https://thesmartlocal.com/read/cost-of-owning-a-dog/">cost of owning a dog in Singapore</a>, <a href="https://thesmartlocal.com/read/dog-runs">free dog runs in Singapore</a> and tips on <a href="https://thesmartlocal.com/read/dog-diet-tips/">improving your dog’s diet</a>.</p>,
#  <p><strong>Book a <a href="https://www.klook.com/en-SG/activity/3901-pub-crawl-singapore/?aid=27405" rel="noopener" target="_blank">pub crawling tour in Singapore</a>.</strong></p>,
#  <p>From educational and cultural museums on Singapore’s history to art and themed galleries around specific niches, there’s a variety of museums for you to explore.</p>,
#  <p><strong><span style="color: #d47978">Address: </span></strong>1 Esplanade Drive, Singapore 038981</p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">8C-8D Jalan Kledek, Singapore 199263</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> 11am-7pm, Daily</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Contact: </b></span><span style="font-weight: 400">6291 2278</span></p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>825B Chuan Hoe Avenue, Singapore 549854<br/>
#  <span style="color: #d47978"><strong>Opening hours:</strong> </span>7am-7pm, Daily<br/>
#  <span style="color: #d47978"><strong>Contact:</strong></span> 6468 0066 (The Japanese Association, Singapore)</p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 15 Science Centre Road, Singapore 609081<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Tue-Sun 10am-5pm (last entry 4.15pm) (Closed Mondays except for public holidays and school holidays)<br/>
#  </span><span style="color: #d47978"><b>Contact:</b></span><span style="font-weight: 400"> 6425 2500</span></p>,
#  <p><span style="font-weight: 400">Find more </span><a href="https://thesmartlocal.com/read/art-exhibits-museums-singapore/"><span style="font-weight: 400">free art exhibits and museums</span></a><span style="font-weight: 400"> in Singapore.<br/>
#  </span></p>,
#  <p><span style="color: #d47978"><b><span style="font-weight: 400"><strong>Admission: </strong><span style="color: #000000">Free</span></span><br/>
#  Address:</b></span><span style="font-weight: 400"> 62 Hill Street, Singapore 179367<br/>
#  </span><span style="color: #d47978"><b>Contact: </b></span><span style="font-weight: 400">6332 2996<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Tue-Sun 10am-5pm (Closed on Mondays)</span></p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">69 Joo Chiat Terrace, Singapore 427231</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> By appointment only</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Contact: </b></span><span style="font-weight: 400">6440 1148</span></p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">39 Keppel Road, Tanjong Pagar Distripark, #01-02, Singapore 089065<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> 10am-7pm, Daily</span></p>,
#  <p><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">54 Lakeshore View, Singapore 09844</span></p>,
#  <p>Read our article on <a href="https://thesmartlocal.com/read/things-to-do-in-chinatown/">lesser-known things to do in Chinatown</a>.</p>,
#  <p><strong>Book a <a href="https://www.klook.com/en-SG/activity/50316-kampong-experience-tour/?aid=27405" rel="noopener" target="_blank">guided tour of Kampong Lorong Buangkok</a>.</strong></p>,
#  <p><strong><span style="color: #d47978">Admission:</span> </strong>Free<br/>
#  <strong><span style="color: #d47978">Address:</span> </strong>3 Sentosa Gateway, Singapore 098544<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Tue-Sun 10am-6pm (Closed on Mondays)</p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>262 Pasir Panjang Road, Singapore 118 628<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Sun-Thu 9am-8pm | Fri-Sat 9am-10pm<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>6773 0103</p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>6 Bayfront Avenue, Singapore 018974<br/>
#  <span style="color: #d47978"><strong>Opening hours:</strong></span> 10am-7pm, Daily<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>6688 8888</p>,
#  <p><strong>Book a <a href="https://www.klook.com/en-SG/activity/51562-kampong-glam-history-tour/?aid=27405" rel="noopener" target="_blank">guided tour of Singapore’s Kampong Gelam</a>.</strong></p>,
#  <p><span style="color: #d47978"><b>Address: </b><span style="color: #000000">National Gallery Singapore,</span> </span><span style="font-weight: 400">1 St Andrew’s Road, Supreme Court Wing Level 3, Singapore 178957</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Mon-Fri 10am-12.30pm &amp; 2pm-5pm (Closed on Sat-Sun &amp; PHs)</span><span style="font-weight: 400"><br/>
#  </span><span style="font-weight: 400"><strong><span style="color: #d47978">Contact:</span> </strong> 6697 9180 </span></p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>80 Siloso Road, Southside Interim Market, Block D #01-04, Singapore 098969<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>11am-7pm, Daily<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>6795 2371<em><span style="font-weight: 400"> </span></em></p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>45 Maxwell Road, Level 1, The URA Centre, Singapore 069118<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Mon-Sat 9am-5pm (Closed on Sundays &amp; PH)</p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>5 Campbell Lane, Singapore 209924<br/>
#  <strong><span style="color: #d47978">Opening hours:</span></strong> Tue-Sun 10am-6pm (Closed on Mondays)<br/>
#  <strong><span style="color: #d47978">Contact:</span></strong> 6291 1601</p>,
#  <p><strong><span style="color: #d47978">Address:</span></strong> Block 159 Ang Mo Kio Ave 5, Singapore 560159<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Sat-Sun &amp; PH 9.30am-12pm</p>,
#  <p>Strike a pose for the gram at these scenic and aesthetic places in Singapore.</p>,
#  <p><span style="font-weight: 400">While some of them are inaccessible or require special permission to enter, there are easy-to-reach options such as </span><a href="https://thesmartlocal.com/read/raffles-marina-lighthouse/"><b>Raffles Marina Lighthouse </b></a><span style="font-weight: 400">and </span><a href="https://thesmartlocal.com/read/fullerton-lighthouse/"><b>Fullerton Lighthouse</b></a><span style="font-weight: 400">. The former is a popular spot for wedding photography and the sunsets there are amazing, while the decommissioned Fullerton Lighthouse now lives on as a vintage landmark near Harbourfront Tower 1.</span><b></b></p>,
#  <p>Read our articles on <a href="https://thesmartlocal.com/read/jewel-changi/">food, shopping, and play zones at Jewel Changi</a>, <a href="https://thesmartlocal.com/read/jewel-changi-attractions/">Jewel Changi Canopy Park attractions and Changi Experience Studio</a>, and <a href="https://thesmartlocal.com/read/jewel-changi-photography/">Jewel Changi’s photo spots</a>.</p>,
#  <p>Our <strong><a href="https://thesmartlocal.com/read/old-school-playgrounds">old-school playgrounds</a></strong> are truly icons of our country, and now that they’re such rare finds, these nostalgia-inducing structures from a simpler time are all the more precious. You already know the classic <a href="https://wiki.sg/p/Dragon_Playground_(Toa_Payoh_Lorong_6)#Existing_dragon_playgrounds" rel="noopener" target="_blank">dragon playgrounds</a> – only 4 of which are left today – but there are a couple other gems such as clock- and dove-shaped ones.<span style="font-weight: 400"><br/>
#  </span></p>,
#  <p>Best of all, it’s free. All you need to bring is your iPhone – or don’t; the latest iPhones will be loaned to you for you to snap away with.</p>,
#  <p><span style="text-decoration: underline"><strong>123ChiCha Selfie Studio</strong></span><br/>
#  <strong><span style="color: #d47978">Address:</span> </strong>110 Lorong 23 Geylang, Victory Center #03-07, Singapore 388410<br/>
#  <strong><span style="color: #d47978">Opening hours:</span></strong> 10am-5pm, Daily<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>9029 4733</p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>2 Orchard Turn, ION Orchard Mall Level 56, Singapore 238801<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Tue-Thu 4pm-8pm | Fri-Sat 2-9pm (Closed Sundays &amp; Mondays)<br/>
#  <span style="font-weight: 400"><strong><span style="color: #d47978">Contact:</span> </strong>6238 8228</span></p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>Near Beach Station, 50 Beach View, Singapore 098604<br/>
#  <strong><span style="color: #d47978">Performance timings:</span></strong> 7.40pm and 8.40pm, Daily<br/>
#  <span style="font-weight: 400"><strong><span style="color: #d47978">Contact:</span></strong> 6361 0088 (Singapore Cable Car ticketing counter)</span></p>,
#  <p><strong><span style="color: #d47978">Address:</span></strong> 88 Market Street, Singapore 048948<br/>
#  <strong><span style="color: #d47978">Contact:</span></strong> 6713 3948</p>,
#  <p>If you’ve got the stomach for it, there’s also a snack bar where you can purchase light bites such as fruit bowls and pastries. Take your grub on the ride with you for a mid-air munch.<br/>
#  <strong><br/>
#  Book a session at <a href="https://fever.pxf.io/c/3631867/1396783/16345?prodsku=110169&amp;u=https%3A%2F%2Ffeverup.com%2Fm%2F110169&amp;intsrc=PUI2_10347" rel="noopener" target="_blank">SkyHelix Sentosa</a>.<br/>
#  </strong><br/>
#  <strong><span style="color: #d47978">Address:</span></strong> 41 Imbiah Road, Sentosa, Singapore 099707<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>10am-9.30pm, Daily<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>6361 0088</p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> Yishun Avenue 1, Singapore 769130</span></p>,
#  <p>Whether you’re a comic book collector, a bundle thrift hunter, or a casual window shopper, there’s no shortage of options when it comes to shopping in Singapore.</p>,
#  <p><strong>Book a <a href="https://www.klook.com/en-SG/activity/59287-singapore-spice-life-little-india?aid=27405" rel="noopener" target="_blank">Little India walking tour</a>.</strong></p>,
#  <p><span style="color: #d47978"><b>Address:</b></span><span style="font-weight: 400"> 3 Yong Siak Street, Singapore 168642<br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Wed-Sat 10am-7pm | Sun-Mon 10am-6pm (Closed on Tuesdays)<br/>
#  </span><span style="color: #d47978"><b>Contact:</b></span><span style="font-weight: 400"> 6222 9980<br/>
#  </span></p>,
#  <p><span style="font-weight: 400">Find out more about what you can do at </span><a href="https://thesmartlocal.com/read/turf-club-road/" rel="noopener noreferrer" target="_blank"><span style="font-weight: 400">Turf Club Road</span></a><span style="font-weight: 400"> and read our articles on antique and vintage furniture and knick-knacks: from </span><a href="https://thesmartlocal.com/read/80s-knicks-knacks/" rel="noopener noreferrer" target="_blank"><span style="font-weight: 400">stores with 80s collectibles in Singapore</span></a><span style="font-weight: 400"> to </span><a href="https://thesmartlocal.com/read/secondhand-furniture/" rel="noopener noreferrer" target="_blank">secondhand furniture stores in Singapore with refurbished vintage and antique items</a> to <a href="https://thesmartlocal.com/read/second-hand-furniture/" rel="noopener noreferrer" target="_blank"><span style="font-weight: 400">undiscovered secondhand furniture stores in Singapore</span></a><span style="font-weight: 400">.</span></p>,
#  <p><b><span style="text-decoration: underline">Joo Chiat outlet</span><br/>
#  </b><span style="color: #d47978"><b>Address: </b></span><span style="font-weight: 400">448 Joo Chiat Road, Singapore 427661</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Opening hours:</b></span><span style="font-weight: 400"> Mon 11am-6pm | Tue-Sat 11am-8pm | Sun &amp; PH 11am-7pm</span><span style="font-weight: 400"><br/>
#  </span><span style="color: #d47978"><b>Contact:</b></span><span style="font-weight: 400"> 6348 0863</span></p>,
#  <p><span style="color: #d47978"><strong>Address:</strong> </span>101 Upper Cross Street, Singapore 058357<br/>
#  <span style="color: #d47978"><strong>Contact:</strong></span> 6535 9177</p>,
#  <p><strong><span style="color: #d47978">Address:</span></strong> 18 Tampines Industrial Crescent, Space @ Tampines #01-02A, Singapore 528605<br/>
#  <strong><span style="color: #d47978">Opening hours:</span> </strong>Mon-Fri 12pm-6pm | Sat-Sun 12pm-7pm<br/>
#  <span style="font-weight: 400"><strong><span style="color: #d47978">Contact:</span> </strong>9021 7376</span></p>,
#  <p><em><span style="font-weight: 400"><img alt="Evernew Book Store" class="alignnone size-full wp-image-114395" decoding="async" height="1125" loading="lazy" sizes="(max-width: 1500px) 100vw, 1500px" src="https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12.png" srcset="https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12.png 1500w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-300x225.png 300w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-1024x768.png 1024w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-150x113.png 150w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-768x576.png 768w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-613x460.png 613w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-667x500.png 667w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-310x233.png 310w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-400x300.png 400w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-187x140.png 187w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-90x68.png 90w, https://thesmartlocal.com/wp-content/uploads/2020/01/121-things-to-do-in-Singapore-12-445x334.png 445w" width="1500"/><br/>
#  Image credit: Evernew Book Store<br/>
#  </span></em><span style="font-weight: 400"><br/>
#  Archie comics and superhero series will always be classics, even as their pages grow yellow and dog-eared with time. Go old-school at <a href="https://thesmartlocal.com/read/comic-book-stores/"><strong>comic book stores in Singapore</strong></a>, and see what gems you might be able to pick up – some of them even have clearance shelves with vintage titles going for as low as $2!</span></p>,
#  <p>Read our article on the <a href="https://thesmartlocal.com/read/don-don-donki-singapore-best-items/">best things to buy at Don Don Donki</a>.</p>,
#  <p><b><span style="color: #d47978">Address:</span></b> 3 New Bugis Street, Singapore 188867<br/>
#  <span style="color: #d47978"><strong>Opening hours:</strong></span> 10am-10pm, Daily<br/>
#  <strong><span style="color: #d47978">Contact:</span> </strong>6338 9513</p>,
#  <p><strong><span style="color: #d47978">Address:</span> </strong>Dempsey Road, Singapore 249679<b></b><b></b><i></i></p>]

# %%
# Remove HTML tags from each bs4.element.Tag object in the list
cleaned_text_list1 = [remove_html_tags(tag_obj) for tag_obj in ls2]

cleaned_text_list1
# Out:
# ['From seeing wildlife animals and birds at the zoo to roller skating and arcade games, there are plenty of fun activities in Singapore to do with the fam.',
#  'Contact: 6269 3411\nAddress: 80 Mandai Lake Road, Singapore 729826\nOpening hours:\nSingapore Zoo: 8.30am-6pm, Daily (Last entry at 5pm)\nRiver Wonders: 10am-7pm, Daily (Last entry at 6pm)\nNight Safari: 7.15pm-12am, Daily (Last entry at 11.15pm)\nBird Paradise: 9am-6pm, Daily (Last entry at 5pm)',
#  'Address: 8 Sentosa Gateway, Sentosa Island, Singapore 098269\nOpening hours: 10am-5pm, Daily',
#  'Address: 100 Loewen Road, Singapore 248837\nOpening hours: Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed on Tuesdays)\n',
#  'Address: 1 Pasir Ris Close, Downtown East, Singapore 519599\nOpening hours: Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Closed on Tuesdays)\nContact: 6581 9128',
#  'Address: 1 Pasir Ris Close, E!Hub, Market Square @ Downtown East, #05-103, Singapore 519599\nOpening hours: Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 11am-10pm\nContact: 9694 4094',
#  'Address: 3 Gateway Drive, Westgate #B1-45, Singapore 608532\nOpening hours: Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-11pm | Sun 10am-10pm\nContact: 6265 1132',
#  '*Airzone is temporarily closed for renovation works.',
#  '\xa0',
#  'Book a session at Kidodo Indoor Playground.',
#  'Address: 21 Jurong Town Hall Road, Singapore 609433\nOpening hours: Tue-Fri 10am-5pm | Sat-Sun & PH 10am-6pm\nContact: 6560 2306',
#  'Address: 481 Bukit Timah Road, Singapore 259769\nOpening hours:\nJacob Ballas Children’s Garden: Tue-Sun 8am-7pm (Closed on Mondays, except PHs)\nSingapore Botanic Gardens: 5am-12am, Daily\nContact: 1800 471 7300',
#  'Address: No. 71 Jalan Lekar, Singapore 698950\nOpening hours: Mon-Fri 9am-6pm | Sat-Sun 9am-7pm\nContact: 6766 1554',
#  'The Cat Cafe\nAddress: 241B Victoria Street, Singapore 188030\nOpening hours: Mon 3pm-10pm | Tue-Fri 10am-9pm | Sat-Sun 10am-10pm\nContact: 6338 6815',
#  'Kitten Sanctuary Singapore\nAddress: 737A North Bridge Road, Singapore 198705\nOpening hours: Sat-Sun 10.30am-11.30am, 12pm-1pm, 2,30pm-3.30pm, 4pm-5pm | Tue 11am-12pm, 7pm-8pm | Fri 11am-12pm (Closed on Mondays)\nContact: 9126 7379\n\nThe Cat Museum & Academy\nAddress: 781A North Bridge Road, #02-01, Singapore 198749\nOpening hours: Sat-Sun 11.30am-12.30pm, 5pm-6pm (Closed from Mondays to Fridays)\nContact: 6336 2133',
#  'Whether you’re a thrill seeker searching for their next adrenaline rush or a tired adult who likes to throw axes to relieve stress, there’s sure to be something for you at these fun outdoor places in Singapore.',
#  'Address: 30 Siloso Beach Walk, Singapore 099011\nOpening hours: Mon-Fri 12.30pm-7pm | Sat–Sun 11.30pm-7pm \nContact: 6911 3070\xa0',
#  'Address: 45 Siloso Beach Walk, Sentosa, Singapore 099003\nOpening hours: Mon-Thu 11am-7.30pm | Fri 11am-9pm | Sat 10am-9pm | Sun 10am-7.30pm\nContact: 6274 0472\xa0\xa0',
#  'Address: 6 Raffles Boulevard, Marina Square #01-208, Singapore 039594\nOpening hours: 12pm-8pm, Daily',
#  'Address: 2 Yishun Walk, HomeTeamNS Khatib, Singapore 767944\nOpening hours: Tue 2pm-5.30pm | Wed-Fri 2pm-5.30pm and 6pm-9.30pm | Sat-Sun, School Holidays & PH 10am-1.30pm, 2pm-5.30pm, and 6pm-9.30pm (Closed on Mondays)\nContact: 6705 9420',
#  'Bukit Timah outlet:\nAddress: 200 Turf Club Road, The Grandstand #01-01B, South Car Park, Singapore 287994\nOpening hours: Wed-Fri 1pm-8.30pm | Sat-Sun 10am-9pm | Closed Mon-Tue\n\nJurong outlet:\nAddress: 511 Upper Jurong Road, Block B, Singapore 638366\nOpening hours: Tue-Fri 1pm-9pm | Sat-Sun 9am-9pm (Closed on Mondays)',
#  'Address: 1206A East Coast Parkway, Singapore 449891\nOpening hours: 10am-8pm, Daily | Sat-Sun 9am-8pm\nContact: 6636 4266',
#  'Address: 200 Turf Club Road, The Grandstand #01-32A/B & #01-34A/B, Singapore 287994\nOpening hours: Tue-Sun 12pm-10pm (Closed on Mondays)\nContact: 8923 8945',
#  'Address: 139 Cecil Street, #13-01, Singapore 069539\nOpening hours: Mon-Sat 7am-12am | Sun 7am-8pm\nContact: 6993 4131',
#  'Address: 43 Siloso Beach Walk, #01-01, Singapore 099010\nOpening hours: Thu-Tue & PH 9am-10pm | Wed 11am-10pm\nContact: 6571 0000',
#  'Jumprrocks at Kinex offers free daily games in its Battle Groundz area at fixed timings, ideal for newbies to try trampolining out, and regular admissions discounts.\n\nBook a session at Jumprrocks at Kinex.',
#  'Apart from the standard rock walls, there are places with AR and Tetris-like walls for a bigger challenge.',
#  'Address: 313 Orchard Road, 313@Somerset #03-27, Singapore 238895\nOpening hours: 10am-1am, Daily\nContact: 6737 5313',
#  'Address: 8 Sentosa Gateway, Singapore 098269\nOpening hours: Refer to Universal Studios Singapore’s calendar for more information\nContact: 6577 8888',
#  'Address: Campsite 1 at Pasir Ris Park, near Carpark F, 133 Pasir Ris Road, Singapore 519149\nOpening hours: Sat-Sun 9am-6pm, by appointment (Closed from Mondays to Fridays)\nContact: 9871 8007',
#  'Address: 10A Siloso Beach Walk, Singapore 099008\nOpening hours: Mon-Fri 2pm-6pm | Sat-Sun & PH 11am-6pm\nContact: 6722 3785',
#  'Contact: 9003 1177',
#  'Kallang Ice World\nAddress: 5 Stadium Walk, Kallang Leisure Park #03-08/09, Singapore 397693\nOpening hours: Sun-Thu 10am-10pm | Fri-Sat & Eve of PH 10am-12am | PH 9am-10pm\nContact: 6348 1347',
#  'Rent a mountain bike in Singapore.',
#  'Address: 8 Sentosa Gateway, Singapore 098269\nOpening hours: Fri-Tue 10am-5pm (Closed Wed-Thu)',
#  'Address: 902 East Coast Park Service Road, Singapore 449874\nOpening hours: Tue-Sun 8am-8pm (Closed on Mondays)',
#  'Opening hours: Various hours; view all GoCycling opening hours\nContact: 8831 3068',
#  'Address: Yuan Ching Road, Jurong Lake Gardens\nOpening hours: Tue-Sun 8am-10pm (Closed on Mondays)',
#  'Address: Bedok Reservoir Park, Singapore 478931\nOpening hours: Mon-Fri 9.30am-6pm | Sat-Sun & PH 9.30am-6.30pm\nContact: 6206 9744',
#  'If you’re planning a chill weekend with your friends, here are some activities that you can consider ranging from scenic road trips and pottery classes to getting rid of those sore muscles at Japanese onsen spas and massages.',
#  'And if you just want a short break from the city, hop on bus 975 with your headphones and enjoy a restful bus ride down the Lim Chu Kang heritage road – it’ll even give you a glimpse of a sea view at the road’s northern end.',
#  'Address: 2 Keppel Bay Vista, Singapore 098382\nOpening hours: Selected nights, 7.45pm – end of screening\nContact: info@cinewav.com',
#  'Address: 85 Lorong Tawas, Singapore 639823\nOpening hours: 9am-5pm, Daily\nContact: 6265 5808 | 8949 0168 (WhatsApp)',
#  'Book a session at HeadRock VR Theme Park Sentosa.\n\nAddress:\xa080 Siloso Road, Block #01-03, Singapore 098969\nOpening hours: Mon-Fri 12pm-7pm | Sat-Sun & PH 11am-7pm (last admission 6pm)\nContact: 6963 4127',
#  'Address: 30 Raffles Avenue, Singapore Flyer #02-06, Singapore 039803\nContact: 6339 2737',
#  'Address: 195 Pearl’s Hill Terrace, Singapore 168976',
#  'Address: 459 Jalan Ahmad Ibrahim, Singapore 639934\nTour schedule: Fri-Sun 1pm-6.30pm (Excluding eves of PH and PH, last tours at 5pm)\nTelephone: 6860 3005',
#  'There’s also a bar from which you can bring snacks and drinks into the screening halls, art and theatre spaces, and a ballroom for live events.\n\nAddress: The Cathay, 2 Handy Rd, #05-01, Singapore 229233\nOpening hours:\xa0',
#  'Address: 3 Lorong Bakar Batu, #03-01, Singapore 348741\nOpening hours: Tue-Thu 2pm-9pm | Fri-Sun 10am-9pm (Closed on Mondays)\nContact: 8268 3160',
#  'Address: 490 MacPherson Road, Singapore 368198\nOpening hours: 12am-10pm, Daily\nContact: 6970 0343',
#  'And with many open past midnight, you can play on through the night with boozy sustenance too.',
#  'Book a session at Trapped Escape Room and VR Escape Room.',
#  'Address: Bugis+, 201 Victoria Street, #07-05, Singapore 188067\nOpening hours: 9am-6am, Daily\nContact: 9008 0201 | 83386530 (WhatsApp)',
#  'Also read our articles about arcade game hacks and nostalgic arcade games in Singapore.',
#  'Book an art jamming session.',
#  'There are private ones such as Elements Wellness, as well as communal ones such as Yunomori Onsen & Spa which gives you that true blue butt-naked experience.\n\nBook a visit to Elements Wellness.',
#  'In case you’re wondering, no, these aren’t the sleazy sort – there are quite a few wholesome spas that open till the wee hours, some even 24 hours a day. A few of these even come with added perks such as buffets and free movies.',
#  'Address: 81 Lorong Chencharu, #01-01, Singapore 769198\nOpening hours:\xa024 hours, Daily (individual establishments’ opening hours apply)\nContact: 6257 8858',
#  'Senoko Fishery Port\nAddress: 31 Attap Valley Road, #02-29, Singapore 759908\nOpening hours: Tue-Sun 2am-6am (Closed on Mondays)\nContact: 6257 6721',
#  'This is your reminder to go outside and touch grass. Plan a romantic picnic date with the bae at one of the many parks in Singapore or immerse yourself in nature by trekking through Maju Forest.',
#  'Address: 12 Nanyang Drive, Singapore 637721\nOpening hours: 24 hours, Daily\nContact:  6791 1744',
#  'Address: Along Bukit Batok East Avenue 5\nGetting there: Walk about 8 minutes from Bukit Gombak MRT station, or take Bus 945 to Bukit Gombak Stadium',
#  'Some of them offer tours with explanations and demonstrations on what the farming process is like.',
#  'Also read our articles about islands in Singapore such as Pulau Hantu, the history behind Pulau Tekong, and\xa0hidden Singapore islands.',
#  'Address: 81 Lorong Chencharu, #01-16, Singapore 769198\nOpening hours: Wed-Mon 10am-6pm (Closed on Tuesdays)\nContact: 6268 5363',
#  'Book a guided kayak fishing tour in Singapore.',
#  'Address: Aviation Park Road',
#  'Board the Kranji Farms Shuttle service to the Kranji Marshes, Sungei Buloh, and other Kranji farm attractions from Kranji MRT, and bring along a pair of binoculars to spot your next rare bird.',
#  'Also read our article on hiking trails in Singapore.',
#  'Opening hours: 7am-7pm, Daily',
#  'Make a Pulau Ubin bike rental and book an Ubin kayaking trip at Round Ketam Kayaking Adventure.',
#  'A less bustling environment means it’s going to be all the more romantic! Some places to visit include Toa Payoh Town Park and Telok Blangah Hill Park, which is full of vibrant pink bougainvillaea blooms.',
#  'Read our article on hiking for beginners and check out our other hiking-related articles, covering topics from hiking to the “Lost Ark” in Alexandra to kid-friendly hiking trails in Singapore.',
#  'Address: Along Gambas Avenue, Singapore 756952',
#  'Address: 104 Yuan Ching Road, Singapore 618665\nOpening hours: 24 hours, Daily',
#  'Or book a guided tour of Bukit Brown Cemetery.',
#  'Address: 301 Neo Tiew Crescent, Singapore 718925\nOpening hours: 7am-7pm, Daily (last entry at 6.30pm)\nContact: 6794 1401',
#  'Check out bike rental services in Singapore that’ll help you cycle up a storm.',
#  'If you’re a foodie on the lookout for their next new meal to review, then check out these restaurants and cafes in Singapore.',
#  '\nImage adapted from: @mighty.explorers, @eatingwitheating via Instagram\n\nA brunch date is the one thing that’s hard to go wrong with whenever we’re planning a day out with bae. To switch things up, choose a cafe based on either your or your SO’s favourite colour from the many colour-themed cafes in Singapore. On top of yummy cafe grub, you’ll be promised cool aesthetics that deserve a spot in your IG feeds.\n\nSome names to bookmark right off the bat: Smile Dessert for its blue and white ball pit; and Fraser Street Brothers for its vibrant rainbow theme.',
#  'Both are date-worthy settings, so save them for a special occasion or when you need to impress!',
#  'Address: 356 Tanglin Road, Singapore 247674\nOpening hours: 8am-10pm, Daily\nContact: 6556 8228',
#  'Address: 01’23’52″N – 103’57’42″E\nOpening hours: 10am-7pm, Daily (Closed on alternate Mondays)\nContact: 9792 7609 (WhatsApp/SMS for reservations)',
#  'Address: 11 Tanjong Katong Road, Kinex Mall #02-16, Singapore 437157\nOpening hours: 11am-10pm, Daily\nContact: 9876 7257',
#  'Address: 1094 Serangoon Road, Singapore 328192\nOpening hours: Tue-Sun 11am-10pm (Closed on Mondays)\nContact: 6204 6003',
#  'Great World Food Junction outlet:\nAddress: 1 Kim Seng Promenade, #03-116 Great World, Singapore 237994\nOpening hours: 10am-10pm, Daily',
#  'Check out our other dog-related articles about dog training hacks, the cost of owning a dog in Singapore, free dog runs in Singapore and tips on improving your dog’s diet.',
#  'Book a pub crawling tour in Singapore.',
#  'From educational and cultural museums on Singapore’s history to art and themed galleries around specific niches, there’s a variety of museums for you to explore.',
#  'Address: 1 Esplanade Drive, Singapore 038981',
#  'Address: 8C-8D Jalan Kledek, Singapore 199263\nOpening hours: 11am-7pm, Daily\nContact: 6291 2278',
#  'Address: 825B Chuan Hoe Avenue, Singapore 549854\nOpening hours: 7am-7pm, Daily\nContact: 6468 0066 (The Japanese Association, Singapore)',
#  'Address: 15 Science Centre Road, Singapore 609081\nOpening hours: Tue-Sun 10am-5pm (last entry 4.15pm) (Closed Mondays except for public holidays and school holidays)\nContact: 6425 2500',
#  'Find more free art exhibits and museums in Singapore.\n',
#  'Admission: Free\nAddress: 62 Hill Street, Singapore 179367\nContact: 6332 2996\nOpening hours: Tue-Sun 10am-5pm (Closed on Mondays)',
#  'Address: 69 Joo Chiat Terrace, Singapore 427231\nOpening hours: By appointment only\nContact: 6440 1148',
#  'Address: 39 Keppel Road, Tanjong Pagar Distripark, #01-02, Singapore 089065\nOpening hours: 10am-7pm, Daily',
#  'Address: 54 Lakeshore View, Singapore 09844',
#  'Read our article on lesser-known things to do in Chinatown.',
#  'Book a guided tour of Kampong Lorong Buangkok.',
#  'Admission: Free\nAddress: 3 Sentosa Gateway, Singapore 098544\nOpening hours: Tue-Sun 10am-6pm (Closed on Mondays)',
#  'Address: 262 Pasir Panjang Road, Singapore 118 628\nOpening hours: Sun-Thu 9am-8pm | Fri-Sat 9am-10pm\nContact: 6773 0103',
#  'Address: 6 Bayfront Avenue, Singapore 018974\nOpening hours: 10am-7pm, Daily\nContact: 6688 8888',
#  'Book a guided tour of Singapore’s Kampong Gelam.',
#  'Address: National Gallery Singapore, 1 St Andrew’s Road, Supreme Court Wing Level 3, Singapore 178957\nOpening hours: Mon-Fri 10am-12.30pm & 2pm-5pm (Closed on Sat-Sun & PHs)\nContact:  6697 9180\xa0',
#  'Address: 80 Siloso Road, Southside Interim Market, Block D #01-04, Singapore 098969\nOpening hours: 11am-7pm, Daily\nContact: 6795 2371\xa0',
#  'Address: 45 Maxwell Road, Level 1, The URA Centre, Singapore 069118\nOpening hours: Mon-Sat 9am-5pm (Closed on Sundays & PH)',
#  'Address: 5 Campbell Lane, Singapore 209924\nOpening hours: Tue-Sun 10am-6pm (Closed on Mondays)\nContact: 6291 1601',
#  'Address: Block 159 Ang Mo Kio Ave 5, Singapore 560159\nOpening hours: Sat-Sun & PH 9.30am-12pm',
#  'Strike a pose for the gram at these scenic and aesthetic places in Singapore.',
#  'While some of them are inaccessible or require special permission to enter, there are easy-to-reach options such as Raffles Marina Lighthouse and Fullerton Lighthouse. The former is a popular spot for wedding photography and the sunsets there are amazing, while the decommissioned Fullerton Lighthouse now lives on as a vintage landmark near Harbourfront Tower 1.',
#  'Read our articles on food, shopping, and play zones at Jewel Changi, Jewel Changi Canopy Park attractions and Changi Experience Studio, and Jewel Changi’s photo spots.',
#  'Our old-school playgrounds are truly icons of our country, and now that they’re such rare finds, these nostalgia-inducing structures from a simpler time are all the more precious. You already know the classic dragon playgrounds – only 4 of which are left today – but there are a couple other gems such as clock- and dove-shaped ones.\n',
#  'Best of all, it’s free. All you need to bring is your iPhone – or don’t; the latest iPhones will be loaned to you for you to snap away with.',
#  '123ChiCha Selfie Studio\nAddress: 110 Lorong 23 Geylang, Victory Center #03-07, Singapore 388410\nOpening hours: 10am-5pm, Daily\nContact: 9029 4733',
#  'Address: 2 Orchard Turn, ION Orchard Mall Level 56, Singapore 238801\nOpening hours: Tue-Thu 4pm-8pm | Fri-Sat 2-9pm (Closed Sundays & Mondays)\nContact: 6238 8228',
#  'Address: Near Beach Station, 50 Beach View, Singapore 098604\nPerformance timings: 7.40pm and 8.40pm, Daily\nContact: 6361 0088 (Singapore Cable Car ticketing counter)',
#  'Address: 88 Market Street, Singapore 048948\nContact: 6713 3948',
#  'If you’ve got the stomach for it, there’s also a snack bar where you can purchase light bites such as fruit bowls and pastries. Take your grub on the ride with you for a mid-air munch.\n\nBook a session at SkyHelix Sentosa.\n\nAddress: 41 Imbiah Road, Sentosa, Singapore 099707\nOpening hours: 10am-9.30pm, Daily\nContact: 6361 0088',
#  'Address: Yishun Avenue 1, Singapore 769130',
#  'Whether you’re a comic book collector, a bundle thrift hunter, or a casual window shopper, there’s no shortage of options when it comes to shopping in Singapore.',
#  'Book a Little India walking tour.',
#  'Address: 3 Yong Siak Street, Singapore 168642\nOpening hours: Wed-Sat 10am-7pm | Sun-Mon 10am-6pm (Closed on Tuesdays)\nContact: 6222 9980\n',
#  'Find out more about what you can do at Turf Club Road\xa0and read our articles on antique and vintage furniture and knick-knacks: from\xa0stores with 80s collectibles in Singapore to secondhand furniture stores in Singapore with refurbished vintage and antique items to\xa0undiscovered secondhand furniture stores in Singapore.',
#  'Joo Chiat outlet\nAddress: 448 Joo Chiat Road, Singapore 427661\nOpening hours: Mon 11am-6pm | Tue-Sat 11am-8pm | Sun & PH 11am-7pm\nContact: 6348 0863',
#  'Address: 101 Upper Cross Street, Singapore 058357\nContact: 6535 9177',
#  'Address: 18 Tampines Industrial Crescent, Space @ Tampines #01-02A, Singapore 528605\nOpening hours: Mon-Fri 12pm-6pm | Sat-Sun 12pm-7pm\nContact: 9021 7376',
#  '\nImage credit: Evernew Book Store\n\nArchie comics and superhero series will always be classics, even as their pages grow yellow and dog-eared with time. Go old-school at comic book stores in Singapore, and see what gems you might be able to pick up – some of them even have clearance shelves with vintage titles going for as low as $2!',
#  'Read our article on the best things to buy at Don Don Donki.',
#  'Address:\xa03 New Bugis Street, Singapore 188867\nOpening hours: 10am-10pm, Daily\nContact: 6338 9513',
#  'Address: Dempsey Road, Singapore 249679']

# %%
len(cleaned_text_list1)
# Out:
# 131

# %%
cleaned_text_list1.pop(0)
# Out:
# 'From seeing wildlife animals and birds at the zoo to roller skating and arcade games, there are plenty of fun activities in Singapore to do with the fam.'

# %% [markdown]
# iterate through lists simultaneously and create dictionary for each activity, with activity name as the key and details as the value

# %%
activity_dicts = []

for name, details in zip(cleaned_text_list, cleaned_text_list1):
  
    detail_lines = details.split('\n')
    detail_dict = {}
    for line in detail_lines:
        if ': ' in line:
            key, value = line.split(': ', 1)
            detail_dict[key] = value

    activity_dict = {name: detail_dict}
    activity_dicts.append(activity_dict)

for activity_dict in activity_dicts:
    print(activity_dict)
# Out:
# {'1. Explore Mandai Wildlife Reserve': {'Contact': '6269 3411', 'Address': '80 Mandai Lake Road, Singapore 729826', 'Singapore Zoo': '8.30am-6pm, Daily (Last entry at 5pm)', 'River Wonders': '10am-7pm, Daily (Last entry at 6pm)', 'Night Safari': '7.15pm-12am, Daily (Last entry at 11.15pm)', 'Bird Paradise': '9am-6pm, Daily (Last entry at 5pm)'}}
# {'2. See the S.E.A. Aquarium': {'Address': '8 Sentosa Gateway, Sentosa Island, Singapore 098269', 'Opening hours': '10am-5pm, Daily'}}
# {'3. Visit the Museum of Ice Cream': {'Address': '100 Loewen Road, Singapore 248837', 'Opening hours': 'Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed on Tuesdays)'}}
# {'4. Swim at Wild Wild Wet': {'Address': '1 Pasir Ris Close, Downtown East, Singapore 519599', 'Opening hours': 'Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Closed on Tuesdays)', 'Contact': '6581 9128'}}
# {'5. Roller skate at Hi-Roller': {'Address': '1 Pasir Ris Close, E!Hub, Market Square @ Downtown East, #05-103, Singapore 519599', 'Opening hours': 'Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 11am-10pm', 'Contact': '9694 4094'}}
# {'6. Play arcade games at Timezone Westgate': {'Address': '3 Gateway Drive, Westgate #B1-45, Singapore 608532', 'Opening hours': 'Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-11pm | Sun 10am-10pm', 'Contact': '6265 1132'}}
# {'7. Frolic around at Airzone (temporarily closed till Oct 2024)': {}}
# {'8. Learn new skills at NLB libraries': {}}
# {'9. Discover new playgrounds in Singapore': {}}
# {'10. Chill out at Snow City': {'Address': '21 Jurong Town Hall Road, Singapore 609433', 'Opening hours': 'Tue-Fri 10am-5pm | Sat-Sun & PH 10am-6pm', 'Contact': '6560 2306'}}
# {'11. Tour the Jacob Ballas Children’s Garden': {'Address': '481 Bukit Timah Road, Singapore 259769', 'Jacob Ballas Children’s Garden': 'Tue-Sun 8am-7pm (Closed on Mondays, except PHs)', 'Singapore Botanic Gardens': '5am-12am, Daily', 'Contact': '1800 471 7300'}}
# {'12. Try fishing at\xa0Qian Hu Fish Farm': {'Address': 'No. 71 Jalan Lekar, Singapore 698950', 'Opening hours': 'Mon-Fri 9am-6pm | Sat-Sun 9am-7pm', 'Contact': '6766 1554'}}
# {'13. Play with felines at The Cat Cafe': {'Address': '241B Victoria Street, Singapore 188030', 'Opening hours': 'Mon 3pm-10pm | Tue-Fri 10am-9pm | Sat-Sun 10am-10pm', 'Contact': '6338 6815'}}
# {'14. Support the Kitten Sanctuary': {'Address': '781A North Bridge Road, #02-01, Singapore 198749', 'Opening hours': 'Sat-Sun 11.30am-12.30pm, 5pm-6pm (Closed from Mondays to Fridays)', 'Contact': '6336 2133'}}
# {'15. Relax in Singapore’s newest hotels': {}}
# {'16. Bungy jump at Skypark Sentosa by AJ Hackett': {'Address': '30 Siloso Beach Walk, Singapore 099011', 'Opening hours': 'Mon-Fri 12.30pm-7pm | Sat–Sun 11.30pm-7pm ', 'Contact': '6911 3070\xa0'}}
# {'17. Ride the Skyline Luge': {'Address': '45 Siloso Beach Walk, Sentosa, Singapore 099003', 'Opening hours': 'Mon-Thu 11am-7.30pm | Fri 11am-9pm | Sat 10am-9pm | Sun 10am-7.30pm', 'Contact': '6274 0472\xa0\xa0'}}
# {'18. Spend a day at NERF Action Xperience (Closed)': {'Address': '6 Raffles Boulevard, Marina Square #01-208, Singapore 039594', 'Opening hours': '12pm-8pm, Daily'}}
# {'19. Retreat to Adventure HQ': {'Address': '2 Yishun Walk, HomeTeamNS Khatib, Singapore 767944', 'Opening hours': 'Tue 2pm-5.30pm | Wed-Fri 2pm-5.30pm and 6pm-9.30pm | Sat-Sun, School Holidays & PH 10am-1.30pm, 2pm-5.30pm, and 6pm-9.30pm (Closed on Mondays)', 'Contact': '6705 9420'}}
# {'20. Go-kart at The Karting Arena': {'Address': '511 Upper Jurong Road, Block B, Singapore 638366', 'Opening hours': 'Tue-Fri 1pm-9pm | Sat-Sun 9am-9pm (Closed on Mondays)'}}
# {'21.\xa0 Cable-ski at Singapore Wake Park': {'Address': '1206A East Coast Parkway, Singapore 449891', 'Opening hours': '10am-8pm, Daily | Sat-Sun 9am-8pm', 'Contact': '6636 4266'}}
# {'22. Throw axes at Axe Factor': {'Address': '200 Turf Club Road, The Grandstand #01-32A/B & #01-34A/B, Singapore 287994', 'Opening hours': 'Tue-Sun 12pm-10pm (Closed on Mondays)', 'Contact': '8923 8945'}}
# {'23. Golf virtually at Five Iron Golf': {'Address': '139 Cecil Street, #13-01, Singapore 069539', 'Opening hours': 'Mon-Sat 7am-12am | Sun 7am-8pm', 'Contact': '6993 4131'}}
# {'24. Skydive indoors at iFly Singapore': {'Address': '43 Siloso Beach Walk, #01-01, Singapore 099010', 'Opening hours': 'Thu-Tue & PH 9am-10pm | Wed 11am-10pm', 'Contact': '6571 0000'}}
# {'25. Jump around in trampoline parks': {}}
# {'26. Try bouldering or rock climbing': {}}
# {'27. Go bowling at K Bowling Club': {'Address': '313 Orchard Road, 313@Somerset #03-27, Singapore 238895', 'Opening hours': '10am-1am, Daily', 'Contact': '6737 5313'}}
# {'28. Ride coasters at Universal Studios Singapore': {'Address': '8 Sentosa Gateway, Singapore 098269', 'Opening hours': 'Refer to Universal Studios Singapore’s calendar for more information', 'Contact': '6577 8888'}}
# {'29. Cycle on water at WaterbikeSG ': {'Address': 'Campsite 1 at Pasir Ris Park, near Carpark F, 133 Pasir Ris Road, Singapore 519149', 'Opening hours': 'Sat-Sun 9am-6pm, by appointment (Closed from Mondays to Fridays)', 'Contact': '9871 8007'}}
# {'30. \xa0Try extreme sports at Mega Adventure': {'Address': '10A Siloso Beach Walk, Singapore 099008', 'Opening hours': 'Mon-Fri 2pm-6pm | Sat-Sun & PH 11am-6pm', 'Contact': '6722 3785'}}
# {'31. Play outdoor laser tag with GO Team': {'Contact': '9003 1177'}}
# {'32. Ice-skate at Kallang Ice World': {'Address': '5 Stadium Walk, Kallang Leisure Park #03-08/09, Singapore 397693', 'Opening hours': 'Sun-Thu 10am-10pm | Fri-Sat & Eve of PH 10am-12am | PH 9am-10pm', 'Contact': '6348 1347'}}
# {'33. Mountain-bike across Singapore': {}}
# {'34. Snorkel at Adventure Cove Waterpark': {'Address': '8 Sentosa Gateway, Singapore 098269', 'Opening hours': 'Fri-Tue 10am-5pm (Closed Wed-Thu)'}}
# {'35. Scale and slide through Coastal PlayGrove': {'Address': '902 East Coast Park Service Road, Singapore 449874', 'Opening hours': 'Tue-Sun 8am-8pm (Closed on Mondays)'}}
# {'36. Bike around Marina Bay': {'Opening hours': 'Various hours; view all GoCycling opening hours', 'Contact': '8831 3068'}}
# {'37. Hang out at Skateparks': {'Address': 'Yuan Ching Road, Jurong Lake Gardens', 'Opening hours': 'Tue-Sun 8am-10pm (Closed on Mondays)'}}
# {'38. Tackle a high elements course at Forest Adventure': {'Address': 'Bedok Reservoir Park, Singapore 478931', 'Opening hours': 'Mon-Fri 9.30am-6pm | Sat-Sun & PH 9.30am-6.30pm', 'Contact': '6206 9744'}}
# {'39. Have an overnight cycling trip': {}}
# {'40. Hop on a scenic bus ride around Singapore': {}}
# {'41. Watch movies at an outdoor cinema': {'Address': '2 Keppel Bay Vista, Singapore 098382', 'Opening hours': 'Selected nights, 7.45pm – end of screening', 'Contact': 'info@cinewav.com'}}
# {'42. Make pottery at Thow Kwang Pottery Jungle': {'Address': '85 Lorong Tawas, Singapore 639823', 'Opening hours': '9am-5pm, Daily', 'Contact': '6265 5808 | 8949 0168 (WhatsApp)'}}
# {'43. Experience VR with Headrock VR': {'Opening hours': 'Mon-Fri 12pm-7pm | Sat-Sun & PH 11am-7pm (last admission 6pm)', 'Contact': '6963 4127'}}
# {'44. Try the Boeing 737 Flight Experience': {'Address': '30 Raffles Avenue, Singapore Flyer #02-06, Singapore 039803', 'Contact': '6339 2737'}}
# {'45. Explore Pearl’s Hill Terrace': {'Address': '195 Pearl’s Hill Terrace, Singapore 168976'}}
# {'46. Tour Tiger Brewery': {'Address': '459 Jalan Ahmad Ibrahim, Singapore 639934', 'Tour schedule': 'Fri-Sun 1pm-6.30pm (Excluding eves of PH and PH, last tours at 5pm)', 'Telephone': '6860 3005'}}
# {'47. Watch films at The Projector': {'Address': 'The Cathay, 2 Handy Rd, #05-01, Singapore 229233'}}
# {'48. Draw graffiti at Heaven Spot': {'Address': '3 Lorong Bakar Batu, #03-01, Singapore 348741', 'Opening hours': 'Tue-Thu 2pm-9pm | Fri-Sun 10am-9pm (Closed on Mondays)', 'Contact': '8268 3160'}}
# {'49.\xa0 Destress at The Fragment Room': {'Address': '490 MacPherson Road, Singapore 368198', 'Opening hours': '12am-10pm, Daily', 'Contact': '6970 0343'}}
# {'50. Hang out at board game cafes': {}}
# {'51. Navigate through an escape room': {}}
# {'52. Go prawning at FishBugis+': {'Address': 'Bugis+, 201 Victoria Street, #07-05, Singapore 188067', 'Opening hours': '9am-6am, Daily', 'Contact': '9008 0201 | 83386530 (WhatsApp)'}}
# {'53. Get competitive at Cow Play Cow Moo': {}}
# {'54. Attend an art jamming session': {}}
# {'55. Bathe in a Japanese-style onsen': {}}
# {'56. Book for a massage': {}}
# {'57. Visit ORTO\xa0': {'Address': '81 Lorong Chencharu, #01-01, Singapore 769198', 'Contact': '6257 8858'}}
# {'58. Travel to Senoko or Jurong Fishery Port': {'Address': '31 Attap Valley Road, #02-29, Singapore 759908', 'Opening hours': 'Tue-Sun 2am-6am (Closed on Mondays)', 'Contact': '6257 6721'}}
# {'59. Stroll around Gardens by the Bay': {}}
# {'60. Drop by NTU’s Yunnan Garden': {'Address': '12 Nanyang Drive, Singapore 637721', 'Opening hours': '24 hours, Daily', 'Contact': ' 6791 1744'}}
# {'61. See Little Guilin': {'Address': 'Along Bukit Batok East Avenue 5', 'Getting there': 'Walk about 8 minutes from Bukit Gombak MRT station, or take Bus 945 to Bukit Gombak Stadium'}}
# {'62. Tour urban farms in Singapore': {}}
# {'63. Island-hop between Lazarus, St John’s, & Kusu Island': {}}
# {'64. Check out the Live Turtle & Tortoise Museum': {'Address': '81 Lorong Chencharu, #01-16, Singapore 769198', 'Opening hours': 'Wed-Mon 10am-6pm (Closed on Tuesdays)', 'Contact': '6268 5363'}}
# {'65. Go fishing around Singapore': {}}
# {'66. Venture out to Changi Bay Point': {'Address': 'Aviation Park Road'}}
# {'67. Birdwatch at Kranji Marshes': {}}
# {'68. Trek through Maju Forest': {}}
# {'69. Conquer the MacRitchie Treetop Walk': {'Opening hours': '7am-7pm, Daily'}}
# {'70. Take a day trip to Pulau Ubin & Chek Jawa Wetlands': {}}
# {'71. Have a romantic picnic': {}}
# {'72. Hike through Singapore’s parks & nature reserves': {}}
# {'73. Unwind at Sembawang Hot Spring Park': {'Address': 'Along Gambas Avenue, Singapore 756952'}}
# {'74. Explore Jurong Lake Gardens': {'Address': '104 Yuan Ching Road, Singapore 618665', 'Opening hours': '24 hours, Daily'}}
# {'75. See “Avatar Trees” at Bukit Brown Cemetery': {}}
# {'76. Walk through Sungei Buloh Wetland Reserve': {'Address': '301 Neo Tiew Crescent, Singapore 718925', 'Opening hours': '7am-7pm, Daily (last entry at 6.30pm)', 'Contact': '6794 1401'}}
# {'77. Bike or hike through the Park Connector Network': {}}
# {'78. Visit the Tropical Montane Orchidetum': {}}
# {'79. Have a brunch date at a cafe': {'Image adapted from': '@mighty.explorers, @eatingwitheating via Instagram', 'Some names to bookmark right off the bat': 'Smile Dessert for its blue and white ball pit; and Fraser Street Brothers for its vibrant rainbow theme.'}}
# {'80. Have a seaside meal while yacht-viewing': {}}
# {'81. Dine amidst nature at Lucky Saigon Cafe': {'Address': '356 Tanglin Road, Singapore 247674', 'Opening hours': '8am-10pm, Daily', 'Contact': '6556 8228'}}
# {'82. Travel to Smith Marine Floating Restaurant': {'Address': '01’23’52″N – 103’57’42″E', 'Opening hours': '10am-7pm, Daily (Closed on alternate Mondays)', 'Contact': '9792 7609 (WhatsApp/SMS for reservations)'}}
# {'83. Dine at Soul Coffee': {'Address': '11 Tanjong Katong Road, Kinex Mall #02-16, Singapore 437157', 'Opening hours': '11am-10pm, Daily', 'Contact': '9876 7257'}}
# {'84. Order a drink at Platform 1094 cafe': {'Address': '1094 Serangoon Road, Singapore 328192', 'Opening hours': 'Tue-Sun 11am-10pm (Closed on Mondays)', 'Contact': '6204 6003'}}
# {'85. Visit unique food courts in Singapore': {'Address': '1 Kim Seng Promenade, #03-116 Great World, Singapore 237994', 'Opening hours': '10am-10pm, Daily'}}
# {'86. Take your dog to a dog-friendly cafe': {}}
# {'87. Go on a pub crawl': {}}
# {'88. Enjoy a foodie & heritage walk in Geylang': {}}
# {'89. Catch free music & art shows at the Esplanade': {'Address': '1 Esplanade Drive, Singapore 038981'}}
# {'90. Check out the Vintage Camera Museum': {'Address': '8C-8D Jalan Kledek, Singapore 199263', 'Opening hours': '11am-7pm, Daily', 'Contact': '6291 2278'}}
# {'91. Walk through the Japanese Cemetery Park': {'Address': '825B Chuan Hoe Avenue, Singapore 549854', 'Opening hours': '7am-7pm, Daily', 'Contact': '6468 0066 (The Japanese Association, Singapore)'}}
# {'92. Visit the Science Centre': {'Address': '15 Science Centre Road, Singapore 609081', 'Opening hours': 'Tue-Sun 10am-5pm (last entry 4.15pm) (Closed Mondays except for public holidays and school holidays)', 'Contact': '6425 2500'}}
# {'93. Go museum-hopping': {}}
# {'94. Visit the Civil Defence Heritage Gallery': {'Admission': 'Free', 'Address': '62 Hill Street, Singapore 179367', 'Contact': '6332 2996', 'Opening hours': 'Tue-Sun 10am-5pm (Closed on Mondays)'}}
# {'95. Tour The Intan': {'Address': '69 Joo Chiat Terrace, Singapore 427231', 'Opening hours': 'By appointment only', 'Contact': '6440 1148'}}
# {'96. Check out the Singapore Art Museum': {'Address': '39 Keppel Road, Tanjong Pagar Distripark, #01-02, Singapore 089065', 'Opening hours': '10am-7pm, Daily'}}
# {'97. Go on a Fort Serapong tour': {'Address': '54 Lakeshore View, Singapore 09844'}}
# {'98. Visit the Buddha Tooth Relic Temple': {}}
# {'99. Explore Kampong Lorong Buangkok': {}}
# {'100. Revisit St James Power Station': {'Admission': 'Free', 'Address': '3 Sentosa Gateway, Singapore 098544', 'Opening hours': 'Tue-Sun 10am-6pm (Closed on Mondays)'}}
# {'101. Explore Haw Par Villa': {'Address': '262 Pasir Panjang Road, Singapore 118 628', 'Opening hours': 'Sun-Thu 9am-8pm | Fri-Sat 9am-10pm', 'Contact': '6773 0103'}}
# {'102. Visit the ArtScience Museum': {'Address': '6 Bayfront Avenue, Singapore 018974', 'Opening hours': '10am-7pm, Daily', 'Contact': '6688 8888'}}
# {'103. Trawl Kampong Gelam': {}}
# {'104. Browse the grand Rotunda Library & Archive': {'Address': 'National Gallery Singapore, 1 St Andrew’s Road, Supreme Court Wing Level 3, Singapore 178957', 'Opening hours': 'Mon-Fri 10am-12.30pm & 2pm-5pm (Closed on Sat-Sun & PHs)', 'Contact': ' 6697 9180\xa0'}}
# {'105. Visit the Trick Eye Museum': {'Address': '80 Siloso Road, Southside Interim Market, Block D #01-04, Singapore 098969', 'Opening hours': '11am-7pm, Daily', 'Contact': '6795 2371\xa0'}}
# {'106. Tour the Singapore City Gallery': {'Address': '45 Maxwell Road, Level 1, The URA Centre, Singapore 069118', 'Opening hours': 'Mon-Sat 9am-5pm (Closed on Sundays & PH)'}}
# {'107. Spend time at the Indian Heritage Centre': {'Address': '5 Campbell Lane, Singapore 209924', 'Opening hours': 'Tue-Sun 10am-6pm (Closed on Mondays)', 'Contact': '6291 1601'}}
# {'108. Join the Kebun Baru Birdsinging Club': {'Address': 'Block 159 Ang Mo Kio Ave 5, Singapore 560159', 'Opening hours': 'Sat-Sun & PH 9.30am-12pm'}}
# {'109. Stop by Gillman Barracks': {}}
# {'110. See lighthouses in Singapore': {}}
# {'111. Admire Jewel Changi’s Rain Vortex': {}}
# {'112. Revisit old-school playgrounds': {}}
# {'113. Go on Apple Photo Walks': {}}
# {'114. Have a photoshoot at selfie studios': {'Address': '110 Lorong 23 Geylang, Victory Center #03-07, Singapore 388410', 'Opening hours': '10am-5pm, Daily', 'Contact': '9029 4733'}}
# {'115. Head up to ION Sky': {'Address': '2 Orchard Turn, ION Orchard Mall Level 56, Singapore 238801', 'Opening hours': 'Tue-Thu 4pm-8pm | Fri-Sat 2-9pm (Closed Sundays & Mondays)', 'Contact': '6238 8228'}}
# {'116. Have a date at Wings of Time': {'Address': 'Near Beach Station, 50 Beach View, Singapore 098604', 'Performance timings': '7.40pm and 8.40pm, Daily', 'Contact': '6361 0088 (Singapore Cable Car ticketing counter)'}}
# {'117. Check out CapitaSpring': {'Address': '88 Market Street, Singapore 048948', 'Contact': '6713 3948'}}
# {'118. Ride on the SkyHelix': {'Address': '41 Imbiah Road, Sentosa, Singapore 099707', 'Opening hours': '10am-9.30pm, Daily', 'Contact': '6361 0088'}}
# {'119. Watch the sunset at Yishun Dam': {'Address': 'Yishun Avenue 1, Singapore 769130'}}
# {'120. Visit rooftop gardens around Singapore': {}}
# {'121. Go shopping in Little India': {}}
# {'122. Read at Woods in the Books': {'Address': '3 Yong Siak Street, Singapore 168642', 'Opening hours': 'Wed-Sat 10am-7pm | Sun-Mon 10am-6pm (Closed on Tuesdays)', 'Contact': '6222 9980'}}
# {'123. Go thrifting at Turf Club Road’s Antique Row': {'Find out more about what you can do at Turf Club Road\xa0and read our articles on antique and vintage furniture and knick-knacks': 'from\xa0stores with 80s collectibles in Singapore to secondhand furniture stores in Singapore with refurbished vintage and antique items to\xa0undiscovered secondhand furniture stores in Singapore.'}}
# {'124. Shop around at Cat Socrates': {'Address': '448 Joo Chiat Road, Singapore 427661', 'Opening hours': 'Mon 11am-6pm | Tue-Sat 11am-8pm | Sun & PH 11am-7pm', 'Contact': '6348 0863'}}
# {'125. Revisit\xa0People’s Park Centre': {'Address': '101 Upper Cross Street, Singapore 058357', 'Contact': '6535 9177'}}
# {'126. Discover T for Toys$1': {'Address': '18 Tampines Industrial Crescent, Space @ Tampines #01-02A, Singapore 528605', 'Opening hours': 'Mon-Fri 12pm-6pm | Sat-Sun 12pm-7pm', 'Contact': '9021 7376'}}
# {'127. Browse through comic book stores': {'Image credit': 'Evernew Book Store'}}
# {'128. Shop at Don Don Donki': {}}
# {'129. Stroll through Bugis Street': {'Opening hours': '10am-10pm, Daily', 'Contact': '6338 9513'}}
# {'130. Wine, dine, and shop at Dempsey Hill': {'Address': 'Dempsey Road, Singapore 249679'}}

# %%
activity_dicts
# Out:
# [{'1. Explore Mandai Wildlife Reserve': {'Contact': '6269 3411',
#    'Address': '80 Mandai Lake Road, Singapore 729826',
#    'Singapore Zoo': '8.30am-6pm, Daily (Last entry at 5pm)',
#    'River Wonders': '10am-7pm, Daily (Last entry at 6pm)',
#    'Night Safari': '7.15pm-12am, Daily (Last entry at 11.15pm)',
#    'Bird Paradise': '9am-6pm, Daily (Last entry at 5pm)'}},
#  {'2. See the S.E.A. Aquarium': {'Address': '8 Sentosa Gateway, Sentosa Island, Singapore 098269',
#    'Opening hours': '10am-5pm, Daily'}},
#  {'3. Visit the Museum of Ice Cream': {'Address': '100 Loewen Road, Singapore 248837',
#    'Opening hours': 'Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed on Tuesdays)'}},
#  {'4. Swim at Wild Wild Wet': {'Address': '1 Pasir Ris Close, Downtown East, Singapore 519599',
#    'Opening hours': 'Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Closed on Tuesdays)',
#    'Contact': '6581 9128'}},
#  {'5. Roller skate at Hi-Roller': {'Address': '1 Pasir Ris Close, E!Hub, Market Square @ Downtown East, #05-103, Singapore 519599',
#    'Opening hours': 'Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 11am-10pm',
#    'Contact': '9694 4094'}},
#  {'6. Play arcade games at Timezone Westgate': {'Address': '3 Gateway Drive, Westgate #B1-45, Singapore 608532',
#    'Opening hours': 'Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-11pm | Sun 10am-10pm',
#    'Contact': '6265 1132'}},
#  {'7. Frolic around at Airzone (temporarily closed till Oct 2024)': {}},
#  {'8. Learn new skills at NLB libraries': {}},
#  {'9. Discover new playgrounds in Singapore': {}},
#  {'10. Chill out at Snow City': {'Address': '21 Jurong Town Hall Road, Singapore 609433',
#    'Opening hours': 'Tue-Fri 10am-5pm | Sat-Sun & PH 10am-6pm',
#    'Contact': '6560 2306'}},
#  {'11. Tour the Jacob Ballas Children’s Garden': {'Address': '481 Bukit Timah Road, Singapore 259769',
#    'Jacob Ballas Children’s Garden': 'Tue-Sun 8am-7pm (Closed on Mondays, except PHs)',
#    'Singapore Botanic Gardens': '5am-12am, Daily',
#    'Contact': '1800 471 7300'}},
#  {'12. Try fishing at\xa0Qian Hu Fish Farm': {'Address': 'No. 71 Jalan Lekar, Singapore 698950',
#    'Opening hours': 'Mon-Fri 9am-6pm | Sat-Sun 9am-7pm',
#    'Contact': '6766 1554'}},
#  {'13. Play with felines at The Cat Cafe': {'Address': '241B Victoria Street, Singapore 188030',
#    'Opening hours': 'Mon 3pm-10pm | Tue-Fri 10am-9pm | Sat-Sun 10am-10pm',
#    'Contact': '6338 6815'}},
#  {'14. Support the Kitten Sanctuary': {'Address': '781A North Bridge Road, #02-01, Singapore 198749',
#    'Opening hours': 'Sat-Sun 11.30am-12.30pm, 5pm-6pm (Closed from Mondays to Fridays)',
#    'Contact': '6336 2133'}},
#  {'15. Relax in Singapore’s newest hotels': {}},
#  {'16. Bungy jump at Skypark Sentosa by AJ Hackett': {'Address': '30 Siloso Beach Walk, Singapore 099011',
#    'Opening hours': 'Mon-Fri 12.30pm-7pm | Sat–Sun 11.30pm-7pm ',
#    'Contact': '6911 3070\xa0'}},
#  {'17. Ride the Skyline Luge': {'Address': '45 Siloso Beach Walk, Sentosa, Singapore 099003',
#    'Opening hours': 'Mon-Thu 11am-7.30pm | Fri 11am-9pm | Sat 10am-9pm | Sun 10am-7.30pm',
#    'Contact': '6274 0472\xa0\xa0'}},
#  {'18. Spend a day at NERF Action Xperience (Closed)': {'Address': '6 Raffles Boulevard, Marina Square #01-208, Singapore 039594',
#    'Opening hours': '12pm-8pm, Daily'}},
#  {'19. Retreat to Adventure HQ': {'Address': '2 Yishun Walk, HomeTeamNS Khatib, Singapore 767944',
#    'Opening hours': 'Tue 2pm-5.30pm | Wed-Fri 2pm-5.30pm and 6pm-9.30pm | Sat-Sun, School Holidays & PH 10am-1.30pm, 2pm-5.30pm, and 6pm-9.30pm (Closed on Mondays)',
#    'Contact': '6705 9420'}},
#  {'20. Go-kart at The Karting Arena': {'Address': '511 Upper Jurong Road, Block B, Singapore 638366',
#    'Opening hours': 'Tue-Fri 1pm-9pm | Sat-Sun 9am-9pm (Closed on Mondays)'}},
#  {'21.\xa0 Cable-ski at Singapore Wake Park': {'Address': '1206A East Coast Parkway, Singapore 449891',
#    'Opening hours': '10am-8pm, Daily | Sat-Sun 9am-8pm',
#    'Contact': '6636 4266'}},
#  {'22. Throw axes at Axe Factor': {'Address': '200 Turf Club Road, The Grandstand #01-32A/B & #01-34A/B, Singapore 287994',
#    'Opening hours': 'Tue-Sun 12pm-10pm (Closed on Mondays)',
#    'Contact': '8923 8945'}},
#  {'23. Golf virtually at Five Iron Golf': {'Address': '139 Cecil Street, #13-01, Singapore 069539',
#    'Opening hours': 'Mon-Sat 7am-12am | Sun 7am-8pm',
#    'Contact': '6993 4131'}},
#  {'24. Skydive indoors at iFly Singapore': {'Address': '43 Siloso Beach Walk, #01-01, Singapore 099010',
#    'Opening hours': 'Thu-Tue & PH 9am-10pm | Wed 11am-10pm',
#    'Contact': '6571 0000'}},
#  {'25. Jump around in trampoline parks': {}},
#  {'26. Try bouldering or rock climbing': {}},
#  {'27. Go bowling at K Bowling Club': {'Address': '313 Orchard Road, 313@Somerset #03-27, Singapore 238895',
#    'Opening hours': '10am-1am, Daily',
#    'Contact': '6737 5313'}},
#  {'28. Ride coasters at Universal Studios Singapore': {'Address': '8 Sentosa Gateway, Singapore 098269',
#    'Opening hours': 'Refer to Universal Studios Singapore’s calendar for more information',
#    'Contact': '6577 8888'}},
#  {'29. Cycle on water at WaterbikeSG ': {'Address': 'Campsite 1 at Pasir Ris Park, near Carpark F, 133 Pasir Ris Road, Singapore 519149',
#    'Opening hours': 'Sat-Sun 9am-6pm, by appointment (Closed from Mondays to Fridays)',
#    'Contact': '9871 8007'}},
#  {'30. \xa0Try extreme sports at Mega Adventure': {'Address': '10A Siloso Beach Walk, Singapore 099008',
#    'Opening hours': 'Mon-Fri 2pm-6pm | Sat-Sun & PH 11am-6pm',
#    'Contact': '6722 3785'}},
#  {'31. Play outdoor laser tag with GO Team': {'Contact': '9003 1177'}},
#  {'32. Ice-skate at Kallang Ice World': {'Address': '5 Stadium Walk, Kallang Leisure Park #03-08/09, Singapore 397693',
#    'Opening hours': 'Sun-Thu 10am-10pm | Fri-Sat & Eve of PH 10am-12am | PH 9am-10pm',
#    'Contact': '6348 1347'}},
#  {'33. Mountain-bike across Singapore': {}},
#  {'34. Snorkel at Adventure Cove Waterpark': {'Address': '8 Sentosa Gateway, Singapore 098269',
#    'Opening hours': 'Fri-Tue 10am-5pm (Closed Wed-Thu)'}},
#  {'35. Scale and slide through Coastal PlayGrove': {'Address': '902 East Coast Park Service Road, Singapore 449874',
#    'Opening hours': 'Tue-Sun 8am-8pm (Closed on Mondays)'}},
#  {'36. Bike around Marina Bay': {'Opening hours': 'Various hours; view all GoCycling opening hours',
#    'Contact': '8831 3068'}},
#  {'37. Hang out at Skateparks': {'Address': 'Yuan Ching Road, Jurong Lake Gardens',
#    'Opening hours': 'Tue-Sun 8am-10pm (Closed on Mondays)'}},
#  {'38. Tackle a high elements course at Forest Adventure': {'Address': 'Bedok Reservoir Park, Singapore 478931',
#    'Opening hours': 'Mon-Fri 9.30am-6pm | Sat-Sun & PH 9.30am-6.30pm',
#    'Contact': '6206 9744'}},
#  {'39. Have an overnight cycling trip': {}},
#  {'40. Hop on a scenic bus ride around Singapore': {}},
#  {'41. Watch movies at an outdoor cinema': {'Address': '2 Keppel Bay Vista, Singapore 098382',
#    'Opening hours': 'Selected nights, 7.45pm – end of screening',
#    'Contact': 'info@cinewav.com'}},
#  {'42. Make pottery at Thow Kwang Pottery Jungle': {'Address': '85 Lorong Tawas, Singapore 639823',
#    'Opening hours': '9am-5pm, Daily',
#    'Contact': '6265 5808 | 8949 0168 (WhatsApp)'}},
#  {'43. Experience VR with Headrock VR': {'Opening hours': 'Mon-Fri 12pm-7pm | Sat-Sun & PH 11am-7pm (last admission 6pm)',
#    'Contact': '6963 4127'}},
#  {'44. Try the Boeing 737 Flight Experience': {'Address': '30 Raffles Avenue, Singapore Flyer #02-06, Singapore 039803',
#    'Contact': '6339 2737'}},
#  {'45. Explore Pearl’s Hill Terrace': {'Address': '195 Pearl’s Hill Terrace, Singapore 168976'}},
#  {'46. Tour Tiger Brewery': {'Address': '459 Jalan Ahmad Ibrahim, Singapore 639934',
#    'Tour schedule': 'Fri-Sun 1pm-6.30pm (Excluding eves of PH and PH, last tours at 5pm)',
#    'Telephone': '6860 3005'}},
#  {'47. Watch films at The Projector': {'Address': 'The Cathay, 2 Handy Rd, #05-01, Singapore 229233'}},
#  {'48. Draw graffiti at Heaven Spot': {'Address': '3 Lorong Bakar Batu, #03-01, Singapore 348741',
#    'Opening hours': 'Tue-Thu 2pm-9pm | Fri-Sun 10am-9pm (Closed on Mondays)',
#    'Contact': '8268 3160'}},
#  {'49.\xa0 Destress at The Fragment Room': {'Address': '490 MacPherson Road, Singapore 368198',
#    'Opening hours': '12am-10pm, Daily',
#    'Contact': '6970 0343'}},
#  {'50. Hang out at board game cafes': {}},
#  {'51. Navigate through an escape room': {}},
#  {'52. Go prawning at FishBugis+': {'Address': 'Bugis+, 201 Victoria Street, #07-05, Singapore 188067',
#    'Opening hours': '9am-6am, Daily',
#    'Contact': '9008 0201 | 83386530 (WhatsApp)'}},
#  {'53. Get competitive at Cow Play Cow Moo': {}},
#  {'54. Attend an art jamming session': {}},
#  {'55. Bathe in a Japanese-style onsen': {}},
#  {'56. Book for a massage': {}},
#  {'57. Visit ORTO\xa0': {'Address': '81 Lorong Chencharu, #01-01, Singapore 769198',
#    'Contact': '6257 8858'}},
#  {'58. Travel to Senoko or Jurong Fishery Port': {'Address': '31 Attap Valley Road, #02-29, Singapore 759908',
#    'Opening hours': 'Tue-Sun 2am-6am (Closed on Mondays)',
#    'Contact': '6257 6721'}},
#  {'59. Stroll around Gardens by the Bay': {}},
#  {'60. Drop by NTU’s Yunnan Garden': {'Address': '12 Nanyang Drive, Singapore 637721',
#    'Opening hours': '24 hours, Daily',
#    'Contact': ' 6791 1744'}},
#  {'61. See Little Guilin': {'Address': 'Along Bukit Batok East Avenue 5',
#    'Getting there': 'Walk about 8 minutes from Bukit Gombak MRT station, or take Bus 945 to Bukit Gombak Stadium'}},
#  {'62. Tour urban farms in Singapore': {}},
#  {'63. Island-hop between Lazarus, St John’s, & Kusu Island': {}},
#  {'64. Check out the Live Turtle & Tortoise Museum': {'Address': '81 Lorong Chencharu, #01-16, Singapore 769198',
#    'Opening hours': 'Wed-Mon 10am-6pm (Closed on Tuesdays)',
#    'Contact': '6268 5363'}},
#  {'65. Go fishing around Singapore': {}},
#  {'66. Venture out to Changi Bay Point': {'Address': 'Aviation Park Road'}},
#  {'67. Birdwatch at Kranji Marshes': {}},
#  {'68. Trek through Maju Forest': {}},
#  {'69. Conquer the MacRitchie Treetop Walk': {'Opening hours': '7am-7pm, Daily'}},
#  {'70. Take a day trip to Pulau Ubin & Chek Jawa Wetlands': {}},
#  {'71. Have a romantic picnic': {}},
#  {'72. Hike through Singapore’s parks & nature reserves': {}},
#  {'73. Unwind at Sembawang Hot Spring Park': {'Address': 'Along Gambas Avenue, Singapore 756952'}},
#  {'74. Explore Jurong Lake Gardens': {'Address': '104 Yuan Ching Road, Singapore 618665',
#    'Opening hours': '24 hours, Daily'}},
#  {'75. See “Avatar Trees” at Bukit Brown Cemetery': {}},
#  {'76. Walk through Sungei Buloh Wetland Reserve': {'Address': '301 Neo Tiew Crescent, Singapore 718925',
#    'Opening hours': '7am-7pm, Daily (last entry at 6.30pm)',
#    'Contact': '6794 1401'}},
#  {'77. Bike or hike through the Park Connector Network': {}},
#  {'78. Visit the Tropical Montane Orchidetum': {}},
#  {'79. Have a brunch date at a cafe': {'Image adapted from': '@mighty.explorers, @eatingwitheating via Instagram',
#    'Some names to bookmark right off the bat': 'Smile Dessert for its blue and white ball pit; and Fraser Street Brothers for its vibrant rainbow theme.'}},
#  {'80. Have a seaside meal while yacht-viewing': {}},
#  {'81. Dine amidst nature at Lucky Saigon Cafe': {'Address': '356 Tanglin Road, Singapore 247674',
#    'Opening hours': '8am-10pm, Daily',
#    'Contact': '6556 8228'}},
#  {'82. Travel to Smith Marine Floating Restaurant': {'Address': '01’23’52″N – 103’57’42″E',
#    'Opening hours': '10am-7pm, Daily (Closed on alternate Mondays)',
#    'Contact': '9792 7609 (WhatsApp/SMS for reservations)'}},
#  {'83. Dine at Soul Coffee': {'Address': '11 Tanjong Katong Road, Kinex Mall #02-16, Singapore 437157',
#    'Opening hours': '11am-10pm, Daily',
#    'Contact': '9876 7257'}},
#  {'84. Order a drink at Platform 1094 cafe': {'Address': '1094 Serangoon Road, Singapore 328192',
#    'Opening hours': 'Tue-Sun 11am-10pm (Closed on Mondays)',
#    'Contact': '6204 6003'}},
#  {'85. Visit unique food courts in Singapore': {'Address': '1 Kim Seng Promenade, #03-116 Great World, Singapore 237994',
#    'Opening hours': '10am-10pm, Daily'}},
#  {'86. Take your dog to a dog-friendly cafe': {}},
#  {'87. Go on a pub crawl': {}},
#  {'88. Enjoy a foodie & heritage walk in Geylang': {}},
#  {'89. Catch free music & art shows at the Esplanade': {'Address': '1 Esplanade Drive, Singapore 038981'}},
#  {'90. Check out the Vintage Camera Museum': {'Address': '8C-8D Jalan Kledek, Singapore 199263',
#    'Opening hours': '11am-7pm, Daily',
#    'Contact': '6291 2278'}},
#  {'91. Walk through the Japanese Cemetery Park': {'Address': '825B Chuan Hoe Avenue, Singapore 549854',
#    'Opening hours': '7am-7pm, Daily',
#    'Contact': '6468 0066 (The Japanese Association, Singapore)'}},
#  {'92. Visit the Science Centre': {'Address': '15 Science Centre Road, Singapore 609081',
#    'Opening hours': 'Tue-Sun 10am-5pm (last entry 4.15pm) (Closed Mondays except for public holidays and school holidays)',
#    'Contact': '6425 2500'}},
#  {'93. Go museum-hopping': {}},
#  {'94. Visit the Civil Defence Heritage Gallery': {'Admission': 'Free',
#    'Address': '62 Hill Street, Singapore 179367',
#    'Contact': '6332 2996',
#    'Opening hours': 'Tue-Sun 10am-5pm (Closed on Mondays)'}},
#  {'95. Tour The Intan': {'Address': '69 Joo Chiat Terrace, Singapore 427231',
#    'Opening hours': 'By appointment only',
#    'Contact': '6440 1148'}},
#  {'96. Check out the Singapore Art Museum': {'Address': '39 Keppel Road, Tanjong Pagar Distripark, #01-02, Singapore 089065',
#    'Opening hours': '10am-7pm, Daily'}},
#  {'97. Go on a Fort Serapong tour': {'Address': '54 Lakeshore View, Singapore 09844'}},
#  {'98. Visit the Buddha Tooth Relic Temple': {}},
#  {'99. Explore Kampong Lorong Buangkok': {}},
#  {'100. Revisit St James Power Station': {'Admission': 'Free',
#    'Address': '3 Sentosa Gateway, Singapore 098544',
#    'Opening hours': 'Tue-Sun 10am-6pm (Closed on Mondays)'}},
#  {'101. Explore Haw Par Villa': {'Address': '262 Pasir Panjang Road, Singapore 118 628',
#    'Opening hours': 'Sun-Thu 9am-8pm | Fri-Sat 9am-10pm',
#    'Contact': '6773 0103'}},
#  {'102. Visit the ArtScience Museum': {'Address': '6 Bayfront Avenue, Singapore 018974',
#    'Opening hours': '10am-7pm, Daily',
#    'Contact': '6688 8888'}},
#  {'103. Trawl Kampong Gelam': {}},
#  {'104. Browse the grand Rotunda Library & Archive': {'Address': 'National Gallery Singapore, 1 St Andrew’s Road, Supreme Court Wing Level 3, Singapore 178957',
#    'Opening hours': 'Mon-Fri 10am-12.30pm & 2pm-5pm (Closed on Sat-Sun & PHs)',
#    'Contact': ' 6697 9180\xa0'}},
#  {'105. Visit the Trick Eye Museum': {'Address': '80 Siloso Road, Southside Interim Market, Block D #01-04, Singapore 098969',
#    'Opening hours': '11am-7pm, Daily',
#    'Contact': '6795 2371\xa0'}},
#  {'106. Tour the Singapore City Gallery': {'Address': '45 Maxwell Road, Level 1, The URA Centre, Singapore 069118',
#    'Opening hours': 'Mon-Sat 9am-5pm (Closed on Sundays & PH)'}},
#  {'107. Spend time at the Indian Heritage Centre': {'Address': '5 Campbell Lane, Singapore 209924',
#    'Opening hours': 'Tue-Sun 10am-6pm (Closed on Mondays)',
#    'Contact': '6291 1601'}},
#  {'108. Join the Kebun Baru Birdsinging Club': {'Address': 'Block 159 Ang Mo Kio Ave 5, Singapore 560159',
#    'Opening hours': 'Sat-Sun & PH 9.30am-12pm'}},
#  {'109. Stop by Gillman Barracks': {}},
#  {'110. See lighthouses in Singapore': {}},
#  {'111. Admire Jewel Changi’s Rain Vortex': {}},
#  {'112. Revisit old-school playgrounds': {}},
#  {'113. Go on Apple Photo Walks': {}},
#  {'114. Have a photoshoot at selfie studios': {'Address': '110 Lorong 23 Geylang, Victory Center #03-07, Singapore 388410',
#    'Opening hours': '10am-5pm, Daily',
#    'Contact': '9029 4733'}},
#  {'115. Head up to ION Sky': {'Address': '2 Orchard Turn, ION Orchard Mall Level 56, Singapore 238801',
#    'Opening hours': 'Tue-Thu 4pm-8pm | Fri-Sat 2-9pm (Closed Sundays & Mondays)',
#    'Contact': '6238 8228'}},
#  {'116. Have a date at Wings of Time': {'Address': 'Near Beach Station, 50 Beach View, Singapore 098604',
#    'Performance timings': '7.40pm and 8.40pm, Daily',
#    'Contact': '6361 0088 (Singapore Cable Car ticketing counter)'}},
#  {'117. Check out CapitaSpring': {'Address': '88 Market Street, Singapore 048948',
#    'Contact': '6713 3948'}},
#  {'118. Ride on the SkyHelix': {'Address': '41 Imbiah Road, Sentosa, Singapore 099707',
#    'Opening hours': '10am-9.30pm, Daily',
#    'Contact': '6361 0088'}},
#  {'119. Watch the sunset at Yishun Dam': {'Address': 'Yishun Avenue 1, Singapore 769130'}},
#  {'120. Visit rooftop gardens around Singapore': {}},
#  {'121. Go shopping in Little India': {}},
#  {'122. Read at Woods in the Books': {'Address': '3 Yong Siak Street, Singapore 168642',
#    'Opening hours': 'Wed-Sat 10am-7pm | Sun-Mon 10am-6pm (Closed on Tuesdays)',
#    'Contact': '6222 9980'}},
#  {'123. Go thrifting at Turf Club Road’s Antique Row': {'Find out more about what you can do at Turf Club Road\xa0and read our articles on antique and vintage furniture and knick-knacks': 'from\xa0stores with 80s collectibles in Singapore to secondhand furniture stores in Singapore with refurbished vintage and antique items to\xa0undiscovered secondhand furniture stores in Singapore.'}},
#  {'124. Shop around at Cat Socrates': {'Address': '448 Joo Chiat Road, Singapore 427661',
#    'Opening hours': 'Mon 11am-6pm | Tue-Sat 11am-8pm | Sun & PH 11am-7pm',
#    'Contact': '6348 0863'}},
#  {'125. Revisit\xa0People’s Park Centre': {'Address': '101 Upper Cross Street, Singapore 058357',
#    'Contact': '6535 9177'}},
#  {'126. Discover T for Toys$1': {'Address': '18 Tampines Industrial Crescent, Space @ Tampines #01-02A, Singapore 528605',
#    'Opening hours': 'Mon-Fri 12pm-6pm | Sat-Sun 12pm-7pm',
#    'Contact': '9021 7376'}},
#  {'127. Browse through comic book stores': {'Image credit': 'Evernew Book Store'}},
#  {'128. Shop at Don Don Donki': {}},
#  {'129. Stroll through Bugis Street': {'Opening hours': '10am-10pm, Daily',
#    'Contact': '6338 9513'}},
#  {'130. Wine, dine, and shop at Dempsey Hill': {'Address': 'Dempsey Road, Singapore 249679'}}]

# %% [markdown]
# Remove this item as it is a duplicate in another scraped activity dataframe

# %%
activity_dicts.pop(0)
# Out:
# {'1. Explore Mandai Wildlife Reserve': {'Contact': '6269 3411',
#   'Address': '80 Mandai Lake Road, Singapore 729826',
#   'Singapore Zoo': '8.30am-6pm, Daily (Last entry at 5pm)',
#   'River Wonders': '10am-7pm, Daily (Last entry at 6pm)',
#   'Night Safari': '7.15pm-12am, Daily (Last entry at 11.15pm)',
#   'Bird Paradise': '9am-6pm, Daily (Last entry at 5pm)'}}

# %% [markdown]
# Iterate through list of dictionaries, extracting activity name and details and appending to new dataframe

# %%
rows = []


for item in activity_dicts:
   
    activity, details = next(iter(item.items()))

    row = {'Activity': activity}
    row['Contact'] = details.get('Contact', 'not available')
    row['Opening hours'] = details.get('Opening hours', 'not available')
    row['Address'] = details.get('Address', 'not available')
    rows.append(row)

df = pd.DataFrame(rows)
df.set_index('Activity', inplace=True)

df.head()
# Out:
#                                                  Contact  \
# Activity
# 2. See the S.E.A. Aquarium                 not available
# 3. Visit the Museum of Ice Cream           not available
# 4. Swim at Wild Wild Wet                       6581 9128
# 5. Roller skate at Hi-Roller                   9694 4094
# 6. Play arcade games at Timezone Westgate      6265 1132
#
#                                                                                Opening hours  \
# Activity
# 2. See the S.E.A. Aquarium                                                   10am-5pm, Daily
# 3. Visit the Museum of Ice Cream           Mon & Wed 10am-6pm | Thu-Sun 10am-9pm (Closed ...
# 4. Swim at Wild Wild Wet                   Mon & Wed-Fri 12pm-6pm | Sat-Sun 11am-6pm (Clo...
# 5. Roller skate at Hi-Roller               Mon-Thu 11am-6.30pm | Fri 12pm-8pm | Sat-Sun 1...
# 6. Play arcade games at Timezone Westgate  Mon-Thu 11am-10pm | Fri 11am-11pm | Sat 10am-1...
#
#                                                                                      Address
# Activity
# 2. See the S.E.A. Aquarium                 8 Sentosa Gateway, Sentosa Island, Singapore 0...
# 3. Visit the Museum of Ice Cream                           100 Loewen Road, Singapore 248837
# 4. Swim at Wild Wild Wet                   1 Pasir Ris Close, Downtown East, Singapore 51...
# 5. Roller skate at Hi-Roller               1 Pasir Ris Close, E!Hub, Market Square @ Down...
# 6. Play arcade games at Timezone Westgate  3 Gateway Drive, Westgate #B1-45, Singapore 60...

# %% [markdown]
# Exporting scraped dataset

# %%
df.to_csv('../datasets/activity.csv')

# %%
df.tail(10)
# Out:
#                                                          Contact  \
# Activity
# 121. Go shopping in Little India                   not available
# 122. Read at Woods in the Books                        6222 9980
# 123. Go thrifting at Turf Club Road’s Antique Row  not available
# 124. Shop around at Cat Socrates                       6348 0863
# 125. Revisit People’s Park Centre                      6535 9177
# 126. Discover T for Toys$1                             9021 7376
# 127. Browse through comic book stores              not available
# 128. Shop at Don Don Donki                         not available
# 129. Stroll through Bugis Street                       6338 9513
# 130. Wine, dine, and shop at Dempsey Hill          not available
#
#                                                                                        Opening hours  \
# Activity
# 121. Go shopping in Little India                                                       not available
# 122. Read at Woods in the Books                    Wed-Sat 10am-7pm | Sun-Mon 10am-6pm (Closed on...
# 123. Go thrifting at Turf Club Road’s Antique Row                                      not available
# 124. Shop around at Cat Socrates                   Mon 11am-6pm | Tue-Sat 11am-8pm | Sun & PH 11a...
# 125. Revisit People’s Park Centre                                                      not available
# 126. Discover T for Toys$1                                       Mon-Fri 12pm-6pm | Sat-Sun 12pm-7pm
# 127. Browse through comic book stores                                                  not available
# 128. Shop at Don Don Donki                                                             not available
# 129. Stroll through Bugis Street                                                    10am-10pm, Daily
# 130. Wine, dine, and shop at Dempsey Hill                                              not available
#
#                                                                                              Address
# Activity
# 121. Go shopping in Little India                                                       not available
# 122. Read at Woods in the Books                                 3 Yong Siak Street, Singapore 168642
# 123. Go thrifting at Turf Club Road’s Antique Row                                      not available
# 124. Shop around at Cat Socrates                                448 Joo Chiat Road, Singapore 427661
# 125. Revisit People’s Park Centre                           101 Upper Cross Street, Singapore 058357
# 126. Discover T for Toys$1                         18 Tampines Industrial Crescent, Space @ Tampi...
# 127. Browse through comic book stores                                                  not available
# 128. Shop at Don Don Donki                                                             not available
# 129. Stroll through Bugis Street                                                       not available
# 130. Wine, dine, and shop at Dempsey Hill                             Dempsey Road, Singapore 249679
