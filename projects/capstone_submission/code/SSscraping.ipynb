# %% [markdown]
# # SecretSingapore Scraping

# %% [markdown]
# In this notebook I will be scraping data from SecretSingapore for activities to do in Singapore.

# %%
import pandas as pd 
import re
from scrapingbee import ScrapingBeeClient
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://secretsingapore.co/things-to-do-singapore/'
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %% [markdown]
# ## Create a Beautiful Soup object

# %%
soup = BeautifulSoup(res.text, 'lxml') # parse html for python
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-GB">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <!-- This site is optimized with the Yoast SEO plugin v22.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>60+ Best Things To Do In Singapore This Year</title>
# <meta content="We've rounded up the best attractions and entertainment experiences in town, providing you the best things to do in Singapore." name="description"/>
# <link href="https://secretsingapore.co/things-to-do-singapore/" rel="canonical"/>
# <meta content="en_GB" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="60 Incredible Things To Do In Singapore At Least Once In Your Life" property="og:title"/>
# <meta content="We've rounded up the best attractions and entertainment experiences in town, providing you the best things to do in Singapore." property="og:description"/>
# <meta content="https://secretsingapore.co/things-to-do-singapore/" property="og:url"/>
# <meta content="Secret Singapore" property="og:site_name"/>
# <meta content="2022-02-24T10:48:41+00:00" property="article:published_time"/>
# <meta content="2024-04-05T09:04:34+00:00" property="article:modified_time"/>
# <meta content="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/13202008/Megan-Article-Covers-2023-05-17T161842.761.png" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="800" property="og:image:height"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="Megan Zara Walsh" name="author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="44 Incredible Things To Do This Year In Singapore" name="twitter:title"/>
# <meta content="Written by" name="twitter:label1"/>
# <meta content="Megan Zara Walsh" name="twitter:data1"/>
# <meta content="Estimated reading time" name="twitter:label2"/>
# <meta content="32 minutes" name="twitter:data2"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"NewsArticle","@id":"https://secretsingapore.co/things-to-do-singapore/#article","isPartOf":{"@id":"https://secretsingapore.co/things-to-do-singapore/"},"author":{"name":"Megan Zara Walsh","@id":"https://secretsingapore.co/#/schema/person/bf065a3c503cb249671594197596d1d3"},"headline":"60 Incredible Things To Do In Singapore At Least Once In Your Life","datePublished":"2022-02-24T10:48:41+00:00","dateModified":"2024-04-05T09:04:34+00:00","mainEntityOfPage":{"@id":"https://secretsingapore.co/things-to-do-singapore/"},"wordCount":5398,"commentCount":0,"publisher":{"@id":"https://secretsingapore.co/#organization"},"image":{"@id":"https://secretsingapore.co/things-to-do-singapore/#primaryimage"},"thumbnailUrl":"https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/13202008/Megan-Article-Covers-2023-05-17T161842.761.png","keywords":["attraction tickets","exhibition","thematic tour","trip / travel"],"articleSection":["Secret Guides","Things To Do"],"inLanguage":"en-GB","potentialAction":[{"@type":"CommentAction","name":"Comment","target":["https://secretsingapore.co/things-to-do-singapore/#respond"]}],"articleBody":"In a city full of excitement, you might feel a little paralysed by choice when wondering what to do in Singapore. When there&#039;s as much on offer as our incredible city provides, it can be pretty overwhelming choosing where to start, and that&#039;s where Secret Singapore steps in to help. Whether you&#039;re a local or a traveller looking to get the best out of this iconic city, we&#039;ve tracked down 60 of the best things to do in Singapore, no matter the time of year.1. See the world&#039;s largest public display of Southeast Asian artNational Gallery Singapore offers the largest public display of modern Southeast Asian art in the world. The  is the perfect place for art lovers of all ages to wander the latest exhibitions and learn about beautiful artworks from across the world. Wonderfully, majority of exhibits at the museum are free entry year round.📍Civic District, Singapore 1789572. Race at Singapore&#039;s only night luge rideSingaporeans are familiar with , but have you heard about their new night experience? Visitors are invited to ride a hybrid go-kart and toboggan down the neon-lit track on Sentosa Island, against the backdrop of groovy tunes, every weekend from 7pm to 9pm. Children over 2 years old can ride with an adult. Definitely, it&#039;s one of the  in Singapore.📍1 Imbiah Rd, Singapore 0996923. Stroll around Gardens By The BayThese wonderful gardens are the star of Singapore and one of  if you&#039;re strapped for cash. Whether you go to Gardens By The Bay during the day or night, you can wander under the famous Supertrees, pose under a majestic skyline, and even attend a magical Light and Sound Show. If you want to walk on the skywalk, you&#039;ll need to pay a small fee.📍 18 Marina Gardens Dr, Singapore 0189534. Indulge on famous Singapore Chilli CrabSingapore Chilli Crab is a must try dish if you&#039;re a tourist in Singapore. It became popular in the 1950s when a lady named Madam Cher Yam Tian put stir-fried crabs and chilli sauce together and sold it to customers. Today, it is one of the most famous  with many different varieties in restaurants across the island.📍 Various Locations 5. Battle it out on Asia&#039;s first gamified electric go-kartsSentosa Island keeps levelling up with new attractions yearly. One of these new experiences is among eight  at The Palawan @ Sentosa. HyperDrive is Asia&#039;s first gamified electric go-karts with 36 eco-friendly karts, and a track with 14 turns across three levels. It&#039;s a mix of real-life racing and virtual gaming at a speed of 50km/h. Definitely, one of the best things to do in Singapore. .📍54 Palawan Beach Walk, Singapore 0982336. Enjoy 360-degree city viewsNo trip to Singapore is complete without checking o ...
# <!-- / Yoast SEO plugin. -->
# <link href="//www.instagram.com" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <script>
# window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/secretsingapore.co\/wp-includes\/js\/wp-emoji-release.min.js?ver=35770932d476e8e75a9581ae19fefb6a"}};
# /*! This file is auto-generated */
# !function(i,n){var o,s,e;function c(e){try{var t={supportTests:e,timestamp:(new Date).valueOf()};sessionStorage.setItem(o,JSON.stringify(t))}catch(e){}}function p(e,t,n){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);var t=new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data),r=(e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(n,0,0),new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data));return t.every(function(e,t){return e===r[t]})}function u(e,t,n){switch(t){case"flag":return n(e,"\ud83c\udff3\ufe0f\u200d\u26a7\ufe0f","\ud83c\udff3\ufe0f\u200b\u26a7\ufe0f")?!1:!n(e,"\ud83c\uddfa\ud83c\uddf3","\ud83c\uddfa\u200b\ud83c\uddf3")&&!n(e,"\ud83c\udff4\udb40\udc67\udb40\udc62\udb40\udc65\udb40\udc6e\udb40\udc67\udb40\udc7f","\ud83c\udff4\u200b\udb40\udc67\u200b\udb40\udc62\u200b\udb40\udc65\u200b\udb40\udc6e\u200b\udb40\udc67\u200b\udb40\udc7f");case"emoji":return!n(e,"\ud83e\udef1\ud83c\udffb\u200d\ud83e\udef2\ud83c\udfff","\ud83e\udef1\ud83c\udffb\u200b\ud83e\udef2\ud83c\udfff")}return!1}function f(e,t,n){var r="undefined"!=typeof WorkerGlobalScope&&self instanceof WorkerGlobalScope?new OffscreenCanvas(300,150):i.createElement("canvas"),a=r.getContext("2d",{willReadFrequently:!0}),o=(a.textBaseline="top",a.font="600 32px Arial",{});return e.forEach(function(e){o[e]=t(a,e,n)}),o}function t(e){var t=i.createElement("script");t.src=e,t.defer=!0,i.head.appendChild(t)}"undefined"!=typeof Promise&&(o="wpEmojiSettingsSupports",s=["flag","emoji"],n.supports={everything:!0,everythingExceptFlag:!0},e=new Promise(function(e){i.addEventListener("DOMContentLoaded",e,{once:!0})}),new Promise(function(t){var n=function(){try{var e=JSON.parse(sessionStorage.getItem(o));if("object"==typeof e&&"number"==typeof e.timestamp&&(new Date).valueOf()<e.timestamp+604800&&"object"==typeof e.supportTests)return e.supportTests}catch(e){}return null}();if(!n){if("undefined"!=typeof Worker&&"undefined"!=typeof OffscreenCanvas&&"undefined"!=typeof URL&&URL.createObjectURL&&"undefined"!=typeof Blob)try{var e="postMessage("+f.toString()+"("+[JSON.stringify(s),u.toString(),p.toString()].join(",")+"));",r=new Blob([e],{type:"text/javascript"}),a=new Worker(URL.createObjectURL(r),{name:"wpTestEmojiSupports"});return void(a.onmessage=function(e){c(n=e.data),a.terminate(),t(n)})}catch(e){}c(n=f(s,u,p))}t(n)}).then(function(e){for(var t in e)n.supports[t]=e[t],n.supports.everything=n.supports.everything&&n.supports[t],"flag"!==t&&(n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&n.supports[t]);n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&!n.supports.flag,n.DOMReady=!1,n.readyCallback=function(){n.DOMReady=!0}}).then(function(){return e}).then(function(){var e;n.supports.everything||(n.readyCallback(),(e=n.source||{}).concatemoji?t(e.concatemoji):e.wpemoji&&e.twemoji&&(t(e.twemoji),t(e.wpemoji)))}))}((window,document),window._wpemojiSettings);
# </script>
# <style id="wp-emoji-styles-inline-css">
#
# 	img.wp-smiley, img.emoji {
# 		display: inline !important;
# 		border: none !important;
# 		box-shadow: none !important;
# 		height: 1em !important;
# 		width: 1em !important;
# 		margin: 0 0.07em !important;
# 		vertical-align: -0.1em !important;
# 		background: none !important;
# 		padding: 0 !important;
# 	}
# </style>
# <link href="https://secretsingapore.co/wp-includes/css/dist/block-library/style.min.css?ver=35770932d476e8e75a9581ae19fefb6a" id="wp-block-library-css" media="all" rel="stylesheet"/>
# <style id="classic-theme-styles-inline-css">
# /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
# </style>
# <style id="global-styles-inline-css">
# body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}:where(.is-layout-grid){gap: 0.5em;}body .is-layout-flow > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-flow > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-flow > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-constrained > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-constrained > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > :where(:not(.alignleft):not(.alignright):not(.alignfull)){max-width: var(--wp--style--global--content-size);margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignwide{max-width: var(--wp--style--global--wide-size);}body .is-layout-flex{display: flex;}body .is-layout-flex{flex-wrap: wrap;align-items: center;}body .is-layout-flex > *{margin: 0;}body .is-layout-grid{display: grid;}body .is-layout-grid > *{margin: 0;}:where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-colu ...
# .wp-block-navigation a:where(:not(.wp-element-button)){color: inherit;}
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# .wp-block-pullquote{font-size: 1.5em;line-height: 1.6;}
# </style>
# <link href="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/css/app.css?ver=4.6.68" id="app-preload-css" media="all" rel="stylesheet"/>
# <style id="rocket-lazyload-inline-css">
# .rll-youtube-player{position:relative;padding-bottom:56.23%;height:0;overflow:hidden;max-width:100%;}.rll-youtube-player:focus-within{outline: 2px solid currentColor;outline-offset: 5px;}.rll-youtube-player iframe{position:absolute;top:0;left:0;width:100%;height:100%;z-index:100;background:0 0}.rll-youtube-player img{bottom:0;display:block;left:0;margin:auto;max-width:100%;width:100%;position:absolute;right:0;top:0;border:none;height:auto;-webkit-transition:.4s all;-moz-transition:.4s all;transition:.4s all}.rll-youtube-player img:hover{-webkit-filter:brightness(75%)}.rll-youtube-player .play{height:100%;width:100%;left:0;top:0;position:absolute;background:url(https://secretsingapore.co/wp-content/plugins/wp-rocket/assets/img/youtube.png) no-repeat center;background-color: transparent !important;cursor:pointer;border:none;}
# </style>
# <link href="https://secretsingapore.co/wp-json/" rel="https://api.w.org/"/><link href="https://secretsingapore.co/wp-json/wp/v2/posts/904" rel="alternate" type="application/json"/><link href="https://secretsingapore.co/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://secretsingapore.co/?p=904" rel="shortlink"/>
# <link href="https://secretsingapore.co/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fsecretsingapore.co%2Fthings-to-do-singapore%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://secretsingapore.co/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fsecretsingapore.co%2Fthings-to-do-singapore%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <link as="font" crossorigin="" href="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/fonts/montserrat-v25-latin-ext_latin-500.woff2" rel="preload"/>
# <link as="font" crossorigin="" href="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/fonts/montserrat-v25-latin-ext_latin-regular.woff2" rel="preload"/>
# <link as="font" crossorigin="" href="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/fonts/montserrat-v25-latin-ext_latin-600.woff2" rel="preload"/>
# <style data-critical-css-common="">
# 	.smn-ad-height-90{height:8.625rem}.smn-ad-height-100{height:9.25rem}.smn-ad-height-250{height:18.625rem}.smn-ad-height-600{height:40.5rem}.gpt-margin-bottom,.gpt-margin-bottom+.gpt-margin-bottom,article+.gpt-margin-bottom{margin-bottom:1rem}.top-bar-social-media__item{display:inline-block;min-width:1.875rem;min-height:2.5rem}.smn-header-logo{min-height:2.5rem}
# </style>
# <style>
# 	.single__featured-image-container{position:relative}.single__featured-image-container .single__featured-image-caption,.single__featured-image-container .wp-caption-text,.wp-caption .single__featured-image-caption,.wp-caption .wp-caption-text{position:absolute;bottom:0;left:0;padding:.25rem .5rem;font-size:.75rem;line-height:1.25}.single__subtitle{font-family:Montserrat,sans-serif;font-size:1rem;font-weight:300;margin-bottom:1.25rem}@media (min-width:768px){.single__subtitle{font-size:1.25rem}}
# </style>
# <!-- InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <script async="true" type="text/javascript">
# 			(function() {
# 				var host = window.location.hostname;
# 				var element = document.createElement('script');
# 				var firstScript = document.getElementsByTagName('script')[0];
# 				var url = 'https://cmp.inmobi.com'
# 					.concat('/choice/', 'q9DDm3u57PCdF', '/', host, '/choice.js?tag_version=V3');
# 				var uspTries = 0;
# 				var uspTriesLimit = 3;
# 				element.async = true;
# 				element.type = 'text/javascript';
# 				element.src = url;
#
# 				firstScript.parentNode.insertBefore(element, firstScript);
#
# 				function makeStub() {
# 					var TCF_LOCATOR_NAME = '__tcfapiLocator';
# 					var queue = [];
# 					var win = window;
# 					var cmpFrame;
#
# 					function addFrame() {
# 						var doc = win.document;
# 						var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
# 						if (!otherCMP) {
# 							if (doc.body) {
# 								var iframe = doc.createElement('iframe');
#
# 								iframe.style.cssText = 'display:none';
# 								iframe.name = TCF_LOCATOR_NAME;
# 								doc.body.appendChild(iframe);
# 							} else {
# 								setTimeout(addFrame, 5);
# 							}
# 						}
# 						return !otherCMP;
# 					}
#
# 					function tcfAPIHandler() {
# 						var gdprApplies;
# 						var args = arguments;
#
# 						if (!args.length) {
# 							return queue;
# 						} else if (args[0] === 'setGdprApplies') {
# 							if (
# 								args.length > 3 &&
# 								args[2] === 2 &&
# 								typeof args[3] === 'boolean'
# 							) {
# 								gdprApplies = args[3];
# 								if (typeof args[2] === 'function') {
# 									args[2]('set', true);
# 								}
# 							}
# 						} else if (args[0] === 'ping') {
# 							var retr = {
# 								gdprApplies: gdprApplies,
# 								cmpLoaded: false,
# 								cmpStatus: 'stub'
# 							};
#
# 							if (typeof args[2] === 'function') {
# 								args[2](retr);
# 							}
# 						} else {
# 							if(args[0] === 'init' && typeof args[3] === 'object') {
# 								args[3] = Object.assign(args[3], { tag_version: 'V3' });
# 							}
# 							queue.push(args);
# 						}
# 					}
#
# 					function postMessageEventHandler(event) {
# 						var msgIsString = typeof event.data === 'string';
# 						var json = {};
#
# 						try {
# 							if (msgIsString) {
# 								json = JSON.parse(event.data);
# 							} else {
# 								json = event.data;
# 							}
# 						} catch (ignore) {}
#
# 						var payload = json.__tcfapiCall;
#
# 						if (payload) {
# 							window.__tcfapi(
# 								payload.command,
# 								payload.version,
# 								function(retValue, success) {
# 									var returnMsg = {
# 										__tcfapiReturn: {
# 											returnValue: retValue,
# 											success: success,
# 											callId: payload.callId
# 										}
# 									};
# 									if (msgIsString) {
# 										returnMsg = JSON.stringify(returnMsg);
# 									}
# 									if (event && event.source && event.source.postMessage) {
# 										event.source.postMessage(returnMsg, '*');
# 									}
# 								},
# 								payload.parameter
# 							);
# 						}
# 					}
#
# 					while (win) {
# 						try {
# 							if (win.frames[TCF_LOCATOR_NAME]) {
# 								cmpFrame = win;
# 								break;
# 							}
# 						} catch (ignore) {}
#
# 						if (win === window.top) {
# 							break;
# 						}
# 						win = win.parent;
# 					}
# 					if (!cmpFrame) {
# 						addFrame();
# 						win.__tcfapi = tcfAPIHandler;
# 						win.addEventListener('message', postMessageEventHandler, false);
# 					}
# 				};
#
# 				makeStub();
#
# 				var uspStubFunction = function() {
# 					var arg = arguments;
# 					if (typeof window.__uspapi !== uspStubFunction) {
# 						setTimeout(function() {
# 							if (typeof window.__uspapi !== 'undefined') {
# 								window.__uspapi.apply(window.__uspapi, arg);
# 							}
# 						}, 500);
# 					}
# 				};
#
# 				var checkIfUspIsReady = function() {
# 					uspTries++;
# 					if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
# 						console.warn('USP is not accessible');
# 					} else {
# 						clearInterval(uspInterval);
# 					}
# 				};
#
# 				if (typeof window.__uspapi === 'undefined') {
# 					window.__uspapi = uspStubFunction;
# 					var uspInterval = setInterval(checkIfUspIsReady, 6000);
# 				}
# 			})();
# 		</script>
# <!-- End InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <script id="fb-pixel">
# 			!function (f, b, e, v, n, t, s) {
# 				if (f.fbq) return;
# 				n = f.fbq = function () {
# 					n.callMethod ?
# 						n.callMethod.apply(n, arguments) : n.queue.push(arguments)
# 				};
# 				if (!f._fbq) f._fbq = n;
# 				n.push = n;
# 				n.loaded = !0;
# 				n.version = '2.0';
# 				n.agent = 'secretmedianetwork';
# 				n.queue = [];
# 				t = b.createElement(e);
# 				t.async = !0;
# 				t.src = v;
# 				s = b.getElementsByTagName(e)[0];
# 				s.parentNode.insertBefore(t, s)
# 			}(window,
# 				document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#
# 			let smn_facebook_pixel = {"pixel_id":"1543543449260625","enable_advanced_events":"yes","fire_delay":0},
# 				smn_facebook_pixel_args = [];
#
# 			// Extend args
# 			if ('yes' === smn_facebook_pixel.enable_advanced_events) {
# 				smn_facebook_pixel_args.userAgent = navigator.userAgent;
# 				smn_facebook_pixel_args.language = navigator.language;
#
# 				if (document.referrer.indexOf(document.domain) < 0) {
# 					smn_facebook_pixel_args.referrer = document.referrer;
# 				}
# 			}
#
# 			fbq('init', smn_facebook_pixel.pixel_id, smn_facebook_pixel.user);
#
# 			setTimeout(function () {
# 				fbq('track', "PageView", smn_facebook_pixel_args);
# 			}, smn_facebook_pixel.fire_delay * 1000);
# 		</script>
# <!-- Start VWO Async SmartCode -->
# <link href="https://dev.visualwebsiteoptimizer.com" rel="preconnect"/>
# <script id="vwoCode" type="text/javascript">
# 			window._vwo_code || (function () {
# 				var account_id = 777835,
# 					version = 2.0,
# 					settings_tolerance = 2000,
# 					hide_element = 'body',
# 					hide_element_style = 'opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important',
# 					/* DO NOT EDIT BELOW THIS LINE */
# 					f = false, w = window, d = document, v = d.querySelector('#vwoCode'),
# 					cK = '_vwo_' + account_id + '_settings', cc = {};
# 				try {
# 					var c = JSON.parse(localStorage.getItem('_vwo_' + account_id + '_config'));
# 					cc = c && typeof c === 'object' ? c : {}
# 				} catch (e) {
# 				}
# 				var stT = cc.stT === 'session' ? w.sessionStorage : w.localStorage;
# 				code = {
# 					use_existing_jquery: function () {
# 						return typeof use_existing_jquery !== 'undefined' ? use_existing_jquery : undefined
# 					}, library_tolerance: function () {
# 						return typeof library_tolerance !== 'undefined' ? library_tolerance : undefined
# 					}, settings_tolerance: function () {
# 						return cc.sT || settings_tolerance
# 					}, hide_element_style: function () {
# 						return '{' + (cc.hES || hide_element_style) + '}'
# 					}, hide_element: function () {
# 						return typeof cc.hE === 'string' ? cc.hE : hide_element
# 					}, getVersion: function () {
# 						return version
# 					}, finish: function () {
# 						if (!f) {
# 							f = true;
# 							var e = d.getElementById('_vis_opt_path_hides');
# 							if (e) e.parentNode.removeChild(e)
# 						}
# 					}, finished: function () {
# 						return f
# 					}, load: function (e) {
# 						var t = this.getSettings(), n = d.createElement('script'), i = this;
# 						if (t) {
# 							n.textContent = t;
# 							d.getElementsByTagName('head')[0].appendChild(n);
# 							if (!w.VWO || VWO.caE) {
# 								stT.removeItem(cK);
# 								i.load(e)
# 							}
# 						} else {
# 							n.fetchPriority = 'high';
# 							n.src = e;
# 							n.type = 'text/javascript';
# 							n.onerror = function () {
# 								_vwo_code.finish()
# 							};
# 							d.getElementsByTagName('head')[0].appendChild(n)
# 						}
# 					}, getSettings: function () {
# 						try {
# 							var e = stT.getItem(cK);
# 							if (!e) {
# 								return
# 							}
# 							e = JSON.parse(e);
# 							if (Date.now() > e.e) {
# 								stT.removeItem(cK);
# 								return
# 							}
# 							return e.s
# 						} catch (e) {
#
# 						}
# 					}, init: function () {
# 						if (d.URL.indexOf('__vwo_disable__') > -1) return;
# 						var e = this.settings_tolerance();
# 						w._vwo_settings_timer = setTimeout(function () {
# 							_vwo_code.finish();
# 							stT.removeItem(cK)
# 						}, e);
# 						var t = d.currentScript, n = d.createElement('style'), i = this.hide_element(),
# 							r = t && !t.async && i ? i + this.hide_element_style() : '',
# 							c = d.getElementsByTagName('head')[0];
# 						n.setAttribute('id', '_vis_opt_path_hides');
# 						v && n.setAttribute('nonce', v.nonce);
# 						n.setAttribute('type', 'text/css');
# 						if (n.styleSheet) n.styleSheet.cssText = r; else n.appendChild(d.createTextNode(r));
# 						c.appendChild(n);
# 						this.load('https://dev.visualwebsiteoptimizer.com/j.php?a=' + account_id + '&u=' + encodeURIComponent(d.URL) + '&vn=' + version)
# 					}
# 				};
# 				w._vwo_code = code;
# 				code.init();
# 			})();
# 		</script>
# <!-- End VWO Async SmartCode -->
# <script>
# 			function e(e) {
# 				var t = !(arguments.length > 1 && void 0 !== arguments[1]) || arguments[1],
# 					c = document.createElement("script");
# 				c.src = e, t ? c.type = "module" : (c.async = !0, c.type = "text/javascript", c.setAttribute("nomodule", ""));
# 				var n = document.getElementsByTagName("script")[0];
# 				n.parentNode.insertBefore(c, n)
# 			}
#
# 			function t(t, c, n) {
# 				var a, o, r;
# 				null !== (a = t.marfeel) && void 0 !== a || (t.marfeel = {}), null !== (o = (r = t.marfeel).cmd) && void 0 !== o || (r.cmd = []), t.marfeel.config = n, t.marfeel.config.accountId = c;
# 				var i = "https://sdk.mrf.io/statics";
# 				e("".concat(i, "/marfeel-sdk.js?id=").concat(c), !0), e("".concat(i, "/marfeel-sdk.es5.js?id=").concat(c), !1)
# 			}
#
# 			!function (e, c) {
# 				var n = arguments.length > 2 && void 0 !== arguments[2] ? arguments[2] : {};
# 				t(e, c, n)
# 			}(window, 489, {} /*config*/);
# 		</script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 					new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 				j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 				'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 			})(window,document,'script','dataLayer','GTM-TPPJNXK4');</script>
# <!-- End Google Tag Manager -->
# <script src="https://www.googleoptimize.com/optimize.js?id=OPT-TGRH28Z"></script>
# <script> window.cta_experiment_id = 18; </script> <style>
# 			:root {
# 				--theme-primary-color: #ef464a;
# 				--theme-primary-color-rgb: 239, 70, 74;
# 				--profile-cards-color: #ef464a;
# 				--contrast-color: #FFFFFF;
# 				--font-stack-primary-font: 'Montserrat', 'Verdana', sans-serif;;
# 			}
# 		</style>
# <style>
# 						.top-bar-social-media [data-social-media-name="Instagram"] {
# 				color: #fbad50;
# 			}
#
# 			.top-bar-social-media [data-social-media-name="Instagram"]:focus {
# 				outline: 0.063rem dotted#fbad50;
# 			}
#
# 						.top-bar-social-media [data-social-media-name="Facebook"] {
# 				color: #1877f2;
# 			}
#
# 			.top-bar-social-media [data-social-media-name="Facebook"]:focus {
# 				outline: 0.063rem dotted#1877f2;
# 			}
#
# 					</style>
# <script>
# 			window.analytics_data = {"content_type":"article","published_date":"2022-02-24T18:48:41+08:00","modified_date":"2024-04-05T17:04:34+08:00","category":"Things To Do","url":"https:\/\/secretsingapore.co\/things-to-do-singapore\/","tags":"attraction tickets;exhibition;thematic tour;trip \/ travel","marketing":{"evergreen":true,"marketplace":true,"profile_card":false,"landing":false,"internal":true},"site":{"name":"Secret Singapore","siteurl":"https:\/\/secretsingapore.co\/","region":"NZ","city":"Singapore","region_label":"New Zealand - English NZ sites"}};
# 		</script>
# <!-- Twitter conversion tracking base code -->
# <script id="twitter_conversion" type="text/javascript">
# 			!function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);
# 			},s.version='1.1',s.queue=[],u=t.createElement(n),u.async=!0,u.src='https://static.ads-twitter.com/uwt.js',
# 				a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,'script');
# 			twq('config','oec5i');
# 		</script>
# <!-- End Twitter conversion tracking base code -->
# <link href="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/03/03044133/cropped-Secret-Singapore-unified-favicon-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/03/03044133/cropped-Secret-Singapore-unified-favicon-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/03/03044133/cropped-Secret-Singapore-unified-favicon-180x180.png" rel="apple-touch-icon"/>
# <meta content="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/03/03044133/cropped-Secret-Singapore-unified-favicon-270x270.png" name="msapplication-TileImage"/>
# <noscript><style id="rocket-lazyload-nojs-css">.rll-youtube-player, [data-lazy-src]{display:none !important;}</style></noscript></head>
# <body class="post-template-default single single-post postid-904 single-format-standard wp-custom-logo pg-body pg-body--border-top">
# <!-- Facebook Pixel Code -->
# <noscript>
# <img alt="" height="1" src="https://www.facebook.com/tr?id=1543543449260625&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TPPJNXK4" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="smn-global-parent-wrapper">
# <div class="smn-body-offcanvas-menu__overlay"></div>
# <!-- Facebook Pixel Code -->
# <noscript>
# <img alt="" height="1" src="https://www.facebook.com/tr?id=1543543449260625&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <div class="loading-fever-spinner">
# <img alt="Loading..." class="loading-fever-spinner__image" data-lazy-src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/images/generic-animated-spinner.svg" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%200%200'%3E%3C/svg%3E"/><noscript><img alt="Loading..." class="loading-fever-spinner__image" src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/images/generic-animated-spinner.svg"/></noscript>
# </div>
# <div class="smn-header-placeholder"></div>
# <header class="smn-header navbar-sticky" lang="en-GB">
# <div class="global-wrapper smn-header__wrapper">
# <div class="smn-header__logo smn-header-logo">
# <a href="https://secretsingapore.co">
# <img alt="Secret Singapore" class="img-fluid smn-header-logo__full" data-lazy-src="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/06/03044825/secretsingapore.co-logo-768x68.png" height="68" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20768%2068'%3E%3C/svg%3E" width="768"/><noscript><img alt="Secret Singapore" class="img-fluid smn-header-logo__full" height="68" src="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/06/03044825/secretsingapore.co-logo-768x68.png" width="768"/></noscript>
# </a>
# </div>
# <div class="smn-header__addons smn-header-addons">
# <div aria-label="Open subscription form popup" class="smn-header-addons__subscribe smn-header-subscribe" data-bs-target=".new-home__modal-subscribe" data-bs-toggle="modal" role="button" tabindex="0">
# <span class="smn-header-subscribe__icon-wrapper">
# <i class="far fa-envelope fa-fw smn-header-subscribe__icon"></i>
# </span>
# <span class="smn-header-subscribe__label"> Subscribe</span>
# </div>
# <div class="smn-header-addons__social-media">
# <div class="new-home__header-social-media">
# <ul class="top-bar-social-media">
# <li class="top-bar-social-media__item">
# <a aria-label="Facebook" data-action="facebook" data-category="follow_buttons_header" data-ga-type="click" data-has-ga="true" data-social-media-name="Facebook" href="https://www.facebook.com/secretsingapore.smn" rel="sponsored noopener noreferrer" target="_blank">
# <i class="fab fa-facebook fa-fw"></i>
# </a>
# </li>
# <li class="top-bar-social-media__item">
# <a aria-label="Instagram" data-action="instagram" data-category="follow_buttons_header" data-ga-type="click" data-has-ga="true" data-social-media-name="Instagram" href="https://www.instagram.com/secret.singapore/" rel="sponsored noopener noreferrer" target="_blank">
# <i class="fab fa-instagram fa-fw"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div aria-label="Search" class="smn-header-addons__search search-icon-block__container" data-action="click" data-category="search_click" data-ga-type="click" data-has-ga="true" id="search-action-top-bar" role="button" tabindex="0">
# <i class="far fa-search"></i>
# </div>
# </div>
# <div class="smn-header__break"></div>
# <button aria-label="Open sidenav menu" class="smn-header__bars new-home__burger-menu-bars toggle-offcanvas-menu" type="button">
# <i class="far fa-bars"></i>
# </button>
# <nav class="smn-header__menu smn-menu">
# <ul class="smn-menu__list smn-menu-list new-home__menu-items-wrapper no-class">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent menu-item-11 smn-menu-list__item">
# <a class="smn-menu-list__link" data-action="Things To Do" data-category="menu_click" data-ga-type="click" data-has-ga="true" href="https://secretsingapore.co/things-to-do/">
# 					Things To Do
# 				</a>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-14 smn-menu-list__item">
# <a class="smn-menu-list__link" data-action="Top News" data-category="menu_click" data-ga-type="click" data-has-ga="true" href="https://secretsingapore.co/top-news/">
# 					Top News
# 				</a>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6 smn-menu-list__item">
# <a class="smn-menu-list__link" data-action="Food &amp; Drink" data-category="menu_click" data-ga-type="click" data-has-ga="true" href="https://secretsingapore.co/food-drink/">
# 					Food &amp; Drink
# 				</a>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-8 smn-menu-list__item">
# <a class="smn-menu-list__link" data-action="Culture" data-category="menu_click" data-ga-type="click" data-has-ga="true" href="https://secretsingapore.co/culture/">
# 					Culture
# 				</a>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-13 smn-menu-list__item">
# <a class="smn-menu-list__link" data-action="Escapes" data-category="menu_click" data-ga-type="click" data-has-ga="true" href="https://secretsingapore.co/escapes/">
# 					Escapes
# 				</a>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-10 smn-menu-list__item">
# <a class="smn-menu-list__link" data-action="Wellness &amp; Nature" data-category="menu_click" data-ga-type="click" data-has-ga="true" href="https://secretsingapore.co/wellness-nature/">
# 					Wellness &amp; Nature
# 				</a>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent menu-item-1609 smn-menu-list__item">
# <a class="smn-menu-list__link" data-action="Secret Guides" data-category="menu_click" data-ga-type="click" data-has-ga="true" href="https://secretsingapore.co/secret-guides/">
# 					Secret Guides
# 				</a>
# </li>
# </ul>
# </nav>
# </div>
# </header>
# <main class="infinite-container" id="infinite-container">
# <div class="floating-share-buttons">
# <a aria-label="Share on Facebook" class="floating-share-buttons__button facebook" data-action="facebook" data-category="shared_content_sticky" data-ga-type="click" data-has-ga="true" href="#" rel="sponsored noopener noreferrer" target="_blank">
# <i class="fab fa-facebook-f"></i>
# </a><a aria-label="Share on Twitter" class="floating-share-buttons__button twitter" data-action="twitter" data-category="shared_content_sticky" data-ga-type="click" data-has-ga="true" href="#" rel="sponsored noopener noreferrer" target="_blank">
# <i class="fab fa-twitter"></i>
# </a><span aria-label="Copy to clipboard" class="floating-share-buttons__button copy-link smn-copy-to-clipboard" data-action="copy_url" data-bs-animation="true" data-bs-content="Copied!" data-bs-placement="bottom" data-bs-toggle="popover" data-category="shared_content_sticky" data-clipboard-text="#" data-ga-type="click" data-has-ga="true" tabindex="0">
# <i class="fas fa-clipboard"></i>
# </span><a aria-label="Share on WhatsApp" class="floating-share-buttons__button whatsapp" data-action="whatsapp" data-category="shared_content_sticky" data-ga-type="click" data-has-ga="true" href="#" rel="sponsored noopener noreferrer" target="_blank">
# <i class="fab fa-whatsapp"></i>
# </a>
# </div>
# <div class="wrapper branded-content-category smn-no-ads-post smn-no-gpt-ads-post">
# <div class="container main-content-container">
# <div class="row">
# <div class="content-wrapper col-12">
# <article class="post-single post-type-post article post-main-content" data-ads-enabled="0" data-copy-url="https://secretsingapore.co/things-to-do-singapore/?utm_content=things-to-do-singapore&amp;utm_source=secretsingapore&amp;utm_medium=post" data-metatitle="60+ Best Things To Do In Singapore This Year" data-post-id="904" data-post-slug="things-to-do-singapore" data-primary-category-id="10" data-primary-category-slug="things-to-do" data-scrollnumber="1" data-url="https://secretsingapore.co/things-to-do-singapore/" id="post-904">
# <header class="col-12">
# <h1 class="single__title word-breaker">60 Incredible Things To Do In Singapore At Least Once In Your Life</h1>
# <p class="single__subtitle">From spectacular rooftops to interactive museums, and many food and drink hotspots, there are always thrilling things to do in Singapore. Here are just some of the best things to do right now!</p>
# <p class="single__author">
# <span class="single__author__avatar">
# <a href="/author/megan-walsh/">
# <img alt="Megan Zara Walsh" class="img-fluid" data-lazy-src="https://secure.gravatar.com/avatar/97e2921370baa8433be1f583dfe12f15?s=24&amp;d=mm&amp;r=g" height="24" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%2024%2024'%3E%3C/svg%3E" width="24"/><noscript><img alt="Megan Zara Walsh" class="img-fluid" height="24" src="https://secure.gravatar.com/avatar/97e2921370baa8433be1f583dfe12f15?s=24&amp;d=mm&amp;r=g" width="24"/></noscript>
# </a>
# </span>
# <a class="notranslate" href="/author/megan-walsh/"> Megan Zara Walsh</a> - Staff Writer			<span class="single__author__bull-divider">•</span>
# <time class="single__author__date" datetime="2024-04-05T09:04:34+00:00">April 5, 2024</time>
# </p>
# </header>
# <section class="article__content">
# <div class="row">
# <section class="article__body col-md-8">
# <figure class="single__featured-image-container">
# <img alt="The best things to do in Singapore year around top attractions" class="img-fluid" data-lazy-src="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/13202008/Megan-Article-Covers-2023-05-17T161842.761-1024x683.png" height="683" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%201024%20683'%3E%3C/svg%3E" width="1024"/><noscript><img alt="The best things to do in Singapore year around top attractions" class="img-fluid" height="683" src="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/13202008/Megan-Article-Covers-2023-05-17T161842.761-1024x683.png" width="1024"/></noscript>
# <figcaption class="single__featured-image-caption">Credit: Megan Zara Walsh (Secret Singapore)</figcaption>
# </figure>
# <p>In a city full of excitement, you might feel a little paralysed by choice when wondering <strong>what to do in Singapore</strong>. When there’s as much on offer as our incredible city provides, it can be pretty overwhelming choosing where to start, and that’s where Secret Singapore steps in to help. Whether you’re a local or a traveller looking to get the best out of this iconic city, we’ve tracked down 60 of the best<strong> things to do</strong> <strong>in</strong> <strong>Singapore</strong>, no matter the time of year.</p>
# <h2>1. See the world’s largest public display of Southeast Asian art</h2>
# <figure aria-describedby="caption-attachment-9077" class="wp-caption alignnone" id="attachment_9077" style="width: 1200px"><img alt="The best Museums and Galleries in Singapore National Gallery red room " class="size-full wp-image-9077" data-lazy-sizes="(max-width: 1200px) 100vw, 1200px" data-lazy-src="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858.png" data-lazy-srcset="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858.png 1200w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858-300x200.png 300w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858-1024x683.png 1024w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858-768x512.png 768w" decoding="async" fetchpriority="high" height="800" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%201200%20800'%3E%3C/svg%3E" width="1200"/><noscript><img alt="The best Museums and Galleries in Singapore National Gallery red room " class="size-full wp-image-9077" decoding="async" fetchpriority="high" height="800" sizes="(max-width: 1200px) 100vw, 1200px" src="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858.png" srcset="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858.png 1200w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858-300x200.png 300w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858-1024x683.png 1024w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/01/13201933/Megan-Article-Covers-2023-05-19T154724.858-768x512.png 768w" width="1200"/></noscript><figcaption class="wp-caption-text" id="caption-attachment-9077">Credit: Megan Zara Walsh (Secret Singapore)</figcaption></figure>
# <p><strong>National Gallery Singapore</strong> offers the largest public display of modern Southeast Asian art in the world. The <a class="shortcode-outbound-link" data-action="cta" data-category="outbound_link" data-ga-type="click" data-has-ga="true" data-label="https://secretsingapore.co/museums-and-galleries-singapore/" href="https://secretsingapore.co/museums-and-galleries-singapore/" rel="follow">modern museum</a> is the perfect place for art lovers of all ages to wander the latest exhibitions and learn about beautiful artworks from across the world. Wonderfully, majority of exhibits at the museum are free entry year round.</p>
# <p>📍<em>Civic District, Singapore 178957</em></p>
# <h2>2. Race at Singapore’s only night luge ride</h2>
# <figure aria-describedby="caption-attachment-12913" class="wp-caption alignnone" id="attachment_12913" style="width: 1200px"><img alt="things to do weekend in Singapore Skyluge new night experience " class="size-full wp-image-12913" data-lazy-sizes="(max-width: 1200px) 100vw, 1200px" data-lazy-src="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge-.jpg" data-lazy-srcset="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge-.jpg 1200w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge--300x200.jpg 300w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge--1024x683.jpg 1024w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge--768x512.jpg 768w" decoding="async" height="800" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%201200%20800'%3E%3C/svg%3E" width="1200"/><noscript><img alt="things to do weekend in Singapore Skyluge new night experience " class="size-full wp-image-12913" decoding="async" height="800" sizes="(max-width: 1200px) 100vw, 1200px" src="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge-.jpg" srcset="https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge-.jpg 1200w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge--300x200.jpg 300w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge--1024x683.jpg 1024w, https://offloadmedia.feverup.com/secretsingapore.co/wp-content/uploads/2022/12/03213540/SkyLuge--768x512.jpg 768w" width="1200"/></noscript><figcaption class="wp-caption-text" id="caption-attachment-12913">Credit: SkyLuge</figcaption></figure>
# ...
# <p><strong class="mc4wp-form__title">GET US IN YOUR INBOX</strong></p>
# <p class="mc4wp-form__description mc4wp-form__hidden">Sign up to our newsletter for the latest and greatest from your city</p>
# </div>
# <div class="new-home__form-field">
# <p class="field-email"><input name="EMAIL" placeholder="E-mail" required="" type="email"/></p>
# <p class="field-submit"><input type="submit" value="Subscribe"/></p>
# <p class="field-terms"><label><input name="AGREE_TO_TERMS" required="" type="checkbox" value="1"/>  I accept <a href="https://feverup.com/legal/all_en.html" rel="nofollow noopener noreferrer" target="_blank">terms &amp; conditions</a></label></p>
# </div></div><label style="display: none !important;">Leave this field empty if you're human: <input autocomplete="off" name="_mc4wp_honeypot" tabindex="-1" type="text" value=""/></label><input name="_mc4wp_timestamp" type="hidden" value="1714644813"/><input name="_mc4wp_form_id" type="hidden" value="5"/><input name="_mc4wp_form_element_id" type="hidden" value="mc4wp-form-2"/><div class="mc4wp-response"></div></form><!-- / Mailchimp for WordPress Plugin --></div></aside>
# </nav>
# <aside class="modal fade new-home new-home__modal new-home__modal-subscribe" tabindex="-1">
# <div class="modal-dialog modal-dialog-centered">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">Subscribe</h5>
# <button aria-label="Close" class="close" data-bs-dismiss="modal" type="button">
# <i class="far fa-times"></i>
# </button>
# </div>
# <div class="modal-body">
# <div class="sidebar-container new-home__mailchimp-area"><script>(function() {
# 	window.mc4wp = window.mc4wp || {
# 		listeners: [],
# 		forms: {
# 			on: function(evt, cb) {
# 				window.mc4wp.listeners.push(
# 					{
# 						event   : evt,
# 						callback: cb
# 					}
# 				);
# 			}
# 		}
# 	}
# })();
# </script><!-- Mailchimp for WordPress v4.9.11 - https://wordpress.org/plugins/mailchimp-for-wp/ --><form class="mc4wp-form mc4wp-form-5" data-id="5" data-name="Newsletter form" id="mc4wp-form-3" method="post"><div class="mc4wp-form-fields"><div class="new-home__form-text">
# <p><strong class="mc4wp-form__title">GET US IN YOUR INBOX</strong></p>
# <p class="mc4wp-form__description mc4wp-form__hidden">Sign up to our newsletter for the latest and greatest from your city</p>
# </div>
# <div class="new-home__form-field">
# <p class="field-email"><input name="EMAIL" placeholder="E-mail" required="" type="email"/></p>
# <p class="field-submit"><input type="submit" value="Subscribe"/></p>
# <p class="field-terms"><label><input name="AGREE_TO_TERMS" required="" type="checkbox" value="1"/>  I accept <a href="https://feverup.com/legal/all_en.html" rel="nofollow noopener noreferrer" target="_blank">terms &amp; conditions</a></label></p>
# </div></div><label style="display: none !important;">Leave this field empty if you're human: <input autocomplete="off" name="_mc4wp_honeypot" tabindex="-1" type="text" value=""/></label><input name="_mc4wp_timestamp" type="hidden" value="1714644813"/><input name="_mc4wp_form_id" type="hidden" value="5"/><input name="_mc4wp_form_element_id" type="hidden" value="mc4wp-form-3"/><div class="mc4wp-response"></div></form><!-- / Mailchimp for WordPress Plugin --></div>
# </div>
# </div>
# </div>
# </aside>
# <script>(function() {function maybePrefixUrlField () {
#   const value = this.value.trim()
#   if (value !== '' && value.indexOf('http') !== 0) {
#     this.value = 'http://' + value
#   }
# }
#
# const urlFields = document.querySelectorAll('.mc4wp-form input[type="url"]')
# for (let j = 0; j < urlFields.length; j++) {
#   urlFields[j].addEventListener('blur', maybePrefixUrlField)
# }
# })();</script> <script>
# 			window.addEventListener('new_post_inserted', init_profile_card);
#
# 			function init_profile_card() {
# 				const profileCardScriptId = "profile_card-js";
# 				const profileCardScriptElement = document.getElementById(profileCardScriptId);
# 				const profileCardElements = document.querySelector('[class*="profile-card"]');
#
# 				if (!profileCardScriptElement && profileCardElements) {
# 					const scriptTag = document.createElement('script');
# 					scriptTag.src = 'https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/js/profileCard.js?ver=4.6.68';
# 					scriptTag.id = profileCardScriptId;
# 					document.head.appendChild(scriptTag);
# 				}
# 			}
#
# 			init_profile_card();
# 		</script>
# <template id="search_item">
# <article class="col-md-4 search_item__result" id="post-">
# <div class="post-thumbnail">
# <a href="#"><img alt="" class="img-fluid no-lazy" src="#"/></a>
# </div>
# <div class="post-category">
# <a class="category-link" href="#"></a>
# </div>
# <div class="post-data">
# <h2 class="title word-breaker"><a href="#"></a></h2>
# <div class="description"><p></p></div>
# <div class="separator"></div>
# </div>
# </article>
# </template>
# <div class="search-results-container">
# <div class="search-results-container__close">
# <span id="close-search-overlay" tabindex="0">×</span>
# </div>
# <p class="search-results-container__tip">TYPE IN YOUR SEARCH AND PRESS ENTER</p>
# <form class="search-results-container__form">
# <label class="sr-only" for="common-search-input">Search</label>
# <input autocomplete="off" class="search-results-container__input" id="common-search-input" placeholder="Search" type="search"/>
# </form>
# <div class="container">
# <div class="row">
# <div class="search-results-container__loader">
# <svg fill="#ef464a" height="140" viewbox="0 0 135 140" width="135" xmlns="http://www.w3.org/2000/svg">
# <rect height="120" rx="6" width="15" y="10">
# <animate attributename="height" begin="0.5s" calcmode="linear" dur="1s" repeatcount="indefinite" values="120;110;100;90;80;70;60;50;40;140;120"></animate>
# <animate attributename="y" begin="0.5s" calcmode="linear" dur="1s" repeatcount="indefinite" values="10;15;20;25;30;35;40;45;50;0;10"></animate>
# </rect>
# <rect height="120" rx="6" width="15" x="30" y="10">
# <animate attributename="height" begin="0.25s" calcmode="linear" dur="1s" repeatcount="indefinite" values="120;110;100;90;80;70;60;50;40;140;120"></animate>
# <animate attributename="y" begin="0.25s" calcmode="linear" dur="1s" repeatcount="indefinite" values="10;15;20;25;30;35;40;45;50;0;10"></animate>
# </rect>
# <rect height="140" rx="6" width="15" x="60">
# <animate attributename="height" begin="0s" calcmode="linear" dur="1s" repeatcount="indefinite" values="120;110;100;90;80;70;60;50;40;140;120"></animate>
# <animate attributename="y" begin="0s" calcmode="linear" dur="1s" repeatcount="indefinite" values="10;15;20;25;30;35;40;45;50;0;10"></animate>
# </rect>
# <rect height="120" rx="6" width="15" x="90" y="10">
# <animate attributename="height" begin="0.25s" calcmode="linear" dur="1s" repeatcount="indefinite" values="120;110;100;90;80;70;60;50;40;140;120"></animate>
# <animate attributename="y" begin="0.25s" calcmode="linear" dur="1s" repeatcount="indefinite" values="10;15;20;25;30;35;40;45;50;0;10"></animate>
# </rect>
# <rect height="120" rx="6" width="15" x="120" y="10">
# <animate attributename="height" begin="0.5s" calcmode="linear" dur="1s" repeatcount="indefinite" values="120;110;100;90;80;70;60;50;40;140;120"></animate>
# <animate attributename="y" begin="0.5s" calcmode="linear" dur="1s" repeatcount="indefinite" values="10;15;20;25;30;35;40;45;50;0;10"></animate>
# </rect>
# </svg>
# </div>
# <div class="search-results-container__results">
# <div class="row p0 search_items">
# </div>
# <div class="row">
# <div class="col-12 text-center">
# <a class="btn btn-outline-dark" href="#" id="more_results_url">View more</a>
# </div>
# </div>
# </div>
# <div class="search-results-container__no-results">
# <div class="col-12">
# <p>No result</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
# 			document.addEventListener('DOMContentLoaded', function (event) {
# 				for (let i = 0; i < document.forms.length; ++i) {
# 					let form = document.forms[i];
# 					if (form.method != "get") {  var input5d7gtobj = document.createElement("input"); input5d7gtobj.setAttribute("type", "hidden"); input5d7gtobj.setAttribute("name", "5d7gtobj");  input5d7gtobj.setAttribute("value", "mrxdgtr5u6zl"); form.appendChild(input5d7gtobj); }
# if (form.method != "get") {  var inputsyt66w2o = document.createElement("input"); inputsyt66w2o.setAttribute("type", "hidden"); inputsyt66w2o.setAttribute("name", "syt66w2o");  inputsyt66w2o.setAttribute("value", "66iz44cuuqq0"); form.appendChild(inputsyt66w2o); }
# if (form.method != "get") {  var input5su6lvkn = document.createElement("input"); input5su6lvkn.setAttribute("type", "hidden"); input5su6lvkn.setAttribute("name", "5su6lvkn");  input5su6lvkn.setAttribute("value", "g5zmb7kh54d2"); form.appendChild(input5su6lvkn); }
# 				}
# 			});
# 		</script>
# <script async="" data-wp-strategy="async" id="instagram-embed-js" src="//www.instagram.com/embed.js"></script>
# <script id="app-js-extra">
# var phpVars = {"data_logging_host":"https:\/\/data-logging.apigw.feverup.com"};
# var _sentry = {"environment":"production","enabled":"1","site_name":"Secret Singapore","version":"4.6.68"};
# var dynamic_title = {"is_user_logged_in":"","label":"We miss you\u2026"};
# var HBOQuiz = {"WrongAnswerText":"","SecretLink":""};
# var wpi18n = {"advertisement":"Advertisement","email_share_message":"I%20saw%20this%20and%20thought%20of%20you%21"};
# var ajax_call = {"ajaxurl":"https:\/\/secretsingapore.co\/wp-admin\/admin-ajax.php","nonce":"31d6c7ffdd","blog_url":"https:\/\/secretsingapore.co"};
# var _settings = {"utm_source":"secretsingapore"};
# var ab_tests = {"infiniteScroll":"normal","post_display_optimization_experiment_id":"","profile_card_sessions_experiment_id":""};
# var profileCardCacheClearer = {"actionForAJAXPlanCacheDeletion":"smn_delete_profile_card_cache_from_link","nonce":"b114d080ff","translations":{"errorTitle":"Error","successTitle":"Success","internalErrorMessage":"Internal error. Reload the page and try again later."}};
# var search = {"ajax_url":"https:\/\/secretsingapore.co\/wp-admin\/admin-ajax.php","nonce":"8cf1b3c8d8","action":"search_posts","placeholder_image":"https:\/\/secretsingapore.co\/wp-content\/themes\/secretmedianetwork\/images\/placeholders\/secret-media-network-350x204.jpg","search_url":"https:\/\/secretsingapore.co\/search\/%search%"};
# var infinite_scroll = {"ajax_url":"https:\/\/secretsingapore.co\/wp-admin\/admin-ajax.php","nonce":"2e82fa6706","action":"get_next_post"};
# </script>
# <script data-wp-strategy="defer" defer="" id="app-js" src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/js/app.js?ver=4.6.68"></script>
# <script data-wp-strategy="defer" defer="" id="hashScroller-js" src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/js/hashScroller.js?ver=4.6.68"></script>
# <script data-wp-strategy="defer" defer="" id="smnOptimizer-js" src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/js/smnOptimizer.js?ver=4.6.68"></script>
# <script async="" data-wp-strategy="async" id="fonts-js" src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/js/fonts.js?ver=4.6.68"></script>
# <script data-wp-strategy="defer" defer="" id="prebid.js-js" src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/js/prebid.js?ver=7.26.0"></script>
# <script async="" data-wp-strategy="async" id="gpt-js" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script id="ads-js-extra">
# var ads_settings = {"prebid_enabled":"1","cmp_enabled":"1","prebid_debug_mode":"0","gpt_debug_mode":"0","bid_cache":"0","bidder_sequence":"random","gpt_id":"21975301918","slots_settings":[],"gpt_tag":"secretsingapore","content_props":{"type":"post","ID":904,"category_slug":"things-to-do","category_id":10},"ad_label_tag_text":"Advertisement","grouped_ads":"0"};
# </script>
# <script data-wp-strategy="defer" defer="" id="ads-js" src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/js/ads.js?ver=4.6.68"></script>
# <script id="recommender_module-js" src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/js/recommenderModule.js?ver=4.6.68"></script>
# <script id="discount_module-js" src="https://secretsingapore.co/wp-content/themes/secretmedianetwork/dist/js/discountModule.js?ver=4.6.68"></script>
# <script id="instagram_embeds-js" src="//www.instagram.com/embed.js"></script>
# <script defer="" id="mc4wp-forms-api-js" src="https://secretsingapore.co/wp-content/plugins/mailchimp-for-wp/assets/js/forms.js?ver=4.9.11"></script>
# <script>window.lazyLoadOptions=[{elements_selector:"img[data-lazy-src],.rocket-lazyload,iframe[data-lazy-src]",data_src:"lazy-src",data_srcset:"lazy-srcset",data_sizes:"lazy-sizes",class_loading:"lazyloading",class_loaded:"lazyloaded",threshold:300,callback_loaded:function(element){if(element.tagName==="IFRAME"&&element.dataset.rocketLazyload=="fitvidscompatible"){if(element.classList.contains("lazyloaded")){if(typeof window.jQuery!="undefined"){if(jQuery.fn.fitVids){jQuery(element).parent().fitVids()}}}}}},{elements_selector:".rocket-lazyload",data_src:"lazy-src",data_srcset:"lazy-srcset",data_sizes:"lazy-sizes",class_loading:"lazyloading",class_loaded:"lazyloaded",threshold:300,}];window.addEventListener('LazyLoad::Initialized',function(e){var lazyLoadInstance=e.detail.instance;if(window.MutationObserver){var observer=new MutationObserver(function(mutations){var image_count=0;var iframe_count=0;var rocketlazy_count=0;mutations.forEach(function(mutation){for(var i=0;i<mutation.addedNodes.length;i++){if(typeof mutation.addedNodes[i].getElementsByTagName!=='function'){continue}
# if(typeof mutation.addedNodes[i].getElementsByClassName!=='function'){continue}
# images=mutation.addedNodes[i].getElementsByTagName('img');is_image=mutation.addedNodes[i].tagName=="IMG";iframes=mutation.addedNodes[i].getElementsByTagName('iframe');is_iframe=mutation.addedNodes[i].tagName=="IFRAME";rocket_lazy=mutation.addedNodes[i].getElementsByClassName('rocket-lazyload');image_count+=images.length;iframe_count+=iframes.length;rocketlazy_count+=rocket_lazy.length;if(is_image){image_count+=1}
# if(is_iframe){iframe_count+=1}}});if(image_count>0||iframe_count>0||rocketlazy_count>0){lazyLoadInstance.update()}});var b=document.getElementsByTagName("body")[0];var config={childList:!0,subtree:!0};observer.observe(b,config)}},!1)</script><script async="" data-no-minify="1" src="https://secretsingapore.co/wp-content/plugins/wp-rocket/assets/js/lazyload/17.8.3/lazyload.min.js"></script><script>function lazyLoadThumb(e,alt){var t='<img data-lazy-src="https://i.ytimg.com/vi/ID/hqdefault.jpg" alt="" width="480" height="360"><noscript><img src="https://i.ytimg.com/vi/ID/hqdefault.jpg" alt="" width="480" height="360"></noscript>',a='<button class="play" aria-label="play Youtube video"></button>';t=t.replace('alt=""','alt="'+alt+'"');return t.replace("ID",e)+a}function lazyLoadYoutubeIframe(){var e=document.createElement("iframe"),t="ID?autoplay=1";t+=0===this.parentNode.dataset.query.length?'':'&'+this.parentNode.dataset.query;e.setAttribute("src",t.replace("ID",this.parentNode.dataset.src)),e.setAttribute("frameborder","0"),e.setAttribute("allowfullscreen","1"),e.setAttribute("allow", "accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture"),this.parentNode.parentNode.replaceChild(e,this.parentNode)}document.addEventListener("DOMContentLoaded",function(){var e,t,p,a=document.getElementsByClassName("rll-youtube-player");for(t=0;t<a.length;t++)e=document.createElement("div"),e.setAttribute("data-id",a[t].dataset.id),e.setAttribute("data-query", a[t].dataset.query),e.setAttribute("data-src", a[t].dataset.src),e.innerHTML=lazyLoadThumb(a[t].dataset.id,a[t].dataset.alt),a[t].appendChild(e),p=e.querySelector('.play'),p.onclick=lazyLoadYoutubeIframe});</script></div></body>
# </html>
# <!--
# Performance optimized by Redis Object Cache. Learn more: https://wprediscache.com
#
# Retrieved 5325 objects (7 MB) from Redis using PhpRedis (v5.3.7).
# -->

# %%
listing = soup.find('h2')
listing.text
# Out:
# '1. See the world’s largest public display of Southeast Asian art'

# %%
location = soup.find('em')
location.text
# Out:
# 'Civic District, Singapore 178957'

# %% [markdown]
# Function to extact all the activity names and add them to a list

# %%
act_list = []
listings = soup.find_all('h2')
for listing in listings:
    act_list.append(listing)
act_list
# Out:
# [<h2>1. See the world’s largest public display of Southeast Asian art</h2>,
#  <h2>2. Race at Singapore’s only night luge ride</h2>,
#  <h2>3. Stroll around Gardens By The Bay</h2>,
#  <h2>4. Indulge on famous Singapore Chilli Crab</h2>,
#  <h2>5. Battle it out on Asia’s first gamified electric go-karts</h2>,
#  <h2>6. Enjoy 360-degree city views</h2>,
#  <h2>7. Zoom down Singapore’s longest indoor waterslide</h2>,
#  <h2>8. See the underwater world</h2>,
#  <h2>9. Play at Asia’s first ski, surf, skate &amp; ski resort</h2>,
#  <h2>10. Be mesmerised by a Candlelight concert</h2>,
#  <h2>11. Explore Singapore on one of the longest trails</h2>,
#  <h2>12. Wander around Chinatown</h2>,
#  <h2>13. Get lost in the ArtScience Museum</h2>,
#  <h2>14. Be mesmerised by nocturnal creatures</h2>,
#  <h2>15. Book an infinity pool experience</h2>,
#  <h2>16. Be entertained by a first-rated colourful night show</h2>,
#  <h2>17. Hop on Singapore Cable Car</h2>,
#  <h2>18. Let the kids run free at Chaos Lab</h2>,
#  <h2>19. Check out the coolest exhibitions</h2>,
#  <h2>20. Try some escape rooms</h2>,
#  <h2>21. Explore Jewel Changi Airport</h2>,
#  <h2>22. Enjoy the city’s best rooftop dining</h2>,
#  <h2>23. Party at Sentosa’s hottest new beach club</h2>,
#  <h2>24. Sleep in a tent</h2>,
#  <h2>25. Brace the cold at Snow City</h2>,
#  <h2>26. Go wild at Universal Studios</h2>,
#  <h2>27. Soak up Chinese mythology</h2>,
#  <h2>28. Unleash your inner Wonkas</h2>,
#  <h2>29. Let out your rage</h2>,
#  <h2>30. Dive into a pink world of ice cream</h2>,
#  <h2>31. Take to the skies</h2>,
#  <h2>32. Admire quirky street art</h2>,
#  <h2>33. Visit the new Bird Paradise</h2>,
#  <h2>34. Indulge at a hawker centre</h2>,
#  <h2>35. Be thrilled on Sentosa Island</h2>,
#  <h2>36. Dine at Singapore’s only underwater restaurant</h2>,
#  <h2>37. Have a picnic in the sunshine</h2>,
#  <h2>38. Party at the best nightlife spots</h2>,
#  <h2>39. Take a ride on a cruise</h2>,
#  <h2>40. Wander around Little India</h2>,
#  <h2>41. Travel back to the 60s</h2>,
#  <h2>42. Take a hike</h2>,
#  <h2>43. Uncover Singapore’s hidden secret places</h2>,
#  <h2>44. Staycation at a lush hotel</h2>,
#  <h2>45. Get up close with animals</h2>,
#  <h2>46. Dance inside Singapore’s first AI-powered futuristic nightclub</h2>,
#  <h2>47. Skydive inside the world’s largest wind tunnel</h2>,
#  <h2>48. Visit the <a class="shortcode-outbound-link" data-action="cta" data-category="outbound_link" data-ga-type="click" data-has-ga="true" data-label="https://secretsingapore.co/berlin-wall-in-singapore/" href="https://secretsingapore.co/berlin-wall-in-singapore/" rel="follow">Berlin Wall</a></h2>,
#  <h2>49. Go for a stroll around a beach carnival</h2>,
#  <h2>50. <a class="shortcode-outbound-link" data-action="cta" data-category="outbound_link" data-ga-type="click" data-has-ga="true" data-label="https://www.vintagecamerasmuseumsg.com/" href="https://www.vintagecamerasmuseumsg.com/" rel="follow" target="_blank">Step inside a camera</a></h2>,
#  <h2>51. Heal your inner child at X-Scap8</h2>,
#  <h2>52. Celebrate in the sky</h2>,
#  <h2>53. Relax in a botanical eatery</h2>,
#  <h2>54. Cosy up with a high tea</h2>,
#  <h2>55. Explore the islands</h2>,
#  <h2>56. Have a unique yacht picnic</h2>,
#  <h2>57. Take the children to the new KidzWorld</h2>,
#  <h2>58. <a class="shortcode-outbound-link" data-action="cta" data-category="outbound_link" data-ga-type="click" data-has-ga="true" data-label="https://kf1karting.com/" href="https://kf1karting.com/" rel="follow" target="_blank">Go crazy at KF1 Karting Circuit</a></h2>,
#  <h2>59. Get your adrenaline fix at the waterpark</h2>,
#  <h2>60. Go on an Instagrammable adventure</h2>,
#  <h2 class="title word-breaker"><a href="#"></a></h2>]

# %% [markdown]
# Removing all unnecessary tags to leave us with just the activity name

# %%
def remove_html_tags(tag_obj):
    return tag_obj.get_text()
cleaned_act_list = [remove_html_tags(tag_obj) for tag_obj in act_list]

cleaned_act_list
# Out:
# ['1. See the world’s largest public display of Southeast Asian art',
#  '2. Race at Singapore’s only night luge ride',
#  '3. Stroll around Gardens By The Bay',
#  '4. Indulge on famous Singapore Chilli Crab',
#  '5. Battle it out on Asia’s first gamified electric go-karts',
#  '6. Enjoy 360-degree city views',
#  '7. Zoom down Singapore’s longest indoor waterslide',
#  '8. See the underwater world',
#  '9. Play at Asia’s first ski, surf, skate & ski resort',
#  '10. Be mesmerised by a Candlelight concert',
#  '11. Explore Singapore on one of the longest trails',
#  '12. Wander around Chinatown',
#  '13. Get lost in the ArtScience Museum',
#  '14. Be mesmerised by nocturnal creatures',
#  '15. Book an infinity pool experience',
#  '16. Be entertained by a first-rated colourful night show',
#  '17. Hop on Singapore Cable Car',
#  '18. Let the kids run free at Chaos Lab',
#  '19. Check out the coolest exhibitions',
#  '20. Try some escape rooms',
#  '21. Explore Jewel Changi Airport',
#  '22. Enjoy the city’s best rooftop dining',
#  '23. Party at Sentosa’s hottest new beach club',
#  '24. Sleep in a tent',
#  '25. Brace the cold at Snow City',
#  '26. Go wild at Universal Studios',
#  '27. Soak up Chinese mythology',
#  '28. Unleash your inner Wonkas',
#  '29. Let out your rage',
#  '30. Dive into a pink world of ice cream',
#  '31. Take to the skies',
#  '32. Admire quirky street art',
#  '33. Visit the new Bird Paradise',
#  '34. Indulge at a hawker centre',
#  '35. Be thrilled on Sentosa Island',
#  '36. Dine at Singapore’s only underwater restaurant',
#  '37. Have a picnic in the sunshine',
#  '38. Party at the best nightlife spots',
#  '39. Take a ride on a cruise',
#  '40. Wander around Little India',
#  '41. Travel back to the 60s',
#  '42. Take a hike',
#  '43. Uncover Singapore’s hidden secret places',
#  '44. Staycation at a lush hotel',
#  '45. Get up close with animals',
#  '46. Dance inside Singapore’s first AI-powered futuristic nightclub',
#  '47. Skydive inside the world’s largest wind tunnel',
#  '48. Visit the Berlin Wall',
#  '49. Go for a stroll around a beach carnival',
#  '50. Step inside a camera',
#  '51. Heal your inner child at X-Scap8',
#  '52. Celebrate in the sky',
#  '53. Relax in a botanical eatery',
#  '54. Cosy up with a high tea',
#  '55. Explore the islands',
#  '56. Have a unique yacht picnic',
#  '57. Take the children to the new KidzWorld',
#  '58. Go crazy at KF1 Karting Circuit',
#  '59. Get your adrenaline fix at the waterpark',
#  '60. Go on an Instagrammable adventure',
#  '']

# %% [markdown]
# Removing entry 47 as it is a duplicate of another scraped activity dataset

# %%
removed_element = cleaned_act_list.pop(47)  
print(cleaned_act_list)  
print(removed_element)
# Out:
# ['1. See the world’s largest public display of Southeast Asian art', '2. Race at Singapore’s only night luge ride', '3. Stroll around Gardens By The Bay', '4. Indulge on famous Singapore Chilli Crab', '5. Battle it out on Asia’s first gamified electric go-karts', '6. Enjoy 360-degree city views', '7. Zoom down Singapore’s longest indoor waterslide', '8. See the underwater world', '9. Play at Asia’s first ski, surf, skate & ski resort', '10. Be mesmerised by a Candlelight concert', '11. Explore Singapore on one of the longest trails', '12. Wander around Chinatown', '13. Get lost in the ArtScience Museum', '14. Be mesmerised by nocturnal creatures', '15. Book an infinity pool experience', '16. Be entertained by a first-rated colourful night show', '17. Hop on Singapore Cable Car', '18. Let the kids run free at Chaos Lab', '19. Check out the coolest exhibitions', '20. Try some escape rooms', '21. Explore Jewel Changi Airport', '22. Enjoy the city’s best rooftop dining', '23. Party at Sentosa’s hottest new beach club', '24. Sleep in a tent', '25. Brace the cold at Snow City', '26. Go wild at Universal Studios', '27. Soak up Chinese mythology', '28. Unleash your inner Wonkas', '29. Let out your rage', '30. Dive into a pink world of ice cream', '31. Take to the skies', '32. Admire quirky street art', '33. Visit the new Bird Paradise', '34. Indulge at a hawker centre', '35. Be thrilled on Sentosa Island', '36. Dine at Singapore’s only underwater restaurant', '37. Have a picnic in the sunshine', '38. Party at the best nightlife spots', '39. Take a ride on a cruise', '40. Wander around Little India', '41. Travel back to the 60s', '42. Take a hike', '43. Uncover Singapore’s hidden secret places', '44. Staycation at a lush hotel', '45. Get up close with animals', '46. Dance inside Singapore’s first AI-powered futuristic nightclub', '47. Skydive inside the world’s largest wind tunnel', '49. Go for a stroll around a beach carnival', '50. Step inside a camera', '51. Heal your inner child at X-Scap8', '52. Celebrate in the sky', '53. Relax in a botanical eatery', '54. Cosy up with a high tea', '55. Explore the islands', '56. Have a unique yacht picnic', '57. Take the children to the new KidzWorld', '58. Go crazy at KF1 Karting Circuit', '59. Get your adrenaline fix at the waterpark', '60. Go on an Instagrammable adventure', '']
# 48. Visit the Berlin Wall

# %% [markdown]
# Removing empty element ''

# %%
removed_element1 = cleaned_act_list.pop(-1) 
print(cleaned_act_list)  
print(removed_element1)
# Out:
# ['1. See the world’s largest public display of Southeast Asian art', '2. Race at Singapore’s only night luge ride', '3. Stroll around Gardens By The Bay', '4. Indulge on famous Singapore Chilli Crab', '5. Battle it out on Asia’s first gamified electric go-karts', '6. Enjoy 360-degree city views', '7. Zoom down Singapore’s longest indoor waterslide', '8. See the underwater world', '9. Play at Asia’s first ski, surf, skate & ski resort', '10. Be mesmerised by a Candlelight concert', '11. Explore Singapore on one of the longest trails', '12. Wander around Chinatown', '13. Get lost in the ArtScience Museum', '14. Be mesmerised by nocturnal creatures', '15. Book an infinity pool experience', '16. Be entertained by a first-rated colourful night show', '17. Hop on Singapore Cable Car', '18. Let the kids run free at Chaos Lab', '19. Check out the coolest exhibitions', '20. Try some escape rooms', '21. Explore Jewel Changi Airport', '22. Enjoy the city’s best rooftop dining', '23. Party at Sentosa’s hottest new beach club', '24. Sleep in a tent', '25. Brace the cold at Snow City', '26. Go wild at Universal Studios', '27. Soak up Chinese mythology', '28. Unleash your inner Wonkas', '29. Let out your rage', '30. Dive into a pink world of ice cream', '31. Take to the skies', '32. Admire quirky street art', '33. Visit the new Bird Paradise', '34. Indulge at a hawker centre', '35. Be thrilled on Sentosa Island', '36. Dine at Singapore’s only underwater restaurant', '37. Have a picnic in the sunshine', '38. Party at the best nightlife spots', '39. Take a ride on a cruise', '40. Wander around Little India', '41. Travel back to the 60s', '42. Take a hike', '43. Uncover Singapore’s hidden secret places', '44. Staycation at a lush hotel', '45. Get up close with animals', '46. Dance inside Singapore’s first AI-powered futuristic nightclub', '47. Skydive inside the world’s largest wind tunnel', '49. Go for a stroll around a beach carnival', '50. Step inside a camera', '51. Heal your inner child at X-Scap8', '52. Celebrate in the sky', '53. Relax in a botanical eatery', '54. Cosy up with a high tea', '55. Explore the islands', '56. Have a unique yacht picnic', '57. Take the children to the new KidzWorld', '58. Go crazy at KF1 Karting Circuit', '59. Get your adrenaline fix at the waterpark', '60. Go on an Instagrammable adventure']

# %%
len(cleaned_act_list)
# Out:
# 59

# %% [markdown]
# Scraping location data

# %%
loc_list = []
locations = soup.find_all('em')
for item in locations:
    loc_list.append(item)
loc_list
# Out:
# [<em>Civic District, Singapore 178957</em>,
#  <em>1 Imbiah Rd, Singapore 099692</em>,
#  <em>18 Marina Gardens Dr, Singapore 018953</em>,
#  <em> Various Locations </em>,
#  <em>54 Palawan Beach Walk, Singapore 098233</em>,
#  <em>10 Bayfront Ave, Singapore 018956</em>,
#  <em>HomeTeamNS Bedok Reservoir, 900 Bedok North Rd, Singapore</em>,
#  <em>RW Sentosa, Singapore </em>,
#  <em>Orchard Road, Singapore</em>,
#  <em>Various Locations</em>,
#  <em>Various Locations</em>,
#  <em> Chinatown, Singapore</em>,
#  <em>FutureWorld</em>,
#  <em> 6 Bayfront Ave, Singapore 018974</em>,
#  <em>80 Mandai Lake Rd, Singapore 729826</em>,
#  <em>Various Locations </em>,
#  <em>50 Beach View, Singapore 09860</em>,
#  <em>Various Locations</em>,
#  <em>Terminal 2, Changi Airport, Singapore </em>,
#  <em>Various Locations</em>,
#  <em> Various Locations</em>,
#  <em>78 Airport Blvd, Singapore 819666</em>,
#  <em>Various Locations</em>,
#  <em>36 Siloso Beach Walk, #01-01, Sentosa Island, Singapore</em>,
#  <em>Various Locations</em>,
#  <em>21 Jurong Town Hall Rd, Singapore 609433</em>,
#  <em>8 Sentosa Gateway, Singapore 098269</em>,
#  <em><span class="LrzXr">262 Pasir Panjang Rd, Singapore 118628</span></em>,
#  <em>13 Dempsey Road, #01-03/04, Singapore 249674</em>,
#  <em>📍490 MacPherson Rd, Singapore, 368198</em>,
#  <em>100 Loewen Road, Dempsey, Singapore 248837</em>,
#  <em>41 Imbiah Rd, Sentosa, Singapore 099707</em>,
#  <em>Various Locations</em>,
#  <em>20 Mandai Lake Rd, Singapore 729825</em>,
#  <em>Various Locations </em>,
#  <em>Sentosa Island, Singapore</em>,
#  <em>Equarius Hotel, B1M West Carpark, Resorts World Sentosa </em>,
#  <em>8 Marina Gardens Dr, Singapore 018951</em>,
#  <em>Various Locations</em>,
#  <em>Clark Quay, Jetty, Singapore </em>,
#  <em>Little India, Singapore</em>,
#  <em>85 Desker Rd, Singapore </em>,
#  <em>Various Locations </em>,
#  <em>Various Locations</em>,
#  <em>Various Locations</em>,
#  <em>80 Mandai Lake Rd, Singapore 729826</em>,
#  <em>Orchard Central Level 11, 181 Orchard Rd, #11 – 01 / 02, Singapore 238896</em>,
#  <em>43 Siloso Beach Walk, #01-01, iFly, Singapore 099010</em>,
#  <em>60 Siloso Beach Walk, Singapore 098997</em>,
#  <em>8C Jln Kledek, Singapore 199263</em>,
#  <em>Orchard Road, Singapore </em>,
#  <em>30 Raffles Ave, Singapore 039803</em>,
#  <em>Various Locations</em>,
#  <em>Various Locations</em>,
#  <em>Various Locations</em>,
#  <em>11 Cove Drive, Sentosa Cove, Singapore 098497</em>,
#  <em>80 Mandai Lake Rd, Singapore 729826</em>,
#  <em><span class="LrzXr">1 Turf Club Avenue, Singapore 738078</span></em>,
#  <em>Various Locations</em>]

# %% [markdown]
# Removing all unecessary tags

# %%
def remove_html_tags(tag_obj):
    return tag_obj.get_text()
cleaned_loc_list = [remove_html_tags(tag_obj) for tag_obj in loc_list]

cleaned_loc_list
# Out:
# ['Civic District, Singapore 178957',
#  '1 Imbiah Rd, Singapore 099692',
#  '18 Marina Gardens Dr, Singapore 018953',
#  ' Various Locations\xa0',
#  '54 Palawan Beach Walk, Singapore 098233',
#  '10 Bayfront Ave, Singapore 018956',
#  'HomeTeamNS Bedok Reservoir, 900 Bedok North Rd, Singapore',
#  'RW Sentosa, Singapore\xa0',
#  'Orchard Road, Singapore',
#  'Various Locations',
#  'Various Locations',
#  ' Chinatown, Singapore',
#  'FutureWorld',
#  ' 6 Bayfront Ave, Singapore 018974',
#  '80 Mandai Lake Rd, Singapore 729826',
#  'Various Locations\xa0',
#  '50 Beach View, Singapore 09860',
#  'Various Locations',
#  'Terminal 2, Changi Airport, Singapore\xa0',
#  'Various Locations',
#  ' Various Locations',
#  '78 Airport Blvd, Singapore 819666',
#  'Various Locations',
#  '36 Siloso Beach Walk, #01-01, Sentosa Island, Singapore',
#  'Various Locations',
#  '21 Jurong Town Hall Rd, Singapore 609433',
#  '8 Sentosa Gateway, Singapore 098269',
#  '262 Pasir Panjang Rd, Singapore 118628',
#  '13 Dempsey Road, #01-03/04, Singapore 249674',
#  '📍490 MacPherson Rd, Singapore, 368198',
#  '100 Loewen Road, Dempsey, Singapore 248837',
#  '41 Imbiah Rd, Sentosa, Singapore 099707',
#  'Various Locations',
#  '20 Mandai Lake Rd, Singapore 729825',
#  'Various Locations\xa0',
#  'Sentosa Island, Singapore',
#  'Equarius Hotel, B1M West Carpark, Resorts World Sentosa ',
#  '8 Marina Gardens Dr, Singapore 018951',
#  'Various Locations',
#  'Clark Quay, Jetty, Singapore\xa0',
#  'Little India, Singapore',
#  '85 Desker Rd, Singapore\xa0',
#  'Various Locations\xa0',
#  'Various Locations',
#  'Various Locations',
#  '80 Mandai Lake Rd, Singapore 729826',
#  'Orchard Central Level 11, 181 Orchard Rd, #11 – 01 / 02, Singapore 238896',
#  '43 Siloso Beach Walk, #01-01, iFly, Singapore 099010',
#  '60 Siloso Beach Walk, Singapore 098997',
#  '8C Jln Kledek, Singapore 199263',
#  'Orchard Road, Singapore\xa0',
#  '30 Raffles Ave, Singapore 039803',
#  'Various Locations',
#  'Various Locations',
#  'Various Locations',
#  '11 Cove Drive, Sentosa Cove, Singapore 098497',
#  '80 Mandai Lake Rd, Singapore 729826',
#  '1 Turf Club Avenue, Singapore 738078',
#  'Various Locations']

# %%
len(cleaned_loc_list)
# Out:
# 59

# %% [markdown]
# Joining the activity list and location list into a single list of dictionaries where the activity is the key and the location is the value

# %%
data = {
    'activity': cleaned_act_list,
    'location': cleaned_loc_list
}

df = pd.DataFrame(data)

df.head()
# Out:
#                                             activity  \
# 0  1. See the world’s largest public display of S...
# 1        2. Race at Singapore’s only night luge ride
# 2                3. Stroll around Gardens By The Bay
# 3         4. Indulge on famous Singapore Chilli Crab
# 4  5. Battle it out on Asia’s first gamified elec...
#
#                                   location
# 0         Civic District, Singapore 178957
# 1            1 Imbiah Rd, Singapore 099692
# 2   18 Marina Gardens Dr, Singapore 018953
# 3                       Various Locations
# 4  54 Palawan Beach Walk, Singapore 098233

# %%
df['activity'] = df['activity'].str.replace(r'^\d+\.\s', '', regex=True)

df.head()
# Out:
#                                             activity  \
# 0  See the world’s largest public display of Sout...
# 1           Race at Singapore’s only night luge ride
# 2                   Stroll around Gardens By The Bay
# 3            Indulge on famous Singapore Chilli Crab
# 4  Battle it out on Asia’s first gamified electri...
#
#                                   location
# 0         Civic District, Singapore 178957
# 1            1 Imbiah Rd, Singapore 099692
# 2   18 Marina Gardens Dr, Singapore 018953
# 3                       Various Locations
# 4  54 Palawan Beach Walk, Singapore 098233

# %% [markdown]
# Exporting scraped data

# %%
df.to_csv('../datasets/ss.csv')
