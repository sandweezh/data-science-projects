# %% [markdown]
# # Data Scraping (Yelp)

# %% [markdown]
# In this notebook, i will be scraping restaurant data from Yelp

# %%
import pandas as pd 
import re
from scrapingbee import ScrapingBeeClient
from bs4 import BeautifulSoup
import requests
import time

# %% [markdown]
# ### Set up requests library to retrieve data from target website (Single Page for testing)

# %%
client = ScrapingBeeClient(api_key = '9LF9S52L1EX49H34GBV3JX5NEUKDQJGN8K8KQOD7NKTV57R5YSBKAKIN3GDZS497TYB137CFNF9X25W0')

#indicate base url
url = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Singapore&attrs=RestaurantsPriceRange2.1'
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.text # returns html
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/dcfe403147fc/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>\n            window.yelp = window.yelp || {};\n            window.yelp.cookieTypePreferencesHeader = \'["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]\';\n            window.OneTrust = window.OneTrust || {};\n            window.OneTrust.dataSubjectParams = window.OneTrust.dataSubjectParams || {};\n            window.OneTrust.dataSubjectParams.id = \'\';\n            window.OneTrust.dataSubjectParams.isAnonymous = true;\n\n            function addCookieManagementScript() {\n                var tag = document.createElement(\'script\');\n                tag.async = true;\n                tag.src = \'https://cdn.cookielaw.org/consent/5fbcd417-fbc1-4fcc-abad-f622f1bba72d/otSDKStub.js\';\n                tag.type = \'text/javascript\';\n                tag.charset = \'UTF-8\';\n                tag.setAttribute(\'data-domain-script\', \'5fbcd417-fbc1-4fcc-abad-f622f1bba72d\');\n                tag.setAttribute(\'data-document-language\', \'true\');\n\n                document.head.appendChild(tag);\n            }\n\n            if (\'requestIdleCallback\' in window) {\n                requestIdleCallback(addCookieManagementScript, { timeout: 4000 });\n            } else {\n                setTimeout(addCookieManagementScript, 2000);\n            }\n        </script><script async src="https://www.google-analytics.com/analytics.js"></script><script async src="https://www.googletagmanager.com/gtag/js?id=G-K9Z2ZEVC8C&l=ga4DataLayer"></script><script>window.ga4DataLayer=window.ga4DataLayer||[];function ga4Tag(){ga4DataLayer.push(arguments);};ga4Tag("js",new Date());ga4Tag("config","G-K9Z2ZEVC8C",{send_page_view:false});</script><meta id="emotion-container"><style data-emotion="yelp-emotion-global xl0fej">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none;}table{border-collapse:collapse;border-spacing:0;}</style><style data-emotion="yelp-emotion-global zpdl00">.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none!important;}@media only screen and (max-width: 600px){.responsive:not(.responsive-biz) .responsive-small-display-inline-block{display:inline-block!important;}.responsive:not(.responsive-biz) .responsive-small-display-block{display:block!important;}.responsive:not(.responsive-biz) .responsive-small-display-inline{display ...

# %% [markdown]
# ### Create a BeautifulSoup object

# %%
soup = BeautifulSoup(res.text, 'lxml')  # parse html for python
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/no-js/,"js");</script><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en-US" http-equiv="Content-Language"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><link content="#FF1A1A" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/><link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/dcfe403147fc/assets/img/logos/favicon.ico" rel="shortcut icon"/><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>
#             window.yelp = window.yelp || {};
#             window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#             window.OneTrust = window.OneTrust || {};
#             window.OneTrust.dataSubjectParams = window.OneTrust.dataSubjectParams || {};
#             window.OneTrust.dataSubjectParams.id = '';
#             window.OneTrust.dataSubjectParams.isAnonymous = true;
#
#             function addCookieManagementScript() {
#                 var tag = document.createElement('script');
#                 tag.async = true;
#                 tag.src = 'https://cdn.cookielaw.org/consent/5fbcd417-fbc1-4fcc-abad-f622f1bba72d/otSDKStub.js';
#                 tag.type = 'text/javascript';
#                 tag.charset = 'UTF-8';
#                 tag.setAttribute('data-domain-script', '5fbcd417-fbc1-4fcc-abad-f622f1bba72d');
#                 tag.setAttribute('data-document-language', 'true');
#
#                 document.head.appendChild(tag);
#             }
#
#             if ('requestIdleCallback' in window) {
#                 requestIdleCallback(addCookieManagementScript, { timeout: 4000 });
#             } else {
#                 setTimeout(addCookieManagementScript, 2000);
#             }
#         </script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-K9Z2ZEVC8C&amp;l=ga4DataLayer"></script><script>window.ga4DataLayer=window.ga4DataLayer||[];function ga4Tag(){ga4DataLayer.push(arguments);};ga4Tag("js",new Date());ga4Tag("config","G-K9Z2ZEVC8C",{send_page_view:false});</script><meta id="emotion-container"/><style data-emotion="yelp-emotion-global xl0fej">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}</style><style data-emotion="yelp-emotion-global zpdl00">.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none!important;}@media only screen and (max-width: 600px){.responsive:not(.responsive-biz) .responsive-small-display-inline-block{display:inline-block!important;}.responsive:not(.responsive-biz) .responsive-small-display-block{display:block!important;}.responsive:not(.responsive-biz) .responsive-small-display-inline{display:inline!important;}}@media only screen and (max-width: 780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block!important;}.responsive-biz .responsive-small-display-block{display:block!important;}.responsive-biz .responsive-small-display-inline{display:inline!important;}}@media only screen and (max-width: 1024px){.responsive:not(.responsive-biz) .responsive-medium-display-inline-block{display:inline-block!important;}.responsive:not(.responsive-biz) .responsive-medium-display-block{display:block!important;}.responsive:not(.responsive-biz) .responsive-medium-display-inline{display:inline!important;}}@media only screen and (max-width: 1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block!important;}.responsive-biz .responsive-medium-display-block{display:block!important;}.responsive-biz .responsive-medium-display-inline{display:inline!important;}}@media only screen and (min-width: 1025px){.responsive:not(.responsive-biz) .responsive-desktop-small-display-inline-block{display:inline-block!important;}.responsive:not(.responsive-biz) .responsive-desktop-small-display-block{display:block!important;}.responsive:not(.responsive-biz) .responsive-desktop-small-display-inline{display:inline!important;}}@media only screen and (min-width: 1241px){.responsive-biz .responsive-desktop-small-display-inline-block{display:inline-block!important;}.responsive-biz .responsive-desktop-small-display-block{display:block!important;}.responsive-biz .responsive-desktop-small-display-inline{display:inline!important;}}@media only screen and (min-width: 1144px){.responsive:not(.responsive-biz) .responsive-desktop-default-display-inline-block{display:inline-block!important;}.responsive:not(.responsive-biz) .responsive-desktop-default-display-block{display:block!important;}.responsive:not(.responsive-biz) .responsive-desktop-default-display-inline{display:inline!important;}}@media only screen and (min-width: 1241px){.responsive-biz .responsive-desktop-default-display-inline-block{display:inline-block!important;}.responsive-biz .responsive-desktop-default-display-block{display:block!important;}.responsive-biz .responsive-desktop-default-display-inline{display:inline!imp ...
# <script>
#         window.yelp = window.yelp || {};
#         window.yelp.critical_css = window.yelp.critical_css || {};
#         window.yelp.critical_css.css_map = {};
#     </script>
# <!-- css-middleware: bootstrap placeholder --><script>(function() { window.yelp.critical_css.recordDone=function(c,l){l.onload=null;var i=window.yelp.critical_css.css_map[c];window.yelp.critical_css.css_map[c]=i&&Object.keys(i).length?i:{loaded:!1,linkTag:l}}; })()</script>
# <meta name="critical_css_middleware"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-regular.yji-aff9b80e384301f2ae0c.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-semibold.yji-d3abae27d3eac73b40a5.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-bold.yji-1145ff0b749fff2d31bb.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/poppins-bold.yji-9690ce6275ddc5645cfa.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/poppins-medium.yji-dc16a3592fdb61b620cc.woff2" rel="preload" type="font/woff2"/><link data-rh="true" href="https://www.yelp.com/search?attrs=RestaurantsPriceRange2.1&amp;find_desc=Restaurants&amp;find_loc=Singapore&amp;start=10" rel="next"/><link data-rh="true" href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/><link as="image" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/gray-spinner.yji-98588e3310fd5dfa96dd.gif" rel="preload"/><link as="style" data-chunk="RelatedCostGuidesSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedCostGuidesSeparator.yji-026255a2df4bda1dd835.chunk.css" rel="preload"/>
# <link as="style" data-chunk="TalkTopics" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/TalkTopics.yji-210fe751cc8b538209c9.chunk.css" rel="preload"/>
# <link as="style" data-chunk="RelatedLinksSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedLinksSeparator.yji-10766fa44911c37e0a4a.chunk.css" rel="preload"/>
# <link as="style" data-chunk="SearchFeedback" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/SearchFeedback.yji-3fea46c36ecde597b392.chunk.css" rel="preload"/>
# <link as="style" data-chunk="PaginationSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/PaginationSeparator.yji-146fb5e1995bd4db5e89.chunk.css" rel="preload"/>
# <link as="script" data-chunk="PaginationSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/PaginationSeparator.yji-e0e415a4b6a63d9d7040.chunk.js" rel="preload"/>
# <link as="script" data-chunk="SearchFeedback" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/SearchFeedback.yji-2b550e2805ba1cf74983.chunk.js" rel="preload"/>
# <link as="script" data-chunk="RelatedLinksSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedLinksSeparator.yji-3be87aa41fac520fde39.chunk.js" rel="preload"/>
# <link as="script" data-chunk="RelatedArticlesForBizOwnersSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedArticlesForBizOwnersSeparator.yji-1537574134e36c30def4.chunk.js" rel="preload"/>
# <link as="script" data-chunk="TalkTopics" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/TalkTopics.yji-1195fb77d5221d05826a.chunk.js" rel="preload"/>
# <link as="script" data-chunk="RelatedCostGuidesSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedCostGuidesSeparator.yji-4a9ffa87c525d858b40a.chunk.js" rel="preload"/>
# <link as="script" data-chunk="FrequentlyAskedQuestionsSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/FrequentlyAskedQuestionsSeparator.yji-a3f226fafe50ace5b1f2.chunk.js" rel="preload"/><link data-chunk="PaginationSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/PaginationSeparator.yji-146fb5e1995bd4db5e89.chunk.css" rel="stylesheet"/>
# <link data-chunk="SearchFeedback" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/SearchFeedback.yji-3fea46c36ecde597b392.chunk.css" rel="stylesheet"/>
# <link data-chunk="RelatedLinksSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedLinksSeparator.yji-10766fa44911c37e0a4a.chunk.css" rel="stylesheet"/>
# <link data-chunk="TalkTopics" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/TalkTopics.yji-210fe751cc8b538209c9.chunk.css" rel="stylesheet"/>
# <link data-chunk="RelatedCostGuidesSeparator" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedCostGuidesSeparator.yji-026255a2df4bda1dd835.chunk.css" rel="stylesheet"/><script async="true" data-rh="true" src="//client.px-cloud.net/PXYK7vmub2/main.min.js"></script><script data-rh="true" data-testid="gtmScript" type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script', 'dataLayer','GTM-THHF2RF');</script><script data-rh="true">window.pageSpeedCustomTimestamps = {};</script><script data-rh="true">
# window.__googleInit = function() {
#
#     if (window.mapInstance != null) {
#         return;
#     }
#
#     window.mapContainer = document.createElement('div');
#     window.mapContainer.style.height = '100%';
#     window.mapContainer.style.width = '100%';
#     window.mapContainer.style.visibility = 'hidden';
#
#     document.body.appendChild(window.mapContainer);
#
#
#     window.mapInstance = new google.maps.Map(
#         window.mapContainer,
#         {
#             gestureHandling: 'cooperative',
#             backgroundColor: 'rgba(229, 227, 223, 1)',
#             mapTypeId: google.maps.MapTypeId.ROADMAP,
#             controlSize: 28,
#             disableDefaultUI: true,
#             zoomControl: false,
#             zoomControlOptions: {
#                 position: google.maps.ControlPosition.TOP_LEFT,
#             },
#             styles: [
#                 {
#                     featureType: 'poi',
#                     elementType: 'labels',
#                     stylers: [{ visibility: 'off' }],
#                 },
#                 {
#                     featureType: 'administrative.neighborhood',
#                     elementType: 'labels',
#                     stylers: [{ lightness: 50 }],
#                 },
#             ],
#         }
#     );
#
#     var marker = new google.maps.Marker({
#         position: {lat: 0, lng: 0},
#         map: window.mapInstance,
#     });
#     marker.setMap(null);
#     window.mapInstance.setCenter({lat: 0, lng: 0});
#
#
#     if(window.__mapReady) {
#         window.__mapReady();
#     }
# }
# </script><script async="true" data-rh="true" src="//maps.googleapis.com/maps/api/js?client=gme-yelp&amp;libraries=places,visualization&amp;language=en&amp;region=US&amp;callback=__googleInit" type="text/javascript"></script><title data-rh="true">Restaurants Singapore, Singapore - Last Updated May 2024 - Yelp</title><meta content="Top 10 Best Restaurants in Singapore, Singapore - May 2024 - Yelp - Sin Heng Kee Porridge, French Ladle, Hong Kong Style Chee Cheong Fun, Tian Tian Hainanese Chicken Rice, Song Fa Bak Kut Teh, Two Men Bagel House, Tim Ho Wan, Zhong Guo La Mian Xiao Long Bao, Wee Nam Kee Chicken Rice" data-rh="true" name="description"/><meta content="noindex" data-rh="true" name="robots"/><meta content="noarchive" data-rh="true" name="bingbot"/><meta content="Yelp" data-rh="true" property="og:site_name"/><meta content="website" data-rh="true" property="og:type"/><meta content="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/a8d26394324f/assets/img/seo_metadata/yelp_og_image.png" data-rh="true" property="og:image"/><meta content="1080" data-rh="true" property="og:image:height"/><meta content="1920" data-rh="true" property="og:image:width"/><meta content="97534753161" data-rh="true" property="fb:app_id"/><meta content="Top 10 Best Restaurants in Singapore, Singapore - May 2024 - Yelp - Sin Heng Kee Porridge, French Ladle, Hong Kong Style Chee Cheong Fun, Tian Tian Hainanese Chicken Rice, Song Fa Bak Kut Teh, Two Men Bagel House, Tim Ho Wan, Zhong Guo La Mian Xiao Long Bao, Wee Nam Kee Chicken Rice" data-rh="true" property="og:description"/><meta content="Restaurants Singapore, Singapore - Last Updated May 2024 - Yelp" data-rh="true" property="og:title"/><meta content="" data-rh="true" property="og:url"/><meta content="app-id=284910350, app-argument=yelp:///search?location=Singapore&amp;terms=Restaurants&amp;utm_campaign=default&amp;utm_source=www" data-rh="true" name="apple-itunes-app"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-lib-yelp-react-component-arrange-14.0.3-pkg.yji-13b4903814928f1bd1e9.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-commons-pkg.yji-6fe00a37c590d09b7650.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-gondola-search-pkg.yji-fc9f8a35f5b0a8ed67d2.css" rel="stylesheet"/>
# <script>document.cookie = "xcj=1|pqyxhPT5FveSZ6L1OHObVvdUWhFBdm5ucCZk-27bx6I; Domain=.yelp.com; expires=Wed, 31 Jul 2024 10:45:15 GMT; Max-Age=7776000; Path=/";</script><link href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/></head><body class="" style="margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline; line-height: 1;"><noscript></noscript><yelp-react-root><div data-hypernova-id="62c6d295-edc3-472a-a2c5-87ab6ecf05b9" data-hypernova-key="yelpfrontend__611__yelpfrontend__GondolaSearch__dynamic"><div class="yelp-emotion-1iy1dwt"><ul class="yelp-emotion-9icx5k"></ul></div><div class="" id="google_one_tap_parent" style="position:fixed;width:auto;height:auto;z-index:9999;top:20px;left:20px"></div><noscript data-testid="gtmNoscript"><iframe class="" height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-THHF2RF" style="display:none;visibility:hidden" width="0"></iframe></noscript><script>window.pageSpeedCustomTimestamps['body:start'] = (new Date()).getTime();</script><div class="alert-notice__09f24__WKrTt yelp-emotion-1iy1dwt" data-module-name="LegalBanner"><iframe class="cookie-iframe-banner__09f24__GnESl" frameborder="0" scrolling="no" src="/eu_cookie_notice?responsive" style="height:0px" tabindex="-1" title="cookie notice"></iframe></div><div class="sticky-wrapper__09f24__hwFNf pageHeader__09f24__e6lW4 v2__09f24__GsUJ_ yelp-emotion-oyzmk4" data-lcp-target-id="CONSUMER_HEADER"><div class="yelp-emotion-ma3bqu"><div class="a11y-menu-container__09f24__V3Frf yelp-emotion-1iy1dwt"></div></div><header class="consumer-header-container__09f24__ieW2P yelp-emotion-n9m8nt"><div class="consumer-header__09f24__GAvyT yelp-emotion-1iy1dwt"><div class="arrange__09f24__LDfbs vertical-align-middle__09f24__zU9sE yelp-emotion-1iy1dwt"><div class="logo-arrange-unit__09f24__Rbwi3 arrange-unit__09f24__rqHTg yelp-emotion-1iy1dwt"><div class="yelp-emotion-1pfcrwg"><div class="logo__09f24__ip022 logo-image__09f24__SXMH_ logo-container__09f24__jaSQB yelp-emotion-1iy1dwt" data-analytics-label="logo" id="logo" style="background-image:url(https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_design_cdn/7ef71bf77a33/assets/img/brand/logo_desktop.svg)"><a class="logo-link__09f24__fS20h yelp-emotion-dcq3ik" href="/">Yelp</a></div></div></div><div class="search-suggest-arrange-unit__09f24__zqa_F arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG yelp-emotion-1iy1dwt"><div class="search-suggest-container-outer__09f24__SUL4j yelp-emotion-1iy1dwt"><div class="search-suggest-container-inner__09f24__WsMGR yelp-emotion-1iy1dwt"><div class="arrange__09f24__LDfbs gutter-2__09f24__CCmUo yelp-emotion-1iy1dwt"><div class="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG yelp-emotion-1iy1dwt"><form action="/search" class="yelp-emotion-9tqvka ewsdu8x6" data-testid="searchSuggest" id="header_find_form" method="get" role="search"><div class="ewsdu8x10 yelp-emotion-yguggy"><label class="label__09f24__y83zE yelp-emotion-1rr8qmb ewsdu8x4" for="search_description"><span alt="Find" aria-hidden="false" aria-label="Find" class="icon--18-search-small yelp-emotion-1rlv2l7" role="img"><svg class="icon_svg" height="18" width="18"><path d="M15.913 14.224a1.324 1.324 0 0 0-.3-.466h.009l-3.377-3.376a5.492 5.492 0 0 0 .802-2.857 5.523 5.523 0 1 0-5.522 5.52 5.491 5.491 0 0 0 2.856-.801l3.369 3.369.004.003c.132.131.293.231.471.298.143.053.296.086.458.086.727 0 1.317-.589 1.317-1.316 0-.163-.033-.317-.087-.46zM7.525 10.94a3.422 3.422 0 0 1-3.418-3.416 3.422 3.422 0 0 1 3.418-3.417 3.422 3.422 0 0 1 3.416 3.417 3.421 3.421 0 0 1-3.416 3.416z"></path></svg></span></label><div aria-expanded="false" aria-haspopup="listbox" class="ewsdu8x7 e140vcx50 yelp-emotion-201gdk" role="combobox"><input aria-hidden="true" autocomplete="off" class="input__09f24__yaqh1 yelp-emotion-168hn1g e140vcx52" data-testid="hiddenInput" disabled="" placeholder=" " spellcheck="false" tabindex="-1" type="text" value=""/><i ...
# Fast service.. great taste and efficient staff.
# Coffee's great.
# Don't order the bean…”<span class="yelp-emotion-h73fpp" data-font-weight="semibold"> <a class="yelp-emotion-33t6hm" href="/biz/sin-heng-kee-porridge-singapore?hrid=BTOoSXspAC75EaPyUPu8RQ&amp;osq=Restaurants" rel="noopener" target="_blank">more</a></span></p></div></div></div></div></div></div></div></div><div class="yelp-emotion-1qdzjxq" data-testid="search-results-divider"></div></li><li class="yelp-emotion-1iy1dwt"><div class="container__09f24__FeTO6 hoverable__09f24___UXLO yelp-emotion-way87j"><div class="yelp-emotion-1he6azc" data-testid="serp-ia-card"><div class="yelp-emotion-1mt4kbn"><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><div class="dontTriggerCardClick__09f24__jC7ap yelp-emotion-zo5ubf" data-lcp-target-id="SCROLLABLE_PHOTO_BOX"><div aria-label="Slideshow" class="container__09f24__M4NRG yelp-emotion-1iy1dwt"><div class="child__09f24__Z2_cG yelp-emotion-1iy1dwt"><a class="yelp-emotion-1nbdmhn" href="/biz/french-ladle-singapore?osq=Restaurants" rel="noopener" target="_blank"><img alt="French Ladle" class="yelp-emotion-fex5b" draggable="true" loading="lazy" sizes="(max-width: 1322px) 168px,(max-width: 1560px) 180px,258px" src="https://s3-media0.fl.yelpcdn.com/bphoto/GShMZ0hD2c9l9xrBc8d00Q/348s.jpg"/></a></div><div aria-disabled="true" aria-label="Previous" class="button__09f24__MPXf0 left__09f24__iiJAG disabled__09f24__I48TE yelp-emotion-1iy1dwt" role="button" tabindex="0"><span alt="" aria-hidden="true" class="icon--24-chevron-left-v2 yelp-emotion-1lac7xd" role="img"><svg class="icon_svg" height="24" width="24"><path d="M14.25 17.58a1 1 0 0 1-.71-.3L9 12.7a1 1 0 0 1 0-1.4l4.5-4.58A1 1 0 0 1 15 6.7a1 1 0 0 1 0 1.42L11.15 12 15 15.88a1 1 0 0 1 0 1.42 1 1 0 0 1-.75.28Z"></path></svg></span></div><div aria-disabled="true" aria-label="Next" class="button__09f24__MPXf0 right__09f24__S1FA0 disabled__09f24__I48TE yelp-emotion-1iy1dwt" role="button" tabindex="0"><span alt="" aria-hidden="true" class="icon--24-chevron-right-v2 yelp-emotion-1lac7xd" role="img"><svg class="icon_svg" height="24" width="24"><path d="M9.75 17.58a1 1 0 0 1-.7-.28 1 1 0 0 1 0-1.42l3.8-3.88L9 8.12a1 1 0 1 1 1.41-1.42L15 11.3a1 1 0 0 1 0 1.4l-4.5 4.58a1 1 0 0 1-.75.3Z"></path></svg></span></div></div></div></div></div></div></div><div class="yelp-emotion-cxcdjj"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="businessName__09f24__HG_pC yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><h3 class="yelp-emotion-i7hfd5">2<!-- -->. <a class="yelp-emotion-idvn5q" href="/biz/french-ladle-singapore?osq=Restaurants" name="French Ladle" rel="noopener" target="_blank">French Ladle</a></h3></div></div></div><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1fnvi93"><div class="yelp-emotion-16z4x7b"><span class="yelp-emotion-pw0opj"><div aria-label="4.8 star rating" class="yelp-emotion-9tnml4" role="img"><div class="yelp-emotion-z05zjh"><svg height="20" viewbox="0 0 20 20" width="20"><path d="M0 4C0 1.79086 1.79086 0 4 0H10V20H4C1.79086 20 0 18.2091 0 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path d="M20 4C20 1.79086 18.2091 0 16 0H10V20H16C18.2091 20 20 18.2091 20 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path clip-rule="evenodd" d="M10 13.3736L12.5949 14.7111C12.7378 14.7848 12.9006 14.8106 13.0593 14.7847C13.4681 14.718 13.7454 14.3325 13.6787 13.9237L13.2085 11.0425L15.2824 8.98796C15.3967 8.8748 15.4715 8.72792 15.4959 8.569C15.5588 8.15958 15.2779 7.77672 14.8685 7.71384L11.983 7.2707L10.6699 4.66338C10.5975 4.51978 10.481 4.40322 10.3374 4.33089C9.96742 4.14458 9.51648 4.29344 9.33017 4.66338L8.01705 7.2707L5.13157 7.71384C4.97265 7.73825 4.82577 7.81309 4.71261 7.92731C4.42109 8.22158 4.42332 8.69645 4.71759 8.98796L6.79152 11.0425L6.32131 13.9237C6.29541 14.0824 6.3212 14.2452  ...
# Starters to share :-
# *Portobello Salad -
# * Escargot
# * Pan-seared Foie…”<span class="yelp-emotion-h73fpp" data-font-weight="semibold"> <a class="yelp-emotion-33t6hm" href="/biz/french-ladle-singapore?hrid=yeJjGDcYUqLtJ1l9RyzcLQ&amp;osq=Restaurants" rel="noopener" target="_blank">more</a></span></p></div></div></div></div></div></div></div></div><div class="yelp-emotion-1qdzjxq" data-testid="search-results-divider"></div></li><li class="yelp-emotion-1iy1dwt"><div class="container__09f24__FeTO6 hoverable__09f24___UXLO yelp-emotion-way87j"><div class="yelp-emotion-1he6azc" data-testid="serp-ia-card"><div class="yelp-emotion-1mt4kbn"><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><div class="dontTriggerCardClick__09f24__jC7ap yelp-emotion-zo5ubf" data-lcp-target-id="SCROLLABLE_PHOTO_BOX"><div aria-label="Slideshow" class="container__09f24__M4NRG yelp-emotion-1iy1dwt"><div class="child__09f24__Z2_cG yelp-emotion-1iy1dwt"><a class="yelp-emotion-1nbdmhn" href="/biz/hong-kong-style-chee-cheong-fun-singapore-3?osq=Restaurants" rel="noopener" target="_blank"><img alt="Hong Kong Style Chee Cheong Fun" class="yelp-emotion-fex5b" draggable="true" loading="lazy" sizes="(max-width: 1322px) 168px,(max-width: 1560px) 180px,258px" src="https://s3-media0.fl.yelpcdn.com/bphoto/uNrSYnQ19hk-Pd7jXXe2EA/348s.jpg"/></a></div><div aria-disabled="true" aria-label="Previous" class="button__09f24__MPXf0 left__09f24__iiJAG disabled__09f24__I48TE yelp-emotion-1iy1dwt" role="button" tabindex="0"><span alt="" aria-hidden="true" class="icon--24-chevron-left-v2 yelp-emotion-1lac7xd" role="img"><svg class="icon_svg" height="24" width="24"><path d="M14.25 17.58a1 1 0 0 1-.71-.3L9 12.7a1 1 0 0 1 0-1.4l4.5-4.58A1 1 0 0 1 15 6.7a1 1 0 0 1 0 1.42L11.15 12 15 15.88a1 1 0 0 1 0 1.42 1 1 0 0 1-.75.28Z"></path></svg></span></div><div aria-disabled="true" aria-label="Next" class="button__09f24__MPXf0 right__09f24__S1FA0 disabled__09f24__I48TE yelp-emotion-1iy1dwt" role="button" tabindex="0"><span alt="" aria-hidden="true" class="icon--24-chevron-right-v2 yelp-emotion-1lac7xd" role="img"><svg class="icon_svg" height="24" width="24"><path d="M9.75 17.58a1 1 0 0 1-.7-.28 1 1 0 0 1 0-1.42l3.8-3.88L9 8.12a1 1 0 1 1 1.41-1.42L15 11.3a1 1 0 0 1 0 1.4l-4.5 4.58a1 1 0 0 1-.75.3Z"></path></svg></span></div></div></div></div></div></div></div><div class="yelp-emotion-cxcdjj"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="businessName__09f24__HG_pC yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><h3 class="yelp-emotion-i7hfd5">3<!-- -->. <a class="yelp-emotion-idvn5q" href="/biz/hong-kong-style-chee-cheong-fun-singapore-3?osq=Restaurants" name="Hong Kong Style Chee Cheong Fun" rel="noopener" target="_blank">Hong Kong Style Chee Cheong Fun</a></h3></div></div></div><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1fnvi93"><div class="yelp-emotion-16z4x7b"><span class="yelp-emotion-pw0opj"><div aria-label="4.6 star rating" class="yelp-emotion-9tnml4" role="img"><div class="yelp-emotion-z05zjh"><svg height="20" viewbox="0 0 20 20" width="20"><path d="M0 4C0 1.79086 1.79086 0 4 0H10V20H4C1.79086 20 0 18.2091 0 16V4Z" fill="rgba(255,100,61,1)" opacity="1"></path><path d="M20 4C20 1.79086 18.2091 0 16 0H10V20H16C18.2091 20 20 18.2091 20 16V4Z" fill="rgba(255,100,61,1)" opacity="1"></path><path clip-rule="evenodd" d="M10 13.3736L12.5949 14.7111C12.7378 14.7848 12.9006 14.8106 13.0593 14.7847C13.4681 14.718 13.7454 14.3325 13.6787 13.9237L13.2085 11.0425L15.2824 8.98796C15.3967 8.8748 15.4715 8.72792 15.4959 8.569C15.5588 8.15958 15.2779 7.77672 14.8685 7.71384L11.983 7.2707L10.6699 4.66338C10.5975 4.51978 10.481 4.40322 10.3374 4.33089C9.96742 4.14458 9.51648 4.29344 9.33017 4.66338L8.01705 7.2707L5.13157 7.71384C4.97265 7.73825 4.82577 7.81309 4.71261 7.92731C4.42109 8.22158 4.4233 ...
#
# When my…”<span class="yelp-emotion-h73fpp" data-font-weight="semibold"> <a class="yelp-emotion-33t6hm" href="/biz/song-fa-bak-kut-teh-singapore-6?hrid=LhM0X3LErYnSNa3GOXJiRg&amp;osq=Restaurants" rel="noopener" target="_blank">more</a></span></p></div></div></div></div></div></div></div></div><div class="yelp-emotion-1qdzjxq" data-testid="search-results-divider"></div></li><li class="yelp-emotion-1iy1dwt"><div class="container__09f24__FeTO6 hoverable__09f24___UXLO yelp-emotion-way87j"><div class="yelp-emotion-1he6azc" data-testid="serp-ia-card"><div class="yelp-emotion-1mt4kbn"><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><div class="dontTriggerCardClick__09f24__jC7ap yelp-emotion-zo5ubf" data-lcp-target-id="SCROLLABLE_PHOTO_BOX"><div aria-label="Slideshow" class="container__09f24__M4NRG yelp-emotion-1iy1dwt"><div class="child__09f24__Z2_cG yelp-emotion-1iy1dwt"><a class="yelp-emotion-1nbdmhn" href="/biz/tim-ho-wan-singapore-7?osq=Restaurants" rel="noopener" target="_blank"><img alt="Tim Ho Wan" class="yelp-emotion-fex5b" draggable="true" loading="lazy" sizes="(max-width: 1322px) 168px,(max-width: 1560px) 180px,258px" src="https://s3-media0.fl.yelpcdn.com/bphoto/Knt4Iztvr5czzJWWC3c3Pg/348s.jpg"/></a></div><div aria-disabled="true" aria-label="Previous" class="button__09f24__MPXf0 left__09f24__iiJAG disabled__09f24__I48TE yelp-emotion-1iy1dwt" role="button" tabindex="0"><span alt="" aria-hidden="true" class="icon--24-chevron-left-v2 yelp-emotion-1lac7xd" role="img"><svg class="icon_svg" height="24" width="24"><path d="M14.25 17.58a1 1 0 0 1-.71-.3L9 12.7a1 1 0 0 1 0-1.4l4.5-4.58A1 1 0 0 1 15 6.7a1 1 0 0 1 0 1.42L11.15 12 15 15.88a1 1 0 0 1 0 1.42 1 1 0 0 1-.75.28Z"></path></svg></span></div><div aria-disabled="true" aria-label="Next" class="button__09f24__MPXf0 right__09f24__S1FA0 disabled__09f24__I48TE yelp-emotion-1iy1dwt" role="button" tabindex="0"><span alt="" aria-hidden="true" class="icon--24-chevron-right-v2 yelp-emotion-1lac7xd" role="img"><svg class="icon_svg" height="24" width="24"><path d="M9.75 17.58a1 1 0 0 1-.7-.28 1 1 0 0 1 0-1.42l3.8-3.88L9 8.12a1 1 0 1 1 1.41-1.42L15 11.3a1 1 0 0 1 0 1.4l-4.5 4.58a1 1 0 0 1-.75.3Z"></path></svg></span></div></div></div></div></div></div></div><div class="yelp-emotion-cxcdjj"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="businessName__09f24__HG_pC yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><h3 class="yelp-emotion-i7hfd5">8<!-- -->. <a class="yelp-emotion-idvn5q" href="/biz/tim-ho-wan-singapore-7?osq=Restaurants" name="Tim Ho Wan" rel="noopener" target="_blank">Tim Ho Wan</a></h3></div></div></div><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1fnvi93"><div class="yelp-emotion-16z4x7b"><span class="yelp-emotion-pw0opj"><div aria-label="4.3 star rating" class="yelp-emotion-9tnml4" role="img"><div class="yelp-emotion-z05zjh"><svg height="20" viewbox="0 0 20 20" width="20"><path d="M0 4C0 1.79086 1.79086 0 4 0H10V20H4C1.79086 20 0 18.2091 0 16V4Z" fill="rgba(255,100,61,1)" opacity="1"></path><path d="M20 4C20 1.79086 18.2091 0 16 0H10V20H16C18.2091 20 20 18.2091 20 16V4Z" fill="rgba(255,100,61,1)" opacity="1"></path><path clip-rule="evenodd" d="M10 13.3736L12.5949 14.7111C12.7378 14.7848 12.9006 14.8106 13.0593 14.7847C13.4681 14.718 13.7454 14.3325 13.6787 13.9237L13.2085 11.0425L15.2824 8.98796C15.3967 8.8748 15.4715 8.72792 15.4959 8.569C15.5588 8.15958 15.2779 7.77672 14.8685 7.71384L11.983 7.2707L10.6699 4.66338C10.5975 4.51978 10.481 4.40322 10.3374 4.33089C9.96742 4.14458 9.51648 4.29344 9.33017 4.66338L8.01705 7.2707L5.13157 7.71384C4.97265 7.73825 4.82577 7.81309 4.71261 7.92731C4.42109 8.22158 4.42332 8.69645 4.71759 8.98796L6.79152 11.0425L6.32131 13.9237C6.29541 14.0824 6.3212 14.2452 6.39486 14.3881C6 ...
# I am Masaaki.S. It is a Yelper in Japan.
# It was decided to go to Singapore for work next week.
#
# In Singapore,…</p></div></div></div></div></div></div><div class="arrange-unit__09f24__rqHTg arrange-unit-grid-column--1__09f24__nuREa yelp-emotion-1iy1dwt"><div class="arrange__09f24__LDfbs gutter-1__09f24__yAbCL yelp-emotion-1iy1dwt"><div class="photoBoxContainer__09f24__rxcZK arrange-unit__09f24__rqHTg yelp-emotion-1iy1dwt"><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1uzn5sv"><img alt="" class="yelp-emotion-dy9j94" draggable="true" height="40" loading="lazy" src="https://s3-media0.fl.yelpcdn.com/photo/RnHth4N0ioWRWVJMIZKccQ/60s.jpg" width="40"/></div></div></div></div></div><div class="talkText__09f24__hkNuB arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG yelp-emotion-1iy1dwt"><div class="yelp-emotion-1iy1dwt"><div aria-hidden="false" class="yelp-emotion-ohs7lg"><div class="yelp-emotion-1iy1dwt"><a class="yelp-emotion-d7opz8" href="/topic/singapore-restaurants-full-vs-empty">Restaurants - Full vs Empty</a><p class="yelp-emotion-19a3fsb">I will be writing two reviews soon.  They are based on dinner dates from last week.  They were on back to back evenings.  They were both traditional…</p></div></div></div></div></div></div></div></div></div></div></li><li class="yelp-emotion-1iy1dwt"></li><li class="yelp-emotion-1iy1dwt"></li><li class="yelp-emotion-1iy1dwt"><div class="yelp-emotion-1w7nfge"><h2 class="yelp-emotion-i7hfd5">Frequently Asked Questions and Answers</h2><div class="arrange__09f24__LDfbs gutter-4__09f24__dajdg layout-equal__09f24__odeM0 yelp-emotion-5qya4l"><div class="arrange-unit__09f24__rqHTg arrange-unit-grid-column--6__09f24__SziCe yelp-emotion-1iy1dwt"><p class="yelp-emotion-12z6kck" data-font-weight="bold">What are people saying about restaurants in Singapore, SG?</p><p class="yelp-emotion-pxnd5f">This is a review for restaurants in Singapore, SG:</p><p class="yelp-emotion-pxnd5f">"Better value than the overpriced bad service Heng Long teochew porridge!! Fast service.. great taste and efficient staff. Coffee's great. Don't order the bean curds.. uncle says stopped selling a year ago.. But the poster still showing!! Great for a hot meal!!"</p><p class="yelp-emotion-pxnd5f"><a class="yelp-emotion-33t6hm" href="/biz/sin-heng-kee-porridge-singapore">See more reviews for this business.</a></p></div><div class="arrange-unit__09f24__rqHTg arrange-unit-grid-column--6__09f24__SziCe yelp-emotion-1iy1dwt"></div></div></div><script type="application/ld+json">{"@context":"https://schema.org","@type":"FAQPage","@id":"https://www.yelp.com/search?find_desc=Restaurants&amp;find_loc=Singapore&amp;attrs=RestaurantsPriceRange2.1/#faq","mainEntity":[{"@type":"Question","name":"What are people saying about restaurants in Singapore, SG?","acceptedAnswer":{"@type":"Answer","text":"This is a review for restaurants in Singapore, SG:&lt;br/&gt;&quot;Better value than the overpriced bad service Heng Long teochew porridge!! Fast service.. great taste and efficient staff. Coffee&apos;s great. Don&apos;t order the bean curds.. uncle says stopped selling a year ago.. But the poster still showing!! Great for a hot meal!!&quot;&lt;br/&gt;&lt;p&gt;&lt;a href=/biz/sin-heng-kee-porridge-singapore&gt;See more reviews for this business.&lt;/a&gt;&lt;/p&gt;"}}]}</script></li></ul><img alt="" class="abpDetectionPixel__09f24__MzxU0" src="/px.gif?ch=1&amp;local_ads=1&amp;rn=7&amp;unique_request_id=a5b7f2d283c95e80&amp;unique_visitor_id=06709B394A8EC0B9"/><img alt="" class="abpDetectionPixel__09f24__MzxU0" src="/px.gif?ch=2&amp;local_ads=1&amp;rn=7&amp;unique_request_id=a5b7f2d283c95e80&amp;unique_visitor_id=06709B394A8EC0B9"/></div></main></div><div class="responsiveRightRail__09f24__rnswI yelp-emotion-5cdi6j"><div class="stickyContainer__09f24__kXuMq innerShadow__09f24__WVAew yelp-emotion-94i2n6"><div class="container__09f24__eRn8z googleMapContainer__09f24__USCVC yelp-emotion-1iy1dwt" data-lcp-target-id="SEARCH_MAP_SPINNER"></div></div> ...
# <script data-hypernova-id="62c6d295-edc3-472a-a2c5-87ab6ecf05b9" data-hypernova-key="yelpfrontend__611__yelpfrontend__GondolaSearch__dynamic" type="application/json"><!--{"locale":"en_US","messages":{},"requestCookies":{"LOCATION":null,"MO_MAP":null},"requestHeaders":{"user-agent":"python-requests/2.31.0"},"requestPath":"/search","requestUrl":"https://www.yelp.com/search?find_desc=Restaurants&amp;find_loc=Singapore&amp;attrs=RestaurantsPriceRange2.1","requestTimestampMs":1714646715825,"routeParams":{},"userId":null,"bizUserId":null,"uniqueRequestId":"5bc7534efa9e1648","site":"www","gaConfig":{"clientID":"06709B394A8EC0B9","dimensions":{"global":{"full_url":[15,"/search?find_desc=Restaurants&amp;find_loc=Singapore&amp;attrs=RestaurantsPriceRange2.1"],"internal_ip":[18,false],"referrer":[28,"none"]},"www":{"full_url":[34,"/search?find_desc=Restaurants&amp;find_loc=Singapore&amp;attrs=RestaurantsPriceRange2.1"],"internal_ip":[27,false],"referrer":[64,"none"]}},"domain":"yelp.com","enable_high_volume_events":false,"ga_enabled":true,"js_dimensions":{"global":{},"www":{}},"metrics":{"global":{},"www":{}},"trackers":{"www":"UA-30501-24","global":"UA-30501-1"},"user_id":null,"customParameters":{"guv":"06709B394A8EC0B9","known_bot":"other","remote_ip":"219.74.163.0","full_url":"/search?find_desc=Restaurants&amp;find_loc=Singapore&amp;attrs=RestaurantsPriceRange2.1","internal_ip":false,"referrer":"none"}},"guv":"06709B394A8EC0B9","legacyProps":{"searchAppProps":{"ajaxScrollablePhotosURI":"/biz_photos/scrollable_photos/yq_Lo6KZqhw53y_PP5KoJw%2CJIjKuhPdH3lSYbFP-4PV_Q%2CxmqDvIrLTi68PcBaCt_0eA%2CfY1IkBnRft1KR0O2tqu7pg%2CCdAmgWWCabZQoYNNWOKcEw%2CwyDfBs1tYSIiBO7HCPKNTg%2Cbkj4QMOWfQB2z0znv0PKPQ%2C0v9kA0A9yVdBvSho7QfjKg%2CwcYmWVGB0kVdjfp3kmovkA%2CXbd6RhIE2tbrKTCg-jqEcQ","autoEnabledAttributes":[],"cookieNames":{"MO_MAP":"mmp","RESERVATION_SEARCH_PARAMS":"rsp"},"locale":"en_US","loggingConfig":{"sitRepConfig":{"isSitRepEnabled":true,"enabledSitRepChannels":{"search_ux":true,"search_suggest_events":true,"ad_syndication_cookie_sync_errors":true,"ad_syndication":true,"message_the_business":true,"ytp_session_events":true,"vertical_search_waitlist":true,"vertical_search_platform":true,"traffic_quality":true,"vertical_search_reservation":true},"servletName":"www.search"},"sitRepParams":{"uniqueRequestID":"a5b7f2d283c95e80","zipkinTraceID":"79b3ac91a7741b70","cfRayID":null,"yuv_record":"LlJK8i3xaIzPUsxAD8oPYAOjsdU2IdG2yDo2z12d_YjwFS3KzuRYhMBAXjMT6CGfvviLM9ezCDmoIKDNAwYeZZHBEqngSBp6","serverStartTime":1714646715099,"datacenter":"us-west-2","site":"main","isLoggedIn":false,"action":"search","servlet":"www.search","clientIP":"219.74.163.228","is_internal_ip":false,"edgeStartTime":1714646714596941,"b3Sampled":"0","edgestageSubdomain":"_disabled","disableBeacon":false}},"loggingData":{"uniqueRequestId":"a5b7f2d283c95e80","gaConfig":{"clientID":"06709B394A8EC0B9","dimensions":{"www":{"account_level":[1,"anon"],"business_id":[141,""],"content_country":[15,"SG"],"decrypted_yuv_id":[3,"06709B394A8EC0B9"],"distil":[53,null],"distil_js_enabled":[138,null],"exact_name_match":[50,"False"],"full_url":[34,"/search?find_desc=Restaurants&amp;find_loc=Singapore&amp;attrs=RestaurantsPriceRange2.1"],"has_canonical":[36,"None"],"integration":[14,""],"internal_ip":[27,"False"],"is_biz_user":[129,"False"],"is_indexable":[42,"False"],"known_bot":[186,"other"],"page_depth":[41,"0"],"query_words_number":[52,"1"],"referrer":[64,"none"],"remote_ip":[4,"219.74.163.0"],"results_on_page":[51,"10"],"search_accuracy":[48,"4"],"search_city":[49,"Singapore"],"search_location_lat_lng":[109,"1.313816,103.849126"],"service":[107,"yelp-main"],"top_level_categories":[11,"restaurants,food"],"viewport_tracking":[29,null],"ad.web_carousel_bottom_of_biz":[78,"status_quo"],"www_education_banner":[190,"enabled"],"contributions.www.remove_review_draft_modules":[183,"status_quo"],"contributions.www.war_attach_photos":[99,"enabled"],"contributions.www.war_compose_recent_photos":[102,"enabled"],"contr ...
# <script crossorigin="anonymous" integrity="sha384-bm7MnzvK++ykSwVJ2tynSE5TRdN+xL418osEVF2DE/L/gfWHj91J2Sphe582B1Bh" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/64141792105e/assets/vendor/react-dom/18.2.0/umd/react-dom.production.min.js"></script>
# <!-- css-middleware: body tag placeholder --><script>(function() { var e=window.yelp.critical_css;function t(e){setTimeout(e,0)}function n(n){for(var o in e.css_map)if(!e.css_map[o].loaded)return;t(n)}function o(t,o){var a=e.css_map[t],i=a.linkTag,r=document.querySelector('style[data-critical-css="'+t+'"]');if(r&&i&&!a.loaded){var c=function(e,t){var n=e.cloneNode();n.rel="stylesheet",n.media="all",n.href=e.href;var o=function(){this.onload=null,this.setAttribute("onload",null),t.parentNode.removeChild(t)};return n.setAttribute("onload",o),n.onload=o,n}(i,r);r.insertAdjacentElement("afterend",c),i.parentNode.removeChild(i),e.css_map[t].loaded=!0,n(o)}else n(o)}function a(n,a){if(!e.css_map||0===Object.keys(e.css_map).length)return void t(n);(a?[a]:Object.keys(e.css_map)).forEach((function(t){e.lowPriorityMode?o(t,n):setTimeout(o,0,t,n)}))}e.criticalCSSReady=function(t){const n=(o=t,function(){return o&&(r=o.apply(i||this,arguments),o=null),r});var o,i,r;a(n);var c=e.recordDone.bind(window);e.recordDone=function(e,t){c.call(this,e,t),a(n,t.dataset.criticalCss)}}; })()</script>
# <script data-id="react-root-props">
#                 window.yelp = window.yelp || {};
#                 window.yelp.react_root_props = {"locale": "en_US", "messages": {}, "requestCookies": {"LOCATION": null, "MO_MAP": null}, "requestHeaders": {"user-agent": "python-requests/2.31.0"}, "requestPath": "/search", "requestUrl": "https://www.yelp.com/search?find_desc=Restaurants&find_loc=Singapore&attrs=RestaurantsPriceRange2.1", "requestTimestampMs": 1714646715825, "routeParams": {}, "userId": null, "bizUserId": null, "uniqueRequestId": "5bc7534efa9e1648", "site": "www", "gaConfig": {"clientID": "06709B394A8EC0B9", "dimensions": {"global": {"full_url": [15, "/search?find_desc=Restaurants&find_loc=Singapore&attrs=RestaurantsPriceRange2.1"], "internal_ip": [18, false], "referrer": [28, "none"]}, "www": {"full_url": [34, "/search?find_desc=Restaurants&find_loc=Singapore&attrs=RestaurantsPriceRange2.1"], "internal_ip": [27, false], "referrer": [64, "none"]}}, "domain": "yelp.com", "enable_high_volume_events": false, "ga_enabled": true, "js_dimensions": {"global": {}, "www": {}}, "metrics": {"global": {}, "www": {}}, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "user_id": null, "customParameters": {"guv": "06709B394A8EC0B9", "known_bot": "other", "remote_ip": "219.74.163.0", "full_url": "/search?find_desc=Restaurants&find_loc=Singapore&attrs=RestaurantsPriceRange2.1", "internal_ip": false, "referrer": "none"}}, "guv": "06709B394A8EC0B9", "legacyProps": {"searchAppProps": {"ajaxScrollablePhotosURI": "/biz_photos/scrollable_photos/yq_Lo6KZqhw53y_PP5KoJw%2CJIjKuhPdH3lSYbFP-4PV_Q%2CxmqDvIrLTi68PcBaCt_0eA%2CfY1IkBnRft1KR0O2tqu7pg%2CCdAmgWWCabZQoYNNWOKcEw%2CwyDfBs1tYSIiBO7HCPKNTg%2Cbkj4QMOWfQB2z0znv0PKPQ%2C0v9kA0A9yVdBvSho7QfjKg%2CwcYmWVGB0kVdjfp3kmovkA%2CXbd6RhIE2tbrKTCg-jqEcQ", "autoEnabledAttributes": [], "cookieNames": {"MO_MAP": "mmp", "RESERVATION_SEARCH_PARAMS": "rsp"}, "locale": "en_US", "loggingConfig": {"sitRepConfig": {"isSitRepEnabled": true, "enabledSitRepChannels": {"search_ux": true, "search_suggest_events": true, "ad_syndication_cookie_sync_errors": true, "ad_syndication": true, "message_the_business": true, "ytp_session_events": true, "vertical_search_waitlist": true, "vertical_search_platform": true, "traffic_quality": true, "vertical_search_reservation": true}, "servletName": "www.search"}, "sitRepParams": {"uniqueRequestID": "a5b7f2d283c95e80", "zipkinTraceID": "79b3ac91a7741b70", "cfRayID": null, "yuv_record": "LlJK8i3xaIzPUsxAD8oPYAOjsdU2IdG2yDo2z12d_YjwFS3KzuRYhMBAXjMT6CGfvviLM9ezCDmoIKDNAwYeZZHBEqngSBp6", "serverStartTime": 1714646715099, "datacenter": "us-west-2", "site": "main", "isLoggedIn": false, "action": "search", "servlet": "www.search", "clientIP": "219.74.163.228", "is_internal_ip": false, "edgeStartTime": 1714646714596941, "b3Sampled": "0", "edgestageSubdomain": "_disabled", "disableBeacon": false}}, "loggingData": {"uniqueRequestId": "a5b7f2d283c95e80", "gaConfig": {"clientID": "06709B394A8EC0B9", "dimensions": {"www": {"account_level": [1, "anon"], "business_id": [141, ""], "content_country": [15, "SG"], "decrypted_yuv_id": [3, "06709B394A8EC0B9"], "distil": [53, null], "distil_js_enabled": [138, null], "exact_name_match": [50, "False"], "full_url": [34, "/search?find_desc=Restaurants&find_loc=Singapore&attrs=RestaurantsPriceRange2.1"], "has_canonical": [36, "None"], "integration": [14, ""], "internal_ip": [27, "False"], "is_biz_user": [129, "False"], "is_indexable": [42, "False"], "known_bot": [186, "other"], "page_depth": [41, "0"], "query_words_number": [52, "1"], "referrer": [64, "none"], "remote_ip": [4, "219.74.163.0"], "results_on_page": [51, "10"], "search_accuracy": [48, "4"], "search_city": [49, "Singapore"], "search_location_lat_lng": [109, "1.313816,103.849126"], "service": [107, "yelp-main"], "top_level_categories": [11, "restaurants,food"], "viewport_tracking": [29, null], "ad.web_carousel_bottom_of_biz": [78, "status_quo"], "www_education_banner": [190, "enabled"], "contributions.www.remove_review_draft_modules": [183, "status_quo"], "contributions.www.war_attach ...
#             </script>
# <script>
#             window.yelp = window.yelp || {};
#             window.yelp.zipkin_id = '79b3ac91a7741b70';
#             window.yelp.unique_request_id = '5bc7534efa9e1648';
#             window.yelp.guv = '06709B394A8EC0B9';
#             window.yelp.yuv_record = 'LlJK8i3xaIzPUsxAD8oPYAOjsdU2IdG2yDo2z12d_YjwFS3KzuRYhMBAXjMT6CGfvviLM9ezCDmoIKDNAwYeZZHBEqngSBp6';
#         </script>
# <script crossorigin="anonymous" integrity="sha384-VWXV8VA+0xZuNh5mksoTGTWM4qM9gdLvcv/y/f3Ps2ZjKN37taVfpJHexdLG2bJI" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/4dc644e84e0b/assets/vendor/regenerator-runtime/0.13.9/regenerator-runtime.min.js"></script>
# <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "3c6d5448bf96e6b7f35ecbc0f4390b1c4fbfce92", "metaData": {"projectName": "gondola-search", "activeVersion": "6.1.1", "deploymentPreviewId": null, "zipkinTraceID": "79b3ac91a7741b70"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1}, "client": "bugsnag", "apiKey": "7a505cfcfc5a2e124a4f37054c4d684d", "enabled": true}</script>
# <script data-source="loadable-ssr" id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[1701,3438,6578,7834,7979,9713,2527]</script><script data-source="loadable-ssr" id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["PaginationSeparator","SearchFeedback","RelatedLinksSeparator","RelatedArticlesForBizOwnersSeparator","TalkTopics","RelatedCostGuidesSeparator","FrequentlyAskedQuestionsSeparator"]}</script>
# <script async="" data-chunk="PaginationSeparator" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/PaginationSeparator.yji-e0e415a4b6a63d9d7040.chunk.js"></script>
# <script async="" data-chunk="SearchFeedback" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/SearchFeedback.yji-2b550e2805ba1cf74983.chunk.js"></script>
# <script async="" data-chunk="RelatedLinksSeparator" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedLinksSeparator.yji-3be87aa41fac520fde39.chunk.js"></script>
# <script async="" data-chunk="RelatedArticlesForBizOwnersSeparator" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedArticlesForBizOwnersSeparator.yji-1537574134e36c30def4.chunk.js"></script>
# <script async="" data-chunk="TalkTopics" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/TalkTopics.yji-1195fb77d5221d05826a.chunk.js"></script>
# <script async="" data-chunk="RelatedCostGuidesSeparator" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/RelatedCostGuidesSeparator.yji-4a9ffa87c525d858b40a.chunk.js"></script>
# <script async="" data-chunk="FrequentlyAskedQuestionsSeparator" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/FrequentlyAskedQuestionsSeparator.yji-a3f226fafe50ace5b1f2.chunk.js"></script>
# <script>window.ySitRepParams = {"guv": "06709B394A8EC0B9", "datacenter": "us-west-2", "unique_request_id": "5bc7534efa9e1648"};</script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_runtime~gondola-search.yji-c43cb0bb47915262b750.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-container-16.0.0.yji-5a276d84abe00c30946e.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-style-utils-8.0.0.yji-6bc722f160d5253501bd.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-typography-23.0.0.yji-8b382b44561756875a54.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-button-20.0.0.yji-09221824122af0ee38da.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-photo-box-16.0.0.yji-9bfefdc0e4d6ca578d96.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-error-boundary-11.0.0.yji-76f4ba4769c56569f16b.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-moment-2.29.4.yji-a4eaa955a9474903661e.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-table-9.0.0.yji-cb3b045271bc5c4d25f7.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-immutable-4.1.0.yji-3a3cb56551b9c394301e.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-search-suggest-19.0.2.yji-d57f49126cc2ad40851e.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-search-116.2.0.yji-de9a9550c09c26f23663.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_commons.yji-6429d0b5bd74946e845a.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-bb96b8c441134e5bad54a41bcc4cf53ecd46f85f.yji-59637a55f1d2da3505d8.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-41932b59a5113321ef490c6554909ebf575396c0.yji-be9122df80d57bab2f1f.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-2f3b340adbca5f689c99b331cc72be47d74e82c9.yji-85c989820739dcae4b5f.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-4689c677c5f14a106e99027fab16a96868a5d68a.yji-9085b3be6b2dbeef1dc8.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-f6a858a80dac1eb586c3ac98fa2fdfce119719c1.yji-019b053e99f0fc05b5f9.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-5fd6084213cf85f91f446b9879068910baa3b66d.yji-f505288de8bdbc913c3a.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-9f4e419a8165d37b575d291cae20538290d6a6ad.yji-8cdf9ab02b05cbd13775.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-64edb8e4f2aa33a287a8ddaad7e2d0e2ecc485d2.yji-8c230a80471073eeaefc.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-58dfcd87bfd35d1d148628c6c299970be8b35d1f.yji-ebf21c00acd113af0b81.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-26ec4579e56829d0bcfa8366f3d45f85119ad63d.yji-d6db2740ef86e09e82fd.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-92fb3906f7aaf64777e7e3dbdd747020dca400d0.yji-1a645a2dc9dfedb6ac6a.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-125c4f32921818cc0e3d87ab5ccc9564d08dae76.yji-d5ad9055f1f46b8b65ba.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-c40052201565d4c1d9ec07e0b10ab10fafd9c645.yji-d02b20af98869541d46b.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-4e0badef86d478c3ac2c14adbc96bdd19309d600.yji-3abcf2d2d5e460a1601f.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-fec2b06b5d01c5c00f6ab36d95c780288e20b460.yji-e81455c0cd3591213691.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-e3e8debddff013820a7d049c8f11256ddcfd4105.yji-da72908064baac654069.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-01b67ded7ddaeeaa4ae9f9da1104b1f46383a9ed.yji-7f98ffeb845e514abfa4.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-045d43f5b4840e503a543ca8f9ee2b1cb7c40ef5.yji-8942a226006a7d9fa434.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-4361909b2e39af39a06c58eff6d563d9f90f6319.yji-6c49b2c79022893cf5a3.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-00b75ab3633dd43befad47bf8e5126232c0bdbe6.yji-52dddd4303f547abab32.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-926615e6541afd1d8eff45d06af8507322ffe6e9.yji-2d7d7c4a5f7b615d1eef.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-1cb5b4eac750c56dc19a9c1a7691b0ce70c91501.yji-942686644e1a273f9085.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-767048acc6d08f474a70491425ec56b8f957ab22.yji-ac9b40b7054fb74918f3.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-8f83899776d9107fd4ee459322e80300667dfdd9.yji-3423c32f8166b3d80412.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-d872e548a5cf62b3fb4d1f1c87bc4be1aa35b81e.yji-e4f2dbcb49ae3f0c23e9.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-cef95d9e463460230b6a848467a1335f1f35252c.yji-b10644cc64b85f4fa20c.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-877984386d8046576478ebcb3512c5ae4158725c.yji-2edbb4926bb599a40a41.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-8bd84634b1b5662e81a5ef0d01981347884f6d1b.yji-33f08051e5f928d069fe.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-fea407f6004692f83e778abe71fc46fe9c051d73.yji-b72e7c313f0feb24a141.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-db3ee1cbfa16752aa70a6f09af06a3589ce8b306.yji-0ad52d8eba6756315710.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-b5fa5df1a7d205bd30d699a82046cccf1c0f0f7c.yji-435103c1385fe19252e4.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-cb5681b4a740c02a4851844dbc36252eca2b1a00.yji-0578f5def8ecc6b6f028.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-4504cd2a281d668a1d0bc3205777822dc30bafbd.yji-5870b073ae18e07474a7.js"></script>
# <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_gondola-search.yji-e49c8d63621137b53244.js"></script>
# <script>window.yelp = window.yelp || {};window.yelp.slow_document_ids = "69b4d1c0e6a1acfcb679b2e8178b3588bc1e4a5c026dc10d9a32987ef16efb4c,e37cb4c7a09e4c9a3d103af15870f58c10b0833fae1235389a8d9063b038181d,f590747b54bba411c8849107b6075ea71c1e54117ca8cd4558680e174fdc76a0,d57a80aac37fad54892774219fb771304e28e1e0b5acb3cbe8031434cb78e49e,e9ead0cffff389b5fde9bd1f55c5347e74fe9c62bea664e1bd5da3bc99f4c0e3,d91e21dcf15f4f8c1c898e0a15ada55618593464182cb3348112362e86ceb2ac,2b12698e77b16a8606a41dc07ea79d4cd7ae752d07eaea093164e1dbee521aa9,efb6827ff1b0b27ee159022a4f1f5073292f7c5a1e3a5cd47db9139ccf803830,9baa395e3df6e38d87cac6fd3e42a3aab1e1059bc268ee91c8691c754bd0f01f,2be416eb597dd2b9216f1f5cb6802050d58ac377412996a4ef7ee845a8a70a94,c8a5be338870c33eb2167c6787e38db0067dc0ba91fbe0c2064fe4c6a79b4ebe,bbb65ac4d8060cbb3338fca550cbc1ea2170c9afdfca94c538e9822f31df46e7,50bdd1c638220f1918c9b34924277aba8389e5ccf11d78d2d6d0f42774042a23,52b97a0175bb6f2299bc05f29ea900e9f890b21a2eff6a3b9bf391ff5ceb6fda,aab42a59984bc8cd86becc3c2d8d64fa473b613411e0b1cc2f35a0934168e6c0,95227e3e50b6b153a6a77fc57944e9ecb797201f74390cc72a58816f0cd7b9ec";</script><script type="text/javascript">window.yelp.initReactComponents();</script></body></html>

# %% [markdown]
# Testing of code to scrape restaurant name

# %%
restaurant = soup.find('div', class_="businessName__09f24__HG_pC yelp-emotion-ohs7lg")

# %%
restaurant.text
# Out:
# '1.\xa0Sin Heng Kee Porridge'

# %% [markdown]
# ## Scraping of first result in page (testing)

# %% [markdown]
# Scraping of restaurant name, rating, cuisine, price range and location

# %%
listing = soup.find('div', class_ = 'container__09f24__FeTO6 hoverable__09f24___UXLO yelp-emotion-way87j')
for item in listing:
    name = item.find('div', class_ = "businessName__09f24__HG_pC yelp-emotion-ohs7lg").text
    rating = item.find('span', class_ = "yelp-emotion-x4y0dd").text
    cuisine = item.find('button', class_ = 'yelp-emotion-10d2rmz').text
    pricerange = item.find('div', class_= 'yelp-emotion-17hd2hl')
    price = pricerange.find('span', class_= 'priceRange__09f24__ZgJXy yelp-emotion-oyrex3').text
    location = pricerange.find('span', class_= 'yelp-emotion-v293gj').text


print(f'name: {name}\nrating:{rating}\ncuisine: {cuisine}\nprice: {price}\nlocation: {location}')
# Out:
# name: 1. Sin Heng Kee Porridge
# rating:4.8
# cuisine: Singaporean
# price: $
# location: Hougang

# %% [markdown]
# Scraping all restaurants in a Single Page and storing in dictionary for conversion to dataframe later on

# %%
listings = soup.find_all('div', class_='container__09f24__FeTO6 hoverable__09f24___UXLO yelp-emotion-way87j')


#instantiate a new restaurants list
restaurants_list = []

# Set counter for iterating thru multiple pages in the website
count = 1

    
for item in listings:
    #instantiate a new restaurants dictionary 
    restaurants_dict = {}
    name = item.find('div', class_="businessName__09f24__HG_pC yelp-emotion-ohs7lg").text
    rating = item.find('span', class_="yelp-emotion-x4y0dd").text
    cuisine_tags = item.find_all('button', class_='yelp-emotion-10d2rmz')
    cuisine = [tag.text for tag in cuisine_tags]
    cuisines = ', '.join(cuisine)
    pricerange = item.find('div', class_='yelp-emotion-17hd2hl')
    
    if pricerange:
        price = pricerange.find('span', class_='priceRange__09f24__ZgJXy yelp-emotion-oyrex3').text
        location = pricerange.find('span', class_='yelp-emotion-v293gj').text
    else:
        price = "Not available"
        location = "Not available"

    print(f'name: {name}\nrating: {rating}\ncuisine: {cuisines}\nprice: {price}\nlocation: {location}')
    print('---')

    restaurants_dict['restaurant number'] = count 
    restaurants_dict['name'] = name
    restaurants_dict['rating'] = rating 
    restaurants_dict['cuisine'] = cuisines
    restaurants_dict['price'] = price 
    restaurants_dict['location'] = location

    #append restaurant to restaurants list 
    restaurants_list.append(restaurants_dict)
    
    
    print(restaurants_dict)
    print('------------------------------')
    count += 1
# Out:
# name: 1. Sin Heng Kee Porridge
# rating: 4.8
# cuisine: Singaporean, Congee
# price: $
# location: Hougang
# ---
# {'restaurant number': 1, 'name': '1.\xa0Sin Heng Kee Porridge', 'rating': '4.8 ', 'cuisine': 'Singaporean, Congee', 'price': '$', 'location': 'Hougang'}
# ------------------------------
# name: 2. French Ladle
# rating: 4.8
# cuisine: French
# price: $
# location: Ulu Pandan
# ---
# {'restaurant number': 2, 'name': '2.\xa0French Ladle', 'rating': '4.8 ', 'cuisine': 'French', 'price': '$', 'location': 'Ulu Pandan'}
# ------------------------------
# name: 3. Hong Kong Style Chee Cheong Fun
# rating: 4.6
# cuisine: Chinese
# price: $
# location: Farrer Park
# ---
# {'restaurant number': 3, 'name': '3.\xa0Hong Kong Style Chee Cheong Fun', 'rating': '4.6 ', 'cuisine': 'Chinese', 'price': '$', 'location': 'Farrer Park'}
# ------------------------------
# name: 4. Tian Tian Hainanese Chicken Rice
# rating: 3.9
# cuisine: Hainan, Chicken Shop
# price: $
# location: Tanjong Pagar
# ---
# {'restaurant number': 4, 'name': '4.\xa0Tian Tian Hainanese Chicken Rice', 'rating': '3.9 ', 'cuisine': 'Hainan, Chicken Shop', 'price': '$', 'location': 'Tanjong Pagar'}
# ------------------------------
# name: 5. Song Fa Bak Kut Teh
# rating: 4.2
# cuisine: Singaporean, Chinese
# price: $
# location: Clarke Quay
# ---
# {'restaurant number': 5, 'name': '5.\xa0Song Fa Bak Kut Teh', 'rating': '4.2 ', 'cuisine': 'Singaporean, Chinese', 'price': '$', 'location': 'Clarke Quay'}
# ------------------------------
# name: 6. Two Men Bagel House
# rating: 4.5
# cuisine: Bagels, Breakfast & Brunch, Sandwiches
# price: $
# location: Tanjong Pagar
# ---
# {'restaurant number': 6, 'name': '6.\xa0Two Men Bagel House', 'rating': '4.5 ', 'cuisine': 'Bagels, Breakfast & Brunch, Sandwiches', 'price': '$', 'location': 'Tanjong Pagar'}
# ------------------------------
# name: 7. Song Fa Bak Kut Teh
# rating: 4.6
# cuisine: Chinese, Singaporean
# price: $
# location: Chinatown
# ---
# {'restaurant number': 7, 'name': '7.\xa0Song Fa Bak Kut Teh', 'rating': '4.6 ', 'cuisine': 'Chinese, Singaporean', 'price': '$', 'location': 'Chinatown'}
# ------------------------------
# name: 8. Tim Ho Wan
# rating: 4.3
# cuisine: Dim Sum, Cantonese
# price: $
# location: City Hall
# ---
# {'restaurant number': 8, 'name': '8.\xa0Tim Ho Wan', 'rating': '4.3 ', 'cuisine': 'Dim Sum, Cantonese', 'price': '$', 'location': 'City Hall'}
# ------------------------------
# name: 9. Zhong Guo La Mian Xiao Long Bao
# rating: 4.4
# cuisine: Shanghainese, Dim Sum, Noodles
# price: $
# location: Chinatown
# ---
# {'restaurant number': 9, 'name': '9.\xa0Zhong Guo La Mian Xiao Long Bao', 'rating': '4.4 ', 'cuisine': 'Shanghainese, Dim Sum, Noodles', 'price': '$', 'location': 'Chinatown'}
# ------------------------------
# name: 10. Wee Nam Kee Chicken Rice
# rating: 4.3
# cuisine: Chicken Shop, Hainan
# price: $
# location: Novena
# ---
# {'restaurant number': 10, 'name': '10.\xa0Wee Nam Kee Chicken Rice', 'rating': '4.3 ', 'cuisine': 'Chicken Shop, Hainan', 'price': '$', 'location': 'Novena'}
# ------------------------------

# %% [markdown]
# Storing Restaurants List in a dataframe

# %%
df = pd.DataFrame(restaurants_list)
df
# Out:
#    restaurant number                                 name rating  \
# 0                  1             1. Sin Heng Kee Porridge   4.8
# 1                  2                      2. French Ladle   4.8
# 2                  3   3. Hong Kong Style Chee Cheong Fun   4.6
# 3                  4  4. Tian Tian Hainanese Chicken Rice   3.9
# 4                  5               5. Song Fa Bak Kut Teh   4.2
# 5                  6               6. Two Men Bagel House   4.5
# 6                  7               7. Song Fa Bak Kut Teh   4.6
# 7                  8                        8. Tim Ho Wan   4.3
# 8                  9   9. Zhong Guo La Mian Xiao Long Bao   4.4
# 9                 10         10. Wee Nam Kee Chicken Rice   4.3
#
#                                   cuisine price       location
# 0                     Singaporean, Congee     $        Hougang
# 1                                  French     $     Ulu Pandan
# 2                                 Chinese     $    Farrer Park
# 3                    Hainan, Chicken Shop     $  Tanjong Pagar
# 4                    Singaporean, Chinese     $    Clarke Quay
# 5  Bagels, Breakfast & Brunch, Sandwiches     $  Tanjong Pagar
# 6                    Chinese, Singaporean     $      Chinatown
# 7                      Dim Sum, Cantonese     $      City Hall
# 8          Shanghainese, Dim Sum, Noodles     $      Chinatown
# 9                    Chicken Shop, Hainan     $         Novena

# %% [markdown]
# ## Scraping of multiple pages

# %%
base_url = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Singapore&l=g%3A103.74664306640625%2C1.2111524670742526%2C103.95126342773438%2C1.417091829441639&attrs=RestaurantsPriceRange2.1%2CRestaurantsPriceRange2.2%2CRestaurantsPriceRange2.3' 

#instantiate a new restaurants list
restaurants_list = []

# Set counter for iterating thru multiple pages in the website
count = 1

total_pages = 24

for page_number in range(1, total_pages + 1):  # Scraping first 24 pages
    url = f'{base_url}&start={page_number * 10}'  # Assuming 10 results per page
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'lxml')
        listings1 = soup.find_all('div', class_='container__09f24__FeTO6 hoverable__09f24___UXLO yelp-emotion-way87j')

        for item in listings1:
            #instantiate a new restaurants dictionary 
            restaurants_dict = {}
            name = item.find('div', class_="businessName__09f24__HG_pC yelp-emotion-ohs7lg").text
            rating = item.find('span', class_="yelp-emotion-x4y0dd").text
            cuisine_tags = item.find_all('button', class_='yelp-emotion-10d2rmz')
            cuisine = [tag.text for tag in cuisine_tags]
            cuisines = ', '.join(cuisine)
            pricerange = item.find('div', class_='yelp-emotion-17hd2hl')
            
            if pricerange:
                price_element = pricerange.find('span', class_='priceRange__09f24__ZgJXy yelp-emotion-oyrex3')
                price = price_element.text if price_element else "Not available"
                location_element = pricerange.find('span', class_='yelp-emotion-v293gj')
                location = location_element.text if location_element else "Not available"

                #price = pricerange.find('span', class_='priceRange__09f24__ZgJXy yelp-emotion-oyrex3').text
                #location = pricerange.find('span', class_='yelp-emotion-v293gj').text
            else:
                price = "Not available"
                location = "Not available"

            print(f'name: {name}\nrating: {rating}\ncuisine: {cuisines}\nprice: {price}\nlocation: {location}')
            print('---')

            restaurants_dict['restaurant number'] = count 
            restaurants_dict['name'] = name
            restaurants_dict['rating'] = rating 
            restaurants_dict['cuisine'] = cuisines
            restaurants_dict['price'] = price 
            restaurants_dict['location'] = location

            #append restaurant to restaurants list 
            restaurants_list.append(restaurants_dict)
            count +=1

        print(f"Scraped page {page_number} of {total_pages} (Total restaurants: {len(restaurants_list)})")
        time.sleep(1)

    else:
        print(f"Failed to fetch page {page_number}. Status code: {response.status_code}")

print("Scraping complete")
# Out:
# name: 11. The Garden @ Sentosa
# rating: 5.0
# cuisine: Modern European
# price: $$$
# location: Sentosa
# ---
# name: 12. Tian Tian Seafood Restaurant
# rating: 4.7
# cuisine: Seafood, Chinese
# price: $$
# location: Tiong Bahru
# ---
# name: 13. Song Fa Bak Kut Teh
# rating: 4.6
# cuisine: Chinese, Singaporean
# price: $
# location: Chinatown
# ---
# name: 14. Zhong Guo La Mian Xiao Long Bao
# rating: 4.4
# cuisine: Shanghainese, Dim Sum, Noodles
# price: $
# location: Chinatown
# ---
# name: 15. La Strada
# rating: 4.4
# cuisine: Italian
# price: $$$
# location: Tanglin
# ---
# name: 16. Wee Nam Kee Chicken Rice
# rating: 4.3
# cuisine: Chicken Shop, Hainan
# price: $
# location: Novena
# ---
# name: 17. Two Men Bagel House
# rating: 4.5
# cuisine: Bagels, Breakfast & Brunch, Sandwiches
# price: $
# location: Tanjong Pagar
# ---
# name: 18. Going Om
# rating: 4.3
# cuisine: Bars, Cafes
# price: $$
# location: Arab Street
# ---
# name: 19. Lang Nuong Viet Nam
# rating: 4.4
# cuisine: Vietnamese, Barbeque
# price: $$
# location: Little India
# ---
# name: 20. Sakurazaka
# rating: 4.7
# cuisine: Japanese
# price: $$$
# location: Bukit Timah
# ---
# Scraped page 1 of 24 (Total restaurants: 10)
# name: 21. Man Man Japanese Unagi
# rating: 4.8
# cuisine: Japanese
# price: $$
# location: Chinatown
# ---
# name: 22. Hong Kong Street Family Restaurant
# rating: 4.3
# cuisine: Cantonese
# price: $
# location: Novena
# ---
# name: 23. Sungei Road Laksa
# rating: 4.4
# cuisine: Singaporean, Chinese, Noodles
# price: $
# location: Lavender
# ---
# name: 24. Founder Bak Kut Teh
# rating: 4.3
# cuisine: Singaporean
# price: $$
# location: Lavender
# ---
# name: 25. Yardbird Table & Bar
# rating: 4.3
# cuisine: American, Bars
# price: $$$
# location: Bayfront
# ---
# name: 26. Vatos Urban Tacos
# rating: 3.9
# cuisine: Mexican
# price: $$
# location: Bugis
# ---
# name: 27. NUDE Seafood
# rating: 4.3
# cuisine: Seafood
# price: $$
# location: Bayfront
# ---
# name: 28. Hokkaido Ramen Santouka
# rating: 4.3
# cuisine: Ramen
# price: $$
# location: Clarke Quay
# ---
# name: 29. The Sushi Bar
# rating: 4.4
# cuisine: Sushi Bars, Japanese
# price: $$
# location: Orchard
# ---
# name: 30. JB Ah Meng
# rating: 4.6
# cuisine: Chinese, Seafood
# price: $$
# location: Geylang
# ---
# Scraped page 2 of 24 (Total restaurants: 20)
# name: 31. Usman Restaurant
# rating: 4.0
# cuisine: Indian
# price: $
# location: Little India
# ---
# name: 32. Katong Keah Kee
# rating: 4.5
# cuisine: Seafood, Specialty Food, Street Vendors
# price: $
# location: Chinatown
# ---
# name: 33. Hambaobao
# rating: 4.6
# cuisine: Burgers
# price: $
# location: Little India
# ---
# name: 34. Komala Vilas Restaurant
# rating: 4.2
# cuisine: Indian, Vegetarian
# price: $
# location: Little India
# ---
# name: 35. Dragon Phoenix
# rating: 4.0
# cuisine: Cantonese
# price: $$
# location: Clarke Quay
# ---
# name: 36. Swee Choon Tim Sum
# rating: 4.0
# cuisine: Dim Sum
# price: $
# location: Little India
# ---
# name: 37. Newton Tian Xiang Big Prawn Noodle
# rating: 4.5
# cuisine: Noodles
# price: $
# location: Newton
# ---
# name: 38. Fat Bird
# rating: 4.0
# cuisine: Chinese
# price: $$
# location: Bugis
# ---
# name: 39. MTR 1924
# rating: 4.4
# cuisine: Indian
# price: $
# location: Little India
# ---
# name: 40. Trattoria Lafiandra
# rating: 4.2
# cuisine: Italian, Wine Bars
# price: $$
# location: Tanglin
# ---
# Scraped page 3 of 24 (Total restaurants: 30)
# name: 41. Taste Paradise
# rating: 4.5
# cuisine: Dim Sum, Cantonese
# price: $$
# location: Orchard
# ---
# name: 42. Tingkat PeraMakan
# rating: 4.3
# cuisine: Singaporean, Seafood, Noodles
# price: $$
# location: Farrer Park
# ---
# name: 43. Penang Seafood Restaurant
# rating: 3.9
# cuisine: Malaysian, Seafood
# price: $
# location: Geylang
# ---
# name: 44. Club55
# rating: 4.3
# cuisine: Buffets
# price: $$
# location: Bayfront
# ---
# name: 45. Wolf Burgers
# rating: 4.3
# cuisine: Burgers
# price: $$
# location: City Hall
# ---
# name: 46. Herbivore
# rating: 4.3
# cuisine: Vegetarian, Japanese
# price: $$
# location: Bencoolen
# ---
# name: 47. Jumbo Seafood
# rating: 3.8
# cuisine: Seafood, Singaporean
# price: $$
# location: Raffles Place
# ---
# name: 48. Khansama Tandoori
# rating: 4.2
# cuisine: Indian
# price: $$
# location: Little India
# ---
# name: 49. Empress
# rating: 4.4
# cuisine: Chinese, Asian Fusion, Singaporean
# price: $$
# location: City Hall
# ---
# name: 50. House of Peranakan Petit
# rating: 4.4
# cuisine: Malaysian
# price: $$
# location: Tiong Bahru
# ---
# Scraped page 4 of 24 (Total restaurants: 40)
# name: 51. Fragrant Garden
# rating: 4.8
# cuisine: Teochew
# price: Not available
# location:
# ---
# name: 52. Satay By The Bay
# rating: 3.8
# cuisine: Seafood, Barbeque
# price: $
# location: Bayfront
# ---
# name: 53. Tai Hwa Pork Noodle
# rating: 4.1
# cuisine: Chinese, Noodles
# price: $
# location: Lavender
# ---
# name: 54. Shabestan
# rating: 4.4
# cuisine: Persian/Iranian
# price: $$$
# location: Robertson Quay
# ---
# name: 55. Liao Fan Hawker Chan
# rating: 3.9
# cuisine: Noodles, Chicken Shop
# price: $
# location: Chinatown
# ---
# name: 56. The Quarters
# rating: 5.0
# cuisine: Cafes, Asian Fusion, Desserts
# price: $$
# location: Tanjong Pagar
# ---
# name: 57. Five Star Hainanese Chicken Rice
# rating: 4.3
# cuisine: Chicken Shop, Hainan
# price: $$
# location: Katong
# ---
# name: 58. Ya Hua Bak Kut Teh
# rating: 4.3
# cuisine: Chinese
# price: $$
# location: Tiong Bahru
# ---
# name: 59. Sawasdee
# rating: 4.1
# cuisine: Thai
# price: $$
# location: Chinatown
# ---
# name: 60. Jai’s Thai-Vientiane Cuisine
# rating: 5.0
# cuisine: Thai
# price: $
# location: Ubi
# ---
# Scraped page 5 of 24 (Total restaurants: 50)
# name: 61. Song Fa Bak Kut Teh
# rating: 4.6
# cuisine: Soup, Chinese
# price: $
# location: Orchard
# ---
# name: 62. Beach Road Kitchen
# rating: 4.7
# cuisine: Breakfast & Brunch, Chinese, Buffets
# price: $$
# location: City Hall
# ---
# name: 63. iO Italian Osteria
# rating: 4.4
# cuisine: Italian
# price: $$$
# location: Bukit Batok
# ---
# name: 64. Il Fiore
# rating: 4.0
# cuisine: Italian
# price: $$
# location: Raffles Place
# ---
# name: 65. Blue Lotus Chinese Eating House
# rating: 4.2
# cuisine: Chinese
# price: $$$
# location: Sentosa
# ---
# name: 66. The Malayan Council
# rating: 4.9
# cuisine: Cafes
# price: $$
# location: Little India
# ---
# name: 67. Hainanese Delicacy Chicken Rice
# rating: 4.4
# cuisine: Chicken Shop, Hainan
# price: $
# location: Orchard
# ---
# name: 68. Da Lian Traditional Noodles
# rating: 3.9
# cuisine: Noodles, Teochew
# price: $
# location: Lavender
# ---
# name: 69. E-Sarn Thai Cuisine
# rating: 4.5
# cuisine: Thai
# price: $$
# location: Thomson
# ---
# name: 70. ShuKuu Izakaya
# rating: 4.2
# cuisine: Izakaya
# price: $$
# location: Tanjong Pagar
# ---
# Scraped page 6 of 24 (Total restaurants: 60)
# name: 71. Mrs Pho
# rating: 3.8
# cuisine: Vietnamese
# price: $
# location: Arab Street
# ---
# name: 72. Hung Kang Teochew Restaurant
# rating: 4.7
# cuisine: Teochew
# price: $$
# location: Clarke Quay
# ---
# name: 73. Jai Thai
# rating: 3.8
# cuisine: Thai
# price: $
# location: Bishan
# ---
# name: 74. Keng Eng Kee Seafood
# rating: 3.9
# cuisine: Seafood
# price: $$
# location: Alexandra
# ---
# name: 75. Chabuton
# rating: 4.8
# cuisine: Ramen
# price: $$
# location: City Hall
# ---
# name: 76. Brazil Churrasco
# rating: 4.4
# cuisine: Brazilian
# price: $$
# location: Sixth Avenue
# ---
# name: 77. Sushi Jin
# rating: 4.1
# cuisine: Japanese
# price: $$$
# location: Little India
# ---
# name: 78. The Naked Finn
# rating: 4.3
# cuisine: Seafood
# price: $$$
# location: Alexandra
# ---
# name: 79. Aromas Of India
# rating: 4.8
# cuisine: Indian
# price: $$
# location: Farrer Park
# ---
# name: 80. Once Upon A Thyme
# rating: 4.4
# cuisine: Street Vendors, Italian
# price: $
# location: Novena
# ---
# Scraped page 7 of 24 (Total restaurants: 70)
# name: 81. Long Ji Zi Char
# rating: 4.4
# cuisine: Seafood
# price: $$
# location: Tiong Bahru
# ---
# name: 82. Ippudo
# rating: 4.5
# cuisine: Ramen
# price: $
# location: Bayfront
# ---
# name: 83. Muddy Murphy’s
# rating: 4.0
# cuisine: Pubs, Irish
# price: $$
# location: Tanglin
# ---
# name: 84. The Reading Room
# rating: 4.0
# cuisine: Bars, Cafes
# price: $$
# location: Chinatown
# ---
# name: 85. Brunches Cafe
# rating: 4.4
# cuisine: Coffee & Tea, Bakeries, Breakfast & Brunch
# price: $$
# location: Farrer Park
# ---
# name: 86. The RiceTable
# rating: 4.3
# cuisine: Indonesian
# price: $$
# location: Tanglin
# ---
# name: 87. Zam Zam Restaurant
# rating: 4.0
# cuisine: Indian, Halal
# price: $
# location: Arab Street
# ---
# name: 88. Ban Leong Wah Hoe Seafood
# rating: 4.3
# cuisine: Seafood
# price: $$
# location: Thomson
# ---
# name: 89. Sidewalk Food Place
# rating: 4.0
# cuisine: Food Court
# price: $
# location: City Hall
# ---
# name: 90. My Little Spanish Place
# rating: 4.0
# cuisine: Tapas/Small Plates, Spanish
# price: $$$
# location: Boat Quay
# ---
# Scraped page 8 of 24 (Total restaurants: 80)
# name: 91. Dolce Vita
# rating: 4.3
# cuisine: Italian
# price: $$$
# location: City Hall
# ---
# name: 92. Pek Kio Market & Food Centre
# rating: 4.6
# cuisine: Coffee & Tea, Breakfast & Brunch
# price: $
# location: Farrer Park
# ---
# name: 93. Cibo Italiano
# rating: 4.2
# cuisine: Wine Bars, Italian, Imported Food
# price: $$
# location: River Valley
# ---
# name: 94. My Little Tapas Bar
# rating: 4.3
# cuisine: Tapas/Small Plates, Spanish
# price: $$$
# location: Ann Siang Hill
# ---
# name: 95. The Banana Leaf Apolo
# rating: 3.9
# cuisine: Indian, Asian Fusion
# price: $$
# location: Farrer Park
# ---
# name: 96. Wang Dae Bak Korean BBQ
# rating: 4.0
# cuisine: Korean, Barbeque
# price: $
# location: Tanjong Pagar
# ---
# name: 97. City Hot Pot Shabu Shabu
# rating: 4.7
# cuisine: Taiwanese, Hot Pot
# price: $$
# location: Raffles Place
# ---
# name: 98. Bar B Q Tonight
# rating: 4.1
# cuisine: Barbeque
# price: $$
# location: Little India
# ---
# name: 99. Tandoori Flame @ Boon Tat
# rating: 4.9
# cuisine: Indian
# price: $$
# location: Tanjong Pagar
# ---
# name: 100. Wing Seong Fatty’s
# rating: 3.7
# cuisine: Chinese, Asian Fusion, Bars
# price: $$
# location: Bencoolen
# ---
# Scraped page 9 of 24 (Total restaurants: 90)
# name: 101. Joo Bar
# rating: 4.1
# cuisine: Korean
# price: $$
# location: Bugis
# ---
# name: 102. San Laksa Steamboat
# rating: 4.1
# cuisine: Hot Pot, Singaporean
# price: $$$
# location: Little India
# ---
# name: 103. Superstar K
# rating: 4.5
# cuisine: Korean, Barbeque
# price: $$$
# location: Duxton Hill
# ---
# name: 104. A Noodle Story
# rating: 4.4
# cuisine: Food Stands, Ramen, Singaporean
# price: $
# location: Tanjong Pagar
# ---
# name: 105. Grazie
# rating: 4.5
# cuisine: Italian
# price: $
# location: Boon Keng
# ---
# name: 106. Public House
# rating: 4.5
# cuisine: Bars, Singaporean
# price: $
# location: Boat Quay
# ---
# name: 107. Old Chengdu Sichuan Cuisine
# rating: 4.1
# cuisine: Szechuan, Imported Food
# price: $$
# location: Chinatown
# ---
# name: 108. Kai Garden
# rating: 4.3
# cuisine: Cantonese, Dim Sum, Seafood
# price: $$
# location: City Hall
# ---
# name: 109. Geylang Lorong 9 Beef Kway Teow
# rating: 4.1
# cuisine: Chinese
# price: $
# location: Geylang
# ---
# name: 110. The Wall
# rating: 5.0
# cuisine: Japanese, Cocktail Bars, Whiskey Bars
# price: $$$
# location: Duxton Hill
# ---
# Scraped page 10 of 24 (Total restaurants: 100)
# name: 111. Café Iguana
# rating: 3.8
# cuisine: Lounges, Tapas/Small Plates, Mexican
# price: $$
# location: Clarke Quay
# ---
# name: 112. Treasures Yi Dian Xin
# rating: 4.7
# cuisine: Congee, Dim Sum, Noodles
# price: $
# location: Bras Brasah
# ---
# name: 113. Din Tai Fung
# rating: 4.2
# cuisine: Shanghainese, Taiwanese, Dumplings
# price: $$
# location: Bayfront
# ---
# name: 114. Astons Specialities
# rating: 4.4
# cuisine: American, Steakhouses
# price: $
# location: Little India
# ---
# name: 115. Red House
# rating: 3.9
# cuisine: Seafood
# price: $$$
# location: Robertson Quay
# ---
# name: 116. Two Men Bagel House
# rating: 4.8
# cuisine: Breakfast & Brunch, Bagels
# price: $
# location: Novena
# ---
# name: 117. Din Tai Fung
# rating: 4.4
# cuisine: Taiwanese, Shanghainese, Dumplings
# price: $$
# location: City Hall
# ---
# name: 118. Imperial Treasure Fine Chinese Cuisine
# rating: 4.1
# cuisine: Chinese
# price: $$
# location: Bayfront
# ---
# name: 119. Blu Kouzina
# rating: 4.5
# cuisine: Mediterranean, Greek
# price: $$$
# location: Dempsey Hill
# ---
# name: 120. Char Restaurant
# rating: 4.4
# cuisine: Cantonese
# price: $$
# location: Little India
# ---
# Scraped page 11 of 24 (Total restaurants: 110)
# name: 121. Thien Long Vietnamese Restaurant
# rating: 4.2
# cuisine: Vietnamese
# price: $
# location: Tanglin
# ---
# name: 122. Isle Eating House
# rating: 4.7
# cuisine: Coffee & Tea, Food Court, Asian Fusion
# price: $
# location: Mount Sophia
# ---
# name: 123. Bee Cheng Hiang - New Bridge Road
# rating: 4.4
# cuisine: Singaporean, Meat Shops, Barbeque
# price: $$
# location: Chinatown
# ---
# name: 124. Wee Nam Kee Hainanese Chicken Rice
# rating: 3.7
# cuisine: Chicken Shop, Hainan
# price: $$
# location: City Hall
# ---
# name: 125. Zhong Hua Steamboat
# rating: 5.0
# cuisine: Chinese
# price: $$
# location: Bugis
# ---
# name: 126. Food Republic
# rating: 4.0
# cuisine: Food Court
# price: $
# location: Bras Brasah
# ---
# name: 127. Indocafe The White House
# rating: 4.2
# cuisine: Indonesian
# price: $$
# location: Newton
# ---
# name: 128. Classic Lao Di Fang Vegetarian
# rating: 4.0
# cuisine: Vegetarian
# price: $
# location: Dhoby Ghaut
# ---
# name: 129. Happy Tummy
# rating: 4.8
# cuisine: Desserts, Salad, Cafes
# price: $
# location: Mount Sophia
# ---
# name: 130. Hamburg Steak Keisuke
# rating: 4.6
# cuisine: Teppanyaki, Steakhouses
# price: $$
# location: Tanjong Pagar
# ---
# Scraped page 12 of 24 (Total restaurants: 120)
# name: 131. Toast Box
# rating: 4.0
# cuisine: Cafes, Breakfast & Brunch
# price: $
# location: Bras Brasah
# ---
# name: 132. Shabu Shabu Tajimaya
# rating: 4.5
# cuisine: Japanese, Hot Pot
# price: $$$
# location: Orchard
# ---
# name: 133. Mellben Seafood
# rating: 4.1
# cuisine: Seafood
# price: $$$
# location: Ang Mo Kio
# ---
# name: 134. Old Airport Road Food Centre
# rating: 4.3
# cuisine: Hawker Centre, Food Court
# price: $
# location: Mountbatten
# ---
# name: 135. The Other Room
# rating: 4.6
# cuisine: Tapas/Small Plates, Cocktail Bars
# price: $$
# location: Orchard
# ---
# name: 136. Majestic Bay
# rating: 3.1
# cuisine: Seafood
# price: $$
# location: Bayfront
# ---
# name: 137. Grain Traders
# rating: 4.1
# cuisine: Cafes
# price: $$
# location: Raffles Place
# ---
# name: 138. Annalakshmi
# rating: 4.0
# cuisine: Indian, Vegetarian
# price: $
# location: Clarke Quay
# ---
# name: 139. Taste Of Morroco
# rating: 5.0
# cuisine: Moroccan
# price: $
# location: West Coast
# ---
# name: 140. Lao You Xuan Noodle Kitchen
# rating: 5.0
# cuisine: Singaporean, Noodles, Soup
# price: $
# location: River Valley
# ---
# Scraped page 13 of 24 (Total restaurants: 130)
# name: 141. Inle Myanmar
# rating: 4.2
# cuisine: Burmese
# price: $
# location: Bras Brasah
# ---
# name: 142. Hai San Chicken Rice
# rating: 5.0
# cuisine: Chinese
# price: $
# location: Tiong Bahru
# ---
# name: 143. Imperial Treasure Nan Bei Restaurant
# rating: 4.6
# cuisine: Chinese
# price: $$
# location: Orchard
# ---
# name: 144. Ji Ji Wanton Noodle Specialist
# rating: 4.5
# cuisine: Chinese
# price: $
# location: Chinatown
# ---
# name: 145. 旺角點心 Mongkok Dim Sum
# rating: 3.7
# cuisine: Dim Sum
# price: $
# location: Geylang
# ---
# name: 146. Cook & Brew
# rating: 3.9
# cuisine: Gastropubs, Lounges
# price: $$$
# location: Bayfront
# ---
# name: 147. Hopheads
# rating: 3.7
# cuisine: Bistros, Tapas/Small Plates
# price: $$
# location: Dhoby Ghaut
# ---
# name: 148. Su Korean BBQ
# rating: 4.5
# cuisine: Korean, Barbeque
# price: $
# location: Toa Payoh
# ---
# name: 149. Haramiya Japanese BBQ Restaurant
# rating: 4.0
# cuisine: Barbeque, Japanese
# price: $$
# location: Clarke Quay
# ---
# name: 150. Alati
# rating: 4.6
# cuisine: Greek
# price: $$$
# location: Tanjong Pagar
# ---
# Scraped page 14 of 24 (Total restaurants: 140)
# name: 151. Seletar Hill
# rating: 5.0
# cuisine: Szechuan
# price: $$
# location: Yio Chu Kang
# ---
# name: 152. Artichoke Cafe & Bar
# rating: 4.0
# cuisine: Bars, Middle Eastern
# price: $$
# location: Bencoolen
# ---
# name: 153. Hup Choon Eating House
# rating: 4.3
# cuisine: Seafood
# price: $
# location: Bukit Timah
# ---
# name: 154. Ramen Keisuke Tori King
# rating: 4.2
# cuisine: Ramen
# price: $$
# location: Tanjong Pagar
# ---
# name: 155. Yi Jia South Village Seafood Restaurant
# rating: 3.3
# cuisine: Seafood
# price: $$
# location: Macpherson
# ---
# name: 156. CreatureS
# rating: 4.1
# cuisine: Breakfast & Brunch, Asian Fusion, Singaporean
# price: $$
# location: Little India
# ---
# name: 157. Kazu Sumiyaki
# rating: 4.5
# cuisine: Japanese
# price: $$$
# location: Orchard
# ---
# name: 158. Red Eye Smokehouse
# rating: 4.3
# cuisine: Bars, American, Barbeque
# price: $$$
# location: Lavender
# ---
# name: 159. Bella Pizza
# rating: 3.8
# cuisine: Italian, Pizza
# price: $$
# location: Robertson Quay
# ---
# name: 160. Sushi Kou
# rating: 4.8
# cuisine: Japanese
# price: $$$
# location: Tanjong Pagar
# ---
# Scraped page 15 of 24 (Total restaurants: 150)
# name: 161. Humpback
# rating: 4.4
# cuisine: American, Seafood, Cocktail Bars
# price: $$$
# location: Chinatown
# ---
# name: 162. Ippudo
# rating: 4.1
# cuisine: Ramen
# price: $$
# location: Somerset
# ---
# name: 163. Bosses Restaurant
# rating: 3.9
# cuisine: Dim Sum, Cantonese
# price: $$
# location: Harbourfront
# ---
# name: 164. Boon Tong Kee
# rating: 4.5
# cuisine: Cantonese
# price: $$
# location: Boon Keng
# ---
# name: 165. Coffee Lounge
# rating: 4.3
# cuisine: Singaporean, Breakfast & Brunch
# price: $$$
# location: Newton
# ---
# name: 166. Old Habits
# rating: 5.0
# cuisine: Cafes
# price: $$
# location: Telok Blangah
# ---
# name: 167. Granny’s Pancake
# rating: 4.0
# cuisine: Breakfast & Brunch, Coffee & Tea
# price: $
# location: Chinatown
# ---
# name: 168. Ya Kun Kaya Toast
# rating: 5.0
# cuisine: Coffee & Tea, Sandwiches
# price: $$
# location: Little India
# ---
# name: 169. Botanico
# rating: 4.5
# cuisine: Modern European
# price: $$$
# location: Bukit Timah
# ---
# name: 170. Third & Sixth Bistrobar
# rating: 4.2
# cuisine: Bars, Burgers
# price: $$
# location: Bras Brasah
# ---
# Scraped page 16 of 24 (Total restaurants: 160)
# name: 171. Fatboy’s The Burger Bar
# rating: 3.9
# cuisine: Burgers
# price: $$
# location: Orchard
# ---
# name: 172. Nagae
# rating: 4.1
# cuisine: Japanese
# price: $$$
# location: River Valley
# ---
# name: 173. Greenwood Fish Market & Bistro
# rating: 3.2
# cuisine: Seafood, Seafood Markets
# price: $$
# location: Bukit Timah
# ---
# name: 174. Leong Kee Bak Kut Teh
# rating: 3.8
# cuisine: Chinese
# price: $
# location: Geylang
# ---
# name: 175. Coq & Balls
# rating: 4.2
# cuisine: Bars, Japanese, Asian Fusion
# price: $$$
# location: Tiong Bahru
# ---
# name: 176. Five Oars Coffee Roasters
# rating: 4.7
# cuisine: Coffee Roasteries, Breakfast & Brunch
# price: $$
# location: Duxton Hill
# ---
# name: 177. Kampong Glam Cafe
# rating: 3.8
# cuisine: Indonesian
# price: $
# location: Arab Street
# ---
# name: 178. Liao Fan Hawker Chan
# rating: 4.0
# cuisine: Noodles, Cantonese
# price: $
# location: Macpherson
# ---
# name: 179. The Marmalade Pantry
# rating: 4.0
# cuisine: Breakfast & Brunch, Cupcakes, Sandwiches
# price: $$
# location: Novena
# ---
# name: 180. Boomarang
# rating: 4.1
# cuisine: Breakfast & Brunch, Bars, Australian
# price: $$
# location: Boat Quay
# ---
# Scraped page 17 of 24 (Total restaurants: 170)
# name: 181. CÉ LA VI Restaurant
# rating: 3.2
# cuisine: Bars, Asian Fusion
# price: $$$
# location: Bayfront
# ---
# name: 182. Dashi Master Marusaya
# rating: 4.3
# cuisine: Japanese
# price: $$$
# location: Robertson Quay
# ---
# name: 183. Longqing Hotpot
# rating: 5.0
# cuisine: Chinese, Hot Pot
# price: $$$
# location: Clarke Quay
# ---
# name: 184. Mahota Commune
# rating: 4.5
# cuisine: Organic Stores, Italian, Venues & Event Spaces
# price: $$
# location: Lavender
# ---
# name: 185. Blue Ginger
# rating: 3.8
# cuisine: Chinese, Asian Fusion
# price: $$$
# location: Tanjong Pagar
# ---
# name: 186. Owls Brew
# rating: 4.2
# cuisine: Bars, Gastropubs
# price: $$
# location: Mount Sophia
# ---
# name: 187. Chopsuey Cafe
# rating: 4.0
# cuisine: Cafes
# price: $$$
# location: Robertson Quay
# ---
# name: 188. Killiney Kopitiam
# rating: 4.0
# cuisine: Breakfast & Brunch, Coffee & Tea
# price: $
# location: Somerset
# ---
# name: 189. Ng Ah Sio Bak Kut Teh
# rating: 4.1
# cuisine: Chinese
# price: $
# location: Farrer Park
# ---
# name: 190. Shang Palace
# rating: 4.4
# cuisine: Cantonese, Dim Sum
# price: $$$
# location: Tanglin
# ---
# Scraped page 18 of 24 (Total restaurants: 180)
# name: 191. Jian Bo Shui Kueh
# rating: 4.6
# cuisine: Singaporean, Food Stands
# price: $
# location: Tiong Bahru
# ---
# name: 192. The Beast
# rating: 3.4
# cuisine: Bars, American, Burgers
# price: $$
# location: Lavender
# ---
# name: 193. Jiang-Nan Chun
# rating: 4.3
# cuisine: Chinese
# price: $$$
# location: Tanglin
# ---
# name: 194. Delicious Boneless Chicken Rice
# rating: 4.5
# cuisine: Chicken Shop, Hainan
# price: $
# location: Katong
# ---
# name: 195. Xin Heng Feng Guo Tiao Tan
# rating: 4.5
# cuisine: Chinese
# price: $
# location: Novena
# ---
# name: 196. Jumbo Seafood
# rating: 4.0
# cuisine: Seafood
# price: $$$
# location: Marine Parade
# ---
# name: 197. Da Paolo Gastronomia - Marina Bay Sands
# rating: 4.3
# cuisine: Italian, Desserts, Coffee & Tea
# price: $$
# location: Bayfront
# ---
# name: 198. Food Republic
# rating: 2.9
# cuisine: Food Court, Singaporean
# price: $
# location: Bencoolen
# ---
# name: 199. Salted & Hung
# rating: 4.3
# cuisine: Australian
# price: $$$
# location: Bugis
# ---
# name: 200. The Landing Point - Fullerton Bay Hotel
# rating: 3.5
# cuisine: Asian Fusion, Cocktail Bars
# price: $$
# location: Raffles Place
# ---
# Scraped page 19 of 24 (Total restaurants: 190)
# name: 201. Lian He Ben Ji Claypot Rice
# rating: 3.8
# cuisine: Chinese
# price: $$
# location: Chinatown
# ---
# name: 202. Chui Huay Lim Teochew Cusine
# rating: 3.9
# cuisine: Teochew
# price: Not available
# location:
# ---
# name: 203. Tonkotsu King Matsuri
# rating: 4.3
# cuisine: Ramen
# price: $$
# location: Marine Parade
# ---
# name: 204. Marché
# rating: 4.2
# cuisine: Restaurants
# price: $$
# location: Harbourfront
# ---
# name: 205. Riverside Indonesian BBQ
# rating: 4.8
# cuisine: Indonesian, Barbeque
# price: $
# location: Orchard
# ---
# name: 206. The Union Bar
# rating: 4.1
# cuisine: American, Sports Bars
# price: $$
# location: Tanglin
# ---
# name: 207. Founder Bak Kut Teh
# rating: 4.1
# cuisine: Chinese, Soup
# price: $
# location: Novena
# ---
# name: 208. Imperial Treasure Super Peking Duck
# rating: 3.8
# cuisine: Chinese
# price: $
# location: Orchard
# ---
# name: 209. Ash & Elm
# rating: 3.9
# cuisine: Modern European
# price: $$$
# location: Bugis
# ---
# name: 210. Culina
# rating: 3.8
# cuisine: Bistros, Specialty Food
# price: $$$
# location: Dempsey Hill
# ---
# Scraped page 20 of 24 (Total restaurants: 200)
# name: 211. Canto Kitchen
# rating: 4.5
# cuisine: Restaurants
# price: $$
# location: Chinatown
# ---
# name: 212. Ah Tai Hainanese Chicken Rice
# rating: 4.5
# cuisine: Chicken Shop, Hainan
# price: $
# location: Tanjong Pagar
# ---
# name: 213. Sanji Kagoshima Ramen
# rating: 4.9
# cuisine: Ramen
# price: $$
# location: Tanjong Pagar
# ---
# name: 214. Al Borgo Italian Restaurant
# rating: 4.0
# cuisine: Italian
# price: $$
# location: Bukit Timah
# ---
# name: 215. Kazbar
# rating: 4.6
# cuisine: Bars, Middle Eastern
# price: $$$
# location: Raffles Place
# ---
# name: 216. Shanghai Ren Jia
# rating: 4.3
# cuisine: Chinese
# price: $$
# location: Ang Mo Kio
# ---
# name: 217. Tabbouleh
# rating: 3.4
# cuisine: Mediterranean, Lebanese
# price: $$
# location: Arab Street
# ---
# name: 218. The Dempsey Cookhouse & Bar
# rating: 3.9
# cuisine: Asian Fusion
# price: $$$
# location: Dempsey Hill
# ---
# name: 219. Dolphins
# rating: 4.0
# cuisine: Restaurants
# price: $$
# location: Macpherson
# ---
# name: 220. Crystal Jade Kitchen
# rating: 4.2
# cuisine: Cantonese
# price: $
# location: Dhoby Ghaut
# ---
# Scraped page 21 of 24 (Total restaurants: 210)
# name: 221. Flutes
# rating: 4.1
# cuisine: Modern European
# price: $$$
# location: Dhoby Ghaut
# ---
# name: 222. Som Tam
# rating: 4.3
# cuisine: Thai, Asian Fusion
# price: $$
# location: Somerset
# ---
# name: 223. Paulaner Bräuhaus Singapore
# rating: 3.6
# cuisine: German, Beer Bar
# price: $$
# location: City Hall
# ---
# name: 224. Ma Maison
# rating: 4.5
# cuisine: Asian Fusion
# price: $$
# location: Alexandra
# ---
# name: 225. Amber Restaurant
# rating: 4.2
# cuisine: Indian
# price: $
# location: Little India
# ---
# name: 226. Flying Monkey
# rating: 4.1
# cuisine: Indian, Cocktail Bars
# price: $$$
# location: Arab Street
# ---
# name: 227. Super Siam Thai Restaurant
# rating: 4.0
# cuisine: Thai
# price: $
# location: Clarke Quay
# ---
# name: 228. Employees Only
# rating: 4.2
# cuisine: Bars, American
# price: $$$
# location: Raffles Place
# ---
# name: 229. Su Korean Cuisine
# rating: 5.0
# cuisine: Korean
# price: $
# location: Orchard
# ---
# name: 230. The Clueless Goat
# rating: 4.1
# cuisine: Coffee & Tea, Breakfast & Brunch
# price: $
# location: Novena
# ---
# Scraped page 22 of 24 (Total restaurants: 220)
# name: 231. Saveur
# rating: 4.0
# cuisine: French, Desserts
# price: $$
# location: Bugis
# ---
# name: 232. Tandoori Corner North Indian Curry House
# rating: 4.4
# cuisine: Indian
# price: $$
# location: Novena
# ---
# name: 233. Goldhill Family Restruant
# rating: 5.0
# cuisine: Singaporean
# price: $
# location: Hougang
# ---
# name: 234. Sanpoutei Ramen
# rating: 4.1
# cuisine: Ramen
# price: $$
# location: Holland Village
# ---
# name: 235. Syun
# rating: 4.4
# cuisine: Japanese
# price: $$$
# location: Sentosa
# ---
# name: 236. Old Hen Kitchen
# rating: 4.7
# cuisine: Cafes
# price: $$
# location: Farrer Park
# ---
# name: 237. Chin Chin Restaurant
# rating: 3.8
# cuisine: Chinese, Coffee & Tea
# price: $
# location: Bugis
# ---
# name: 238. Hong Chang Eating House
# rating: 5.0
# cuisine: Chinese
# price: $$
# location: Serangoon
# ---
# name: 239. Whampoa Keng
# rating: 4.0
# cuisine: Teochew
# price: $$
# location: Farrer Park
# ---
# name: 240. Westlake
# rating: 3.8
# cuisine: Chinese
# price: $$
# location: Bukit Timah
# ---
# Scraped page 23 of 24 (Total restaurants: 230)
# Scraped page 24 of 24 (Total restaurants: 230)
# Scraping complete

# %%
restaurants_list
# Out:
# [{'restaurant number': 1,
#   'name': '11.\xa0The Garden @ Sentosa',
#   'rating': '5.0 ',
#   'cuisine': 'Modern European',
#   'price': '$$$',
#   'location': 'Sentosa'},
#  {'restaurant number': 2,
#   'name': '12.\xa0Tian Tian Seafood Restaurant',
#   'rating': '4.7 ',
#   'cuisine': 'Seafood, Chinese',
#   'price': '$$',
#   'location': 'Tiong Bahru'},
#  {'restaurant number': 3,
#   'name': '13.\xa0Song Fa Bak Kut Teh',
#   'rating': '4.6 ',
#   'cuisine': 'Chinese, Singaporean',
#   'price': '$',
#   'location': 'Chinatown'},
#  {'restaurant number': 4,
#   'name': '14.\xa0Zhong Guo La Mian Xiao Long Bao',
#   'rating': '4.4 ',
#   'cuisine': 'Shanghainese, Dim Sum, Noodles',
#   'price': '$',
#   'location': 'Chinatown'},
#  {'restaurant number': 5,
#   'name': '15.\xa0La Strada',
#   'rating': '4.4 ',
#   'cuisine': 'Italian',
#   'price': '$$$',
#   'location': 'Tanglin'},
#  {'restaurant number': 6,
#   'name': '16.\xa0Wee Nam Kee Chicken Rice',
#   'rating': '4.3 ',
#   'cuisine': 'Chicken Shop, Hainan',
#   'price': '$',
#   'location': 'Novena'},
#  {'restaurant number': 7,
#   'name': '17.\xa0Two Men Bagel House',
#   'rating': '4.5 ',
#   'cuisine': 'Bagels, Breakfast & Brunch, Sandwiches',
#   'price': '$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 8,
#   'name': '18.\xa0Going Om',
#   'rating': '4.3 ',
#   'cuisine': 'Bars, Cafes',
#   'price': '$$',
#   'location': 'Arab Street'},
#  {'restaurant number': 9,
#   'name': '19.\xa0Lang Nuong Viet Nam',
#   'rating': '4.4 ',
#   'cuisine': 'Vietnamese, Barbeque',
#   'price': '$$',
#   'location': 'Little India'},
#  {'restaurant number': 10,
#   'name': '20.\xa0Sakurazaka',
#   'rating': '4.7 ',
#   'cuisine': 'Japanese',
#   'price': '$$$',
#   'location': 'Bukit Timah'},
#  {'restaurant number': 11,
#   'name': '21.\xa0Man Man Japanese Unagi',
#   'rating': '4.8 ',
#   'cuisine': 'Japanese',
#   'price': '$$',
#   'location': 'Chinatown'},
#  {'restaurant number': 12,
#   'name': '22.\xa0Hong Kong Street Family Restaurant',
#   'rating': '4.3 ',
#   'cuisine': 'Cantonese',
#   'price': '$',
#   'location': 'Novena'},
#  {'restaurant number': 13,
#   'name': '23.\xa0Sungei Road Laksa',
#   'rating': '4.4 ',
#   'cuisine': 'Singaporean, Chinese, Noodles',
#   'price': '$',
#   'location': 'Lavender'},
#  {'restaurant number': 14,
#   'name': '24.\xa0Founder Bak Kut Teh',
#   'rating': '4.3 ',
#   'cuisine': 'Singaporean',
#   'price': '$$',
#   'location': 'Lavender'},
#  {'restaurant number': 15,
#   'name': '25.\xa0Yardbird Table & Bar',
#   'rating': '4.3 ',
#   'cuisine': 'American, Bars',
#   'price': '$$$',
#   'location': 'Bayfront'},
#  {'restaurant number': 16,
#   'name': '26.\xa0Vatos Urban Tacos',
#   'rating': '3.9 ',
#   'cuisine': 'Mexican',
#   'price': '$$',
#   'location': 'Bugis'},
#  {'restaurant number': 17,
#   'name': '27.\xa0NUDE Seafood',
#   'rating': '4.3 ',
#   'cuisine': 'Seafood',
#   'price': '$$',
#   'location': 'Bayfront'},
#  {'restaurant number': 18,
#   'name': '28.\xa0Hokkaido Ramen Santouka',
#   'rating': '4.3 ',
#   'cuisine': 'Ramen',
#   'price': '$$',
#   'location': 'Clarke Quay'},
#  {'restaurant number': 19,
#   'name': '29.\xa0The Sushi Bar',
#   'rating': '4.4 ',
#   'cuisine': 'Sushi Bars, Japanese',
#   'price': '$$',
#   'location': 'Orchard'},
#  {'restaurant number': 20,
#   'name': '30.\xa0JB Ah Meng',
#   'rating': '4.6 ',
#   'cuisine': 'Chinese, Seafood',
#   'price': '$$',
#   'location': 'Geylang'},
#  {'restaurant number': 21,
#   'name': '31.\xa0Usman Restaurant',
#   'rating': '4.0 ',
#   'cuisine': 'Indian',
#   'price': '$',
#   'location': 'Little India'},
#  {'restaurant number': 22,
#   'name': '32.\xa0Katong Keah Kee',
#   'rating': '4.5 ',
#   'cuisine': 'Seafood, Specialty Food, Street Vendors',
#   'price': '$',
#   'location': 'Chinatown'},
#  {'restaurant number': 23,
#   'name': '33.\xa0Hambaobao',
#   'rating': '4.6 ',
#   'cuisine': 'Burgers',
#   'price': '$',
#   'location': 'Little India'},
#  {'restaurant number': 24,
#   'name': '34.\xa0Komala Vilas Restaurant',
#   'rating': '4.2 ',
#   'cuisine': 'Indian, Vegetarian',
#   'price': '$',
#   'location': 'Little India'},
#  {'restaurant number': 25,
#   'name': '35.\xa0Dragon Phoenix',
#   'rating': '4.0 ',
#   'cuisine': 'Cantonese',
#   'price': '$$',
#   'location': 'Clarke Quay'},
#  {'restaurant number': 26,
#   'name': '36.\xa0Swee Choon Tim Sum',
#   'rating': '4.0 ',
#   'cuisine': 'Dim Sum',
#   'price': '$',
#   'location': 'Little India'},
#  {'restaurant number': 27,
#   'name': '37.\xa0Newton Tian Xiang Big Prawn Noodle',
#   'rating': '4.5 ',
#   'cuisine': 'Noodles',
#   'price': '$',
#   'location': 'Newton'},
#  {'restaurant number': 28,
#   'name': '38.\xa0Fat Bird',
#   'rating': '4.0 ',
#   'cuisine': 'Chinese',
#   'price': '$$',
#   'location': 'Bugis'},
#  {'restaurant number': 29,
#   'name': '39.\xa0MTR 1924',
#   'rating': '4.4 ',
#   'cuisine': 'Indian',
#   'price': '$',
#   'location': 'Little India'},
#  {'restaurant number': 30,
#   'name': '40.\xa0Trattoria Lafiandra',
#   'rating': '4.2 ',
#   'cuisine': 'Italian, Wine Bars',
#   'price': '$$',
#   'location': 'Tanglin'},
#  {'restaurant number': 31,
#   'name': '41.\xa0Taste Paradise',
#   'rating': '4.5 ',
#   'cuisine': 'Dim Sum, Cantonese',
#   'price': '$$',
#   'location': 'Orchard'},
#  {'restaurant number': 32,
#   'name': '42.\xa0Tingkat PeraMakan',
#   'rating': '4.3 ',
#   'cuisine': 'Singaporean, Seafood, Noodles',
#   'price': '$$',
#   'location': 'Farrer Park'},
#  {'restaurant number': 33,
#   'name': '43.\xa0Penang Seafood Restaurant',
#   'rating': '3.9 ',
#   'cuisine': 'Malaysian, Seafood',
#   'price': '$',
#   'location': 'Geylang'},
#  {'restaurant number': 34,
#   'name': '44.\xa0Club55',
#   'rating': '4.3 ',
#   'cuisine': 'Buffets',
#   'price': '$$',
#   'location': 'Bayfront'},
#  {'restaurant number': 35,
#   'name': '45.\xa0Wolf Burgers',
#   'rating': '4.3 ',
#   'cuisine': 'Burgers',
#   'price': '$$',
#   'location': 'City Hall'},
#  {'restaurant number': 36,
#   'name': '46.\xa0Herbivore',
#   'rating': '4.3 ',
#   'cuisine': 'Vegetarian, Japanese',
#   'price': '$$',
#   'location': 'Bencoolen'},
#  {'restaurant number': 37,
#   'name': '47.\xa0Jumbo Seafood',
#   'rating': '3.8 ',
#   'cuisine': 'Seafood, Singaporean',
#   'price': '$$',
#   'location': 'Raffles Place'},
#  {'restaurant number': 38,
#   'name': '48.\xa0Khansama Tandoori',
#   'rating': '4.2 ',
#   'cuisine': 'Indian',
#   'price': '$$',
#   'location': 'Little India'},
#  {'restaurant number': 39,
#   'name': '49.\xa0Empress',
#   'rating': '4.4 ',
#   'cuisine': 'Chinese, Asian Fusion, Singaporean',
#   'price': '$$',
#   'location': 'City Hall'},
#  {'restaurant number': 40,
#   'name': '50.\xa0House of Peranakan Petit',
#   'rating': '4.4 ',
#   'cuisine': 'Malaysian',
#   'price': '$$',
#   'location': 'Tiong Bahru'},
#  {'restaurant number': 41,
#   'name': '51.\xa0Fragrant Garden',
#   'rating': '4.8 ',
#   'cuisine': 'Teochew',
#   'price': 'Not available',
#   'location': ''},
#  {'restaurant number': 42,
#   'name': '52.\xa0Satay By The Bay',
#   'rating': '3.8 ',
#   'cuisine': 'Seafood, Barbeque',
#   'price': '$',
#   'location': 'Bayfront'},
#  {'restaurant number': 43,
#   'name': '53.\xa0Tai Hwa Pork Noodle',
#   'rating': '4.1 ',
#   'cuisine': 'Chinese, Noodles',
#   'price': '$',
#   'location': 'Lavender'},
#  {'restaurant number': 44,
#   'name': '54.\xa0Shabestan',
#   'rating': '4.4 ',
#   'cuisine': 'Persian/Iranian',
#   'price': '$$$',
#   'location': 'Robertson Quay'},
#  {'restaurant number': 45,
#   'name': '55.\xa0Liao Fan Hawker Chan',
#   'rating': '3.9 ',
#   'cuisine': 'Noodles, Chicken Shop',
#   'price': '$',
#   'location': 'Chinatown'},
#  {'restaurant number': 46,
#   'name': '56.\xa0The Quarters',
#   'rating': '5.0 ',
#   'cuisine': 'Cafes, Asian Fusion, Desserts',
#   'price': '$$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 47,
#   'name': '57.\xa0Five Star Hainanese Chicken Rice',
#   'rating': '4.3 ',
#   'cuisine': 'Chicken Shop, Hainan',
#   'price': '$$',
#   'location': 'Katong'},
#  {'restaurant number': 48,
#   'name': '58.\xa0Ya Hua Bak Kut Teh',
#   'rating': '4.3 ',
#   'cuisine': 'Chinese',
#   'price': '$$',
#   'location': 'Tiong Bahru'},
#  {'restaurant number': 49,
#   'name': '59.\xa0Sawasdee',
#   'rating': '4.1 ',
#   'cuisine': 'Thai',
#   'price': '$$',
#   'location': 'Chinatown'},
#  {'restaurant number': 50,
#   'name': '60.\xa0Jai’s Thai-Vientiane Cuisine',
#   'rating': '5.0 ',
#   'cuisine': 'Thai',
#   'price': '$',
#   'location': 'Ubi'},
#  {'restaurant number': 51,
#   'name': '61.\xa0Song Fa Bak Kut Teh',
#   'rating': '4.6 ',
#   'cuisine': 'Soup, Chinese',
#   'price': '$',
#   'location': 'Orchard'},
#  {'restaurant number': 52,
#   'name': '62.\xa0Beach Road Kitchen',
#   'rating': '4.7 ',
#   'cuisine': 'Breakfast & Brunch, Chinese, Buffets',
#   'price': '$$',
#   'location': 'City Hall'},
#  {'restaurant number': 53,
#   'name': '63.\xa0iO Italian Osteria',
#   'rating': '4.4 ',
#   'cuisine': 'Italian',
#   'price': '$$$',
#   'location': 'Bukit Batok'},
#  {'restaurant number': 54,
#   'name': '64.\xa0Il Fiore',
#   'rating': '4.0 ',
#   'cuisine': 'Italian',
#   'price': '$$',
#   'location': 'Raffles Place'},
#  {'restaurant number': 55,
#   'name': '65.\xa0Blue Lotus Chinese Eating House',
#   'rating': '4.2 ',
#   'cuisine': 'Chinese',
#   'price': '$$$',
#   'location': 'Sentosa'},
#  {'restaurant number': 56,
#   'name': '66.\xa0The Malayan Council',
#   'rating': '4.9 ',
#   'cuisine': 'Cafes',
#   'price': '$$',
#   'location': 'Little India'},
#  {'restaurant number': 57,
#   'name': '67.\xa0Hainanese Delicacy Chicken Rice',
#   'rating': '4.4 ',
#   'cuisine': 'Chicken Shop, Hainan',
#   'price': '$',
#   'location': 'Orchard'},
#  {'restaurant number': 58,
#   'name': '68.\xa0Da Lian Traditional Noodles',
#   'rating': '3.9 ',
#   'cuisine': 'Noodles, Teochew',
#   'price': '$',
#   'location': 'Lavender'},
#  {'restaurant number': 59,
#   'name': '69.\xa0E-Sarn Thai Cuisine',
#   'rating': '4.5 ',
#   'cuisine': 'Thai',
#   'price': '$$',
#   'location': 'Thomson'},
#  {'restaurant number': 60,
#   'name': '70.\xa0ShuKuu Izakaya',
#   'rating': '4.2 ',
#   'cuisine': 'Izakaya',
#   'price': '$$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 61,
#   'name': '71.\xa0Mrs Pho',
#   'rating': '3.8 ',
#   'cuisine': 'Vietnamese',
#   'price': '$',
#   'location': 'Arab Street'},
#  {'restaurant number': 62,
#   'name': '72.\xa0Hung Kang Teochew Restaurant',
#   'rating': '4.7 ',
#   'cuisine': 'Teochew',
#   'price': '$$',
#   'location': 'Clarke Quay'},
#  {'restaurant number': 63,
#   'name': '73.\xa0Jai Thai',
#   'rating': '3.8 ',
#   'cuisine': 'Thai',
#   'price': '$',
#   'location': 'Bishan'},
#  {'restaurant number': 64,
#   'name': '74.\xa0Keng Eng Kee Seafood',
#   'rating': '3.9 ',
#   'cuisine': 'Seafood',
#   'price': '$$',
#   'location': 'Alexandra'},
#  {'restaurant number': 65,
#   'name': '75.\xa0Chabuton',
#   'rating': '4.8 ',
#   'cuisine': 'Ramen',
#   'price': '$$',
#   'location': 'City Hall'},
#  {'restaurant number': 66,
#   'name': '76.\xa0Brazil Churrasco',
#   'rating': '4.4 ',
#   'cuisine': 'Brazilian',
#   'price': '$$',
#   'location': 'Sixth Avenue'},
#  {'restaurant number': 67,
#   'name': '77.\xa0Sushi Jin',
#   'rating': '4.1 ',
#   'cuisine': 'Japanese',
#   'price': '$$$',
#   'location': 'Little India'},
#  {'restaurant number': 68,
#   'name': '78.\xa0The Naked Finn',
#   'rating': '4.3 ',
#   'cuisine': 'Seafood',
#   'price': '$$$',
#   'location': 'Alexandra'},
#  {'restaurant number': 69,
#   'name': '79.\xa0Aromas Of India',
#   'rating': '4.8 ',
#   'cuisine': 'Indian',
#   'price': '$$',
#   'location': 'Farrer Park'},
#  {'restaurant number': 70,
#   'name': '80.\xa0Once Upon A Thyme',
#   'rating': '4.4 ',
#   'cuisine': 'Street Vendors, Italian',
#   'price': '$',
#   'location': 'Novena'},
#  {'restaurant number': 71,
#   'name': '81.\xa0Long Ji Zi Char',
#   'rating': '4.4 ',
#   'cuisine': 'Seafood',
#   'price': '$$',
#   'location': 'Tiong Bahru'},
#  {'restaurant number': 72,
#   'name': '82.\xa0Ippudo',
#   'rating': '4.5 ',
#   'cuisine': 'Ramen',
#   'price': '$',
#   'location': 'Bayfront'},
#  {'restaurant number': 73,
#   'name': '83.\xa0Muddy Murphy’s',
#   'rating': '4.0 ',
#   'cuisine': 'Pubs, Irish',
#   'price': '$$',
#   'location': 'Tanglin'},
#  {'restaurant number': 74,
#   'name': '84.\xa0The Reading Room',
#   'rating': '4.0 ',
#   'cuisine': 'Bars, Cafes',
#   'price': '$$',
#   'location': 'Chinatown'},
#  {'restaurant number': 75,
#   'name': '85.\xa0Brunches Cafe',
#   'rating': '4.4 ',
#   'cuisine': 'Coffee & Tea, Bakeries, Breakfast & Brunch',
#   'price': '$$',
#   'location': 'Farrer Park'},
#  {'restaurant number': 76,
#   'name': '86.\xa0The RiceTable',
#   'rating': '4.3 ',
#   'cuisine': 'Indonesian',
#   'price': '$$',
#   'location': 'Tanglin'},
#  {'restaurant number': 77,
#   'name': '87.\xa0Zam Zam Restaurant',
#   'rating': '4.0 ',
#   'cuisine': 'Indian, Halal',
#   'price': '$',
#   'location': 'Arab Street'},
#  {'restaurant number': 78,
#   'name': '88.\xa0Ban Leong Wah Hoe Seafood',
#   'rating': '4.3 ',
#   'cuisine': 'Seafood',
#   'price': '$$',
#   'location': 'Thomson'},
#  {'restaurant number': 79,
#   'name': '89.\xa0Sidewalk Food Place',
#   'rating': '4.0 ',
#   'cuisine': 'Food Court',
#   'price': '$',
#   'location': 'City Hall'},
#  {'restaurant number': 80,
#   'name': '90.\xa0My Little Spanish Place',
#   'rating': '4.0 ',
#   'cuisine': 'Tapas/Small Plates, Spanish',
#   'price': '$$$',
#   'location': 'Boat Quay'},
#  {'restaurant number': 81,
#   'name': '91.\xa0Dolce Vita',
#   'rating': '4.3 ',
#   'cuisine': 'Italian',
#   'price': '$$$',
#   'location': 'City Hall'},
#  {'restaurant number': 82,
#   'name': '92.\xa0Pek Kio Market & Food Centre',
#   'rating': '4.6 ',
#   'cuisine': 'Coffee & Tea, Breakfast & Brunch',
#   'price': '$',
#   'location': 'Farrer Park'},
#  {'restaurant number': 83,
#   'name': '93.\xa0Cibo Italiano',
#   'rating': '4.2 ',
#   'cuisine': 'Wine Bars, Italian, Imported Food',
#   'price': '$$',
#   'location': 'River Valley'},
#  {'restaurant number': 84,
#   'name': '94.\xa0My Little Tapas Bar',
#   'rating': '4.3 ',
#   'cuisine': 'Tapas/Small Plates, Spanish',
#   'price': '$$$',
#   'location': 'Ann Siang Hill'},
#  {'restaurant number': 85,
#   'name': '95.\xa0The Banana Leaf Apolo',
#   'rating': '3.9 ',
#   'cuisine': 'Indian, Asian Fusion',
#   'price': '$$',
#   'location': 'Farrer Park'},
#  {'restaurant number': 86,
#   'name': '96.\xa0Wang Dae Bak Korean BBQ',
#   'rating': '4.0 ',
#   'cuisine': 'Korean, Barbeque',
#   'price': '$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 87,
#   'name': '97.\xa0City Hot Pot Shabu Shabu',
#   'rating': '4.7 ',
#   'cuisine': 'Taiwanese, Hot Pot',
#   'price': '$$',
#   'location': 'Raffles Place'},
#  {'restaurant number': 88,
#   'name': '98.\xa0Bar B Q Tonight',
#   'rating': '4.1 ',
#   'cuisine': 'Barbeque',
#   'price': '$$',
#   'location': 'Little India'},
#  {'restaurant number': 89,
#   'name': '99.\xa0Tandoori Flame @ Boon Tat',
#   'rating': '4.9 ',
#   'cuisine': 'Indian',
#   'price': '$$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 90,
#   'name': '100.\xa0Wing Seong Fatty’s',
#   'rating': '3.7 ',
#   'cuisine': 'Chinese, Asian Fusion, Bars',
#   'price': '$$',
#   'location': 'Bencoolen'},
#  {'restaurant number': 91,
#   'name': '101.\xa0Joo Bar',
#   'rating': '4.1 ',
#   'cuisine': 'Korean',
#   'price': '$$',
#   'location': 'Bugis'},
#  {'restaurant number': 92,
#   'name': '102.\xa0San Laksa Steamboat',
#   'rating': '4.1 ',
#   'cuisine': 'Hot Pot, Singaporean',
#   'price': '$$$',
#   'location': 'Little India'},
#  {'restaurant number': 93,
#   'name': '103.\xa0Superstar K',
#   'rating': '4.5 ',
#   'cuisine': 'Korean, Barbeque',
#   'price': '$$$',
#   'location': 'Duxton Hill'},
#  {'restaurant number': 94,
#   'name': '104.\xa0A Noodle Story',
#   'rating': '4.4 ',
#   'cuisine': 'Food Stands, Ramen, Singaporean',
#   'price': '$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 95,
#   'name': '105.\xa0Grazie',
#   'rating': '4.5 ',
#   'cuisine': 'Italian',
#   'price': '$',
#   'location': 'Boon Keng'},
#  {'restaurant number': 96,
#   'name': '106.\xa0Public House',
#   'rating': '4.5 ',
#   'cuisine': 'Bars, Singaporean',
#   'price': '$',
#   'location': 'Boat Quay'},
#  {'restaurant number': 97,
#   'name': '107.\xa0Old Chengdu Sichuan Cuisine',
#   'rating': '4.1 ',
#   'cuisine': 'Szechuan, Imported Food',
#   'price': '$$',
#   'location': 'Chinatown'},
#  {'restaurant number': 98,
#   'name': '108.\xa0Kai Garden',
#   'rating': '4.3 ',
#   'cuisine': 'Cantonese, Dim Sum, Seafood',
#   'price': '$$',
#   'location': 'City Hall'},
#  {'restaurant number': 99,
#   'name': '109.\xa0Geylang Lorong 9 Beef Kway Teow',
#   'rating': '4.1 ',
#   'cuisine': 'Chinese',
#   'price': '$',
#   'location': 'Geylang'},
#  {'restaurant number': 100,
#   'name': '110.\xa0The Wall',
#   'rating': '5.0 ',
#   'cuisine': 'Japanese, Cocktail Bars, Whiskey Bars',
#   'price': '$$$',
#   'location': 'Duxton Hill'},
#  {'restaurant number': 101,
#   'name': '111.\xa0Café Iguana',
#   'rating': '3.8 ',
#   'cuisine': 'Lounges, Tapas/Small Plates, Mexican',
#   'price': '$$',
#   'location': 'Clarke Quay'},
#  {'restaurant number': 102,
#   'name': '112.\xa0Treasures Yi Dian Xin',
#   'rating': '4.7 ',
#   'cuisine': 'Congee, Dim Sum, Noodles',
#   'price': '$',
#   'location': 'Bras Brasah'},
#  {'restaurant number': 103,
#   'name': '113.\xa0Din Tai Fung',
#   'rating': '4.2 ',
#   'cuisine': 'Shanghainese, Taiwanese, Dumplings',
#   'price': '$$',
#   'location': 'Bayfront'},
#  {'restaurant number': 104,
#   'name': '114.\xa0Astons Specialities',
#   'rating': '4.4 ',
#   'cuisine': 'American, Steakhouses',
#   'price': '$',
#   'location': 'Little India'},
#  {'restaurant number': 105,
#   'name': '115.\xa0Red House',
#   'rating': '3.9 ',
#   'cuisine': 'Seafood',
#   'price': '$$$',
#   'location': 'Robertson Quay'},
#  {'restaurant number': 106,
#   'name': '116.\xa0Two Men Bagel House',
#   'rating': '4.8 ',
#   'cuisine': 'Breakfast & Brunch, Bagels',
#   'price': '$',
#   'location': 'Novena'},
#  {'restaurant number': 107,
#   'name': '117.\xa0Din Tai Fung',
#   'rating': '4.4 ',
#   'cuisine': 'Taiwanese, Shanghainese, Dumplings',
#   'price': '$$',
#   'location': 'City Hall'},
#  {'restaurant number': 108,
#   'name': '118.\xa0Imperial Treasure Fine Chinese Cuisine',
#   'rating': '4.1 ',
#   'cuisine': 'Chinese',
#   'price': '$$',
#   'location': 'Bayfront'},
#  {'restaurant number': 109,
#   'name': '119.\xa0Blu Kouzina',
#   'rating': '4.5 ',
#   'cuisine': 'Mediterranean, Greek',
#   'price': '$$$',
#   'location': 'Dempsey Hill'},
#  {'restaurant number': 110,
#   'name': '120.\xa0Char Restaurant',
#   'rating': '4.4 ',
#   'cuisine': 'Cantonese',
#   'price': '$$',
#   'location': 'Little India'},
#  {'restaurant number': 111,
#   'name': '121.\xa0Thien Long Vietnamese Restaurant',
#   'rating': '4.2 ',
#   'cuisine': 'Vietnamese',
#   'price': '$',
#   'location': 'Tanglin'},
#  {'restaurant number': 112,
#   'name': '122.\xa0Isle Eating House',
#   'rating': '4.7 ',
#   'cuisine': 'Coffee & Tea, Food Court, Asian Fusion',
#   'price': '$',
#   'location': 'Mount Sophia'},
#  {'restaurant number': 113,
#   'name': '123.\xa0Bee Cheng Hiang - New Bridge Road',
#   'rating': '4.4 ',
#   'cuisine': 'Singaporean, Meat Shops, Barbeque',
#   'price': '$$',
#   'location': 'Chinatown'},
#  {'restaurant number': 114,
#   'name': '124.\xa0Wee Nam Kee Hainanese Chicken Rice',
#   'rating': '3.7 ',
#   'cuisine': 'Chicken Shop, Hainan',
#   'price': '$$',
#   'location': 'City Hall'},
#  {'restaurant number': 115,
#   'name': '125.\xa0Zhong Hua Steamboat',
#   'rating': '5.0 ',
#   'cuisine': 'Chinese',
#   'price': '$$',
#   'location': 'Bugis'},
#  {'restaurant number': 116,
#   'name': '126.\xa0Food Republic',
#   'rating': '4.0 ',
#   'cuisine': 'Food Court',
#   'price': '$',
#   'location': 'Bras Brasah'},
#  {'restaurant number': 117,
#   'name': '127.\xa0Indocafe The White House',
#   'rating': '4.2 ',
#   'cuisine': 'Indonesian',
#   'price': '$$',
#   'location': 'Newton'},
#  {'restaurant number': 118,
#   'name': '128.\xa0Classic Lao Di Fang Vegetarian',
#   'rating': '4.0 ',
#   'cuisine': 'Vegetarian',
#   'price': '$',
#   'location': 'Dhoby Ghaut'},
#  {'restaurant number': 119,
#   'name': '129.\xa0Happy Tummy',
#   'rating': '4.8 ',
#   'cuisine': 'Desserts, Salad, Cafes',
#   'price': '$',
#   'location': 'Mount Sophia'},
#  {'restaurant number': 120,
#   'name': '130.\xa0Hamburg Steak Keisuke',
#   'rating': '4.6 ',
#   'cuisine': 'Teppanyaki, Steakhouses',
#   'price': '$$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 121,
#   'name': '131.\xa0Toast Box',
#   'rating': '4.0 ',
#   'cuisine': 'Cafes, Breakfast & Brunch',
#   'price': '$',
#   'location': 'Bras Brasah'},
#  {'restaurant number': 122,
#   'name': '132.\xa0Shabu Shabu Tajimaya',
#   'rating': '4.5 ',
#   'cuisine': 'Japanese, Hot Pot',
#   'price': '$$$',
#   'location': 'Orchard'},
#  {'restaurant number': 123,
#   'name': '133.\xa0Mellben Seafood',
#   'rating': '4.1 ',
#   'cuisine': 'Seafood',
#   'price': '$$$',
#   'location': 'Ang Mo Kio'},
#  {'restaurant number': 124,
#   'name': '134.\xa0Old Airport Road Food Centre',
#   'rating': '4.3 ',
#   'cuisine': 'Hawker Centre, Food Court',
#   'price': '$',
#   'location': 'Mountbatten'},
#  {'restaurant number': 125,
#   'name': '135.\xa0The Other Room',
#   'rating': '4.6 ',
#   'cuisine': 'Tapas/Small Plates, Cocktail Bars',
#   'price': '$$',
#   'location': 'Orchard'},
#  {'restaurant number': 126,
#   'name': '136.\xa0Majestic Bay',
#   'rating': '3.1 ',
#   'cuisine': 'Seafood',
#   'price': '$$',
#   'location': 'Bayfront'},
#  {'restaurant number': 127,
#   'name': '137.\xa0Grain Traders',
#   'rating': '4.1 ',
#   'cuisine': 'Cafes',
#   'price': '$$',
#   'location': 'Raffles Place'},
#  {'restaurant number': 128,
#   'name': '138.\xa0Annalakshmi',
#   'rating': '4.0 ',
#   'cuisine': 'Indian, Vegetarian',
#   'price': '$',
#   'location': 'Clarke Quay'},
#  {'restaurant number': 129,
#   'name': '139.\xa0Taste Of Morroco',
#   'rating': '5.0 ',
#   'cuisine': 'Moroccan',
#   'price': '$',
#   'location': 'West Coast'},
#  {'restaurant number': 130,
#   'name': '140.\xa0Lao You Xuan Noodle Kitchen',
#   'rating': '5.0 ',
#   'cuisine': 'Singaporean, Noodles, Soup',
#   'price': '$',
#   'location': 'River Valley'},
#  {'restaurant number': 131,
#   'name': '141.\xa0Inle Myanmar',
#   'rating': '4.2 ',
#   'cuisine': 'Burmese',
#   'price': '$',
#   'location': 'Bras Brasah'},
#  {'restaurant number': 132,
#   'name': '142.\xa0Hai San Chicken Rice',
#   'rating': '5.0 ',
#   'cuisine': 'Chinese',
#   'price': '$',
#   'location': 'Tiong Bahru'},
#  {'restaurant number': 133,
#   'name': '143.\xa0Imperial Treasure Nan Bei Restaurant',
#   'rating': '4.6 ',
#   'cuisine': 'Chinese',
#   'price': '$$',
#   'location': 'Orchard'},
#  {'restaurant number': 134,
#   'name': '144.\xa0Ji Ji Wanton Noodle Specialist',
#   'rating': '4.5 ',
#   'cuisine': 'Chinese',
#   'price': '$',
#   'location': 'Chinatown'},
#  {'restaurant number': 135,
#   'name': '145.\xa0旺角點心 Mongkok Dim Sum',
#   'rating': '3.7 ',
#   'cuisine': 'Dim Sum',
#   'price': '$',
#   'location': 'Geylang'},
#  {'restaurant number': 136,
#   'name': '146.\xa0Cook & Brew',
#   'rating': '3.9 ',
#   'cuisine': 'Gastropubs, Lounges',
#   'price': '$$$',
#   'location': 'Bayfront'},
#  {'restaurant number': 137,
#   'name': '147.\xa0Hopheads',
#   'rating': '3.7 ',
#   'cuisine': 'Bistros, Tapas/Small Plates',
#   'price': '$$',
#   'location': 'Dhoby Ghaut'},
#  {'restaurant number': 138,
#   'name': '148.\xa0Su Korean BBQ',
#   'rating': '4.5 ',
#   'cuisine': 'Korean, Barbeque',
#   'price': '$',
#   'location': 'Toa Payoh'},
#  {'restaurant number': 139,
#   'name': '149.\xa0Haramiya Japanese BBQ Restaurant',
#   'rating': '4.0 ',
#   'cuisine': 'Barbeque, Japanese',
#   'price': '$$',
#   'location': 'Clarke Quay'},
#  {'restaurant number': 140,
#   'name': '150.\xa0Alati',
#   'rating': '4.6 ',
#   'cuisine': 'Greek',
#   'price': '$$$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 141,
#   'name': '151.\xa0Seletar Hill',
#   'rating': '5.0 ',
#   'cuisine': 'Szechuan',
#   'price': '$$',
#   'location': 'Yio Chu Kang'},
#  {'restaurant number': 142,
#   'name': '152.\xa0Artichoke Cafe & Bar',
#   'rating': '4.0 ',
#   'cuisine': 'Bars, Middle Eastern',
#   'price': '$$',
#   'location': 'Bencoolen'},
#  {'restaurant number': 143,
#   'name': '153.\xa0Hup Choon Eating House',
#   'rating': '4.3 ',
#   'cuisine': 'Seafood',
#   'price': '$',
#   'location': 'Bukit Timah'},
#  {'restaurant number': 144,
#   'name': '154.\xa0Ramen Keisuke Tori King',
#   'rating': '4.2 ',
#   'cuisine': 'Ramen',
#   'price': '$$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 145,
#   'name': '155.\xa0Yi Jia South Village Seafood Restaurant',
#   'rating': '3.3 ',
#   'cuisine': 'Seafood',
#   'price': '$$',
#   'location': 'Macpherson'},
#  {'restaurant number': 146,
#   'name': '156.\xa0CreatureS',
#   'rating': '4.1 ',
#   'cuisine': 'Breakfast & Brunch, Asian Fusion, Singaporean',
#   'price': '$$',
#   'location': 'Little India'},
#  {'restaurant number': 147,
#   'name': '157.\xa0Kazu Sumiyaki',
#   'rating': '4.5 ',
#   'cuisine': 'Japanese',
#   'price': '$$$',
#   'location': 'Orchard'},
#  {'restaurant number': 148,
#   'name': '158.\xa0Red Eye Smokehouse',
#   'rating': '4.3 ',
#   'cuisine': 'Bars, American, Barbeque',
#   'price': '$$$',
#   'location': 'Lavender'},
#  {'restaurant number': 149,
#   'name': '159.\xa0Bella Pizza',
#   'rating': '3.8 ',
#   'cuisine': 'Italian, Pizza',
#   'price': '$$',
#   'location': 'Robertson Quay'},
#  {'restaurant number': 150,
#   'name': '160.\xa0Sushi Kou',
#   'rating': '4.8 ',
#   'cuisine': 'Japanese',
#   'price': '$$$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 151,
#   'name': '161.\xa0Humpback',
#   'rating': '4.4 ',
#   'cuisine': 'American, Seafood, Cocktail Bars',
#   'price': '$$$',
#   'location': 'Chinatown'},
#  {'restaurant number': 152,
#   'name': '162.\xa0Ippudo',
#   'rating': '4.1 ',
#   'cuisine': 'Ramen',
#   'price': '$$',
#   'location': 'Somerset'},
#  {'restaurant number': 153,
#   'name': '163.\xa0Bosses Restaurant',
#   'rating': '3.9 ',
#   'cuisine': 'Dim Sum, Cantonese',
#   'price': '$$',
#   'location': 'Harbourfront'},
#  {'restaurant number': 154,
#   'name': '164.\xa0Boon Tong Kee',
#   'rating': '4.5 ',
#   'cuisine': 'Cantonese',
#   'price': '$$',
#   'location': 'Boon Keng'},
#  {'restaurant number': 155,
#   'name': '165.\xa0Coffee Lounge',
#   'rating': '4.3 ',
#   'cuisine': 'Singaporean, Breakfast & Brunch',
#   'price': '$$$',
#   'location': 'Newton'},
#  {'restaurant number': 156,
#   'name': '166.\xa0Old Habits',
#   'rating': '5.0 ',
#   'cuisine': 'Cafes',
#   'price': '$$',
#   'location': 'Telok Blangah'},
#  {'restaurant number': 157,
#   'name': '167.\xa0Granny’s Pancake',
#   'rating': '4.0 ',
#   'cuisine': 'Breakfast & Brunch, Coffee & Tea',
#   'price': '$',
#   'location': 'Chinatown'},
#  {'restaurant number': 158,
#   'name': '168.\xa0Ya Kun Kaya Toast',
#   'rating': '5.0 ',
#   'cuisine': 'Coffee & Tea, Sandwiches',
#   'price': '$$',
#   'location': 'Little India'},
#  {'restaurant number': 159,
#   'name': '169.\xa0Botanico',
#   'rating': '4.5 ',
#   'cuisine': 'Modern European',
#   'price': '$$$',
#   'location': 'Bukit Timah'},
#  {'restaurant number': 160,
#   'name': '170.\xa0Third & Sixth Bistrobar',
#   'rating': '4.2 ',
#   'cuisine': 'Bars, Burgers',
#   'price': '$$',
#   'location': 'Bras Brasah'},
#  {'restaurant number': 161,
#   'name': '171.\xa0Fatboy’s The Burger Bar',
#   'rating': '3.9 ',
#   'cuisine': 'Burgers',
#   'price': '$$',
#   'location': 'Orchard'},
#  {'restaurant number': 162,
#   'name': '172.\xa0Nagae',
#   'rating': '4.1 ',
#   'cuisine': 'Japanese',
#   'price': '$$$',
#   'location': 'River Valley'},
#  {'restaurant number': 163,
#   'name': '173.\xa0Greenwood Fish Market & Bistro',
#   'rating': '3.2 ',
#   'cuisine': 'Seafood, Seafood Markets',
#   'price': '$$',
#   'location': 'Bukit Timah'},
#  {'restaurant number': 164,
#   'name': '174.\xa0Leong Kee Bak Kut Teh',
#   'rating': '3.8 ',
#   'cuisine': 'Chinese',
#   'price': '$',
#   'location': 'Geylang'},
#  {'restaurant number': 165,
#   'name': '175.\xa0Coq & Balls',
#   'rating': '4.2 ',
#   'cuisine': 'Bars, Japanese, Asian Fusion',
#   'price': '$$$',
#   'location': 'Tiong Bahru'},
#  {'restaurant number': 166,
#   'name': '176.\xa0Five Oars Coffee Roasters',
#   'rating': '4.7 ',
#   'cuisine': 'Coffee Roasteries, Breakfast & Brunch',
#   'price': '$$',
#   'location': 'Duxton Hill'},
#  {'restaurant number': 167,
#   'name': '177.\xa0Kampong Glam Cafe',
#   'rating': '3.8 ',
#   'cuisine': 'Indonesian',
#   'price': '$',
#   'location': 'Arab Street'},
#  {'restaurant number': 168,
#   'name': '178.\xa0Liao Fan Hawker Chan',
#   'rating': '4.0 ',
#   'cuisine': 'Noodles, Cantonese',
#   'price': '$',
#   'location': 'Macpherson'},
#  {'restaurant number': 169,
#   'name': '179.\xa0The Marmalade Pantry',
#   'rating': '4.0 ',
#   'cuisine': 'Breakfast & Brunch, Cupcakes, Sandwiches',
#   'price': '$$',
#   'location': 'Novena'},
#  {'restaurant number': 170,
#   'name': '180.\xa0Boomarang',
#   'rating': '4.1 ',
#   'cuisine': 'Breakfast & Brunch, Bars, Australian',
#   'price': '$$',
#   'location': 'Boat Quay'},
#  {'restaurant number': 171,
#   'name': '181.\xa0CÉ LA VI Restaurant',
#   'rating': '3.2 ',
#   'cuisine': 'Bars, Asian Fusion',
#   'price': '$$$',
#   'location': 'Bayfront'},
#  {'restaurant number': 172,
#   'name': '182.\xa0Dashi Master Marusaya',
#   'rating': '4.3 ',
#   'cuisine': 'Japanese',
#   'price': '$$$',
#   'location': 'Robertson Quay'},
#  {'restaurant number': 173,
#   'name': '183.\xa0Longqing Hotpot',
#   'rating': '5.0 ',
#   'cuisine': 'Chinese, Hot Pot',
#   'price': '$$$',
#   'location': 'Clarke Quay'},
#  {'restaurant number': 174,
#   'name': '184.\xa0Mahota Commune',
#   'rating': '4.5 ',
#   'cuisine': 'Organic Stores, Italian, Venues & Event Spaces',
#   'price': '$$',
#   'location': 'Lavender'},
#  {'restaurant number': 175,
#   'name': '185.\xa0Blue Ginger',
#   'rating': '3.8 ',
#   'cuisine': 'Chinese, Asian Fusion',
#   'price': '$$$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 176,
#   'name': '186.\xa0Owls Brew',
#   'rating': '4.2 ',
#   'cuisine': 'Bars, Gastropubs',
#   'price': '$$',
#   'location': 'Mount Sophia'},
#  {'restaurant number': 177,
#   'name': '187.\xa0Chopsuey Cafe',
#   'rating': '4.0 ',
#   'cuisine': 'Cafes',
#   'price': '$$$',
#   'location': 'Robertson Quay'},
#  {'restaurant number': 178,
#   'name': '188.\xa0Killiney Kopitiam',
#   'rating': '4.0 ',
#   'cuisine': 'Breakfast & Brunch, Coffee & Tea',
#   'price': '$',
#   'location': 'Somerset'},
#  {'restaurant number': 179,
#   'name': '189.\xa0Ng Ah Sio Bak Kut Teh',
#   'rating': '4.1 ',
#   'cuisine': 'Chinese',
#   'price': '$',
#   'location': 'Farrer Park'},
#  {'restaurant number': 180,
#   'name': '190.\xa0Shang Palace',
#   'rating': '4.4 ',
#   'cuisine': 'Cantonese, Dim Sum',
#   'price': '$$$',
#   'location': 'Tanglin'},
#  {'restaurant number': 181,
#   'name': '191.\xa0Jian Bo Shui Kueh',
#   'rating': '4.6 ',
#   'cuisine': 'Singaporean, Food Stands',
#   'price': '$',
#   'location': 'Tiong Bahru'},
#  {'restaurant number': 182,
#   'name': '192.\xa0The Beast',
#   'rating': '3.4 ',
#   'cuisine': 'Bars, American, Burgers',
#   'price': '$$',
#   'location': 'Lavender'},
#  {'restaurant number': 183,
#   'name': '193.\xa0Jiang-Nan Chun',
#   'rating': '4.3 ',
#   'cuisine': 'Chinese',
#   'price': '$$$',
#   'location': 'Tanglin'},
#  {'restaurant number': 184,
#   'name': '194.\xa0Delicious Boneless Chicken Rice',
#   'rating': '4.5 ',
#   'cuisine': 'Chicken Shop, Hainan',
#   'price': '$',
#   'location': 'Katong'},
#  {'restaurant number': 185,
#   'name': '195.\xa0Xin Heng Feng Guo Tiao Tan',
#   'rating': '4.5 ',
#   'cuisine': 'Chinese',
#   'price': '$',
#   'location': 'Novena'},
#  {'restaurant number': 186,
#   'name': '196.\xa0Jumbo Seafood',
#   'rating': '4.0 ',
#   'cuisine': 'Seafood',
#   'price': '$$$',
#   'location': 'Marine Parade'},
#  {'restaurant number': 187,
#   'name': '197.\xa0Da Paolo Gastronomia - Marina Bay Sands',
#   'rating': '4.3 ',
#   'cuisine': 'Italian, Desserts, Coffee & Tea',
#   'price': '$$',
#   'location': 'Bayfront'},
#  {'restaurant number': 188,
#   'name': '198.\xa0Food Republic',
#   'rating': '2.9 ',
#   'cuisine': 'Food Court, Singaporean',
#   'price': '$',
#   'location': 'Bencoolen'},
#  {'restaurant number': 189,
#   'name': '199.\xa0Salted & Hung',
#   'rating': '4.3 ',
#   'cuisine': 'Australian',
#   'price': '$$$',
#   'location': 'Bugis'},
#  {'restaurant number': 190,
#   'name': '200.\xa0The Landing Point - Fullerton Bay Hotel',
#   'rating': '3.5 ',
#   'cuisine': 'Asian Fusion, Cocktail Bars',
#   'price': '$$',
#   'location': 'Raffles Place'},
#  {'restaurant number': 191,
#   'name': '201.\xa0Lian He Ben Ji Claypot Rice',
#   'rating': '3.8 ',
#   'cuisine': 'Chinese',
#   'price': '$$',
#   'location': 'Chinatown'},
#  {'restaurant number': 192,
#   'name': '202.\xa0Chui Huay Lim Teochew Cusine',
#   'rating': '3.9 ',
#   'cuisine': 'Teochew',
#   'price': 'Not available',
#   'location': ''},
#  {'restaurant number': 193,
#   'name': '203.\xa0Tonkotsu King Matsuri',
#   'rating': '4.3 ',
#   'cuisine': 'Ramen',
#   'price': '$$',
#   'location': 'Marine Parade'},
#  {'restaurant number': 194,
#   'name': '204.\xa0Marché',
#   'rating': '4.2 ',
#   'cuisine': 'Restaurants',
#   'price': '$$',
#   'location': 'Harbourfront'},
#  {'restaurant number': 195,
#   'name': '205.\xa0Riverside Indonesian BBQ',
#   'rating': '4.8 ',
#   'cuisine': 'Indonesian, Barbeque',
#   'price': '$',
#   'location': 'Orchard'},
#  {'restaurant number': 196,
#   'name': '206.\xa0The Union Bar',
#   'rating': '4.1 ',
#   'cuisine': 'American, Sports Bars',
#   'price': '$$',
#   'location': 'Tanglin'},
#  {'restaurant number': 197,
#   'name': '207.\xa0Founder Bak Kut Teh',
#   'rating': '4.1 ',
#   'cuisine': 'Chinese, Soup',
#   'price': '$',
#   'location': 'Novena'},
#  {'restaurant number': 198,
#   'name': '208.\xa0Imperial Treasure Super Peking Duck',
#   'rating': '3.8 ',
#   'cuisine': 'Chinese',
#   'price': '$',
#   'location': 'Orchard'},
#  {'restaurant number': 199,
#   'name': '209.\xa0Ash & Elm',
#   'rating': '3.9 ',
#   'cuisine': 'Modern European',
#   'price': '$$$',
#   'location': 'Bugis'},
#  {'restaurant number': 200,
#   'name': '210.\xa0Culina',
#   'rating': '3.8 ',
#   'cuisine': 'Bistros, Specialty Food',
#   'price': '$$$',
#   'location': 'Dempsey Hill'},
#  {'restaurant number': 201,
#   'name': '211.\xa0Canto Kitchen',
#   'rating': '4.5 ',
#   'cuisine': 'Restaurants',
#   'price': '$$',
#   'location': 'Chinatown'},
#  {'restaurant number': 202,
#   'name': '212.\xa0Ah Tai Hainanese Chicken Rice',
#   'rating': '4.5 ',
#   'cuisine': 'Chicken Shop, Hainan',
#   'price': '$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 203,
#   'name': '213.\xa0Sanji Kagoshima Ramen',
#   'rating': '4.9 ',
#   'cuisine': 'Ramen',
#   'price': '$$',
#   'location': 'Tanjong Pagar'},
#  {'restaurant number': 204,
#   'name': '214.\xa0Al Borgo Italian Restaurant',
#   'rating': '4.0 ',
#   'cuisine': 'Italian',
#   'price': '$$',
#   'location': 'Bukit Timah'},
#  {'restaurant number': 205,
#   'name': '215.\xa0Kazbar',
#   'rating': '4.6 ',
#   'cuisine': 'Bars, Middle Eastern',
#   'price': '$$$',
#   'location': 'Raffles Place'},
#  {'restaurant number': 206,
#   'name': '216.\xa0Shanghai Ren Jia',
#   'rating': '4.3 ',
#   'cuisine': 'Chinese',
#   'price': '$$',
#   'location': 'Ang Mo Kio'},
#  {'restaurant number': 207,
#   'name': '217.\xa0Tabbouleh',
#   'rating': '3.4 ',
#   'cuisine': 'Mediterranean, Lebanese',
#   'price': '$$',
#   'location': 'Arab Street'},
#  {'restaurant number': 208,
#   'name': '218.\xa0The Dempsey Cookhouse & Bar',
#   'rating': '3.9 ',
#   'cuisine': 'Asian Fusion',
#   'price': '$$$',
#   'location': 'Dempsey Hill'},
#  {'restaurant number': 209,
#   'name': '219.\xa0Dolphins',
#   'rating': '4.0 ',
#   'cuisine': 'Restaurants',
#   'price': '$$',
#   'location': 'Macpherson'},
#  {'restaurant number': 210,
#   'name': '220.\xa0Crystal Jade Kitchen',
#   'rating': '4.2 ',
#   'cuisine': 'Cantonese',
#   'price': '$',
#   'location': 'Dhoby Ghaut'},
#  {'restaurant number': 211,
#   'name': '221.\xa0Flutes',
#   'rating': '4.1 ',
#   'cuisine': 'Modern European',
#   'price': '$$$',
#   'location': 'Dhoby Ghaut'},
#  {'restaurant number': 212,
#   'name': '222.\xa0Som Tam',
#   'rating': '4.3 ',
#   'cuisine': 'Thai, Asian Fusion',
#   'price': '$$',
#   'location': 'Somerset'},
#  {'restaurant number': 213,
#   'name': '223.\xa0Paulaner Bräuhaus Singapore',
#   'rating': '3.6 ',
#   'cuisine': 'German, Beer Bar',
#   'price': '$$',
#   'location': 'City Hall'},
#  {'restaurant number': 214,
#   'name': '224.\xa0Ma Maison',
#   'rating': '4.5 ',
#   'cuisine': 'Asian Fusion',
#   'price': '$$',
#   'location': 'Alexandra'},
#  {'restaurant number': 215,
#   'name': '225.\xa0Amber Restaurant',
#   'rating': '4.2 ',
#   'cuisine': 'Indian',
#   'price': '$',
#   'location': 'Little India'},
#  {'restaurant number': 216,
#   'name': '226.\xa0Flying Monkey',
#   'rating': '4.1 ',
#   'cuisine': 'Indian, Cocktail Bars',
#   'price': '$$$',
#   'location': 'Arab Street'},
#  {'restaurant number': 217,
#   'name': '227.\xa0Super Siam Thai Restaurant',
#   'rating': '4.0 ',
#   'cuisine': 'Thai',
#   'price': '$',
#   'location': 'Clarke Quay'},
#  {'restaurant number': 218,
#   'name': '228.\xa0Employees Only',
#   'rating': '4.2 ',
#   'cuisine': 'Bars, American',
#   'price': '$$$',
#   'location': 'Raffles Place'},
#  {'restaurant number': 219,
#   'name': '229.\xa0Su Korean Cuisine',
#   'rating': '5.0 ',
#   'cuisine': 'Korean',
#   'price': '$',
#   'location': 'Orchard'},
#  {'restaurant number': 220,
#   'name': '230.\xa0The Clueless Goat',
#   'rating': '4.1 ',
#   'cuisine': 'Coffee & Tea, Breakfast & Brunch',
#   'price': '$',
#   'location': 'Novena'},
#  {'restaurant number': 221,
#   'name': '231.\xa0Saveur',
#   'rating': '4.0 ',
#   'cuisine': 'French, Desserts',
#   'price': '$$',
#   'location': 'Bugis'},
#  {'restaurant number': 222,
#   'name': '232.\xa0Tandoori Corner North Indian Curry House',
#   'rating': '4.4 ',
#   'cuisine': 'Indian',
#   'price': '$$',
#   'location': 'Novena'},
#  {'restaurant number': 223,
#   'name': '233.\xa0Goldhill Family Restruant',
#   'rating': '5.0 ',
#   'cuisine': 'Singaporean',
#   'price': '$',
#   'location': 'Hougang'},
#  {'restaurant number': 224,
#   'name': '234.\xa0Sanpoutei Ramen',
#   'rating': '4.1 ',
#   'cuisine': 'Ramen',
#   'price': '$$',
#   'location': 'Holland Village'},
#  {'restaurant number': 225,
#   'name': '235.\xa0Syun',
#   'rating': '4.4 ',
#   'cuisine': 'Japanese',
#   'price': '$$$',
#   'location': 'Sentosa'},
#  {'restaurant number': 226,
#   'name': '236.\xa0Old Hen Kitchen',
#   'rating': '4.7 ',
#   'cuisine': 'Cafes',
#   'price': '$$',
#   'location': 'Farrer Park'},
#  {'restaurant number': 227,
#   'name': '237.\xa0Chin Chin Restaurant',
#   'rating': '3.8 ',
#   'cuisine': 'Chinese, Coffee & Tea',
#   'price': '$',
#   'location': 'Bugis'},
#  {'restaurant number': 228,
#   'name': '238.\xa0Hong Chang Eating House',
#   'rating': '5.0 ',
#   'cuisine': 'Chinese',
#   'price': '$$',
#   'location': 'Serangoon'},
#  {'restaurant number': 229,
#   'name': '239.\xa0Whampoa Keng',
#   'rating': '4.0 ',
#   'cuisine': 'Teochew',
#   'price': '$$',
#   'location': 'Farrer Park'},
#  {'restaurant number': 230,
#   'name': '240.\xa0Westlake',
#   'rating': '3.8 ',
#   'cuisine': 'Chinese',
#   'price': '$$',
#   'location': 'Bukit Timah'}]

# %% [markdown]
# Exporting scraped data

# %%
df = pd.DataFrame(restaurants_list)

# %%
df.head()
# Out:
#    restaurant number                                 name rating  \
# 0                  1             11. The Garden @ Sentosa   5.0
# 1                  2     12. Tian Tian Seafood Restaurant   4.7
# 2                  3              13. Song Fa Bak Kut Teh   4.6
# 3                  4  14. Zhong Guo La Mian Xiao Long Bao   4.4
# 4                  5                        15. La Strada   4.4
#
#                           cuisine price     location
# 0                 Modern European   $$$      Sentosa
# 1                Seafood, Chinese    $$  Tiong Bahru
# 2            Chinese, Singaporean     $    Chinatown
# 3  Shanghainese, Dim Sum, Noodles     $    Chinatown
# 4                         Italian   $$$      Tanglin

# %%
df.to_csv('../datasets/yelp.csv')

# %% [markdown]
# ------------------
#
# # 2. Scraping for Restaurants on Google

# %% [markdown]
# Results on Google Places was scraped externally on google sheets.
